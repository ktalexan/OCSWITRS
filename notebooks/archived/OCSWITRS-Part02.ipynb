# %% [markdown]
# <center>
# <h1 style="font-size: 50px; font-weight: bold; color:sandybrown">OC SWITRS Data Processing</h1>
#
# <div style="font-size: 40px; font-weight: bold; color: sandybrown">Part 02: ArcGIS and Spatial Geoprocessing</div>
# <div style="font-size: 30px; font-weight: bold; color: sandybrown">v.5, August 2024</div>
# </center>
#
# ---

# %% [markdown]
# ## <font color="orangered">**Referencing Libraries and Initialization**</font>

# %% [markdown]
# ### <font color="lime">**Preliminaries**</font>

# %% [markdown]
# Instantiating python libraries for the project

# %%
# Import Python libraries
import os, json, pytz, math, arcpy, arcgis
from datetime import date, time, datetime, timedelta, tzinfo, timezone
from tqdm.notebook import trange, tqdm, tqdm_notebook
import pandas as pd
import numpy as np
from arcpy import metadata as md

# important as it "enhances" Pandas by importing these classes (from ArcGIS API for Python)
from arcgis.features import GeoAccessor, GeoSeriesAccessor

# %% [markdown]
# ### <font color="lime">**Project and Workspace Variables**</font>

# %% [markdown]
# Define and maintain project, workspace, ArcGIS, and data-related variables.

# %% [markdown]
# Project and ArcGIS Pro project paths

# %%
# Environment variables for OneDrive path
#oneDrivePath = os.getenv("OneDriveCommercial")

# OC SWITRS project path
#projectPath = os.path.join(oneDrivePath, "Projects", "OCTraffic", "OCSWITRS")
projectPath = os.path.join(r"I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS")

# OC SWITRS ArcGIS Pro project path
agpPath = os.path.join(projectPath, "AGPSWITRS")

# %% [markdown]
# ArcGIS Pro-related paths

# %%
# ArcGIS Pro project name and path
aprx = "AGPSWITRS.aprx"
aprxPath = os.path.join(agpPath, aprx)

# ArcGIS Pro project geodatabase and path
gdb = "AGPSWITRS.gdb"
gdbPath = os.path.join(agpPath, gdb)

# Current ArcGIS workspace (arcpy)
arcpy.env.workspace = gdbPath
workspace = arcpy.env.workspace

# Enable overwriting existing outputs
arcpy.env.overwriteOutput = True

# %% [markdown]
# Project folder paths

# %%
# Raw data folder path
rawDataPath = os.path.join(projectPath, "RawData")

# Layers folder path
layersPath = os.path.join(projectPath, "Layers")

# Notebooks folder path
notebooksPath = os.path.join(projectPath, "Notebooks")

# Supporting data path on the project geodatabase (feature directory)
supportingDataPath = os.path.join(workspace, "SupportingData")

# %% [markdown]
# Data folder paths and contents

# %% [markdown]
# The most current raw data files cover the periods from 01/01/2013 to 06/30/2024. The data files are in CSV format and are stored in the data folder, after downloaded from the SWITRS Database (https://tims.berkeley.edu/tools/query/summary.php). Date variables are defined below.

# %%
# add the date 01/01/2013 to a new python datetime object named 'rawDateStart'
rawDateStart = datetime(2013, 1, 1)

# add the date 06/30/2024 to a new python datetime object named 'rawDateEnd'
rawDateEnd = datetime(2024, 6, 30)

# %%
# Paths to raw data (crashes, parties, victims)
#rawCrashesPath = os.path.join(rawDataPath, "Crashes.csv")
#rawPartiesPath = os.path.join(rawDataPath, "Parties.csv")
#rawVictimsPath = os.path.join(rawDataPath, "Victims.csv")
rawCrashesPath = os.path.join(rawDataPath, "Crashes_"+rawDateStart.strftime("%Y%m%d")+"_"+rawDateEnd.strftime("%Y%m%d")+".csv")
rawPartiesPath = os.path.join(rawDataPath, "Parties_"+rawDateStart.strftime("%Y%m%d")+"_"+rawDateEnd.strftime("%Y%m%d")+".csv")
rawVictimsPath = os.path.join(rawDataPath, "Victims_"+rawDateStart.strftime("%Y%m%d")+"_"+rawDateEnd.strftime("%Y%m%d")+".csv")

# Path to JSON codebook
codebookPath = os.path.join(rawDataPath, "codebook.json")

# Paths to supporting data (feature classes)
boundariesPath = os.path.join(supportingDataPath, "OCSWITRS_Boundaries")
citiesPath = os.path.join(supportingDataPath, "OCSWITRS_Cities")
roadsPath = os.path.join(supportingDataPath, "OCSWITRS_Roads")
lookupPath = os.path.join(supportingDataPath, "OCSWITRS_Lookup")

# Paths to saved dataframe pickles (crashes, parties, victims, collisions)
dfCrashesPickle = os.path.join(rawDataPath, "dfCrashes.pkl")
dfPartiesPickle = os.path.join(rawDataPath, "dfParties.pkl")
dfVictimsPickle = os.path.join(rawDataPath, "dfVictims.pkl")
dfCollisionsPickle = os.path.join(rawDataPath, "dfCollisions.pkl")

# Paths to saved excel files (crashes, parties, victims, collisions) ready to be imported to ArcGIS Pro
dfCrashesExcel = os.path.join(rawDataPath, "dfCrashes.xlsx")
dfPartiesExcel = os.path.join(rawDataPath, "dfParties.xlsx")
dfVictimsExcel = os.path.join(rawDataPath, "dfVictims.xlsx")
dfCollisionsExcel = os.path.join(rawDataPath, "dfCollisions.xlsx")

# %% [markdown]
# Display all information about paths, folders, and data files

# %%
# Display all information
print("Key Project Information")
print(f"\n\t- Name {aprx}\n\t- Path: {aprxPath}\n\t- Project Path: {projectPath}\n\t- Workspace: {workspace}\n\t- Geodatabase: {gdb}\n\t- Geodatabase Path: {gdbPath}")
print("\nProject Directories:")
print(f"\n\t- Raw Data: {rawDataPath}\n\t- Layers: {layersPath}\n\t- Notebooks: {notebooksPath}\n\t- Supporting Data: {supportingDataPath}")
print("\nSupporting Feature Classes:")
print(f"\n\t- Boundaries: {boundariesPath}\n\t- Cities: {citiesPath}\n\t- Roads: {roadsPath}\n\t- Lookup: {lookupPath}")
print("\nOther Supporting Data")
print(f"\n\t- Codebook: {codebookPath}\n\t- Raw Data Files:\n\t\t- Crashes: {rawCrashesPath}\n\t\t- Parties: {rawPartiesPath}\n\t\t- Victims: {rawVictimsPath}")
print(f"\n\t- Saved datafram Pickles:\n\t\t- Crashes: {dfCrashesPickle}\n\t\t- Parties: {dfPartiesPickle}\n\t\t- Victims: {dfVictimsPickle}\n\t\t- Collisions: {dfCollisionsPickle}")
print(f"\n\t- Saved Excel dataframes:\n\t\t- Crashes: {dfCrashesExcel}\n\t\t- Parties: {dfPartiesExcel}\n\t\t- Victims: {dfVictimsExcel}\n\t\t- Collisions: {dfCollisionsExcel}")
# Out:
# Key Project Information
#
# 	- Name AGPSWITRS.aprx
# 	- Path: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.aprx
# 	- Project Path: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS
# 	- Workspace: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb
# 	- Geodatabase: AGPSWITRS.gdb
# 	- Geodatabase Path: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb
#
# Project Directories:
#
# 	- Raw Data: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\RawData
# 	- Layers: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\Layers
# 	- Notebooks: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\Notebooks
# 	- Supporting Data: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\SupportingData
#
# Supporting Feature Classes:
#
# 	- Boundaries: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\SupportingData\OCSWITRS_Boundaries
# 	- Cities: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\SupportingData\OCSWITRS_Cities
# 	- Roads: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\SupportingData\OCSWITRS_Roads
# 	- Lookup: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\SupportingData\OCSWITRS_Lookup
#
# Other Supporting Data
#
# 	- Codebook: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\RawData\codebook.json
# 	- Raw Data Files:
# 		- Crashes: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\RawData\Crashes_20130101_20240630.csv
# 		- Parties: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\RawData\Parties_20130101_20240630.csv
# 		- Victims: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\RawData\Victims_20130101_20240630.csv
#
# 	- Saved datafram Pickles:
# 		- Crashes: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\RawData\dfCrashes.pkl
# 		- Parties: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\RawData\dfParties.pkl
# 		- Victims: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\RawData\dfVictims.pkl
# 		- Collisions: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\RawData\dfCollisions.pkl
#
# 	- Saved Excel dataframes:
# 		- Crashes: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\RawData\dfCrashes.xlsx
# 		- Parties: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\RawData\dfParties.xlsx
# 		- Victims: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\RawData\dfVictims.xlsx
# 		- Collisions: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\RawData\dfCollisions.xlsx

# %% [markdown]
# Define ArcGIS Pro project and map list

# %%
# Current ArcGIS Pro project
aprx = arcpy.mp.ArcGISProject(aprxPath)

# Current ArcGIS Pro project map
map = aprx.listMaps()[0]

# %% [markdown]
# ## <font color="orangered">**Functions and Definitions**</font>

# %% [markdown]
# The definitions include:
# - Dictionary Definitions (JSON)
#
# This session will focus on the following functions:
# - Date and time: `update_datetime(purpose)`
# - Clean up project data: `clean_project_data(aprx, map)`
# - Field type transformations: `agp_type(myType)`
# - Field mappings: `get_field_mappings(myCodebook, myFieldlist, myPath)`
# - Update and renumbering codebook: `update_codebook(myPath)`
# - Create codebook dataframe: `create_codebook_dataframe(myCodebook)`
# - Modify field types: `modify_agp_types(myCodebook, myFeatureClass)`

# %% [markdown]
# ### <font color="lime">**Dictionary Definitions (JSON)**</font>

# %% [markdown]
# Defining dictionary codebook for field aliases for all three levels (crashes, parties, and victims).
#
# The fields for each codebook contains:
#
# 1. Variable name (*key*): the JSON dictionary key for each of the variables.
# 2. Field alias (*alias*): the arcgis attribute field aliases for the variables.
# 3. Description (*desc*): the description of the variable used in the domain description definition.
# 4. Type (*type*): the arcgis attribute table field type.
# 5. Domain (*dbin*): Y/N whether the variable has a domain or not.
# 6. Domain Details (*domain*): If *dbin* above is Y, then this dictionary (and subsequent child entries) detail the domain attributes.
#
# The variables and domain definitions come from the [SWIRTS Codebook Link](https://tims.berkeley.edu/help/SWITRS.php#Crash_Level)
#
# The JSON codebooks are saved in the RawData folder of this project. Each of the codebook path can be called using the codebookPath variable from the *Preliminaries* session of this notebook.

# %% [markdown]
# ### <font color="gold">**Function: date and time**</font>

# %% [markdown]
# Setting-up a function to update times, and display start and end times for each operation. Options for `purpose` include:
# - *'default'*: last update with full date and time
# - *'data'*: last data update with date only
# - *'start'*: start time for each operation with full date and time
# - *'end'*: end time for each operation with full date and time
# - *'today'*: today's date with full date and time
# - *'save'*: save time with full date and time
# - *'load'*: load time with full date and time

# %%
def update_datetime(purpose="default"):
    """Function updating the date and time of the command being executed.
        
    Args:
        purpose (str, optional): The purpose of the execution. Defaults to "default". Other options include "data", "start", "end", "today", "save", "load".
            
    Returns:
        print (str): The date and time of the command being executed
    """
        
    global today, lastUpdateDate, lastUpdateDatetime, startTime, endTime, timeZone
        
    # Define time and date variables
    timeZone = pytz.timezone("US/Pacific")
    today = datetime.now(timeZone)
    lastUpdateDate = today.strftime("%B %d, %Y")
    lastUpdateDatetime = today.strftime("%A %B %d, %Y, %I:%M %p (%Z)")
        
    # Match the purpose of the function (user input)
    match purpose:
        case "default":
            print(f"Last update: {lastUpdateDatetime}")
        case "data":
            print(f"Last data update: {lastUpdateDate}")
        case "start":
            startTime = datetime.now(timeZone)
            print(f"Start: {lastUpdateDatetime}")
        case "end":
            endTime = datetime.now(timeZone)
            delta = endTime - startTime
            elapsed = delta - timedelta(microseconds=delta.microseconds)
            print(f"End: {lastUpdateDatetime}. Elapsed time: {elapsed}")
        case "today":
            print(f"Today's date: {lastUpdateDatetime}")
        case "save":
            print(f"Project saved on: {lastUpdateDatetime}")
        case "load":
            print(f"Project loaded on: {lastUpdateDatetime}")

# %% [markdown]
# ### <font color="gold">**Function: clean project data**</font>

# %% [markdown]
# In this function we will be cleaning up the project data by removing all the tables and feature classes from the geodatabase, along with all the layers from the map.

# %% [markdown]
# > <font color="orange">**Note:**</font> Use this function 'as needed' usually in the beginning of running this notebook and re-running the code.

# %%
def clean_project_data(aprx, map):
    """Function to remove and clean all data from the geodatabase and the map of the ArcGIS Pro project.
    
    Args:
        aprx (arcpy.mp.ArcGISProject): The current ArcGIS Pro project
        map (arcpy.mp.Map): The current map in the ArcGIS Pro project
        
    Returns:
        None: The function does not return anything
    """
    
    update_datetime("start")
    
    # Remove all tables from the geodatabase
    for table in arcpy.ListTables():
        print(f"Removing table: {table}")
        arcpy.Delete_management(table)
        print(f"Removing table: {table}")
        print(arcpy.GetMessages())
    
    # Remove all feature classes from the geodatabase
    for feature in arcpy.ListFeatureClasses():
        print(f"Removing feature class: {feature}")
        arcpy.Delete_management(feature)
        print(f"Removing feature class: {feature}")
        print(arcpy.GetMessages())
    
    # Remove all layers from the map that have "OCSWITRS" in the name
    for layer in map.listLayers():
        if "OCSWITRS" in layer.name:
            print(f"Removing layer: {layer.name}")
            map.removeLayer(layer)
            print(f"Removing layer: {layer.name}")
            print(arcpy.GetMessages())

    # Save the project
    print("Saving the project")
    aprx.save()
        
    update_datetime("end")

# %% [markdown]
# ### <font color="gold">**Function: Field Type Transformationss**</font>

# %% [markdown]
# In this function we will be changing codebook field types to match the ones genrated in geodatabase tables and feature classes.
#
# Before using the codebook, we need to update the field types to match the ones on the table, using the following function, that reads the fied types from the tables or feature classes and changes (if necessary) the field types in the codebook.

# %%
def agp_type(myType):
    """Function mapping ArcGIS feature class types to codebook field types.

    Args:
        myType (str): field type from data
        
    Returns:
        str: ArcGIS feature class type
    """
    
    # Match codebook column and return the appropriate ArcGIS feature class type
    match myType:
        case "OID":
            return "ID"
        case "GlobalID":
            return "GlobalID"
        case "GUID":
            return "GUID"
        case "Geometry":
            return "GEOMETRY"
        case "Integer":
            return "LONG"
        case "SmallInteger":
            return "SHORT"
        case "BigInteger":
            return "BIG"
        case "Double":
            return "DOUBLE"
        case "Date":
            return "DATE"
        case "DateOnly":
            return "DATE"
        case "String":
            return "TEXT"

# %% [markdown]
# ### <font color="gold">**Function: get field mappings**</font>

# %% [markdown]
# This function generates field mapping lists for operations that require field mapping. The function takes three arguments: `myCodebook`, `myFieldlist`, and `myPath`.

# %%
def get_field_mappings(myCodebook, myFieldList, myPath):
    """Function generating field mapping lists of fields used in ArcGIS geoprocessing tasks.

    Args:
        myCodebook (dict): the project's JSON dictionary containing the codebook of all the data variables
        myFieldList (list): the list of fields for which the field mapping is performed
        myPath (path): the path to the feature class being processed.
        
    Returns:
        fieldMappings (arcpy.FieldMappings): the field mapping object used in ArcGIS geoprocessing tasks
    """
    
    # Get a list of field names from the user-submitted field list
    myFieldNames = list(myField.name for myField in myFieldList)
    
    # Create an empty list to hold the field mappings
    myMappingList = []
    
    # Iterate the keys of the codebook dictionary
    for key in list(myCodebook.keys()):        
        # Check if the key is in the list of field names
        if key in myFieldNames:
            # Obtain the index location of the key field in the dataset
            myIndex = myFieldNames.index(key)
            # Obtain the field type of the field
            myType = agp_type(myFieldList[myIndex].type)
            if myType in ["ID", "GlobalID", "GUID", "GEOMETRY", "LONG", "SHORT", "BIG", "DOUBLE"]:
                s = "-1"
            elif myType in ["TEXT", "DATE", "DATEONLY"]:
                s = "#"
                
            # Create a field mapping object string for each of the fields in the dataset
            mapString = f'{myFieldList[myIndex].name} "{myFieldList[myIndex].aliasName}" {myFieldList[myIndex].editable} {myFieldList[myIndex].isNullable} {myFieldList[myIndex].required} {myFieldList[myIndex].length} {myType} {myFieldList[myIndex].precision} {myFieldList[myIndex].scale},First,#,{myPath},{myFieldList[myIndex].name},"{myFieldList[myIndex].aliasName}",{s},{s}'
            
            # Append the string to the list of field mappings
            myMappingList.append(mapString)
            
    # Join the list of field mappings into a single string (separated by semicolons)
    return ";".join(myMappingList)

# %% [markdown]
# ### <font color="gold">**Function: update codebook**</font>

# %% [markdown]
# This function reads a JSON file from a path, updates the numbering and order of the fields, and returns a functional codebook dictionary for the project.

# %%
def update_codebook(myPath):
    """Function to update the JSON codebook file
        
    Args:
        myPath (str): path to the JSON codebook file
            
    Returns:
        dictData (dict): updated JSON dictionary data
    """
        
    # Load the JSON file from directory
    print("Opening dictionary from file...")
    with open(myPath, "r") as jsonFile:
        # Load the JSON data into dictionary
        dictData = json.load(jsonFile)
        
    # start the counter
    counter = 1
        
    # Loop through the dictionary and update the "no" key
    print("Renumbering the dictionary...")
        
    for key in dictData:
        if "no" in dictData[key]:
            dictData[key]["no"] = counter
            # increment the counter
            counter += 1
        
    # Reopen the JSON data file for writing
    print("Writing the updated dictionary to file...")
    with open(myPath, "w") as jsonFile:
        # Write the updated dictionary to the file
        json.dump(dictData, jsonFile, indent=4)
        
    print(f"Total records: {counter - 1}\nOutput file: {myPath}")
        
    return dictData

# %% [markdown]
# ### <font color="gold">**Function: create codebook dataframe**</font>

# %% [markdown]
# Creating and displaying a Pandas dataframe from the codebook JSON dictionary

# %%
def create_codebook_dataframe(myCodebook):
    """Function creating a Pandas dataframe from the project's JSON codebook dictionary.

    Args:
        myCodebook (dict): the project's JSON codebook dictionary
        
    Returns:
        pd.dataframe (dataFrame): the Pandas dataframe of the codebook
    """
    
    # Create a new, empty pandas dataframe
    mydf = {}
    
    # Add the codebook keys as column fields, and the codebook values as rows for the dataframe
    mydf["ORDER"] = [myCodebook[field]["no"] for field in myCodebook]
    mydf["COLUMN"] = [field for field in myCodebook]
    mydf["NAME"] = [myCodebook[field]["alias"] for field in myCodebook]
    mydf["DESCRIPTION"] = [myCodebook[field]["desc"] for field in myCodebook]
    mydf["LEVEL"] = [myCodebook[field]["level"] for field in myCodebook]
    mydf["TYPE"] = [myCodebook[field]["type"] for field in myCodebook]
    mydf["CATEGORY"] = [myCodebook[field]["cat"] for field in myCodebook]
    mydf["DOMAIN"] = [myCodebook[field]["dbin"] for field in myCodebook]
    
    return pd.DataFrame(mydf)

# %% [markdown]
# ### <font color="gold">**Function: modify field types**</font>

# %% [markdown]
# This function is modifying the field types on the codebook, based on the fields on a feature class field list

# %%
def modify_agp_types(myCodebook, myFeatureClass):
    """Function modifying field types on the codebook, based on the fields in the feature class.

    Args:
        myCodebook (dict): the codebook JSON dictionary of the project
        myFeatureClass (str): the name of the ArcGIS feature class to be used for
        
    Returns:
        myCodebook (dict): the updated codebook JSON dictionary
    """
    
    # Iterate feature class columns and select each column by name
    for field in list(myFeatureClass):
        # Check first if the feature class field exists in the codebook keys
        if field in list(myCodebook.keys()):
            # Obtain the codebook field type from the codebook dictionary
            myCodebookType = myCodebook[field]["type"]
            # Get the corresponding feature class type based on the function agp_type() defined above
            myDataframeType = agp_type(myDataframeType)
            
            # Check to see if these two types don't match
            if myCodebookType != myDataframeType:
                print(f"\t{field}: {myCodebookType} -> {myDataframeType}")
                # Update the codebook field type to match the feature class field type
                myCodebook[field]["type"] = myDataframeType
                
    # Return the updated codebook dictionary
    return myCodebook

# %% [markdown]
# ## <font color="orangered">**Data Procesing Operations**</font>

# %% [markdown]
# ### <font color="lime">**Data Prepparation**</font>

# %% [markdown]
# If needed clean up the project data
#
# > <font color="orange">⚠️ **Note:**</font> Use this function 'as needed' usually in the beginning of running this notebook and re-running the code.

# %%
# Clean the project data
clean_project_data(aprx, map)
# Out:
# Start: Wednesday November 13, 2024, 06:55 AM (PST)
# Saving the project
# End: Wednesday November 13, 2024, 06:55 AM (PST). Elapsed time: 0:00:00

# %% [markdown]
# Run the function `update_codebook(myPath)` to update the codebook for the project for the first time

# %%
codebook = update_codebook(codebookPath)
# Out:
# Opening dictionary from file...
# Renumbering the dictionary...
# Writing the updated dictionary to file...
# Total records: 145
# Output file: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\RawData\codebook.json

# %% [markdown]
# Create the codebook dataframe and display the table for inspection

# %%
dfCodebook = create_codebook_dataframe(codebook)

# %% [markdown]
# Display the codebook dataframe with all rows visible

# %%
# Display codebook dataframe
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(dfCodebook)
# Out:
#      ORDER                          COLUMN  \
# 0        1                        OBJECTID
# 1        2                        GlobalID
# 2        3                            GUID
# 3        4                         CASE_ID
# 4        5                             CID
# 5        6                             PID
# 6        7                             VID
# 7        8                    PARTY_NUMBER
# 8        9                   VICTIM_NUMBER
# 9       10               CRASHES_INDICATOR
# 10      11               PARTIES_INDICATOR
# 11      12               VICTIMS_INDICATOR
# 12      13                            CITY
# 13      14                       CITY_NAME
# 14      15                      PLACE_TYPE
# 15      16              COLLISION_DATETIME
# 16      17                  COLLISION_DATE
# 17      18                  COLLISION_TIME
# 18      19                   ACCIDENT_YEAR
# 19      20                 COLLISION_MONTH
# 20      21                     DAY_OF_WEEK
# 21      22                       PROC_DATE
# 22      23        COLLISION_TIME_INTERVALS
# 23      24       COLLISION_TIME_RUSH_HOURS
# 24      25              COLLISION_SEVERITY
# 25      26       COLLISION_SEVERITY_BINARY
# 26      27      COLLISION_SEVERITY_RECLASS
# 27      28       COLLISION_SEVERITY_RANKED
# 28      29                     PARTY_COUNT
# 29      30                    VICTIM_COUNT
# 30      31                   NUMBER_KILLED
# 31      32                  NUMBER_INJURED
# 32      33                COUNT_SEVERE_INJ
# 33      34               COUNT_VISIBLE_INJ
# 34      35            COUNT_COMPLAINT_PAIN
# 35      36                COUNT_PED_KILLED
# 36      37               COUNT_PED_INJURED
# 37      38          COUNT_BICYCLIST_KILLED
# 38      39         COUNT_BICYCLIST_INJURED
# 39      40                 COUNT_MC_KILLED
# 40      41                COUNT_MC_INJURED
# 41      42             PRIMARY_COLL_FACTOR
# 42      43               TYPE_OF_COLLISION
# 43      44             PEDESTRIAN_ACCIDENT
# 44      45                BICYCLE_ACCIDENT
# 45      46             MOTORCYCLE_ACCIDENT
# 46      47                  TRUCK_ACCIDENT
# 47      48                     HIT_AND_RUN
# 48      49                ALCOHOL_INVOLVED
# 49      50                           JURIS
# 50      51                      OFFICER_ID
# 51      52              REPORTING_DISTRICT
# 52      53                       CHP_SHIFT
# 53      54                   CNTY_CITY_LOC
# 54      55                    SPECIAL_COND
# 55      56                       BEAT_TYPE
# 56      57                   CHP_BEAT_TYPE
# 57      58                  CHP_BEAT_CLASS
# 58      59                     BEAT_NUMBER
# 59      60                      PRIMARY_RD
# 60      61                    SECONDARY_RD
# 61      62                        DISTANCE
# 62      63                       DIRECTION
# 63      64                    INTERSECTION
# 64      65                       WEATHER_1
# 65      66                       WEATHER_2
# 66      67                WEATHER_COMBINED
# 67      68                    ROAD_SURFACE
# 68      69                     ROAD_COND_1
# 69      70                     ROAD_COND_2
# 70      71                        LIGHTING
# 71      72                  CONTROL_DEVICE
# 72      73                   STATE_HWY_IND
# 73      74                     SIDE_OF_HWY
# 74      75                        TOW_AWAY
# 75      76                PCF_CODE_OF_VIOL
# 76      77               PCF_VIOL_CATEGORY
# 77      78                   PCF_VIOLATION
# 78      79             PCF_VIOL_SUBSECTION
# 79      80                            MVIW
# 80      81                      PED_ACTION
# 81      82            NOT_PRIVATE_PROPERTY
# 82      83           STWD_VEHTYPE_AT_FAULT
# 83      84            CHP_VEHTYPE_AT_FAULT
# 84      85                    PRIMARY_RAMP
# 85      86                  SECONDARY_RAMP
# 86      87                      PARTY_TYPE
# 87      88                        AT_FAULT
# 88      89                       PARTY_SEX
# 89      90                       PARTY_AGE
# 90      91                            RACE
# 91      92             PARTY_NUMBER_KILLED
# 92      93            PARTY_NUMBER_INJURED
# 93      94                     INATTENTION
# 94      95                  PARTY_SOBRIETY
# 95      96             PARTY_DRUG_PHYSICAL
# 96      97                   DIR_OF_TRAVEL
# 97      98            PARTY_SAFETY_EQUIP_1
# 98      99            PARTY_SAFETY_EQUIP_2
# 99     100                   FINAN_RESPONS
# 100    101                       SP_INFO_1
# 101    102                       SP_INFO_2
# 102    103                       SP_INFO_3
# 103    104              OAF_VIOLATION_CODE
# 104    105                    OAF_VIOL_CAT
# 105    106                OAF_VIOL_SECTION
# 106    107            OAF_VIOLATION_SUFFIX
# 107    108                           OAF_1
# 108    109                           OAF_2
# 109    110                    MOVE_PRE_ACC
# 110    111                    VEHICLE_YEAR
# 111    112                    VEHICLE_MAKE
# 112    113               STWD_VEHICLE_TYPE
# 113    114             CHP_VEH_TYPE_TOWING
# 114    115              CHP_VEH_TYPE_TOWED
# 115    116                  SPECIAL_INFO_F
# 116    117                  SPECIAL_INFO_G
# 117    118                     VICTIM_ROLE
# 118    119                      VICTIM_SEX
# 119    120                      VICTIM_AGE
# 120    121         VICTIM_DEGREE_OF_INJURY
# 121    122  VICTIM_DEGREE_OF_INJURY_BINARY
# 122    123         VICTIM_SEATING_POSITION
# 123    124           VICTIM_SAFETY_EQUIP_1
# 124    125           VICTIM_SAFETY_EQUIP_2
# 125    126                  VICTIM_EJECTED
# 126    127                  CITY_AREA_SQMI
# 127    128                    CITY_POPDENS
# 128    129                     CITY_HUDENS
# 129    130                       CITY_POPT
# 130    131                        CITY_HUT
# 131    132                       CITY_POPA
# 132    133                       CITY_POPB
# 133    134                       CITY_POPH
# 134    135                       CITY_POPW
# 135    136                   CITY_VEHICLES
# 136    137                CITY_TRAVEL_TIME
# 137    138                             RID
# 138    139                           RNAME
# 139    140                            RCAT
# 140    141                         RLENGTH
# 141    142                        LATITUDE
# 142    143                       LONGITUDE
# 143    144                         POINT_X
# 144    145                         POINT_Y
#
#                                             NAME  \
# 0                                      Object ID
# 1                                      Global ID
# 2                  GUID Related Table Identifier
# 3                                        Case ID
# 4                                       Crash ID
# 5                                       Party ID
# 6                                      Victim ID
# 7                                   Party Number
# 8                                  Victim Number
# 9                       Crashes Binary Indicator
# 10                      Parties Binary Indicator
# 11                      Victims Binary Indicator
# 12                                          City
# 13                                     City Name
# 14                                    Place Type
# 15                           Crash Date and Time
# 16                                    Crash Date
# 17                                    Crash Time
# 18                                    Crash Year
# 19                                   Crash Month
# 20                                   Day of Week
# 21                               Processing Date
# 22                          Crash Time Intervals
# 23                                    Rush Hours
# 24                                Crash Severity
# 25                       Crash Severity (Binary)
# 26                   Crash Severity Reclassified
# 27                         Crash Severity Ranked
# 28                                   Party Count
# 29                                  Victim Count
# 30                                Killed victims
# 31                               Injured victims
# 32                           Severe Injury Count
# 33                    Other Visible Injury Count
# 34                Complaint of Pain Injury Count
# 35                       Pedestrian Killed Count
# 36                      Pedestrian Injured Count
# 37                        Bicyclist Killed Count
# 38                       Bicyclist Injured Count
# 39                     Motorcyclist Killed Count
# 40                    Motorcyclist Injured Count
# 41                          Primary Crash Factor
# 42                                 Type of Crash
# 43                              Pedestrian Crash
# 44                                 Bicycle Crash
# 45                              Motorcycle Crash
# 46                                   Truck Crash
# 47                                   Hit and Run
# 48                              Alcohol Involved
# 49                                  Jurisdiction
# 50                                    Officer ID
# 51                            Reporting District
# 52                                     CHP Shift
# 53                          County City Location
# 54                             Special Condition
# 55                                     Beat Type
# 56                                 CHP Beat Type
# 57                                CHP Beat Class
# 58                                   Beat Number
# 59                                  Primary Road
# 60                                Secondary Road
# 61                                      Distance
# 62                                     Direction
# 63                                  Intersection
# 64                                     Weather 1
# 65                                     Weather 2
# 66                   Combined Weather Conditions
# 67                                  Road Surface
# 68                              Road Condition 1
# 69                              Road Condition 2
# 70                                      Lighting
# 71                                Control Device
# 72                       State Highway Indicator
# 73                               Side of Highway
# 74                                      Tow Away
# 75                            PCF Violation Code
# 76                        PCF Violation Category
# 77                                 PCF Violation
# 78                      PCF Violation Subsection
# 79                   Motor Vehicle Involved With
# 80                                    Ped Action
# 81                          Not Private Property
# 82               Statewide Vehicle Type At Fault
# 83                     CHP Vehicle Type At Fault
# 84                                  Primary Ramp
# 85                                Secondary Ramp
# 86                                    Party Type
# 87                                      At Fault
# 88                                     Party Sex
# 89                                     Party Age
# 90                                    Party Race
# 91                           Party Number Killed
# 92                          Party Number Injured
# 93                                   Inattention
# 94                                Party Sobriety
# 95                           Party Drug Physical
# 96                           Direction of Travel
# 97                      Party Safety Equipment 1
# 98                      Party Safety Equipment 2
# 99                      Financial Responsibility
# 100                        Special Information 1
# 101                        Special Information 2
# 102                        Special Information 3
# 103                           OAF Violation Code
# 104                       OAF Violation Category
# 105                        OAF Violation Section
# 106                         OAF Violation Suffix
# 107                    Other Associated Factor 1
# 108                    Other Associated Factor 2
# 109                     Movement Preceding Crash
# 110                                 Vehicle Year
# 111                                 Vehicle Make
# 112                       Statewide Vehicle Type
# 113                      CHP Vehicle Type Towing
# 114                       CHP Vehicle Type Towed
# 115                               Special Info F
# 116                               Special Info G
# 117                                  Victim Role
# 118                                   Victim Sex
# 119                                   Victim Age
# 120                      Victim Degree of Injury
# 121              Victim Injury Severity (Binary)
# 122                      Victim Seating Position
# 123                    Victim Safety Equipment 1
# 124                    Victim Safety Equipment 2
# 125                               Victim Ejected
# 126                        City Area (sq. miles)
# 127         City Population Density (per sq. mi)
# 128            City Housing Density (per sq. mi)
# 129                        City Total Population
# 130                     City Total Housing Units
# 131                        City Asian Population
# 132                        City Black Population
# 133                     City Hispanic Population
# 134                        City White Population
# 135  City Aggregate Number of Vehicles Commuting
# 136     City Aggregate Travel Time to Work (min)
# 137                                      Road ID
# 138                                    Road Name
# 139                                Road Category
# 140                                  Road Length
# 141                                 GPS Latitude
# 142                                GPS Longitude
# 143                        X Coordinate Location
# 144                        Y Coordinate Location
#
#                                            DESCRIPTION   LEVEL      TYPE  \
# 0                                       ESRI Object ID     GIS       OID
# 1                     ESRI Global ID string identifier     GIS  GlobalID
# 2       ESRI GUID to be used in merging related tables     GIS      Guid
# 3                  Unique identifier of the crash case   Crash      LONG
# 4                  Unique identifier of the crash case   Crash      TEXT
# 5                 Unique identifier for the party case   Party      TEXT
# 6                 Unique identifier of the victim case  Victim      TEXT
# 7    A number that together with the CASE_ID unique...   Party      LONG
# 8                  The unique identifier of the victim  Victim      LONG
# 9    Binary flag, 1 if the record is a crash, 0 if not   Crash      LONG
# 10   Binary flag, 1 if the record is a party, 0 if not   Party      LONG
# 11   Binary flag, 1 if the record is a victim, 0 if...  Victim      LONG
# 12                          Reported City of the crash    City      TEXT
# 13                     City name from locational query    City      TEXT
# 14                         City or Unincorporated Area    City      TEXT
# 15              Full date and time string of the crash   Crash      DATE
# 16                    The date when the crash occurred   Crash      DATE
# 17      The time when the crash occurred in 24h format   Crash      LONG
# 18                    The year when the crash occurred   Crash      LONG
# 19                        Month number from crash date   Crash      LONG
# 20   Code for the day of the week when the crash oc...   Crash      LONG
# 21       The date that the crash case was last changed   Crash      DATE
# 22           Crash time interval ranges classification   Crash      LONG
# 23   Rush hours interval ranges (Mon-Fri mornings a...   Crash      LONG
# 24   The worst injury suffered by any victim in the...   Crash      LONG
# 25   Binary classification of the worst injury suff...   Crash      LONG
# 26   Reclassified crash severity based on the worst...   Crash      LONG
# 27   Ranked crash severity based on the worst injur...   Crash      LONG
# 28             Number of parties involved in the crash   Party      LONG
# 29            Number of victims involved in each party  Victim      LONG
# 30                            Number of killed victims   Crash      LONG
# 31                           Number of injured victims   Crash      LONG
# 32   Number of victims in the crash with suspected ...   Crash      LONG
# 33   Number of victims in the crash with suspected ...   Crash      LONG
# 34   Number of victims in the crash with possible i...   Crash      LONG
# 35                 Number of killed pedestrian victims   Crash      LONG
# 36                Number of injured pedestrian victims   Crash      LONG
# 37                         Number of killed bicyclists   Crash      LONG
# 38                        Number of injured bicyclists   Crash      LONG
# 39                      Number of killed motorcyclists   Crash      LONG
# 40                     Number of injured motorcyclists   Crash      LONG
# 41                      The primary cause of the crash   Crash      TEXT
# 42   The general type of crash as determined by the...   Crash      TEXT
# 43   Indicates whether the crash involved a pedestrian   Crash      TEXT
# 44      Indicates whether the crash involved a bicycle   Crash      TEXT
# 45   Indicates whether the crash involved a motorcycle   Crash      TEXT
# 46    Indicates whether the crash involved a big truck   Crash      TEXT
# 47   A flag to indicate the severity of hit-and-run...   Crash      TEXT
# 48   Indicates whether the crash involved a party t...   Crash      TEXT
# 49   Law enforcement agency that has jurisdiction o...   Crash      LONG
# 50   The badge number of the officer who wrote the ...   Crash      TEXT
# 51              Reporting District on the crash report   Crash      TEXT
# 52                  CHP shift at the time of the crash   Crash      LONG
# 53   The city or unincorporated county where the cr...   Crash      LONG
# 54      A computed value. O means not private property   Crash      LONG
# 55                     Location of crash based on beat   Crash      LONG
# 56                     Location of crash based on beat   Crash      TEXT
# 57                     Location of crash based on beat   Crash      LONG
# 58          Beat of the officer who reported the crash   Crash      TEXT
# 59   The name of the roadway on which the crash occ...   Crash      TEXT
# 60   The name of the roadway that intersects the pr...   Crash      TEXT
# 61   Distance of the crash from the intersection wi...   Crash    DOUBLE
# 62   Direction of the crash from the intersection w...   Crash      TEXT
# 63   A flag that denotes if the crash occurred at t...   Crash      TEXT
# 64          Weather condition at the time of the crash   Crash      TEXT
# 65   Additional weather condition at the time of th...   Crash      TEXT
# 66   Combined Weather Conditions from WEATHER_1 and...   Crash      LONG
# 67   Roadway surface condition at the time of the c...   Crash      TEXT
# 68   Roadway condition at the time of the crash in ...   Crash      TEXT
# 69   Second roadway condition at the time of the cr...   Crash      TEXT
# 70   Lighting conditions at the crash location and ...   Crash      TEXT
# 71   Presence and condition of crash related traffi...   Crash      TEXT
# 72   A flag to indicate whether the crash is on or ...   Crash      TEXT
# 73   Code provided by Caltrans Coders, applies to d...   Crash      TEXT
# 74   A flag to indicate whether the vehicle was tow...   Crash      TEXT
# 75   The law code that was violated and was the pri...   Crash      TEXT
# 76   A value computed from the law section that was...   Crash      TEXT
# 77   The law section given as the primary cause of ...   Crash    DOUBLE
# 78   The subsection of the law section given as the...   Crash      TEXT
# 79   Describes what, in conjunction with a motor ve...   Crash      TEXT
# 80   The action just prior to the crash of the firs...   Crash      TEXT
# 81   Y indicates that the crash did not occur on pr...   Crash      TEXT
# 82   Indicates the Statewide Vehicle Type of the pa...   Crash      TEXT
# 83   Indicates the CHP Vehicle Type of the party wh...   Crash      TEXT
# 84   A description of the ramp, if any, on primary ...   Crash      TEXT
# 85   A description of the ramp, if any, on secondar...   Crash      TEXT
# 86                                 Involved party type   Party      TEXT
# 87   Indicates whether the party was at fault in th...   Party      TEXT
# 88                             The gender of the party   Party      TEXT
# 89       The age of the party at the time of the crash   Party      LONG
# 90   The party's race based on the reporting office...   Party      TEXT
# 91               Number of killed victims in the party   Party      LONG
# 92              Number of injured victims in the party   Party      LONG
# 93                                 Type of inattention   Party      TEXT
# 94                  The state of sobriety of the party   Party      TEXT
# 95   The state of the party with regard to drugs an...   Party      TEXT
# 96   Direction that the party was traveling at the ...   Party      TEXT
# 97                   The safety equipment of the party   Party      TEXT
# 98                   The safety equipment of the party   Party      TEXT
# 99               Financial responsibility of the party   Party      TEXT
# 100  Value A indicates that the crash involved in a...   Party      TEXT
# 101                             Cell Phone Information   Party      TEXT
# 102  Value E indicates that the crash involved a mo...   Party      TEXT
# 103          Other associated factor law code violated   Party      TEXT
# 104  Category of the factor that contributed to the...   Party      TEXT
# 105  The CVC section of the secondary violation tha...   Party    DOUBLE
# 106  the subsection of the CVC section of the secon...   Party      TEXT
# 107  A factor that contributed to the crash but was...   Party      TEXT
# 108  A factor that contributed to the crash but was...   Party      TEXT
# 109  The action of the vehicle prior to the crash a...   Party      TEXT
# 110              The model year of the party's vehicle   Party      LONG
# 111                    The make of the party's vehicle   Party      TEXT
# 112  Type of the party's vehicle according to a lis...   Party      TEXT
# 113  The type of the solitary vehicle or the tracto...   Party      TEXT
# 114  The type of the first trailer unit according t...   Party      TEXT
# 115  The value F indicate that the party's vehicle ...   Party      TEXT
# 116  The value G indicates that the party's vehicle...   Party      TEXT
# 117                             The role of the victim  Victim      LONG
# 118                           The gender of the victim  Victim      TEXT
# 119     The age of the victim at the time of the crash  Victim      LONG
# 120           The severity of the injury to the victim  Victim      LONG
# 121  Binary classification of the severity of the i...  Victim      LONG
# 122                 The seating position of the victim  Victim      TEXT
# 123                 The safety equipment of the victim  Victim      TEXT
# 124                 The safety equipment of the victim  Victim      TEXT
# 125  Indicates whether the victim was ejected from ...  Victim      TEXT
# 126                          City Area in Square Miles    City    DOUBLE
# 127  City population density, population per square...    City    DOUBLE
# 128       City housing density, houses per square mile    City    DOUBLE
# 129                Total population in the city's area    City      LONG
# 130             Total housing units in the city's area    City      LONG
# 131          Total Asian population in the city's area    City      LONG
# 132  Total Black or African American population in ...    City      LONG
# 133       Total Hispanic population in the city's area    City      LONG
# 134          Total White population in the city's area    City      LONG
# 135  Aggregate number of vehicles used in commuting...    City      LONG
# 136  Aggregate travel time to work (in minutes) in ...    City      LONG
# 137             Road ID matching from the road's layer    Road      TEXT
# 138            Road name from the OC Tiger/Lines layer    Road      TEXT
# 139        Road category from the OC Tiger/Lines layer    Road      TEXT
# 140          Road length from the OC Tiger/Lines layer    Road    DOUBLE
# 141  Latitude of the crash location in decimal degr...   Crash    DOUBLE
# 142  Longitude of the crash location in decimal deg...   Crash    DOUBLE
# 143  The longitude of the geocoded location, uses t...   Crash    DOUBLE
# 144  The latitude of the geocoded location, uses th...   Crash    DOUBLE
#
#                    CATEGORY DOMAIN
# 0         Unique Identifier      N
# 1         Unique Identifier      N
# 2         Unique Identifier      N
# 3         Unique Identifier      N
# 4         Unique Identifier      N
# 5         Unique Identifier      N
# 6         Unique Identifier      N
# 7         Unique Identifier      N
# 8         Unique Identifier      N
# 9                    Binary      N
# 10                   Binary      N
# 11                   Binary      N
# 12   Location or Place Name      N
# 13   Location or Place Name      N
# 14   Location or Place Name      N
# 15            Date and Time      N
# 16            Date and Time      N
# 17            Date and Time      N
# 18            Date and Time      N
# 19            Date and Time      Y
# 20            Date and Time      Y
# 21            Date and Time      N
# 22            Date and Time      Y
# 23            Date and Time      Y
# 24         Type or Category      Y
# 25         Type or Category      Y
# 26         Type or Category      Y
# 27         Type or Category      Y
# 28          Count or Amount      N
# 29          Count or Amount      N
# 30          Count or Amount      N
# 31          Count or Amount      N
# 32          Count or Amount      N
# 33          Count or Amount      N
# 34          Count or Amount      N
# 35          Count or Amount      N
# 36          Count or Amount      N
# 37          Count or Amount      N
# 38          Count or Amount      N
# 39          Count or Amount      N
# 40          Count or Amount      N
# 41         Type or Category      Y
# 42         Type or Category      Y
# 43                   Binary      Y
# 44                   Binary      Y
# 45                   Binary      Y
# 46                   Binary      Y
# 47         Type or Category      Y
# 48                   Binary      Y
# 49         Type or Category      N
# 50        Unique Identifier      N
# 51   Location or Place Name      N
# 52         Type or Category      Y
# 53   Location or Place Name      N
# 54         Type or Category      Y
# 55         Type or Category      Y
# 56         Type or Category      Y
# 57         Type or Category      Y
# 58         Type or Category      N
# 59   Location or Place Name      N
# 60   Location or Place Name      N
# 61              Measurement      N
# 62              Measurement      Y
# 63         Type or Category      Y
# 64         Type or Category      Y
# 65         Type or Category      Y
# 66         Type or Category      Y
# 67         Type or Category      Y
# 68         Type or Category      Y
# 69         Type or Category      Y
# 70         Type or Category      Y
# 71         Type or Category      Y
# 72         Type or Category      Y
# 73         Type or Category      Y
# 74                   Binary      Y
# 75         Type or Category      Y
# 76         Type or Category      Y
# 77         Type or Category      N
# 78         Type or Category      N
# 79         Type or Category      Y
# 80         Type or Category      Y
# 81                   Binary      Y
# 82         Type or Category      Y
# 83         Type or Category      Y
# 84         Type or Category      Y
# 85         Type or Category      Y
# 86         Type or Category      Y
# 87                   Binary      Y
# 88         Type or Category      Y
# 89              Measurement      Y
# 90         Type or Category      Y
# 91          Count or Amount      N
# 92          Count or Amount      N
# 93         Type or Category      Y
# 94         Type or Category      Y
# 95         Type or Category      Y
# 96              Measurement      Y
# 97         Type or Category      Y
# 98         Type or Category      Y
# 99         Type or Category      Y
# 100        Type or Category      Y
# 101        Type or Category      Y
# 102        Type or Category      Y
# 103        Type or Category      Y
# 104        Type or Category      Y
# 105        Type or Category      N
# 106        Type or Category      N
# 107        Type or Category      Y
# 108        Type or Category      Y
# 109        Type or Category      Y
# 110           Date and Time      Y
# 111        Type or Category      Y
# 112        Type or Category      Y
# 113        Type or Category      Y
# 114        Type or Category      Y
# 115        Type or Category      Y
# 116        Type or Category      Y
# 117        Type or Category      Y
# 118        Type or Category      Y
# 119             Measurement      Y
# 120        Type or Category      Y
# 121        Type or Category      Y
# 122        Type or Category      Y
# 123        Type or Category      Y
# 124        Type or Category      Y
# 125        Type or Category      Y
# 126             Measurement      N
# 127         Count or Amount      N
# 128         Count or Amount      N
# 129         Count or Amount      N
# 130         Count or Amount      N
# 131         Count or Amount      N
# 132         Count or Amount      N
# 133         Count or Amount      N
# 134         Count or Amount      N
# 135         Count or Amount      N
# 136         Count or Amount      N
# 137       Unique Identifier      N
# 138                    Name      N
# 139        Type or Category      N
# 140             Measurement      N
# 141              Coordinate      N
# 142              Coordinate      N
# 143              Coordinate      N
# 144              Coordinate      N

# %% [markdown]
# ### <font color="lime">**Importing Excel data into geodatabase tables**</font>

# %% [markdown]
# Importing the excel files into geodatabase tables in ArcGIS Pro

# %% [markdown]
# #### <font color="deepskyblue">Crashes Table</font>

# %% [markdown]
# Importing the Crashes excel file into the ArcGIS Pro project as a geodatabase table

# %%
update_datetime("start")

print("Converting Excel to Table: CrashesRaw")
# Importing the Crashes excel file into an ArCGIS Pro project table
arcpy.conversion.ExcelToTable(
    Input_Excel_File = dfCrashesExcel,
    Output_Table = "CrashesRaw",
    field_names_row = 1,
    cell_range = ""
)
print(arcpy.GetMessages())

update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 06:55 AM (PST)
# Converting Excel to Table: CrashesRaw
# Start Time: Wednesday, November 13, 2024 6:55:39 AM
# Succeeded at Wednesday, November 13, 2024 7:04:08 AM (Elapsed Time: 8 minutes 29 seconds)
# End: Wednesday November 13, 2024, 07:04 AM (PST). Elapsed time: 0:08:30

# %% [markdown]
# #### <font color="deepskyblue">Parties Table</font>

# %% [markdown]
# Importing the Parties excel table into the ArcGIS Pro project as a geodatabase table

# %%
update_datetime("start")

print("Converting Excel to Table: PartiesRaw")
# Importing the Parties excel file into an ArCGIS Pro project table
arcpy.conversion.ExcelToTable(
    Input_Excel_File = dfPartiesExcel,
    Output_Table = "PartiesRaw",
    field_names_row = 1,
    cell_range = ""
)
print(arcpy.GetMessages())

update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 07:04 AM (PST)
# Converting Excel to Table: PartiesRaw
# Start Time: Wednesday, November 13, 2024 7:04:08 AM
# Succeeded at Wednesday, November 13, 2024 7:29:21 AM (Elapsed Time: 25 minutes 12 seconds)
# End: Wednesday November 13, 2024, 07:29 AM (PST). Elapsed time: 0:25:13

# %% [markdown]
# #### <font color="deepskyblue">Victims Table</font>

# %% [markdown]
# Importing the Victims excel table into the ArcGIS Pro project as a geodatabase table

# %%
update_datetime("start")

print("Convert Excel to Table: VictimsRaw")
# Importing the Victims excel file into an ArCGIS Pro project table
arcpy.conversion.ExcelToTable(
    Input_Excel_File = dfVictimsExcel,
    Output_Table = "VictimsRaw",
    field_names_row = 1,
    cell_range = ""
)
print(arcpy.GetMessages())

update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 07:29 AM (PST)
# Convert Excel to Table: VictimsRaw
# Start Time: Wednesday, November 13, 2024 7:29:21 AM
# Succeeded at Wednesday, November 13, 2024 7:52:24 AM (Elapsed Time: 23 minutes 2 seconds)
# End: Wednesday November 13, 2024, 07:52 AM (PST). Elapsed time: 0:23:02

# %% [markdown]
# #### <font color="deepskyblue">Collisions Table</font>

# %% [markdown]
# Importing the Collisions excel table into the ArcGIS Pro project as a geodatabase table

# %%
update_datetime('end')

print("Converting Excel to Table: CollisionsRaw")
# Importing the Collisions excel file into an ArcGIS Pro project table
arcpy.conversion.ExcelToTable(
    Input_Excel_File = dfCollisionsExcel,
    Output_Table = "CollisionsRaw",
    field_names_row = 1,
    cell_range = ""
)
print(arcpy.GetMessages())

update_datetime("end")
# Out:
# End: Wednesday November 13, 2024, 07:52 AM (PST). Elapsed time: 0:23:02
# Converting Excel to Table: CollisionsRaw
# Start Time: Wednesday, November 13, 2024 7:52:24 AM
# Succeeded at Wednesday, November 13, 2024 8:16:52 AM (Elapsed Time: 24 minutes 28 seconds)
# End: Wednesday November 13, 2024, 08:16 AM (PST). Elapsed time: 0:47:31

# %% [markdown]
# Save the ArCGIS Pro project

# %%
# Save the project
aprx.save()

# %% [markdown]
# #### <font color="deepskyblue">Updating fields and counts</font>

# %% [markdown]
# Updating lists: tables, fields, and row counts from the ArcGIS Pro project geodatabase

# %%
# Get the list of tables in the geodatabase
gdbTables = arcpy.ListTables()

# Get each of the individual tables in the geodatabase
crashesTable = os.path.join(workspace, arcpy.ListTables("CrashesRaw")[0])
partiesTable = os.path.join(workspace, arcpy.ListTables("PartiesRaw")[0])
victimsTable = os.path.join(workspace, arcpy.ListTables("VictimsRaw")[0])
collisionsTable = os.path.join(workspace, arcpy.ListTables("CollisionsRaw")[0])

print(f"Geodatabase Tables: {gdbTables}")
print(f"\tCrashes: {crashesTable}\n\tParties: {partiesTable}\n\tVictims: {victimsTable}\n\tCollisions: {collisionsTable}")
# Out:
# Geodatabase Tables: ['CrashesRaw', 'PartiesRaw', 'VictimsRaw', 'CollisionsRaw']
# 	Crashes: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\CrashesRaw
# 	Parties: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\PartiesRaw
# 	Victims: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\VictimsRaw
# 	Collisions: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\CollisionsRaw

# %% [markdown]
# Updating the list of fields from each of the geodatabase tables

# %%
# Field lists for each of the geodatabase data tables
fieldsCrashes = arcpy.ListFields(crashesTable)
fieldsParties = arcpy.ListFields(partiesTable)
fieldsVictims = arcpy.ListFields(victimsTable)
fieldsCollisions = arcpy.ListFields(collisionsTable)

# %% [markdown]
# Count rows in each of the geodatabase tables

# %%
# Get the row count for each of the tables
countCrashes = int(arcpy.management.GetCount(crashesTable)[0])
countParties = int(arcpy.management.GetCount(partiesTable)[0])
countVictims = int(arcpy.management.GetCount(victimsTable)[0])
countCollisions = int(arcpy.management.GetCount(collisionsTable)[0])

print(f"Counts:\n- Crashes: {countCrashes:,}\n- Parties: {countParties:,}\n- Victims: {countVictims:,}\n- Collisions: {countCollisions:,}")
# Out:
# Counts:
# - Crashes: 149,764
# - Parties: 323,542
# - Victims: 260,120
# - Collisions: 260,120

# %% [markdown]
# Updating the mappings of the tables

# %%
# Mapping the fields using the function get_field_mappings() for each of the tables
mappingCrashes = get_field_mappings(codebook, fieldsCrashes, crashesTable)
mappingParties = get_field_mappings(codebook, fieldsParties, partiesTable)
mappingVictims = get_field_mappings(codebook, fieldsVictims, victimsTable)
mappingCollisions = get_field_mappings(codebook, fieldsCollisions, collisionsTable)

# %% [markdown]
# ### <font color="lime">**Reordering and Exporting Tables**</font>

# %% [markdown]
# In this subsection, we will reorder the fields in the tables to match the codebook order and will remove any old fields that are not in the codebook.

# %% [markdown]
# #### <font color="deepskyblue">Crashes Table</font>

# %% [markdown]
# Reordering and exporting the Crashes table

# %%
update_datetime("start")

# Generate field list and field mappings for the Crashes table
currentFieldList = arcpy.ListFields(crashesTable)
currentFieldMappings = get_field_mappings(codebook, currentFieldList, crashesTable)

print("Exporting Crashes Table")
# Export the table to a new table
arcpy.conversion.ExportTable(
    in_table = crashesTable,
    out_table = os.path.join(workspace, "CrashesTable"),
    where_clause = "",
    use_field_alias_as_name = "NOT_USE_ALIAS",
    field_mapping = currentFieldMappings,
    sort_field = None
)
print(arcpy.GetMessages())

update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 08:17 AM (PST)
# Exporting Crashes Table
# Start Time: Wednesday, November 13, 2024 8:17:39 AM
# Succeeded at Wednesday, November 13, 2024 8:18:03 AM (Elapsed Time: 23.57 seconds)
# End: Wednesday November 13, 2024, 08:18 AM (PST). Elapsed time: 0:00:24

# %% [markdown]
# #### <font color="deepskyblue">Parties Table</font>

# %% [markdown]
# Reordering and exporting the Parties table

# %%
update_datetime("start")

# Generate field list and field mappings for the Parties table
currentFieldList = arcpy.ListFields(partiesTable)
currentFieldMappings = get_field_mappings(codebook, currentFieldList, partiesTable)

print("Exporting Parties Table")
# Export the table to a new table
arcpy.conversion.ExportTable(
    in_table = partiesTable,
    out_table = os.path.join(workspace, "PartiesTable"),
    where_clause = "",
    use_field_alias_as_name = "NOT_USE_ALIAS",
    field_mapping = currentFieldMappings,
    sort_field = None
)
print(arcpy.GetMessages())

update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 08:18 AM (PST)
# Exporting Parties Table
# Start Time: Wednesday, November 13, 2024 8:18:03 AM
# Succeeded at Wednesday, November 13, 2024 8:19:08 AM (Elapsed Time: 1 minutes 4 seconds)
# End: Wednesday November 13, 2024, 08:19 AM (PST). Elapsed time: 0:01:04

# %% [markdown]
# #### <font color="deepskyblue">Victims Table</font>

# %% [markdown]
# Reordering and exporting the Victims table

# %%
update_datetime("start")

# Generate field list and field mappings for the Victims table
currentFieldList = arcpy.ListFields(victimsTable)
currentFieldMappings = get_field_mappings(codebook, currentFieldList, victimsTable)

print("Exporting Victims Table")
# Export the table to a new table
arcpy.conversion.ExportTable(
    in_table = victimsTable,
    out_table = os.path.join(workspace, "VictimsTable"),
    where_clause = "",
    use_field_alias_as_name = "NOT_USE_ALIAS",
    field_mapping = currentFieldMappings,
    sort_field = None
)
print(arcpy.GetMessages())

update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 08:19 AM (PST)
# Exporting Victims Table
# Start Time: Wednesday, November 13, 2024 8:19:09 AM
# Succeeded at Wednesday, November 13, 2024 8:20:05 AM (Elapsed Time: 56.45 seconds)
# End: Wednesday November 13, 2024, 08:20 AM (PST). Elapsed time: 0:00:57

# %% [markdown]
# #### <font color="deepskyblue">Collisions Table</font>

# %% [markdown]
# Reordering and exporting the Collisions table

# %%
update_datetime("start")

# Generate field list and field mappings for the Collisions table
currentFieldList = arcpy.ListFields(collisionsTable)
currentFieldMappings = get_field_mappings(codebook, currentFieldList, collisionsTable)

print("Exporting Collisions Table")
# Export the table to a new table
arcpy.conversion.ExportTable(
    in_table = collisionsTable,
    out_table = os.path.join(workspace, "CollisionsTable"),
    where_clause = "",
    use_field_alias_as_name = "NOT_USE_ALIAS",
    field_mapping = currentFieldMappings,
    sort_field = None
)
print(arcpy.GetMessages())

update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 08:20 AM (PST)
# Exporting Collisions Table
# Start Time: Wednesday, November 13, 2024 8:20:06 AM
# Succeeded at Wednesday, November 13, 2024 8:21:01 AM (Elapsed Time: 55.45 seconds)
# End: Wednesday November 13, 2024, 08:21 AM (PST). Elapsed time: 0:00:56

# %% [markdown]
# Delete the old unordered tables from the ArcGIS Pro project

# %%
update_datetime("start")

print("Deleting old tables")
# Delete old tables
arcpy.management.Delete(
    in_data = f"CrashesRaw; PartiesRaw; VictimsRaw; CollisionsRaw; {crashesTable}; {partiesTable}; {victimsTable}; {collisionsTable}",
    data_type = ""
)
print(arcpy.GetMessages())

update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 08:23 AM (PST)
# Deleting old tables
# Start Time: Wednesday, November 13, 2024 8:23:31 AM
# Succeeded at Wednesday, November 13, 2024 8:23:35 AM (Elapsed Time: 3.56 seconds)
# End: Wednesday November 13, 2024, 08:23 AM (PST). Elapsed time: 0:00:04

# %% [markdown]
# Delete old and obsolete OBJECTID fields from the tables

# %%
update_datetime("start")

# Iterate through the four tables and delete the OBJECTID_1 field
for table in [os.path.join(workspace, "CrashesTable"), os.path.join(workspace, "PartiesTable"), os.path.join(workspace, "VictimsTable"), os.path.join(workspace, "CollisionsTable")]:
    print(f"Deleting field OBJECTID_1 from {table}")
    arcpy.management.DeleteField(
        in_table = table,
        drop_field = "OBJECTID_1",
        method = "DELETE_FIELDS"
    )
    print(arcpy.GetMessages())

update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 08:23 AM (PST)
# Deleting field OBJECTID_1 from I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\CrashesTable
# Start Time: Wednesday, November 13, 2024 8:23:38 AM
# Succeeded at Wednesday, November 13, 2024 8:23:57 AM (Elapsed Time: 18.11 seconds)
# Deleting field OBJECTID_1 from I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\PartiesTable
# Start Time: Wednesday, November 13, 2024 8:23:57 AM
# Succeeded at Wednesday, November 13, 2024 8:24:38 AM (Elapsed Time: 41.16 seconds)
# Deleting field OBJECTID_1 from I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\VictimsTable
# Start Time: Wednesday, November 13, 2024 8:24:38 AM
# Succeeded at Wednesday, November 13, 2024 8:25:09 AM (Elapsed Time: 31.11 seconds)
# Deleting field OBJECTID_1 from I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\CollisionsTable
# Start Time: Wednesday, November 13, 2024 8:25:10 AM
# Succeeded at Wednesday, November 13, 2024 8:25:41 AM (Elapsed Time: 31.68 seconds)
# End: Wednesday November 13, 2024, 08:25 AM (PST). Elapsed time: 0:02:03

# %% [markdown]
# ### <font color="lime">**Updating Tables and Field Lists**</font>

# %% [markdown]
# Updating the list and contents of the python variables containing the tables

# %%
# Get the table list from the ArcGIS Pro project geodatabase
gdbTables = arcpy.ListTables()

# Get all the tables by name
crashesTable = os.path.join(workspace, arcpy.ListTables("CrashesTable")[0])
partiesTable = os.path.join(workspace, arcpy.ListTables("PartiesTable")[0])
victimsTable = os.path.join(workspace, arcpy.ListTables("VictimsTable")[0])
collisionsTable = os.path.join(workspace, arcpy.ListTables("CollisionsTable")[0])

print(f"Geodatabase Tables: {gdbTables}")
print(f"\tCrashes: {crashesTable}\n\tParties: {partiesTable}\n\tVictims: {victimsTable}\n\tCollisions: {collisionsTable}")
# Out:
# Geodatabase Tables: ['CrashesTable', 'PartiesTable', 'VictimsTable', 'CollisionsTable']
# 	Crashes: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\CrashesTable
# 	Parties: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\PartiesTable
# 	Victims: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\VictimsTable
# 	Collisions: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\CollisionsTable

# %% [markdown]
# Updating the field lists of the tables

# %%
# Field lists for each of the geodatabase data tables
fieldsCrashes = arcpy.ListFields(crashesTable)
fieldsParties = arcpy.ListFields(partiesTable)
fieldsVictims = arcpy.ListFields(victimsTable)
fieldsCollisions = arcpy.ListFields(collisionsTable)

# %% [markdown]
# Count rows in each of the geodatabase tables

# %%
# Get the row count for each of the tables
countCrashes = int(arcpy.management.GetCount(crashesTable)[0])
countParties = int(arcpy.management.GetCount(partiesTable)[0])
countVictims = int(arcpy.management.GetCount(victimsTable)[0])
countCollisions = int(arcpy.management.GetCount(collisionsTable)[0])

print(f"Counts:\n- Crashes: {countCrashes:,}\n- Parties: {countParties:,}\n- Victims: {countVictims:,}\n- Collisions: {countCollisions:,}")
# Out:
# Counts:
# - Crashes: 149,764
# - Parties: 323,542
# - Victims: 260,120
# - Collisions: 260,120

# %% [markdown]
# Updating the mappings of the tables

# %%
# Mapping the fields using the function get_field_mappings() for each of the tables
mappingCrashes = get_field_mappings(codebook, fieldsCrashes, crashesTable)
mappingParties = get_field_mappings(codebook, fieldsParties, partiesTable)
mappingVictims = get_field_mappings(codebook, fieldsVictims, victimsTable)
mappingCollisions = get_field_mappings(codebook, fieldsCollisions, collisionsTable)

# %% [markdown]
# Save the ArcGIS Pro project

# %%
# Save the project
aprx.save()

# %% [markdown]
# ## <font color="orangered">**Codebook for Field Aliases**</font>

# %% [markdown]
# ### <font color="lime">**Assigning field aliases**</font>

# %% [markdown]
# Creating and assigning field aliases for the geodatabase tables using the JSON codebook dictionary

# %% [markdown]
# #### <font color="deepskyblue">Crashes Table</font>

# %% [markdown]
# Field aliases for the Crashes table

# %%
update_datetime("start")

# Field aliases for the Crashes geodatabase table
print("Adding field aliases to the Crashes table...")
for field in fieldsCrashes:
    if field.name in list(codebook.keys()):
        print(f"\tMatch {codebook[field.name]['no']}: {field.name} ({codebook[field.name]['alias']}): {codebook[field.name]['desc']}")
        arcpy.management.AlterField(
            in_table = crashesTable,
            field = field.name,
            new_field_name = field.name,
            new_field_alias = codebook[field.name]["alias"]
        )
        #print(arcpy.GetMessages())
        
update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 08:26 AM (PST)
# Adding field aliases to the Crashes table...
# 	Match 1: OBJECTID (Object ID): ESRI Object ID
# 	Match 4: CASE_ID (Case ID): Unique identifier of the crash case
# 	Match 5: CID (Crash ID): Unique identifier of the crash case
# 	Match 13: CITY (City): Reported City of the crash
# 	Match 14: CITY_NAME (City Name): City name from locational query
# 	Match 15: PLACE_TYPE (Place Type): City or Unincorporated Area
# 	Match 16: COLLISION_DATETIME (Crash Date and Time): Full date and time string of the crash
# 	Match 17: COLLISION_DATE (Crash Date): The date when the crash occurred
# 	Match 18: COLLISION_TIME (Crash Time): The time when the crash occurred in 24h format
# 	Match 19: ACCIDENT_YEAR (Crash Year): The year when the crash occurred
# 	Match 20: COLLISION_MONTH (Crash Month): Month number from crash date
# 	Match 21: DAY_OF_WEEK (Day of Week): Code for the day of the week when the crash occurred
# 	Match 22: PROC_DATE (Processing Date): The date that the crash case was last changed
# 	Match 23: COLLISION_TIME_INTERVALS (Crash Time Intervals): Crash time interval ranges classification
# 	Match 24: COLLISION_TIME_RUSH_HOURS (Rush Hours): Rush hours interval ranges (Mon-Fri mornings and evenings)
# 	Match 25: COLLISION_SEVERITY (Crash Severity): The worst injury suffered by any victim in the crash
# 	Match 26: COLLISION_SEVERITY_BINARY (Crash Severity (Binary)): Binary classification of the worst injury suffered by any victim in the crash
# 	Match 27: COLLISION_SEVERITY_RECLASS (Crash Severity Reclassified): Reclassified crash severity based on the worst injury suffered by any victim in the crash
# 	Match 28: COLLISION_SEVERITY_RANKED (Crash Severity Ranked): Ranked crash severity based on the worst injury suffered by any victim in the crash
# 	Match 29: PARTY_COUNT (Party Count): Number of parties involved in the crash
# 	Match 30: VICTIM_COUNT (Victim Count): Number of victims involved in each party
# 	Match 31: NUMBER_KILLED (Killed victims): Number of killed victims
# 	Match 32: NUMBER_INJURED (Injured victims): Number of injured victims
# 	Match 33: COUNT_SEVERE_INJ (Severe Injury Count): Number of victims in the crash with suspected serous injury or severe injury
# 	Match 34: COUNT_VISIBLE_INJ (Other Visible Injury Count): Number of victims in the crash with suspected minor injury or visible injury
# 	Match 35: COUNT_COMPLAINT_PAIN (Complaint of Pain Injury Count): Number of victims in the crash with possible injury or complaint of pain
# 	Match 36: COUNT_PED_KILLED (Pedestrian Killed Count): Number of killed pedestrian victims
# 	Match 37: COUNT_PED_INJURED (Pedestrian Injured Count): Number of injured pedestrian victims
# 	Match 38: COUNT_BICYCLIST_KILLED (Bicyclist Killed Count): Number of killed bicyclists
# 	Match 39: COUNT_BICYCLIST_INJURED (Bicyclist Injured Count): Number of injured bicyclists
# 	Match 40: COUNT_MC_KILLED (Motorcyclist Killed Count): Number of killed motorcyclists
# 	Match 41: COUNT_MC_INJURED (Motorcyclist Injured Count): Number of injured motorcyclists
# 	Match 42: PRIMARY_COLL_FACTOR (Primary Crash Factor): The primary cause of the crash
# 	Match 43: TYPE_OF_COLLISION (Type of Crash): The general type of crash as determined by the first injury or damage-causing event
# 	Match 44: PEDESTRIAN_ACCIDENT (Pedestrian Crash): Indicates whether the crash involved a pedestrian
# 	Match 45: BICYCLE_ACCIDENT (Bicycle Crash): Indicates whether the crash involved a bicycle
# 	Match 46: MOTORCYCLE_ACCIDENT (Motorcycle Crash): Indicates whether the crash involved a motorcycle
# 	Match 47: TRUCK_ACCIDENT (Truck Crash): Indicates whether the crash involved a big truck
# 	Match 48: HIT_AND_RUN (Hit and Run): A flag to indicate the severity of hit-and-run crash. Felony hit-and-run resulted in injury or death to other parties. Misdemeanor hit-and-run did not result in injury or death to other parties
# 	Match 49: ALCOHOL_INVOLVED (Alcohol Involved): Indicates whether the crash involved a party that had been drinking. Note - a passenger does not count as a party
# 	Match 50: JURIS (Jurisdiction): Law enforcement agency that has jurisdiction over the crash
# 	Match 51: OFFICER_ID (Officer ID): The badge number of the officer who wrote the crash report
# 	Match 52: REPORTING_DISTRICT (Reporting District): Reporting District on the crash report
# 	Match 53: CHP_SHIFT (CHP Shift): CHP shift at the time of the crash
# 	Match 54: CNTY_CITY_LOC (County City Location): The city or unincorporated county where the crash occurred
# 	Match 55: SPECIAL_COND (Special Condition): A computed value. O means not private property
# 	Match 56: BEAT_TYPE (Beat Type): Location of crash based on beat
# 	Match 57: CHP_BEAT_TYPE (CHP Beat Type): Location of crash based on beat
# 	Match 58: CHP_BEAT_CLASS (CHP Beat Class): Location of crash based on beat
# 	Match 59: BEAT_NUMBER (Beat Number): Beat of the officer who reported the crash
# 	Match 60: PRIMARY_RD (Primary Road): The name of the roadway on which the crash occurred
# 	Match 61: SECONDARY_RD (Secondary Road): The name of the roadway that intersects the primary roadway
# 	Match 62: DISTANCE (Distance): Distance of the crash from the intersection with the secondary roadway in ft
# 	Match 63: DIRECTION (Direction): Direction of the crash from the intersection with the secondary roadway
# 	Match 64: INTERSECTION (Intersection): A flag that denotes if the crash occurred at the intersection with the secondary roadway
# 	Match 65: WEATHER_1 (Weather 1): Weather condition at the time of the crash
# 	Match 66: WEATHER_2 (Weather 2): Additional weather condition at the time of the crash
# 	Match 67: WEATHER_COMBINED (Combined Weather Conditions): Combined Weather Conditions from WEATHER_1 and WEATHER_2 fields in numeric codes by weather conditions severity
# 	Match 68: ROAD_SURFACE (Road Surface): Roadway surface condition at the time of the crash in the traffic lane(s) involved
# 	Match 69: ROAD_COND_1 (Road Condition 1): Roadway condition at the time of the crash in the traffic lane(s) involved
# 	Match 70: ROAD_COND_2 (Road Condition 2): Second roadway condition at the time of the crash in the traffic lane(s) involved
# 	Match 71: LIGHTING (Lighting): Lighting conditions at the crash location and the time of the crash
# 	Match 72: CONTROL_DEVICE (Control Device): Presence and condition of crash related traffic control devices at the time of the crash. Control devices include regulatory, warning, and construction sings. This excludes striping and officers or other persons directing traffic
# 	Match 73: STATE_HWY_IND (State Highway Indicator): A flag to indicate whether the crash is on or near a state highway
# 	Match 74: SIDE_OF_HWY (Side of Highway): Code provided by Caltrans Coders, applies to divided highway, based on nominal direction of route, for single vehicle is same as nominal direction of travel, overruled by impact with second vehicle after crossing median
# 	Match 75: TOW_AWAY (Tow Away): A flag to indicate whether the vehicle was towed away from the crash scene
# 	Match 76: PCF_CODE_OF_VIOL (PCF Violation Code): The law code that was violated and was the primary cause of the crash
# 	Match 77: PCF_VIOL_CATEGORY (PCF Violation Category): A value computed from the law section that was given as the primary cause of the crash
# 	Match 78: PCF_VIOLATION (PCF Violation): The law section given as the primary cause of the crash. The subsection is in the data element pcf_viol_subsection
# 	Match 79: PCF_VIOL_SUBSECTION (PCF Violation Subsection): The subsection of the law section given as the primary cause of the crash in the data element pcf_violation
# 	Match 80: MVIW (Motor Vehicle Involved With): Describes what, in conjunction with a motor vehicle in-transport, produced the first injury or damage-causing event, on or off the road
# 	Match 81: PED_ACTION (Ped Action): The action just prior to the crash of the first pedestrian injured or otherwise involved
# 	Match 82: NOT_PRIVATE_PROPERTY (Not Private Property): Y indicates that the crash did not occur on private property
# 	Match 83: STWD_VEHTYPE_AT_FAULT (Statewide Vehicle Type At Fault): Indicates the Statewide Vehicle Type of the party who is at fault
# 	Match 84: CHP_VEHTYPE_AT_FAULT (CHP Vehicle Type At Fault): Indicates the CHP Vehicle Type of the party whi is at fault
# 	Match 85: PRIMARY_RAMP (Primary Ramp): A description of the ramp, if any, on primary roadway. This value is computed by the key operator from information on the crash report
# 	Match 86: SECONDARY_RAMP (Secondary Ramp): A description of the ramp, if any, on secondary roadway. This value is computed by the key operator from information on the crash report
# 	Match 127: CITY_AREA_SQMI (City Area (sq. miles)): City Area in Square Miles
# 	Match 128: CITY_POPDENS (City Population Density (per sq. mi)): City population density, population per square mile
# 	Match 129: CITY_HUDENS (City Housing Density (per sq. mi)): City housing density, houses per square mile
# 	Match 130: CITY_POPT (City Total Population): Total population in the city's area
# 	Match 131: CITY_HUT (City Total Housing Units): Total housing units in the city's area
# 	Match 132: CITY_POPA (City Asian Population): Total Asian population in the city's area
# 	Match 133: CITY_POPB (City Black Population): Total Black or African American population in the city's area
# 	Match 134: CITY_POPH (City Hispanic Population): Total Hispanic population in the city's area
# 	Match 135: CITY_POPW (City White Population): Total White population in the city's area
# 	Match 136: CITY_VEHICLES (City Aggregate Number of Vehicles Commuting): Aggregate number of vehicles used in commuting in the city's area
# 	Match 137: CITY_TRAVEL_TIME (City Aggregate Travel Time to Work (min)): Aggregate travel time to work (in minutes) in the city's area
# 	Match 138: RID (Road ID): Road ID matching from the road's layer
# 	Match 139: RNAME (Road Name): Road name from the OC Tiger/Lines layer
# 	Match 140: RCAT (Road Category): Road category from the OC Tiger/Lines layer
# 	Match 141: RLENGTH (Road Length): Road length from the OC Tiger/Lines layer
# 	Match 142: LATITUDE (GPS Latitude): Latitude of the crash location in decimal degrees. The decimal point is included. LATITUDE and LONGITUDE are from the crash report
# 	Match 143: LONGITUDE (GPS Longitude): Longitude of the crash location in decimal degrees. The decimal point is included. There is no minus sign. The longitude is understood to be West of Meridian. LATITUDE and LONGITUDE are from the crash report
# 	Match 144: POINT_X (X Coordinate Location): The longitude of the geocoded location, uses the World Geodetic System from 1984 (WGS84). POINT_X and POINT_Y are generated using the geociding process by UC Berkeley Safe TREC
# 	Match 145: POINT_Y (Y Coordinate Location): The latitude of the geocoded location, uses the World Geodetic System from 1984 (WGS84). POINT_X and POINT_Y are generated using the geociding process by UC Berkeley Safe TREC
# End: Wednesday November 13, 2024, 08:27 AM (PST). Elapsed time: 0:00:51

# %% [markdown]
# #### <font color="deepskyblue">Parties Table</font>

# %% [markdown]
# Field aliases for the Parties table

# %%
update_datetime("start")

# Field aliases for the Parties geodatabase table
print("Adding field aliases to the Parties table...")
for field in fieldsParties:
    if field.name in list(codebook.keys()):
        print(f"\tMatch {codebook[field.name]['no']}: {field.name} ({codebook[field.name]['alias']}): {codebook[field.name]['desc']}")
        arcpy.management.AlterField(
            in_table = partiesTable,
            field = field.name,
            new_field_name = field.name,
            new_field_alias = codebook[field.name]["alias"]
        )
        #print(arcpy.GetMessages())
        
update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 08:27 AM (PST)
# Adding field aliases to the Parties table...
# 	Match 1: OBJECTID (Object ID): ESRI Object ID
# 	Match 4: CASE_ID (Case ID): Unique identifier of the crash case
# 	Match 5: CID (Crash ID): Unique identifier of the crash case
# 	Match 6: PID (Party ID): Unique identifier for the party case
# 	Match 8: PARTY_NUMBER (Party Number): A number that together with the CASE_ID uniquely identifies a party in a crash
# 	Match 13: CITY (City): Reported City of the crash
# 	Match 14: CITY_NAME (City Name): City name from locational query
# 	Match 15: PLACE_TYPE (Place Type): City or Unincorporated Area
# 	Match 16: COLLISION_DATETIME (Crash Date and Time): Full date and time string of the crash
# 	Match 17: COLLISION_DATE (Crash Date): The date when the crash occurred
# 	Match 18: COLLISION_TIME (Crash Time): The time when the crash occurred in 24h format
# 	Match 19: ACCIDENT_YEAR (Crash Year): The year when the crash occurred
# 	Match 20: COLLISION_MONTH (Crash Month): Month number from crash date
# 	Match 21: DAY_OF_WEEK (Day of Week): Code for the day of the week when the crash occurred
# 	Match 22: PROC_DATE (Processing Date): The date that the crash case was last changed
# 	Match 23: COLLISION_TIME_INTERVALS (Crash Time Intervals): Crash time interval ranges classification
# 	Match 24: COLLISION_TIME_RUSH_HOURS (Rush Hours): Rush hours interval ranges (Mon-Fri mornings and evenings)
# 	Match 25: COLLISION_SEVERITY (Crash Severity): The worst injury suffered by any victim in the crash
# 	Match 26: COLLISION_SEVERITY_BINARY (Crash Severity (Binary)): Binary classification of the worst injury suffered by any victim in the crash
# 	Match 27: COLLISION_SEVERITY_RECLASS (Crash Severity Reclassified): Reclassified crash severity based on the worst injury suffered by any victim in the crash
# 	Match 28: COLLISION_SEVERITY_RANKED (Crash Severity Ranked): Ranked crash severity based on the worst injury suffered by any victim in the crash
# 	Match 29: PARTY_COUNT (Party Count): Number of parties involved in the crash
# 	Match 30: VICTIM_COUNT (Victim Count): Number of victims involved in each party
# 	Match 31: NUMBER_KILLED (Killed victims): Number of killed victims
# 	Match 32: NUMBER_INJURED (Injured victims): Number of injured victims
# 	Match 33: COUNT_SEVERE_INJ (Severe Injury Count): Number of victims in the crash with suspected serous injury or severe injury
# 	Match 34: COUNT_VISIBLE_INJ (Other Visible Injury Count): Number of victims in the crash with suspected minor injury or visible injury
# 	Match 35: COUNT_COMPLAINT_PAIN (Complaint of Pain Injury Count): Number of victims in the crash with possible injury or complaint of pain
# 	Match 36: COUNT_PED_KILLED (Pedestrian Killed Count): Number of killed pedestrian victims
# 	Match 37: COUNT_PED_INJURED (Pedestrian Injured Count): Number of injured pedestrian victims
# 	Match 38: COUNT_BICYCLIST_KILLED (Bicyclist Killed Count): Number of killed bicyclists
# 	Match 39: COUNT_BICYCLIST_INJURED (Bicyclist Injured Count): Number of injured bicyclists
# 	Match 40: COUNT_MC_KILLED (Motorcyclist Killed Count): Number of killed motorcyclists
# 	Match 41: COUNT_MC_INJURED (Motorcyclist Injured Count): Number of injured motorcyclists
# 	Match 42: PRIMARY_COLL_FACTOR (Primary Crash Factor): The primary cause of the crash
# 	Match 43: TYPE_OF_COLLISION (Type of Crash): The general type of crash as determined by the first injury or damage-causing event
# 	Match 44: PEDESTRIAN_ACCIDENT (Pedestrian Crash): Indicates whether the crash involved a pedestrian
# 	Match 45: BICYCLE_ACCIDENT (Bicycle Crash): Indicates whether the crash involved a bicycle
# 	Match 46: MOTORCYCLE_ACCIDENT (Motorcycle Crash): Indicates whether the crash involved a motorcycle
# 	Match 47: TRUCK_ACCIDENT (Truck Crash): Indicates whether the crash involved a big truck
# 	Match 48: HIT_AND_RUN (Hit and Run): A flag to indicate the severity of hit-and-run crash. Felony hit-and-run resulted in injury or death to other parties. Misdemeanor hit-and-run did not result in injury or death to other parties
# 	Match 49: ALCOHOL_INVOLVED (Alcohol Involved): Indicates whether the crash involved a party that had been drinking. Note - a passenger does not count as a party
# 	Match 50: JURIS (Jurisdiction): Law enforcement agency that has jurisdiction over the crash
# 	Match 51: OFFICER_ID (Officer ID): The badge number of the officer who wrote the crash report
# 	Match 52: REPORTING_DISTRICT (Reporting District): Reporting District on the crash report
# 	Match 53: CHP_SHIFT (CHP Shift): CHP shift at the time of the crash
# 	Match 54: CNTY_CITY_LOC (County City Location): The city or unincorporated county where the crash occurred
# 	Match 55: SPECIAL_COND (Special Condition): A computed value. O means not private property
# 	Match 56: BEAT_TYPE (Beat Type): Location of crash based on beat
# 	Match 57: CHP_BEAT_TYPE (CHP Beat Type): Location of crash based on beat
# 	Match 58: CHP_BEAT_CLASS (CHP Beat Class): Location of crash based on beat
# 	Match 59: BEAT_NUMBER (Beat Number): Beat of the officer who reported the crash
# 	Match 60: PRIMARY_RD (Primary Road): The name of the roadway on which the crash occurred
# 	Match 61: SECONDARY_RD (Secondary Road): The name of the roadway that intersects the primary roadway
# 	Match 62: DISTANCE (Distance): Distance of the crash from the intersection with the secondary roadway in ft
# 	Match 63: DIRECTION (Direction): Direction of the crash from the intersection with the secondary roadway
# 	Match 64: INTERSECTION (Intersection): A flag that denotes if the crash occurred at the intersection with the secondary roadway
# 	Match 65: WEATHER_1 (Weather 1): Weather condition at the time of the crash
# 	Match 66: WEATHER_2 (Weather 2): Additional weather condition at the time of the crash
# 	Match 67: WEATHER_COMBINED (Combined Weather Conditions): Combined Weather Conditions from WEATHER_1 and WEATHER_2 fields in numeric codes by weather conditions severity
# 	Match 68: ROAD_SURFACE (Road Surface): Roadway surface condition at the time of the crash in the traffic lane(s) involved
# 	Match 69: ROAD_COND_1 (Road Condition 1): Roadway condition at the time of the crash in the traffic lane(s) involved
# 	Match 70: ROAD_COND_2 (Road Condition 2): Second roadway condition at the time of the crash in the traffic lane(s) involved
# 	Match 71: LIGHTING (Lighting): Lighting conditions at the crash location and the time of the crash
# 	Match 72: CONTROL_DEVICE (Control Device): Presence and condition of crash related traffic control devices at the time of the crash. Control devices include regulatory, warning, and construction sings. This excludes striping and officers or other persons directing traffic
# 	Match 73: STATE_HWY_IND (State Highway Indicator): A flag to indicate whether the crash is on or near a state highway
# 	Match 74: SIDE_OF_HWY (Side of Highway): Code provided by Caltrans Coders, applies to divided highway, based on nominal direction of route, for single vehicle is same as nominal direction of travel, overruled by impact with second vehicle after crossing median
# 	Match 75: TOW_AWAY (Tow Away): A flag to indicate whether the vehicle was towed away from the crash scene
# 	Match 76: PCF_CODE_OF_VIOL (PCF Violation Code): The law code that was violated and was the primary cause of the crash
# 	Match 77: PCF_VIOL_CATEGORY (PCF Violation Category): A value computed from the law section that was given as the primary cause of the crash
# 	Match 78: PCF_VIOLATION (PCF Violation): The law section given as the primary cause of the crash. The subsection is in the data element pcf_viol_subsection
# 	Match 79: PCF_VIOL_SUBSECTION (PCF Violation Subsection): The subsection of the law section given as the primary cause of the crash in the data element pcf_violation
# 	Match 80: MVIW (Motor Vehicle Involved With): Describes what, in conjunction with a motor vehicle in-transport, produced the first injury or damage-causing event, on or off the road
# 	Match 81: PED_ACTION (Ped Action): The action just prior to the crash of the first pedestrian injured or otherwise involved
# 	Match 82: NOT_PRIVATE_PROPERTY (Not Private Property): Y indicates that the crash did not occur on private property
# 	Match 83: STWD_VEHTYPE_AT_FAULT (Statewide Vehicle Type At Fault): Indicates the Statewide Vehicle Type of the party who is at fault
# 	Match 84: CHP_VEHTYPE_AT_FAULT (CHP Vehicle Type At Fault): Indicates the CHP Vehicle Type of the party whi is at fault
# 	Match 85: PRIMARY_RAMP (Primary Ramp): A description of the ramp, if any, on primary roadway. This value is computed by the key operator from information on the crash report
# 	Match 86: SECONDARY_RAMP (Secondary Ramp): A description of the ramp, if any, on secondary roadway. This value is computed by the key operator from information on the crash report
# 	Match 87: PARTY_TYPE (Party Type): Involved party type
# 	Match 88: AT_FAULT (At Fault): Indicates whether the party was at fault in the crash
# 	Match 89: PARTY_SEX (Party Sex): The gender of the party
# 	Match 90: PARTY_AGE (Party Age): The age of the party at the time of the crash
# 	Match 91: RACE (Party Race): The party's race based on the reporting officer's judgment
# 	Match 92: PARTY_NUMBER_KILLED (Party Number Killed): Number of killed victims in the party
# 	Match 93: PARTY_NUMBER_INJURED (Party Number Injured): Number of injured victims in the party
# 	Match 94: INATTENTION (Inattention): Type of inattention
# 	Match 95: PARTY_SOBRIETY (Party Sobriety): The state of sobriety of the party
# 	Match 96: PARTY_DRUG_PHYSICAL (Party Drug Physical): The state of the party with regard to drugs and physical condition
# 	Match 97: DIR_OF_TRAVEL (Direction of Travel): Direction that the party was traveling at the time of the crash. The direction is the direction of the highway, not the compass direction
# 	Match 98: PARTY_SAFETY_EQUIP_1 (Party Safety Equipment 1): The safety equipment of the party
# 	Match 99: PARTY_SAFETY_EQUIP_2 (Party Safety Equipment 2): The safety equipment of the party
# 	Match 100: FINAN_RESPONS (Financial Responsibility): Financial responsibility of the party
# 	Match 101: SP_INFO_1 (Special Information 1): Value A indicates that the crash involved in a vehicle known to be, or believed to be, transporting a hazardous material as defined in CVC Section 353, whether or not the crash involved a hazardous material incident
# 	Match 102: SP_INFO_2 (Special Information 2): Cell Phone Information
# 	Match 103: SP_INFO_3 (Special Information 3): Value E indicates that the crash involved a motor vehicle in-transport passing a stopped school bus with its red signal lamps in operation pursuant to CVC Section 22112, or reacting to, pursuant to CVC Section 22454
# 	Match 104: OAF_VIOLATION_CODE (OAF Violation Code): Other associated factor law code violated
# 	Match 105: OAF_VIOL_CAT (OAF Violation Category): Category of the factor that contributed to the crash but was not the primary cause of the crash
# 	Match 106: OAF_VIOL_SECTION (OAF Violation Section): The CVC section of the secondary violation that contributed to the crash
# 	Match 107: OAF_VIOLATION_SUFFIX (OAF Violation Suffix): the subsection of the CVC section of the secondary violation that contributed to the crash
# 	Match 108: OAF_1 (Other Associated Factor 1): A factor that contributed to the crash but was not the primary cause of the crash
# 	Match 109: OAF_2 (Other Associated Factor 2): A factor that contributed to the crash but was not the primary cause of the crash
# 	Match 110: MOVE_PRE_ACC (Movement Preceding Crash): The action of the vehicle prior to the crash and before evasive action. This movement does not have to correspond with the PCF
# 	Match 111: VEHICLE_YEAR (Vehicle Year): The model year of the party's vehicle
# 	Match 112: VEHICLE_MAKE (Vehicle Make): The make of the party's vehicle
# 	Match 113: STWD_VEHICLE_TYPE (Statewide Vehicle Type): Type of the party's vehicle according to a list called statewide vehicle type
# 	Match 114: CHP_VEH_TYPE_TOWING (CHP Vehicle Type Towing): The type of the solitary vehicle or the tractor unit according to the CHP manual HPM 110.5 Chapter 3 Annex F vehicle type codes
# 	Match 115: CHP_VEH_TYPE_TOWED (CHP Vehicle Type Towed): The type of the first trailer unit according to the CHP manual HPM 110.5 Chapter 3 Annex F vehicle type codes
# 	Match 116: SPECIAL_INFO_F (Special Info F): The value F indicate that the party's vehicle is a 75ft motor truck combo
# 	Match 117: SPECIAL_INFO_G (Special Info G): The value G indicates that the party's vehicle is a 32ft trailer combo
# 	Match 127: CITY_AREA_SQMI (City Area (sq. miles)): City Area in Square Miles
# 	Match 128: CITY_POPDENS (City Population Density (per sq. mi)): City population density, population per square mile
# 	Match 129: CITY_HUDENS (City Housing Density (per sq. mi)): City housing density, houses per square mile
# 	Match 130: CITY_POPT (City Total Population): Total population in the city's area
# 	Match 131: CITY_HUT (City Total Housing Units): Total housing units in the city's area
# 	Match 132: CITY_POPA (City Asian Population): Total Asian population in the city's area
# 	Match 133: CITY_POPB (City Black Population): Total Black or African American population in the city's area
# 	Match 134: CITY_POPH (City Hispanic Population): Total Hispanic population in the city's area
# 	Match 135: CITY_POPW (City White Population): Total White population in the city's area
# 	Match 136: CITY_VEHICLES (City Aggregate Number of Vehicles Commuting): Aggregate number of vehicles used in commuting in the city's area
# 	Match 137: CITY_TRAVEL_TIME (City Aggregate Travel Time to Work (min)): Aggregate travel time to work (in minutes) in the city's area
# 	Match 138: RID (Road ID): Road ID matching from the road's layer
# 	Match 139: RNAME (Road Name): Road name from the OC Tiger/Lines layer
# 	Match 140: RCAT (Road Category): Road category from the OC Tiger/Lines layer
# 	Match 141: RLENGTH (Road Length): Road length from the OC Tiger/Lines layer
# 	Match 142: LATITUDE (GPS Latitude): Latitude of the crash location in decimal degrees. The decimal point is included. LATITUDE and LONGITUDE are from the crash report
# 	Match 143: LONGITUDE (GPS Longitude): Longitude of the crash location in decimal degrees. The decimal point is included. There is no minus sign. The longitude is understood to be West of Meridian. LATITUDE and LONGITUDE are from the crash report
# 	Match 144: POINT_X (X Coordinate Location): The longitude of the geocoded location, uses the World Geodetic System from 1984 (WGS84). POINT_X and POINT_Y are generated using the geociding process by UC Berkeley Safe TREC
# 	Match 145: POINT_Y (Y Coordinate Location): The latitude of the geocoded location, uses the World Geodetic System from 1984 (WGS84). POINT_X and POINT_Y are generated using the geociding process by UC Berkeley Safe TREC
# End: Wednesday November 13, 2024, 08:28 AM (PST). Elapsed time: 0:01:10

# %% [markdown]
# #### <font color="deepskyblue">Victims Table</font>

# %% [markdown]
# Field aliases for the Victims table

# %%
update_datetime("start")

# Field aliases for the Victims geodatabase table
print("Adding field aliases to the Victims table...")
for field in fieldsVictims:
    if field.name in list(codebook.keys()):
        print(f"\tMatch {codebook[field.name]['no']}: {field.name} ({codebook[field.name]['alias']}): {codebook[field.name]['desc']}")
        arcpy.management.AlterField(
            in_table = victimsTable,
            field = field.name,
            new_field_name = field.name,
            new_field_alias = codebook[field.name]["alias"]
        )
        #print(arcpy.GetMessages())
        
update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 08:28 AM (PST)
# Adding field aliases to the Victims table...
# 	Match 1: OBJECTID (Object ID): ESRI Object ID
# 	Match 4: CASE_ID (Case ID): Unique identifier of the crash case
# 	Match 5: CID (Crash ID): Unique identifier of the crash case
# 	Match 6: PID (Party ID): Unique identifier for the party case
# 	Match 7: VID (Victim ID): Unique identifier of the victim case
# 	Match 8: PARTY_NUMBER (Party Number): A number that together with the CASE_ID uniquely identifies a party in a crash
# 	Match 9: VICTIM_NUMBER (Victim Number): The unique identifier of the victim
# 	Match 13: CITY (City): Reported City of the crash
# 	Match 14: CITY_NAME (City Name): City name from locational query
# 	Match 15: PLACE_TYPE (Place Type): City or Unincorporated Area
# 	Match 16: COLLISION_DATETIME (Crash Date and Time): Full date and time string of the crash
# 	Match 17: COLLISION_DATE (Crash Date): The date when the crash occurred
# 	Match 18: COLLISION_TIME (Crash Time): The time when the crash occurred in 24h format
# 	Match 19: ACCIDENT_YEAR (Crash Year): The year when the crash occurred
# 	Match 20: COLLISION_MONTH (Crash Month): Month number from crash date
# 	Match 21: DAY_OF_WEEK (Day of Week): Code for the day of the week when the crash occurred
# 	Match 22: PROC_DATE (Processing Date): The date that the crash case was last changed
# 	Match 23: COLLISION_TIME_INTERVALS (Crash Time Intervals): Crash time interval ranges classification
# 	Match 24: COLLISION_TIME_RUSH_HOURS (Rush Hours): Rush hours interval ranges (Mon-Fri mornings and evenings)
# 	Match 25: COLLISION_SEVERITY (Crash Severity): The worst injury suffered by any victim in the crash
# 	Match 26: COLLISION_SEVERITY_BINARY (Crash Severity (Binary)): Binary classification of the worst injury suffered by any victim in the crash
# 	Match 27: COLLISION_SEVERITY_RECLASS (Crash Severity Reclassified): Reclassified crash severity based on the worst injury suffered by any victim in the crash
# 	Match 28: COLLISION_SEVERITY_RANKED (Crash Severity Ranked): Ranked crash severity based on the worst injury suffered by any victim in the crash
# 	Match 29: PARTY_COUNT (Party Count): Number of parties involved in the crash
# 	Match 30: VICTIM_COUNT (Victim Count): Number of victims involved in each party
# 	Match 31: NUMBER_KILLED (Killed victims): Number of killed victims
# 	Match 32: NUMBER_INJURED (Injured victims): Number of injured victims
# 	Match 33: COUNT_SEVERE_INJ (Severe Injury Count): Number of victims in the crash with suspected serous injury or severe injury
# 	Match 34: COUNT_VISIBLE_INJ (Other Visible Injury Count): Number of victims in the crash with suspected minor injury or visible injury
# 	Match 35: COUNT_COMPLAINT_PAIN (Complaint of Pain Injury Count): Number of victims in the crash with possible injury or complaint of pain
# 	Match 36: COUNT_PED_KILLED (Pedestrian Killed Count): Number of killed pedestrian victims
# 	Match 37: COUNT_PED_INJURED (Pedestrian Injured Count): Number of injured pedestrian victims
# 	Match 38: COUNT_BICYCLIST_KILLED (Bicyclist Killed Count): Number of killed bicyclists
# 	Match 39: COUNT_BICYCLIST_INJURED (Bicyclist Injured Count): Number of injured bicyclists
# 	Match 40: COUNT_MC_KILLED (Motorcyclist Killed Count): Number of killed motorcyclists
# 	Match 41: COUNT_MC_INJURED (Motorcyclist Injured Count): Number of injured motorcyclists
# 	Match 42: PRIMARY_COLL_FACTOR (Primary Crash Factor): The primary cause of the crash
# 	Match 43: TYPE_OF_COLLISION (Type of Crash): The general type of crash as determined by the first injury or damage-causing event
# 	Match 44: PEDESTRIAN_ACCIDENT (Pedestrian Crash): Indicates whether the crash involved a pedestrian
# 	Match 45: BICYCLE_ACCIDENT (Bicycle Crash): Indicates whether the crash involved a bicycle
# 	Match 46: MOTORCYCLE_ACCIDENT (Motorcycle Crash): Indicates whether the crash involved a motorcycle
# 	Match 47: TRUCK_ACCIDENT (Truck Crash): Indicates whether the crash involved a big truck
# 	Match 48: HIT_AND_RUN (Hit and Run): A flag to indicate the severity of hit-and-run crash. Felony hit-and-run resulted in injury or death to other parties. Misdemeanor hit-and-run did not result in injury or death to other parties
# 	Match 49: ALCOHOL_INVOLVED (Alcohol Involved): Indicates whether the crash involved a party that had been drinking. Note - a passenger does not count as a party
# 	Match 50: JURIS (Jurisdiction): Law enforcement agency that has jurisdiction over the crash
# 	Match 51: OFFICER_ID (Officer ID): The badge number of the officer who wrote the crash report
# 	Match 52: REPORTING_DISTRICT (Reporting District): Reporting District on the crash report
# 	Match 53: CHP_SHIFT (CHP Shift): CHP shift at the time of the crash
# 	Match 54: CNTY_CITY_LOC (County City Location): The city or unincorporated county where the crash occurred
# 	Match 55: SPECIAL_COND (Special Condition): A computed value. O means not private property
# 	Match 56: BEAT_TYPE (Beat Type): Location of crash based on beat
# 	Match 57: CHP_BEAT_TYPE (CHP Beat Type): Location of crash based on beat
# 	Match 58: CHP_BEAT_CLASS (CHP Beat Class): Location of crash based on beat
# 	Match 59: BEAT_NUMBER (Beat Number): Beat of the officer who reported the crash
# 	Match 60: PRIMARY_RD (Primary Road): The name of the roadway on which the crash occurred
# 	Match 61: SECONDARY_RD (Secondary Road): The name of the roadway that intersects the primary roadway
# 	Match 62: DISTANCE (Distance): Distance of the crash from the intersection with the secondary roadway in ft
# 	Match 63: DIRECTION (Direction): Direction of the crash from the intersection with the secondary roadway
# 	Match 64: INTERSECTION (Intersection): A flag that denotes if the crash occurred at the intersection with the secondary roadway
# 	Match 65: WEATHER_1 (Weather 1): Weather condition at the time of the crash
# 	Match 66: WEATHER_2 (Weather 2): Additional weather condition at the time of the crash
# 	Match 67: WEATHER_COMBINED (Combined Weather Conditions): Combined Weather Conditions from WEATHER_1 and WEATHER_2 fields in numeric codes by weather conditions severity
# 	Match 68: ROAD_SURFACE (Road Surface): Roadway surface condition at the time of the crash in the traffic lane(s) involved
# 	Match 69: ROAD_COND_1 (Road Condition 1): Roadway condition at the time of the crash in the traffic lane(s) involved
# 	Match 70: ROAD_COND_2 (Road Condition 2): Second roadway condition at the time of the crash in the traffic lane(s) involved
# 	Match 71: LIGHTING (Lighting): Lighting conditions at the crash location and the time of the crash
# 	Match 72: CONTROL_DEVICE (Control Device): Presence and condition of crash related traffic control devices at the time of the crash. Control devices include regulatory, warning, and construction sings. This excludes striping and officers or other persons directing traffic
# 	Match 73: STATE_HWY_IND (State Highway Indicator): A flag to indicate whether the crash is on or near a state highway
# 	Match 74: SIDE_OF_HWY (Side of Highway): Code provided by Caltrans Coders, applies to divided highway, based on nominal direction of route, for single vehicle is same as nominal direction of travel, overruled by impact with second vehicle after crossing median
# 	Match 75: TOW_AWAY (Tow Away): A flag to indicate whether the vehicle was towed away from the crash scene
# 	Match 76: PCF_CODE_OF_VIOL (PCF Violation Code): The law code that was violated and was the primary cause of the crash
# 	Match 77: PCF_VIOL_CATEGORY (PCF Violation Category): A value computed from the law section that was given as the primary cause of the crash
# 	Match 78: PCF_VIOLATION (PCF Violation): The law section given as the primary cause of the crash. The subsection is in the data element pcf_viol_subsection
# 	Match 79: PCF_VIOL_SUBSECTION (PCF Violation Subsection): The subsection of the law section given as the primary cause of the crash in the data element pcf_violation
# 	Match 80: MVIW (Motor Vehicle Involved With): Describes what, in conjunction with a motor vehicle in-transport, produced the first injury or damage-causing event, on or off the road
# 	Match 81: PED_ACTION (Ped Action): The action just prior to the crash of the first pedestrian injured or otherwise involved
# 	Match 82: NOT_PRIVATE_PROPERTY (Not Private Property): Y indicates that the crash did not occur on private property
# 	Match 83: STWD_VEHTYPE_AT_FAULT (Statewide Vehicle Type At Fault): Indicates the Statewide Vehicle Type of the party who is at fault
# 	Match 84: CHP_VEHTYPE_AT_FAULT (CHP Vehicle Type At Fault): Indicates the CHP Vehicle Type of the party whi is at fault
# 	Match 85: PRIMARY_RAMP (Primary Ramp): A description of the ramp, if any, on primary roadway. This value is computed by the key operator from information on the crash report
# 	Match 86: SECONDARY_RAMP (Secondary Ramp): A description of the ramp, if any, on secondary roadway. This value is computed by the key operator from information on the crash report
# 	Match 87: PARTY_TYPE (Party Type): Involved party type
# 	Match 88: AT_FAULT (At Fault): Indicates whether the party was at fault in the crash
# 	Match 89: PARTY_SEX (Party Sex): The gender of the party
# 	Match 90: PARTY_AGE (Party Age): The age of the party at the time of the crash
# 	Match 91: RACE (Party Race): The party's race based on the reporting officer's judgment
# 	Match 92: PARTY_NUMBER_KILLED (Party Number Killed): Number of killed victims in the party
# 	Match 93: PARTY_NUMBER_INJURED (Party Number Injured): Number of injured victims in the party
# 	Match 94: INATTENTION (Inattention): Type of inattention
# 	Match 95: PARTY_SOBRIETY (Party Sobriety): The state of sobriety of the party
# 	Match 96: PARTY_DRUG_PHYSICAL (Party Drug Physical): The state of the party with regard to drugs and physical condition
# 	Match 97: DIR_OF_TRAVEL (Direction of Travel): Direction that the party was traveling at the time of the crash. The direction is the direction of the highway, not the compass direction
# 	Match 98: PARTY_SAFETY_EQUIP_1 (Party Safety Equipment 1): The safety equipment of the party
# 	Match 99: PARTY_SAFETY_EQUIP_2 (Party Safety Equipment 2): The safety equipment of the party
# 	Match 100: FINAN_RESPONS (Financial Responsibility): Financial responsibility of the party
# 	Match 101: SP_INFO_1 (Special Information 1): Value A indicates that the crash involved in a vehicle known to be, or believed to be, transporting a hazardous material as defined in CVC Section 353, whether or not the crash involved a hazardous material incident
# 	Match 102: SP_INFO_2 (Special Information 2): Cell Phone Information
# 	Match 103: SP_INFO_3 (Special Information 3): Value E indicates that the crash involved a motor vehicle in-transport passing a stopped school bus with its red signal lamps in operation pursuant to CVC Section 22112, or reacting to, pursuant to CVC Section 22454
# 	Match 104: OAF_VIOLATION_CODE (OAF Violation Code): Other associated factor law code violated
# 	Match 105: OAF_VIOL_CAT (OAF Violation Category): Category of the factor that contributed to the crash but was not the primary cause of the crash
# 	Match 106: OAF_VIOL_SECTION (OAF Violation Section): The CVC section of the secondary violation that contributed to the crash
# 	Match 107: OAF_VIOLATION_SUFFIX (OAF Violation Suffix): the subsection of the CVC section of the secondary violation that contributed to the crash
# 	Match 108: OAF_1 (Other Associated Factor 1): A factor that contributed to the crash but was not the primary cause of the crash
# 	Match 109: OAF_2 (Other Associated Factor 2): A factor that contributed to the crash but was not the primary cause of the crash
# 	Match 110: MOVE_PRE_ACC (Movement Preceding Crash): The action of the vehicle prior to the crash and before evasive action. This movement does not have to correspond with the PCF
# 	Match 111: VEHICLE_YEAR (Vehicle Year): The model year of the party's vehicle
# 	Match 112: VEHICLE_MAKE (Vehicle Make): The make of the party's vehicle
# 	Match 113: STWD_VEHICLE_TYPE (Statewide Vehicle Type): Type of the party's vehicle according to a list called statewide vehicle type
# 	Match 114: CHP_VEH_TYPE_TOWING (CHP Vehicle Type Towing): The type of the solitary vehicle or the tractor unit according to the CHP manual HPM 110.5 Chapter 3 Annex F vehicle type codes
# 	Match 115: CHP_VEH_TYPE_TOWED (CHP Vehicle Type Towed): The type of the first trailer unit according to the CHP manual HPM 110.5 Chapter 3 Annex F vehicle type codes
# 	Match 116: SPECIAL_INFO_F (Special Info F): The value F indicate that the party's vehicle is a 75ft motor truck combo
# 	Match 117: SPECIAL_INFO_G (Special Info G): The value G indicates that the party's vehicle is a 32ft trailer combo
# 	Match 118: VICTIM_ROLE (Victim Role): The role of the victim
# 	Match 119: VICTIM_SEX (Victim Sex): The gender of the victim
# 	Match 120: VICTIM_AGE (Victim Age): The age of the victim at the time of the crash
# 	Match 121: VICTIM_DEGREE_OF_INJURY (Victim Degree of Injury): The severity of the injury to the victim
# 	Match 122: VICTIM_DEGREE_OF_INJURY_BINARY (Victim Injury Severity (Binary)): Binary classification of the severity of the injury to the victim
# 	Match 123: VICTIM_SEATING_POSITION (Victim Seating Position): The seating position of the victim
# 	Match 124: VICTIM_SAFETY_EQUIP_1 (Victim Safety Equipment 1): The safety equipment of the victim
# 	Match 125: VICTIM_SAFETY_EQUIP_2 (Victim Safety Equipment 2): The safety equipment of the victim
# 	Match 126: VICTIM_EJECTED (Victim Ejected): Indicates whether the victim was ejected from the vehicle
# 	Match 127: CITY_AREA_SQMI (City Area (sq. miles)): City Area in Square Miles
# 	Match 128: CITY_POPDENS (City Population Density (per sq. mi)): City population density, population per square mile
# 	Match 129: CITY_HUDENS (City Housing Density (per sq. mi)): City housing density, houses per square mile
# 	Match 130: CITY_POPT (City Total Population): Total population in the city's area
# 	Match 131: CITY_HUT (City Total Housing Units): Total housing units in the city's area
# 	Match 132: CITY_POPA (City Asian Population): Total Asian population in the city's area
# 	Match 133: CITY_POPB (City Black Population): Total Black or African American population in the city's area
# 	Match 134: CITY_POPH (City Hispanic Population): Total Hispanic population in the city's area
# 	Match 135: CITY_POPW (City White Population): Total White population in the city's area
# 	Match 136: CITY_VEHICLES (City Aggregate Number of Vehicles Commuting): Aggregate number of vehicles used in commuting in the city's area
# 	Match 137: CITY_TRAVEL_TIME (City Aggregate Travel Time to Work (min)): Aggregate travel time to work (in minutes) in the city's area
# 	Match 138: RID (Road ID): Road ID matching from the road's layer
# 	Match 139: RNAME (Road Name): Road name from the OC Tiger/Lines layer
# 	Match 140: RCAT (Road Category): Road category from the OC Tiger/Lines layer
# 	Match 141: RLENGTH (Road Length): Road length from the OC Tiger/Lines layer
# 	Match 142: LATITUDE (GPS Latitude): Latitude of the crash location in decimal degrees. The decimal point is included. LATITUDE and LONGITUDE are from the crash report
# 	Match 143: LONGITUDE (GPS Longitude): Longitude of the crash location in decimal degrees. The decimal point is included. There is no minus sign. The longitude is understood to be West of Meridian. LATITUDE and LONGITUDE are from the crash report
# 	Match 144: POINT_X (X Coordinate Location): The longitude of the geocoded location, uses the World Geodetic System from 1984 (WGS84). POINT_X and POINT_Y are generated using the geociding process by UC Berkeley Safe TREC
# 	Match 145: POINT_Y (Y Coordinate Location): The latitude of the geocoded location, uses the World Geodetic System from 1984 (WGS84). POINT_X and POINT_Y are generated using the geociding process by UC Berkeley Safe TREC
# End: Wednesday November 13, 2024, 08:29 AM (PST). Elapsed time: 0:01:15

# %% [markdown]
# #### <font color="deepskyblue">Collisions Table</font>

# %% [markdown]
# Field aliases for the Collisions table

# %%
update_datetime("start")

# Field aliases for the Collisions geodatabase table
print("Adding field aliases to the Collisions table...")
for field in fieldsCollisions:
    if field.name in list(codebook.keys()):
        print(f"\tMatch {codebook[field.name]['no']}: {field.name} ({codebook[field.name]['alias']}): {codebook[field.name]['desc']}")
        arcpy.management.AlterField(
            in_table = collisionsTable,
            field = field.name,
            new_field_name = field.name,
            new_field_alias = codebook[field.name]["alias"]
        )
        #print(arcpy.GetMessages())
        
update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 08:29 AM (PST)
# Adding field aliases to the Collisions table...
# 	Match 1: OBJECTID (Object ID): ESRI Object ID
# 	Match 4: CASE_ID (Case ID): Unique identifier of the crash case
# 	Match 5: CID (Crash ID): Unique identifier of the crash case
# 	Match 6: PID (Party ID): Unique identifier for the party case
# 	Match 7: VID (Victim ID): Unique identifier of the victim case
# 	Match 8: PARTY_NUMBER (Party Number): A number that together with the CASE_ID uniquely identifies a party in a crash
# 	Match 9: VICTIM_NUMBER (Victim Number): The unique identifier of the victim
# 	Match 13: CITY (City): Reported City of the crash
# 	Match 14: CITY_NAME (City Name): City name from locational query
# 	Match 15: PLACE_TYPE (Place Type): City or Unincorporated Area
# 	Match 16: COLLISION_DATETIME (Crash Date and Time): Full date and time string of the crash
# 	Match 17: COLLISION_DATE (Crash Date): The date when the crash occurred
# 	Match 18: COLLISION_TIME (Crash Time): The time when the crash occurred in 24h format
# 	Match 19: ACCIDENT_YEAR (Crash Year): The year when the crash occurred
# 	Match 20: COLLISION_MONTH (Crash Month): Month number from crash date
# 	Match 21: DAY_OF_WEEK (Day of Week): Code for the day of the week when the crash occurred
# 	Match 22: PROC_DATE (Processing Date): The date that the crash case was last changed
# 	Match 23: COLLISION_TIME_INTERVALS (Crash Time Intervals): Crash time interval ranges classification
# 	Match 24: COLLISION_TIME_RUSH_HOURS (Rush Hours): Rush hours interval ranges (Mon-Fri mornings and evenings)
# 	Match 25: COLLISION_SEVERITY (Crash Severity): The worst injury suffered by any victim in the crash
# 	Match 26: COLLISION_SEVERITY_BINARY (Crash Severity (Binary)): Binary classification of the worst injury suffered by any victim in the crash
# 	Match 27: COLLISION_SEVERITY_RECLASS (Crash Severity Reclassified): Reclassified crash severity based on the worst injury suffered by any victim in the crash
# 	Match 28: COLLISION_SEVERITY_RANKED (Crash Severity Ranked): Ranked crash severity based on the worst injury suffered by any victim in the crash
# 	Match 29: PARTY_COUNT (Party Count): Number of parties involved in the crash
# 	Match 30: VICTIM_COUNT (Victim Count): Number of victims involved in each party
# 	Match 31: NUMBER_KILLED (Killed victims): Number of killed victims
# 	Match 32: NUMBER_INJURED (Injured victims): Number of injured victims
# 	Match 33: COUNT_SEVERE_INJ (Severe Injury Count): Number of victims in the crash with suspected serous injury or severe injury
# 	Match 34: COUNT_VISIBLE_INJ (Other Visible Injury Count): Number of victims in the crash with suspected minor injury or visible injury
# 	Match 35: COUNT_COMPLAINT_PAIN (Complaint of Pain Injury Count): Number of victims in the crash with possible injury or complaint of pain
# 	Match 36: COUNT_PED_KILLED (Pedestrian Killed Count): Number of killed pedestrian victims
# 	Match 37: COUNT_PED_INJURED (Pedestrian Injured Count): Number of injured pedestrian victims
# 	Match 38: COUNT_BICYCLIST_KILLED (Bicyclist Killed Count): Number of killed bicyclists
# 	Match 39: COUNT_BICYCLIST_INJURED (Bicyclist Injured Count): Number of injured bicyclists
# 	Match 40: COUNT_MC_KILLED (Motorcyclist Killed Count): Number of killed motorcyclists
# 	Match 41: COUNT_MC_INJURED (Motorcyclist Injured Count): Number of injured motorcyclists
# 	Match 42: PRIMARY_COLL_FACTOR (Primary Crash Factor): The primary cause of the crash
# 	Match 43: TYPE_OF_COLLISION (Type of Crash): The general type of crash as determined by the first injury or damage-causing event
# 	Match 44: PEDESTRIAN_ACCIDENT (Pedestrian Crash): Indicates whether the crash involved a pedestrian
# 	Match 45: BICYCLE_ACCIDENT (Bicycle Crash): Indicates whether the crash involved a bicycle
# 	Match 46: MOTORCYCLE_ACCIDENT (Motorcycle Crash): Indicates whether the crash involved a motorcycle
# 	Match 47: TRUCK_ACCIDENT (Truck Crash): Indicates whether the crash involved a big truck
# 	Match 48: HIT_AND_RUN (Hit and Run): A flag to indicate the severity of hit-and-run crash. Felony hit-and-run resulted in injury or death to other parties. Misdemeanor hit-and-run did not result in injury or death to other parties
# 	Match 49: ALCOHOL_INVOLVED (Alcohol Involved): Indicates whether the crash involved a party that had been drinking. Note - a passenger does not count as a party
# 	Match 50: JURIS (Jurisdiction): Law enforcement agency that has jurisdiction over the crash
# 	Match 51: OFFICER_ID (Officer ID): The badge number of the officer who wrote the crash report
# 	Match 52: REPORTING_DISTRICT (Reporting District): Reporting District on the crash report
# 	Match 53: CHP_SHIFT (CHP Shift): CHP shift at the time of the crash
# 	Match 54: CNTY_CITY_LOC (County City Location): The city or unincorporated county where the crash occurred
# 	Match 55: SPECIAL_COND (Special Condition): A computed value. O means not private property
# 	Match 56: BEAT_TYPE (Beat Type): Location of crash based on beat
# 	Match 57: CHP_BEAT_TYPE (CHP Beat Type): Location of crash based on beat
# 	Match 58: CHP_BEAT_CLASS (CHP Beat Class): Location of crash based on beat
# 	Match 59: BEAT_NUMBER (Beat Number): Beat of the officer who reported the crash
# 	Match 60: PRIMARY_RD (Primary Road): The name of the roadway on which the crash occurred
# 	Match 61: SECONDARY_RD (Secondary Road): The name of the roadway that intersects the primary roadway
# 	Match 62: DISTANCE (Distance): Distance of the crash from the intersection with the secondary roadway in ft
# 	Match 63: DIRECTION (Direction): Direction of the crash from the intersection with the secondary roadway
# 	Match 64: INTERSECTION (Intersection): A flag that denotes if the crash occurred at the intersection with the secondary roadway
# 	Match 65: WEATHER_1 (Weather 1): Weather condition at the time of the crash
# 	Match 66: WEATHER_2 (Weather 2): Additional weather condition at the time of the crash
# 	Match 67: WEATHER_COMBINED (Combined Weather Conditions): Combined Weather Conditions from WEATHER_1 and WEATHER_2 fields in numeric codes by weather conditions severity
# 	Match 68: ROAD_SURFACE (Road Surface): Roadway surface condition at the time of the crash in the traffic lane(s) involved
# 	Match 69: ROAD_COND_1 (Road Condition 1): Roadway condition at the time of the crash in the traffic lane(s) involved
# 	Match 70: ROAD_COND_2 (Road Condition 2): Second roadway condition at the time of the crash in the traffic lane(s) involved
# 	Match 71: LIGHTING (Lighting): Lighting conditions at the crash location and the time of the crash
# 	Match 72: CONTROL_DEVICE (Control Device): Presence and condition of crash related traffic control devices at the time of the crash. Control devices include regulatory, warning, and construction sings. This excludes striping and officers or other persons directing traffic
# 	Match 73: STATE_HWY_IND (State Highway Indicator): A flag to indicate whether the crash is on or near a state highway
# 	Match 74: SIDE_OF_HWY (Side of Highway): Code provided by Caltrans Coders, applies to divided highway, based on nominal direction of route, for single vehicle is same as nominal direction of travel, overruled by impact with second vehicle after crossing median
# 	Match 75: TOW_AWAY (Tow Away): A flag to indicate whether the vehicle was towed away from the crash scene
# 	Match 76: PCF_CODE_OF_VIOL (PCF Violation Code): The law code that was violated and was the primary cause of the crash
# 	Match 77: PCF_VIOL_CATEGORY (PCF Violation Category): A value computed from the law section that was given as the primary cause of the crash
# 	Match 78: PCF_VIOLATION (PCF Violation): The law section given as the primary cause of the crash. The subsection is in the data element pcf_viol_subsection
# 	Match 79: PCF_VIOL_SUBSECTION (PCF Violation Subsection): The subsection of the law section given as the primary cause of the crash in the data element pcf_violation
# 	Match 80: MVIW (Motor Vehicle Involved With): Describes what, in conjunction with a motor vehicle in-transport, produced the first injury or damage-causing event, on or off the road
# 	Match 81: PED_ACTION (Ped Action): The action just prior to the crash of the first pedestrian injured or otherwise involved
# 	Match 82: NOT_PRIVATE_PROPERTY (Not Private Property): Y indicates that the crash did not occur on private property
# 	Match 83: STWD_VEHTYPE_AT_FAULT (Statewide Vehicle Type At Fault): Indicates the Statewide Vehicle Type of the party who is at fault
# 	Match 84: CHP_VEHTYPE_AT_FAULT (CHP Vehicle Type At Fault): Indicates the CHP Vehicle Type of the party whi is at fault
# 	Match 85: PRIMARY_RAMP (Primary Ramp): A description of the ramp, if any, on primary roadway. This value is computed by the key operator from information on the crash report
# 	Match 86: SECONDARY_RAMP (Secondary Ramp): A description of the ramp, if any, on secondary roadway. This value is computed by the key operator from information on the crash report
# 	Match 87: PARTY_TYPE (Party Type): Involved party type
# 	Match 88: AT_FAULT (At Fault): Indicates whether the party was at fault in the crash
# 	Match 89: PARTY_SEX (Party Sex): The gender of the party
# 	Match 90: PARTY_AGE (Party Age): The age of the party at the time of the crash
# 	Match 91: RACE (Party Race): The party's race based on the reporting officer's judgment
# 	Match 92: PARTY_NUMBER_KILLED (Party Number Killed): Number of killed victims in the party
# 	Match 93: PARTY_NUMBER_INJURED (Party Number Injured): Number of injured victims in the party
# 	Match 94: INATTENTION (Inattention): Type of inattention
# 	Match 95: PARTY_SOBRIETY (Party Sobriety): The state of sobriety of the party
# 	Match 96: PARTY_DRUG_PHYSICAL (Party Drug Physical): The state of the party with regard to drugs and physical condition
# 	Match 97: DIR_OF_TRAVEL (Direction of Travel): Direction that the party was traveling at the time of the crash. The direction is the direction of the highway, not the compass direction
# 	Match 98: PARTY_SAFETY_EQUIP_1 (Party Safety Equipment 1): The safety equipment of the party
# 	Match 99: PARTY_SAFETY_EQUIP_2 (Party Safety Equipment 2): The safety equipment of the party
# 	Match 100: FINAN_RESPONS (Financial Responsibility): Financial responsibility of the party
# 	Match 101: SP_INFO_1 (Special Information 1): Value A indicates that the crash involved in a vehicle known to be, or believed to be, transporting a hazardous material as defined in CVC Section 353, whether or not the crash involved a hazardous material incident
# 	Match 102: SP_INFO_2 (Special Information 2): Cell Phone Information
# 	Match 103: SP_INFO_3 (Special Information 3): Value E indicates that the crash involved a motor vehicle in-transport passing a stopped school bus with its red signal lamps in operation pursuant to CVC Section 22112, or reacting to, pursuant to CVC Section 22454
# 	Match 104: OAF_VIOLATION_CODE (OAF Violation Code): Other associated factor law code violated
# 	Match 105: OAF_VIOL_CAT (OAF Violation Category): Category of the factor that contributed to the crash but was not the primary cause of the crash
# 	Match 106: OAF_VIOL_SECTION (OAF Violation Section): The CVC section of the secondary violation that contributed to the crash
# 	Match 107: OAF_VIOLATION_SUFFIX (OAF Violation Suffix): the subsection of the CVC section of the secondary violation that contributed to the crash
# 	Match 108: OAF_1 (Other Associated Factor 1): A factor that contributed to the crash but was not the primary cause of the crash
# 	Match 109: OAF_2 (Other Associated Factor 2): A factor that contributed to the crash but was not the primary cause of the crash
# 	Match 110: MOVE_PRE_ACC (Movement Preceding Crash): The action of the vehicle prior to the crash and before evasive action. This movement does not have to correspond with the PCF
# 	Match 111: VEHICLE_YEAR (Vehicle Year): The model year of the party's vehicle
# 	Match 112: VEHICLE_MAKE (Vehicle Make): The make of the party's vehicle
# 	Match 113: STWD_VEHICLE_TYPE (Statewide Vehicle Type): Type of the party's vehicle according to a list called statewide vehicle type
# 	Match 114: CHP_VEH_TYPE_TOWING (CHP Vehicle Type Towing): The type of the solitary vehicle or the tractor unit according to the CHP manual HPM 110.5 Chapter 3 Annex F vehicle type codes
# 	Match 115: CHP_VEH_TYPE_TOWED (CHP Vehicle Type Towed): The type of the first trailer unit according to the CHP manual HPM 110.5 Chapter 3 Annex F vehicle type codes
# 	Match 116: SPECIAL_INFO_F (Special Info F): The value F indicate that the party's vehicle is a 75ft motor truck combo
# 	Match 117: SPECIAL_INFO_G (Special Info G): The value G indicates that the party's vehicle is a 32ft trailer combo
# 	Match 118: VICTIM_ROLE (Victim Role): The role of the victim
# 	Match 119: VICTIM_SEX (Victim Sex): The gender of the victim
# 	Match 120: VICTIM_AGE (Victim Age): The age of the victim at the time of the crash
# 	Match 121: VICTIM_DEGREE_OF_INJURY (Victim Degree of Injury): The severity of the injury to the victim
# 	Match 122: VICTIM_DEGREE_OF_INJURY_BINARY (Victim Injury Severity (Binary)): Binary classification of the severity of the injury to the victim
# 	Match 123: VICTIM_SEATING_POSITION (Victim Seating Position): The seating position of the victim
# 	Match 124: VICTIM_SAFETY_EQUIP_1 (Victim Safety Equipment 1): The safety equipment of the victim
# 	Match 125: VICTIM_SAFETY_EQUIP_2 (Victim Safety Equipment 2): The safety equipment of the victim
# 	Match 126: VICTIM_EJECTED (Victim Ejected): Indicates whether the victim was ejected from the vehicle
# 	Match 127: CITY_AREA_SQMI (City Area (sq. miles)): City Area in Square Miles
# 	Match 128: CITY_POPDENS (City Population Density (per sq. mi)): City population density, population per square mile
# 	Match 129: CITY_HUDENS (City Housing Density (per sq. mi)): City housing density, houses per square mile
# 	Match 130: CITY_POPT (City Total Population): Total population in the city's area
# 	Match 131: CITY_HUT (City Total Housing Units): Total housing units in the city's area
# 	Match 132: CITY_POPA (City Asian Population): Total Asian population in the city's area
# 	Match 133: CITY_POPB (City Black Population): Total Black or African American population in the city's area
# 	Match 134: CITY_POPH (City Hispanic Population): Total Hispanic population in the city's area
# 	Match 135: CITY_POPW (City White Population): Total White population in the city's area
# 	Match 136: CITY_VEHICLES (City Aggregate Number of Vehicles Commuting): Aggregate number of vehicles used in commuting in the city's area
# 	Match 137: CITY_TRAVEL_TIME (City Aggregate Travel Time to Work (min)): Aggregate travel time to work (in minutes) in the city's area
# 	Match 138: RID (Road ID): Road ID matching from the road's layer
# 	Match 139: RNAME (Road Name): Road name from the OC Tiger/Lines layer
# 	Match 140: RCAT (Road Category): Road category from the OC Tiger/Lines layer
# 	Match 141: RLENGTH (Road Length): Road length from the OC Tiger/Lines layer
# 	Match 142: LATITUDE (GPS Latitude): Latitude of the crash location in decimal degrees. The decimal point is included. LATITUDE and LONGITUDE are from the crash report
# 	Match 143: LONGITUDE (GPS Longitude): Longitude of the crash location in decimal degrees. The decimal point is included. There is no minus sign. The longitude is understood to be West of Meridian. LATITUDE and LONGITUDE are from the crash report
# 	Match 144: POINT_X (X Coordinate Location): The longitude of the geocoded location, uses the World Geodetic System from 1984 (WGS84). POINT_X and POINT_Y are generated using the geociding process by UC Berkeley Safe TREC
# 	Match 145: POINT_Y (Y Coordinate Location): The latitude of the geocoded location, uses the World Geodetic System from 1984 (WGS84). POINT_X and POINT_Y are generated using the geociding process by UC Berkeley Safe TREC
# End: Wednesday November 13, 2024, 08:31 AM (PST). Elapsed time: 0:01:14

# %% [markdown]
# Save the ArcGIS Pro project

# %%
# Save the project
aprx.save()

# %% [markdown]
# ## <font color="coral">**Geodatabase Tables to Point Feature Classes**</font>

# %% [markdown]
# ### <font color="lime">**Tables to Point Features Conversion**</font>

# %% [markdown]
# In this section we will convert the geodatabase tables to point feature classes.

# %% [markdown]
# First, we will geocode the tables to create point feature classes for the Crashes, Parties, Victims, and Collisions tables from the X and Y coordinates.

# %% [markdown]
# #### <font color="deepskyblue">Geocoding Crashes Table</font>

# %% [markdown]
# Processing Crashes table

# %%
update_datetime("start")

print("Creating a point feature class from the X and Y coordinates of the Crashes table")
# Crashes table to point feature
arcpy.management.XYTableToPoint(
    in_table = crashesTable,
    out_feature_class = os.path.join(workspace, "CrashesPoints"),
    x_field = "POINT_X",
    y_field = "POINT_Y",
    z_field = None,
    coordinate_system = arcpy.SpatialReference(4326)
)
print(arcpy.GetMessages())

update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 08:31 AM (PST)
# Creating a point feature class from the X and Y coordinates of the Crashes table
# Start Time: Wednesday, November 13, 2024 8:31:10 AM
# Succeeded at Wednesday, November 13, 2024 8:31:29 AM (Elapsed Time: 19.01 seconds)
# End: Wednesday November 13, 2024, 08:31 AM (PST). Elapsed time: 0:00:19

# %% [markdown]
# #### <font color="deepskyblue">Geocoding Parties Table</font>

# %% [markdown]
# Processing Parties table

# %%
update_datetime("start")

print("Creating a point feature class from the X and Y coordinates of the Parties table")
# Parties table to point feature
arcpy.management.XYTableToPoint(
    in_table = partiesTable,
    out_feature_class = os.path.join(workspace, "PartiesPoints"),
    x_field = "POINT_X",
    y_field = "POINT_Y",
    z_field = None,
    coordinate_system = arcpy.SpatialReference(4326)
)
print(arcpy.GetMessages())

update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 08:31 AM (PST)
# Creating a point feature class from the X and Y coordinates of the Parties table
# Start Time: Wednesday, November 13, 2024 8:31:29 AM
# Succeeded at Wednesday, November 13, 2024 8:32:13 AM (Elapsed Time: 43.98 seconds)
# End: Wednesday November 13, 2024, 08:32 AM (PST). Elapsed time: 0:00:44

# %% [markdown]
# #### <font color="deepskyblue">Geocoding Victims Table</font>

# %% [markdown]
# Processing Victims table

# %%
update_datetime("start")

print("Creating a point feature class from the X and Y coordinates of the Victims table")
# Victims table to point feature
arcpy.management.XYTableToPoint(
    in_table = victimsTable,
    out_feature_class = os.path.join(workspace, "VictimsPoints"),
    x_field = "POINT_X",
    y_field = "POINT_Y",
    z_field = None,
    coordinate_system = arcpy.SpatialReference(4326)
)
print(arcpy.GetMessages())

update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 08:32 AM (PST)
# Creating a point feature class from the X and Y coordinates of the Victi table
# Start Time: Wednesday, November 13, 2024 8:32:14 AM
# Succeeded at Wednesday, November 13, 2024 8:32:50 AM (Elapsed Time: 35.79 seconds)
# End: Wednesday November 13, 2024, 08:32 AM (PST). Elapsed time: 0:00:36

# %% [markdown]
# #### <font color="deepskyblue">Geocoding Collisions Table</font>

# %% [markdown]
# Processing Collisions table

# %%
update_datetime("start")

print("Creating a point feature class from the X and Y coordinates of the Collisions table")
# Collisions table to point feature
arcpy.management.XYTableToPoint(
    in_table = collisionsTable,
    out_feature_class = os.path.join(workspace, "CollisionsPoints"),
    x_field = "POINT_X",
    y_field = "POINT_Y",
    z_field = None,
    coordinate_system = arcpy.SpatialReference(4326)
)
print(arcpy.GetMessages())

update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 08:32 AM (PST)
# Creating a point feature class from the X and Y coordinates of the Collisions table
# Start Time: Wednesday, November 13, 2024 8:32:50 AM
# Succeeded at Wednesday, November 13, 2024 8:33:25 AM (Elapsed Time: 35.52 seconds)
# End: Wednesday November 13, 2024, 08:33 AM (PST). Elapsed time: 0:00:35

# %% [markdown]
# Save the ArcGIS Pro project

# %%
# Save the project
aprx.save()

# %% [markdown]
# ### <font color="lime">**Creating Dataset Indicators for Collisions**</font>

# %% [markdown]
# Adding indicator fields to Collisions feature class

# %%
update_datetime("start")

print("Adding new fields to the Crashes table")
# Adding new fields to the Collisions table
arcpy.management.AddFields(
    in_table = os.path.join(workspace, "CollisionsPoints"),
    field_description = "CRASHES_INDICATOR LONG 'Crashes Dataset Indicator' # # #;PARTIES_INDICATOR LONG 'Parties Dataset Indicator' # # #;VICTIMS_INDICATOR LONG 'Victims Dataset Indicator' # # #",
    template = None
)
print(arcpy.GetMessages())

update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 08:33 AM (PST)
# Adding new fields to the Crashes table
# Start Time: Wednesday, November 13, 2024 8:33:30 AM
# Adding CRASHES_INDICATOR to CollisionsPoints...
# Adding PARTIES_INDICATOR to CollisionsPoints...
# Adding VICTIMS_INDICATOR to CollisionsPoints...
# Succeeded at Wednesday, November 13, 2024 8:33:31 AM (Elapsed Time: 0.71 seconds)
# End: Wednesday November 13, 2024, 08:33 AM (PST). Elapsed time: 0:00:01

# %% [markdown]
# #### <font color="deepskyblue">Calculating Victims indicator field</font>

# %% [markdown]
# - **Condition**: if VID is not empty, then set indicator value to 1, otherwise set indicator value to 0
# - **Result**: gives all cases identifying unique victims records in the Collisions feature class

# %%
update_datetime("start")

print("Calculating new fields in the Crashes table")
# Calculate new fields in the Collisions table
arcpy.management.CalculateField(
    in_table = os.path.join(workspace, "CollisionsPoints"),
    field = "VICTIMS_INDICATOR",
    expression = "vind(!VID!)",
    expression_type = "PYTHON3",
    code_block = """def vind(x):
    if x != "":
        return 1
    else:
        return 0""",
    field_type = "TEXT",
    enforce_domains= "NO_ENFORCE_DOMAINS"
)
print(arcpy.GetMessages())

update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 08:33 AM (PST)
# Calculating new fields in the Crashes table
# Start Time: Wednesday, November 13, 2024 8:33:36 AM
# Succeeded at Wednesday, November 13, 2024 8:34:29 AM (Elapsed Time: 53.22 seconds)
# End: Wednesday November 13, 2024, 08:34 AM (PST). Elapsed time: 0:00:53

# %% [markdown]
# #### <font color="deepskyblue">Calculating Parties indicator field</font>

# %% [markdown]
# - **Condition**: if Victim Number is 1 or None, set indicator value to 1, otherwise set indicator value to 0
# - **Result**: gives all cases identifying unique parties records in the Collisions feature class

# %%
update_datetime("start")

print("Adding new fields to the Collisions table")
# Calculate new fields in the Collisions table
arcpy.management.CalculateField(
    in_table = os.path.join(workspace, "CollisionsPoints"),
    field = "PARTIES_INDICATOR",
    expression = "pind(!VICTIM_NUMBER!)",
    expression_type = "PYTHON3",
    code_block="""def pind(x):
    if x == 1 or x==None:
        return 1
    else:
        return 0""",
    field_type = "TEXT",
    enforce_domains= "NO_ENFORCE_DOMAINS"
)
print(arcpy.GetMessages())

update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 08:34 AM (PST)
# Adding new fields to the Collisions table
# Start Time: Wednesday, November 13, 2024 8:34:29 AM
# Succeeded at Wednesday, November 13, 2024 8:35:22 AM (Elapsed Time: 53.17 seconds)
# End: Wednesday November 13, 2024, 08:35 AM (PST). Elapsed time: 0:00:53

# %% [markdown]
# #### <font color="deepskyblue">Calculating Crashes indicator field</font>

# %% [markdown]
# - **Condition**: if Party Number is 1 and Victim Number is either 1 or None, set indicator value to 1, otherwise set indicator value to 0
# - **Result**: gives all cases identifying unique crashes records in the Collisions feature class

# %%
update_datetime("start")

print("Calculating new fields in the Collisions table")
# Calculate new fields in the Collisions table
arcpy.management.CalculateField(
    in_table = os.path.join(workspace, "CollisionsPoints"),
    field = "CRASHES_INDICATOR",
    expression = "cind(!PARTY_NUMBER!,!VICTIM_NUMBER!)",
    expression_type = "PYTHON3",
    code_block="""def cind(x,y):
    if x == 1:
        if y == 1 or y == None:
            return 1
    else:
        return 0""",
    field_type = "TEXT",
    enforce_domains= "NO_ENFORCE_DOMAINS"
)
print(arcpy.GetMessages())

update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 08:35 AM (PST)
# Calculating new fields in the Collisions table
# Start Time: Wednesday, November 13, 2024 8:35:23 AM
# Succeeded at Wednesday, November 13, 2024 8:36:16 AM (Elapsed Time: 53.62 seconds)
# End: Wednesday November 13, 2024, 08:36 AM (PST). Elapsed time: 0:00:53

# %% [markdown]
# Update the field list and field mappings for the Collisions feature class

# %%
# Update fields in the Collisions table
fieldsCollisions = arcpy.ListFields(collisionsTable)

# Update the mappings for the Collisions table
mappingCollisions = get_field_mappings(codebook, fieldsCollisions, collisionsTable)

# %% [markdown]
# Save the ArcGIS Pro project

# %%
# Save the project
aprx.save()

# %% [markdown]
# ### <font color="lime">**Obtaining data paths, locations and field tables**</font>

# %% [markdown]
# In this section we will obtain the paths, locations, and field tables for the feature classes.

# %% [markdown]
# Get a list of geodatabase tables

# %%
# List all tables in the geodatabase
gdbTables = arcpy.ListTables()
print(f"Geodatabase Tables: {gdbTables}")
# Out:
# Geodatabase Tables: ['CrashesTable', 'PartiesTable', 'VictimsTable', 'CollisionsTable']

# %% [markdown]
# Obtain the list of point feature classes from the geodatabase

# %%
# List all feature classes in the geodatabase root
gdbFeatureClasses = arcpy.ListFeatureClasses(feature_type="Point")
print(f"Geodatabase Point Feature Classes: {gdbFeatureClasses}")

# Get the feature classes by name
crashesPoints = arcpy.ListFeatureClasses("CrashesPoints")[0]
partiesPoints = arcpy.ListFeatureClasses("PartiesPoints")[0]
victimsPoints = arcpy.ListFeatureClasses("VictimsPoints")[0]
collisionsPoints = arcpy.ListFeatureClasses("CollisionsPoints")[0]
# Out:
# Geodatabase Point Feature Classes: ['CrashesPoints', 'PartiesPoints', 'VictimsPoints', 'CollisionsPoints']

# %% [markdown]
# Format the feature class paths for the four levels

# %%
# Get the paths of each of the layers: Crashes, Parties, Victims, Collisions
crashesPointsPath = os.path.join(workspace, crashesPoints)
partiesPointsPath = os.path.join(workspace, partiesPoints)
victimsPointsPath = os.path.join(workspace, victimsPoints)
collisionsPointsPath = os.path.join(workspace, collisionsPoints)

print(f"Feature Paths:\n- Crashes: {crashesPointsPath}\n- Parties: {partiesPointsPath}\n- Victims: {victimsPointsPath}\n- Collisions: {collisionsPointsPath}\n")
# Out:
# Feature Paths:
# - Crashes: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\CrashesPoints
# - Parties: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\PartiesPoints
# - Victims: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\VictimsPoints
# - Collisions: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\CollisionsPoints

# %% [markdown]
# Get the field lists for the four feature classes

# %%
# Get the field list for each of the feature classes
crashesPointsFields = arcpy.ListFields(crashesPointsPath)
partiesPointsFields = arcpy.ListFields(partiesPointsPath)
victimsPointsFields = arcpy.ListFields(victimsPointsPath)
collisionsPointsFields = arcpy.ListFields(collisionsPointsPath)

# %% [markdown]
# Get the row counts for the four feature classes

# %%
# Obtain the row counts for each of the feature classes
countCrashesPoints = int(arcpy.management.GetCount(crashesPointsPath)[0])
countPartiesPoints = int(arcpy.management.GetCount(partiesPointsPath)[0])
countVictimsPoints = int(arcpy.management.GetCount(victimsPointsPath)[0])
countCollisionsPoints = int(arcpy.management.GetCount(collisionsPointsPath)[0])

print(f"Point Feature Counts:\n- Crashes: {countCrashesPoints:,}\n- Parties: {countPartiesPoints:,}\n- Victims: {countVictimsPoints:,}\n- Collisions: {countCollisionsPoints:,}")
# Out:
# Point Feature Counts:
# - Crashes: 149,764
# - Parties: 323,542
# - Victims: 260,120
# - Collisions: 260,120

# %% [markdown]
# Update the field mappings for the four feature classes

# %%
mappingCrashesPoints = get_field_mappings(codebook, crashesPointsFields, crashesPointsPath)
mappingPartiesPoints = get_field_mappings(codebook, partiesPointsFields, partiesPointsPath)
mappingVictimsPoints = get_field_mappings(codebook, victimsPointsFields, victimsPointsPath)
mappingCollisionsPoints = get_field_mappings(codebook, collisionsPointsFields, collisionsPointsPath)

# %% [markdown]
# Modifying the field types for the four feature classes

# %%
print("Crashes: Modifying codebook field types...")
modify_agp_types(codebook, crashesPointsFields)
# Out:
# Crashes: Modifying codebook field types...
# {'OBJECTID': {'no': 1,
#   'level': 'GIS',
#   'alias': 'Object ID',
#   'desc': 'ESRI Object ID',
#   'type': 'OID',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'GlobalID': {'no': 2,
#   'level': 'GIS',
#   'alias': 'Global ID',
#   'desc': 'ESRI Global ID string identifier',
#   'type': 'GlobalID',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'GUID': {'no': 3,
#   'level': 'GIS',
#   'alias': 'GUID Related Table Identifier',
#   'desc': 'ESRI GUID to be used in merging related tables',
#   'type': 'Guid',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'CASE_ID': {'no': 4,
#   'level': 'Crash',
#   'alias': 'Case ID',
#   'desc': 'Unique identifier of the crash case',
#   'type': 'LONG',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'CID': {'no': 5,
#   'level': 'Crash',
#   'alias': 'Crash ID',
#   'desc': 'Unique identifier of the crash case',
#   'type': 'TEXT',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'PID': {'no': 6,
#   'level': 'Party',
#   'alias': 'Party ID',
#   'desc': 'Unique identifier for the party case',
#   'type': 'TEXT',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'VID': {'no': 7,
#   'level': 'Victim',
#   'alias': 'Victim ID',
#   'desc': 'Unique identifier of the victim case',
#   'type': 'TEXT',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'PARTY_NUMBER': {'no': 8,
#   'level': 'Party',
#   'alias': 'Party Number',
#   'desc': 'A number that together with the CASE_ID uniquely identifies a party in a crash',
#   'type': 'LONG',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'VICTIM_NUMBER': {'no': 9,
#   'level': 'Victim',
#   'alias': 'Victim Number',
#   'desc': 'The unique identifier of the victim',
#   'type': 'LONG',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'CRASHES_INDICATOR': {'no': 10,
#   'level': 'Crash',
#   'alias': 'Crashes Binary Indicator',
#   'desc': 'Binary flag, 1 if the record is a crash, 0 if not',
#   'type': 'LONG',
#   'cat': 'Binary',
#   'dbin': 'N'},
#  'PARTIES_INDICATOR': {'no': 11,
#   'level': 'Party',
#   'alias': 'Parties Binary Indicator',
#   'desc': 'Binary flag, 1 if the record is a party, 0 if not',
#   'type': 'LONG',
#   'cat': 'Binary',
#   'dbin': 'N'},
#  'VICTIMS_INDICATOR': {'no': 12,
#   'level': 'Victim',
#   'alias': 'Victims Binary Indicator',
#   'desc': 'Binary flag, 1 if the record is a victim, 0 if not',
#   'type': 'LONG',
#   'cat': 'Binary',
#   'dbin': 'N'},
#  'CITY': {'no': 13,
#   'level': 'City',
#   'alias': 'City',
#   'desc': 'Reported City of the crash',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'CITY_NAME': {'no': 14,
#   'level': 'City',
#   'alias': 'City Name',
#   'desc': 'City name from locational query',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'PLACE_TYPE': {'no': 15,
#   'level': 'City',
#   'alias': 'Place Type',
#   'desc': 'City or Unincorporated Area',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'COLLISION_DATETIME': {'no': 16,
#   'level': 'Crash',
#   'alias': 'Crash Date and Time',
#   'desc': 'Full date and time string of the crash',
#   'type': 'DATE',
#   'cat': 'Date and Time',
#   'dbin': 'N'},
#  'COLLISION_DATE': {'no': 17,
#   'level': 'Crash',
#   'alias': 'Crash Date',
#   'desc': 'The date when the crash occurred',
#   'type': 'DATE',
#   'cat': 'Date and Time',
#   'dbin': 'N'},
#  'COLLISION_TIME': {'no': 18,
#   'level': 'Crash',
#   'alias': 'Crash Time',
#   'desc': 'The time when the crash occurred in 24h format',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'N'},
#  'ACCIDENT_YEAR': {'no': 19,
#   'level': 'Crash',
#   'alias': 'Crash Year',
#   'desc': 'The year when the crash occurred',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'N'},
#  'COLLISION_MONTH': {'no': 20,
#   'level': 'Crash',
#   'alias': 'Crash Month',
#   'desc': 'Month number from crash date',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'January',
#    '2': 'February',
#    '3': 'March',
#    '4': 'April',
#    '5': 'May',
#    '6': 'June',
#    '7': 'July',
#    '8': 'August',
#    '9': 'September',
#    '10': 'October',
#    '11': 'November',
#    '12': 'December'}},
#  'DAY_OF_WEEK': {'no': 21,
#   'level': 'Crash',
#   'alias': 'Day of Week',
#   'desc': 'Code for the day of the week when the crash occurred',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Monday',
#    '2': 'Tuesday',
#    '3': 'Wednesday',
#    '4': 'Thursday',
#    '5': 'Friday',
#    '6': 'Saturday',
#    '7': 'Sunday'}},
#  'PROC_DATE': {'no': 22,
#   'level': 'Crash',
#   'alias': 'Processing Date',
#   'desc': 'The date that the crash case was last changed',
#   'type': 'DATE',
#   'cat': 'Date and Time',
#   'dbin': 'N'},
#  'COLLISION_TIME_INTERVALS': {'no': 23,
#   'level': 'Crash',
#   'alias': 'Crash Time Intervals',
#   'desc': 'Crash time interval ranges classification',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Night (00:00am to 06:00am)',
#    '2': 'Morning (06:00am to 12:00pm)',
#    '3': 'Afternoon (12:00pm to 06:00pm)',
#    '4': 'Evening (06:00pm to 00:00am)',
#    '999': 'Unknown Time'}},
#  'COLLISION_TIME_RUSH_HOURS': {'no': 24,
#   'level': 'Crash',
#   'alias': 'Rush Hours',
#   'desc': 'Rush hours interval ranges (Mon-Fri mornings and evenings)',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Rush Hours (Morning)',
#    '2': 'Rush Hours (Evening)',
#    '3': 'Non-Rush Hours',
#    '999': 'Unknown Time'}},
#  'COLLISION_SEVERITY': {'no': 25,
#   'level': 'Crash',
#   'alias': 'Crash Severity',
#   'desc': 'The worst injury suffered by any victim in the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'No injury, aka property damage only or PDO',
#    '1': 'Fatal injury',
#    '2': 'Suspected serous injury or severe injury',
#    '3': 'Suspected minor injury or visible injury',
#    '4': 'Possible injury or complaint of pain'}},
#  'COLLISION_SEVERITY_BINARY': {'no': 26,
#   'level': 'Crash',
#   'alias': 'Crash Severity (Binary)',
#   'desc': 'Binary classification of the worst injury suffered by any victim in the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Minor (minor injury, pain, or no injury)',
#    '1': 'Severe (killed or serious injury)'}},
#  'COLLISION_SEVERITY_RECLASS': {'no': 27,
#   'level': 'Crash',
#   'alias': 'Crash Severity Reclassified',
#   'desc': 'Reclassified crash severity based on the worst injury suffered by any victim in the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'None',
#    '1': 'Possible Injury or Pain',
#    '2': 'Minor or Visible Injury',
#    '3': 'Serious or Severe Injury',
#    '4': 'Fatal Injury'}},
#  'COLLISION_SEVERITY_RANKED': {'no': 28,
#   'level': 'Crash',
#   'alias': 'Crash Severity Ranked',
#   'desc': 'Ranked crash severity based on the worst injury suffered by any victim in the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'None or Minor Injuries',
#    '1': 'Single Injury (Severe)',
#    '2': 'Multiple Injuries (Severe)',
#    '3': 'Single Fatality, No Injuries (Fatal)',
#    '4': 'Single Fatality, Single Injury (Fatal)',
#    '5': 'Single Fatality, Multiple Injuries (Fatal)',
#    '6': 'Multiple Fatalities, No Injuries (Fatal)',
#    '7': 'Multiple Fatalities, Single Injury (Fatal)',
#    '8': 'Multiple Fatalities, Multiple Injuries (Fatal)'}},
#  'PARTY_COUNT': {'no': 29,
#   'level': 'Party',
#   'alias': 'Party Count',
#   'desc': 'Number of parties involved in the crash',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'VICTIM_COUNT': {'no': 30,
#   'level': 'Victim',
#   'alias': 'Victim Count',
#   'desc': 'Number of victims involved in each party',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'NUMBER_KILLED': {'no': 31,
#   'level': 'Crash',
#   'alias': 'Killed victims',
#   'desc': 'Number of killed victims',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'NUMBER_INJURED': {'no': 32,
#   'level': 'Crash',
#   'alias': 'Injured victims',
#   'desc': 'Number of injured victims',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_SEVERE_INJ': {'no': 33,
#   'level': 'Crash',
#   'alias': 'Severe Injury Count',
#   'desc': 'Number of victims in the crash with suspected serous injury or severe injury',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_VISIBLE_INJ': {'no': 34,
#   'level': 'Crash',
#   'alias': 'Other Visible Injury Count',
#   'desc': 'Number of victims in the crash with suspected minor injury or visible injury',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_COMPLAINT_PAIN': {'no': 35,
#   'level': 'Crash',
#   'alias': 'Complaint of Pain Injury Count',
#   'desc': 'Number of victims in the crash with possible injury or complaint of pain',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_PED_KILLED': {'no': 36,
#   'level': 'Crash',
#   'alias': 'Pedestrian Killed Count',
#   'desc': 'Number of killed pedestrian victims',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_PED_INJURED': {'no': 37,
#   'level': 'Crash',
#   'alias': 'Pedestrian Injured Count',
#   'desc': 'Number of injured pedestrian victims',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_BICYCLIST_KILLED': {'no': 38,
#   'level': 'Crash',
#   'alias': 'Bicyclist Killed Count',
#   'desc': 'Number of killed bicyclists',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_BICYCLIST_INJURED': {'no': 39,
#   'level': 'Crash',
#   'alias': 'Bicyclist Injured Count',
#   'desc': 'Number of injured bicyclists',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_MC_KILLED': {'no': 40,
#   'level': 'Crash',
#   'alias': 'Motorcyclist Killed Count',
#   'desc': 'Number of killed motorcyclists',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_MC_INJURED': {'no': 41,
#   'level': 'Crash',
#   'alias': 'Motorcyclist Injured Count',
#   'desc': 'Number of injured motorcyclists',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'PRIMARY_COLL_FACTOR': {'no': 42,
#   'level': 'Crash',
#   'alias': 'Primary Crash Factor',
#   'desc': 'The primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Vehicle Code Violation',
#    'B': 'Other Improper Driving',
#    'C': 'Other Than Driver',
#    'D': 'Unknown',
#    'E': 'Fell Asleep',
#    '-': 'Not Stated'}},
#  'TYPE_OF_COLLISION': {'no': 43,
#   'level': 'Crash',
#   'alias': 'Type of Crash',
#   'desc': 'The general type of crash as determined by the first injury or damage-causing event',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Head-On',
#    'B': 'Sideswipe',
#    'C': 'Rear End',
#    'D': 'Broadside',
#    'E': 'Hit Object',
#    'F': 'Overturned',
#    'G': 'Vehicle/Pedestrian',
#    'H': 'Other',
#    '-': 'Not Stated'}},
#  'PEDESTRIAN_ACCIDENT': {'no': 44,
#   'level': 'Crash',
#   'alias': 'Pedestrian Crash',
#   'desc': 'Indicates whether the crash involved a pedestrian',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'BICYCLE_ACCIDENT': {'no': 45,
#   'level': 'Crash',
#   'alias': 'Bicycle Crash',
#   'desc': 'Indicates whether the crash involved a bicycle',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'MOTORCYCLE_ACCIDENT': {'no': 46,
#   'level': 'Crash',
#   'alias': 'Motorcycle Crash',
#   'desc': 'Indicates whether the crash involved a motorcycle',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'TRUCK_ACCIDENT': {'no': 47,
#   'level': 'Crash',
#   'alias': 'Truck Crash',
#   'desc': 'Indicates whether the crash involved a big truck',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'HIT_AND_RUN': {'no': 48,
#   'level': 'Crash',
#   'alias': 'Hit and Run',
#   'desc': 'A flag to indicate the severity of hit-and-run crash. Felony hit-and-run resulted in injury or death to other parties. Misdemeanor hit-and-run did not result in injury or death to other parties',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'F': 'Felony', 'M': 'Misdemeanor', 'N': 'Not Hit and Run'}},
#  'ALCOHOL_INVOLVED': {'no': 49,
#   'level': 'Crash',
#   'alias': 'Alcohol Involved',
#   'desc': 'Indicates whether the crash involved a party that had been drinking. Note - a passenger does not count as a party',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'JURIS': {'no': 50,
#   'level': 'Crash',
#   'alias': 'Jurisdiction',
#   'desc': 'Law enforcement agency that has jurisdiction over the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'OFFICER_ID': {'no': 51,
#   'level': 'Crash',
#   'alias': 'Officer ID',
#   'desc': 'The badge number of the officer who wrote the crash report',
#   'type': 'TEXT',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'REPORTING_DISTRICT': {'no': 52,
#   'level': 'Crash',
#   'alias': 'Reporting District',
#   'desc': 'Reporting District on the crash report',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'CHP_SHIFT': {'no': 53,
#   'level': 'Crash',
#   'alias': 'CHP Shift',
#   'desc': 'CHP shift at the time of the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': '0600 thru 1359',
#    '2': '1400 thru 2159',
#    '3': '2200 thru 0559',
#    '4': 'CHP Not Stated',
#    '5': 'Not CHP'}},
#  'CNTY_CITY_LOC': {'no': 54,
#   'level': 'Crash',
#   'alias': 'County City Location',
#   'desc': 'The city or unincorporated county where the crash occurred',
#   'type': 'LONG',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'SPECIAL_COND': {'no': 55,
#   'level': 'Crash',
#   'alias': 'Special Condition',
#   'desc': 'A computed value. O means not private property',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not Above',
#    '1': 'Schoolbus on Public Roadway',
#    '2': 'State University (Also SFIA)',
#    '3': 'Schoolbus Not on Public Roadway',
#    '4': 'Offroad (Unimproved)',
#    '5': 'Vista Point or Rest Area or Sales or Inspection Facility',
#    '6': 'Other Public Access (Improved)',
#    '-': 'Not Stated'}},
#  'BEAT_TYPE': {'no': 56,
#   'level': 'Crash',
#   'alias': 'Beat Type',
#   'desc': 'Location of crash based on beat',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not CHP',
#    '1': 'CHP State Highway',
#    '2': 'CHP County RoadLine',
#    '3': 'CHP County RoadArea',
#    '4': 'Schoolbus on City Roadway',
#    '5': 'Schoolbus not on Public Roadway',
#    '6': 'Offroad (Unimproved)',
#    '7': 'Vista Point or Rest Area or Scales or Inspection Facility',
#    '8': 'Other Public Access (Improved)'}},
#  'CHP_BEAT_TYPE': {'no': 57,
#   'level': 'Crash',
#   'alias': 'CHP Beat Type',
#   'desc': 'Location of crash based on beat',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'NOT CHP',
#    '1': 'Interstate',
#    '2': 'US Highway',
#    '3': 'State Route',
#    '4': 'County RoadLine',
#    '5': 'County RoadArea',
#    '6': 'US Highway',
#    '7': 'State Route',
#    '8': 'County RoadLine',
#    '9': 'County RoadArea'}},
#  'CHP_BEAT_CLASS': {'no': 58,
#   'level': 'Crash',
#   'alias': 'CHP Beat Class',
#   'desc': 'Location of crash based on beat',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not CHP', '1': 'CHP Primary', '2': 'CHP Other'}},
#  'BEAT_NUMBER': {'no': 59,
#   'level': 'Crash',
#   'alias': 'Beat Number',
#   'desc': 'Beat of the officer who reported the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'PRIMARY_RD': {'no': 60,
#   'level': 'Crash',
#   'alias': 'Primary Road',
#   'desc': 'The name of the roadway on which the crash occurred',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'SECONDARY_RD': {'no': 61,
#   'level': 'Crash',
#   'alias': 'Secondary Road',
#   'desc': 'The name of the roadway that intersects the primary roadway',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'DISTANCE': {'no': 62,
#   'level': 'Crash',
#   'alias': 'Distance',
#   'desc': 'Distance of the crash from the intersection with the secondary roadway in ft',
#   'type': 'DOUBLE',
#   'cat': 'Measurement',
#   'dbin': 'N'},
#  'DIRECTION': {'no': 63,
#   'level': 'Crash',
#   'alias': 'Direction',
#   'desc': 'Direction of the crash from the intersection with the secondary roadway',
#   'type': 'TEXT',
#   'cat': 'Measurement',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'N': 'North',
#    'E': 'East',
#    'S': 'South',
#    'W': 'West',
#    '-': 'Not Stated'}},
#  'INTERSECTION': {'no': 64,
#   'level': 'Crash',
#   'alias': 'Intersection',
#   'desc': 'A flag that denotes if the crash occurred at the intersection with the secondary roadway',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Intersection', 'N': 'Not Intersection', '-': 'Not Stated'}},
#  'WEATHER_1': {'no': 65,
#   'level': 'Crash',
#   'alias': 'Weather 1',
#   'desc': 'Weather condition at the time of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Clear',
#    'B': 'Cloudy',
#    'C': 'Raining',
#    'D': 'Snowing',
#    'E': 'Fog',
#    'F': 'Other',
#    'G': 'Wind',
#    '-': 'Not Stated'}},
#  'WEATHER_2': {'no': 66,
#   'level': 'Crash',
#   'alias': 'Weather 2',
#   'desc': 'Additional weather condition at the time of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Clear',
#    'B': 'Cloudy',
#    'C': 'Raining',
#    'D': 'Snowing',
#    'E': 'Fog',
#    'F': 'Other',
#    'G': 'Wind',
#    '-': 'Not Stated'}},
#  'WEATHER_COMBINED': {'no': 67,
#   'level': 'Crash',
#   'alias': 'Combined Weather Conditions',
#   'desc': 'Combined Weather Conditions from WEATHER_1 and WEATHER_2 fields in numeric codes by weather conditions severity',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not Stated',
#    '10': 'Clear',
#    '12': 'Clear Cloudy',
#    '13': 'Clear Other',
#    '14': 'Clear Wind',
#    '15': 'Clear Raining',
#    '16': 'Clear Snowing',
#    '17': 'Clear Fog',
#    '20': 'Cloudy',
#    '21': 'Cloudy Clear',
#    '23': 'Cloudy Other',
#    '24': 'Cloudy Wind',
#    '25': 'Cloudy Raining',
#    '26': 'Cloudy Snowing',
#    '27': 'Cloudy Fog',
#    '30': 'Other',
#    '31': 'Other Clear',
#    '32': 'Other Cloudy',
#    '34': 'Other Wind',
#    '35': 'Other Raining',
#    '36': 'Other Snowing',
#    '37': 'Other Fog',
#    '40': 'Wind',
#    '41': 'Wind Clear',
#    '42': 'Wind Cloudy',
#    '43': 'Wind Other',
#    '45': 'Wind Raining',
#    '46': 'Wind Snowing',
#    '47': 'Wind Fog',
#    '50': 'Raining',
#    '51': 'Raining Clear',
#    '52': 'Raining Cloudy',
#    '53': 'Raining Other',
#    '54': 'Raining Wind',
#    '56': 'Raining Snowing',
#    '57': 'Raining Fog',
#    '60': 'Snowing',
#    '61': 'Snowing Clear',
#    '62': 'Snowing Cloudy',
#    '63': 'Snowing Other',
#    '64': 'Snowing Wind',
#    '65': 'Snowing Raining',
#    '67': 'Snowing Fog',
#    '70': 'Fog',
#    '71': 'Fog Clear',
#    '72': 'Fog Cloudy',
#    '73': 'Fog Other',
#    '74': 'Fog Wind',
#    '75': 'Fog Raining',
#    '76': 'Fog Snowing'}},
#  'ROAD_SURFACE': {'no': 68,
#   'level': 'Crash',
#   'alias': 'Road Surface',
#   'desc': 'Roadway surface condition at the time of the crash in the traffic lane(s) involved',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Dry',
#    'B': 'Wet',
#    'C': 'Snowy or Icy',
#    'D': 'Slippery (Muddy, Oily, etc)',
#    'O': 'Other',
#    '-': 'Not Stated'}},
#  'ROAD_COND_1': {'no': 69,
#   'level': 'Crash',
#   'alias': 'Road Condition 1',
#   'desc': 'Roadway condition at the time of the crash in the traffic lane(s) involved',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Holes, Deep Ruts',
#    'B': 'Loose Material on Roadway',
#    'C': 'Obstruction on Roadway',
#    'D': 'Construction or Repair Zone',
#    'E': 'Reduced Roadway Width',
#    'F': 'Flooded',
#    'G': 'Other',
#    'H': 'No Unusual Condition',
#    '-': 'Not Stated'}},
#  'ROAD_COND_2': {'no': 70,
#   'level': 'Crash',
#   'alias': 'Road Condition 2',
#   'desc': 'Second roadway condition at the time of the crash in the traffic lane(s) involved',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Holes, Deep Ruts',
#    'B': 'Loose Material on Roadway',
#    'C': 'Obstruction on Roadway',
#    'D': 'Construction or Repair Zone',
#    'E': 'Reduced Roadway Width',
#    'F': 'Flooded',
#    'G': 'Other',
#    'H': 'No Unusual Condition',
#    '-': 'Not Stated'}},
#  'LIGHTING': {'no': 71,
#   'level': 'Crash',
#   'alias': 'Lighting',
#   'desc': 'Lighting conditions at the crash location and the time of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Daylight',
#    'B': 'Dusk-Dawn',
#    'C': 'Dark-Street Lights',
#    'D': 'Dark-No Street Lights',
#    'E': 'Dark-Street Lights Not Functioning',
#    '-': 'Not Stated'}},
#  'CONTROL_DEVICE': {'no': 72,
#   'level': 'Crash',
#   'alias': 'Control Device',
#   'desc': 'Presence and condition of crash related traffic control devices at the time of the crash. Control devices include regulatory, warning, and construction sings. This excludes striping and officers or other persons directing traffic',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Functioning',
#    'B': 'Not Functioning',
#    'C': 'Obscured',
#    'D': 'None',
#    '-': 'Not Stated'}},
#  'STATE_HWY_IND': {'no': 73,
#   'level': 'Crash',
#   'alias': 'State Highway Indicator',
#   'desc': 'A flag to indicate whether the crash is on or near a state highway',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'State Highway', 'N': 'Not State Highway'}},
#  'SIDE_OF_HWY': {'no': 74,
#   'level': 'Crash',
#   'alias': 'Side of Highway',
#   'desc': 'Code provided by Caltrans Coders, applies to divided highway, based on nominal direction of route, for single vehicle is same as nominal direction of travel, overruled by impact with second vehicle after crossing median',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'N': 'Northbound',
#    'S': 'Southbound',
#    'E': 'Eastbound',
#    'W': 'Westbound'}},
#  'TOW_AWAY': {'no': 75,
#   'level': 'Crash',
#   'alias': 'Tow Away',
#   'desc': 'A flag to indicate whether the vehicle was towed away from the crash scene',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes', 'N': 'No'}},
#  'PCF_CODE_OF_VIOL': {'no': 76,
#   'level': 'Crash',
#   'alias': 'PCF Violation Code',
#   'desc': 'The law code that was violated and was the primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'B': 'Business and Professions',
#    'C': 'Vehicle',
#    'H': 'City Health and Safety',
#    'I': 'City Ordinance',
#    'O': 'County Ordinance',
#    'P': 'Penal',
#    'S': 'Streets and Highways',
#    'W': 'Welfare and Institutions',
#    '-': 'Not Stated'}},
#  'PCF_VIOL_CATEGORY': {'no': 77,
#   'level': 'Crash',
#   'alias': 'PCF Violation Category',
#   'desc': 'A value computed from the law section that was given as the primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Unknown',
#    '1': 'Driving or Bicycling Under the Influence of Alcohol or Drug',
#    '2': 'Impeding Traffic',
#    '3': 'Unsafe Speed',
#    '4': 'Following Too Closely',
#    '5': 'Wrong Side of Road',
#    '6': 'Improper Passing',
#    '7': 'Unsafe Lane Change',
#    '8': 'Improper Turning',
#    '9': 'Automobile Right of Way',
#    '10': 'Pedestrian Right of Way',
#    '11': 'Pedestrian Violation',
#    '12': 'Traffic Signals and Signs',
#    '13': 'Hazardous Parking',
#    '14': 'Lights',
#    '15': 'Brakes',
#    '16': 'Other Equipment',
#    '17': 'Other Hazardous Violation',
#    '18': 'Other Than Driver or Pedestrian',
#    '21': 'Unsafe Starting or Backing',
#    '22': 'Other Improper Driving',
#    '23': 'Pedestrian or Other Under the Influence of Alcohol or Drug',
#    '24': 'Fell Asleep',
#    '-': 'Not Stated'}},
#  'PCF_VIOLATION': {'no': 78,
#   'level': 'Crash',
#   'alias': 'PCF Violation',
#   'desc': 'The law section given as the primary cause of the crash. The subsection is in the data element pcf_viol_subsection',
#   'type': 'DOUBLE',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'PCF_VIOL_SUBSECTION': {'no': 79,
#   'level': 'Crash',
#   'alias': 'PCF Violation Subsection',
#   'desc': 'The subsection of the law section given as the primary cause of the crash in the data element pcf_violation',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'MVIW': {'no': 80,
#   'level': 'Crash',
#   'alias': 'Motor Vehicle Involved With',
#   'desc': 'Describes what, in conjunction with a motor vehicle in-transport, produced the first injury or damage-causing event, on or off the road',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Non-Collision and Additional Object',
#    '1': 'Pedestrian and Additional Object',
#    '2': 'Other Motor Vehicle and Additional Object',
#    '3': 'Motor Vehicle on Other Roadway and Additional Object',
#    '4': 'Parked Motor Vehicle and Additional Object',
#    '5': 'Train and Additional Object',
#    '6': 'Bicycle and Additional Object',
#    '7': 'Animal and Additional Object',
#    '8': 'Fixed Object and Additional Object',
#    '9': 'Other Object and Additional Object',
#    'A': 'Non-Collision',
#    'B': 'Pedestrian',
#    'C': 'Other Motor Vehicle',
#    'D': 'Motor Vehicle on Other Roadway',
#    'E': 'Parked Motor Vehicle',
#    'F': 'Train',
#    'G': 'Bicycle',
#    'H': 'Animal',
#    'I': 'Fixed Object',
#    'J': 'Other Object',
#    '-': 'Not Stated'}},
#  'PED_ACTION': {'no': 81,
#   'level': 'Crash',
#   'alias': 'Ped Action',
#   'desc': 'The action just prior to the crash of the first pedestrian injured or otherwise involved',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'No Pedestrian Involved',
#    'B': 'Crossing in Crosswalk at Intersection',
#    'C': 'Crossing in Crosswalk Not at Intersection',
#    'D': 'Crossing Not in Crosswalk',
#    'E': 'In Road, Including Shoulder',
#    'F': 'Not in Road',
#    'G': 'Approaching or Leaving School Bus',
#    '-': 'Not Stated'}},
#  'NOT_PRIVATE_PROPERTY': {'no': 82,
#   'level': 'Crash',
#   'alias': 'Not Private Property',
#   'desc': 'Y indicates that the crash did not occur on private property',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'STWD_VEHTYPE_AT_FAULT': {'no': 83,
#   'level': 'Crash',
#   'alias': 'Statewide Vehicle Type At Fault',
#   'desc': 'Indicates the Statewide Vehicle Type of the party who is at fault',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Passenger car/station wagon',
#    'B': 'Passenger car with trailer',
#    'C': 'Motorcycle/scooter',
#    'D': 'Pickup or panel truck',
#    'E': 'Pickup or panel truck with trailer',
#    'F': 'Truck or truck tractor',
#    'G': 'Truck or truck tractor with trailer',
#    'H': 'Schoolbus',
#    'I': 'Other bus',
#    'J': 'Emergency vehicle',
#    'K': 'Highway construction equipment',
#    'L': 'Bicycle',
#    'M': 'Other vehicle',
#    'N': 'Pedestrian',
#    'O': 'Moped',
#    '-': 'Not Stated'}},
#  'CHP_VEHTYPE_AT_FAULT': {'no': 84,
#   'level': 'Crash',
#   'alias': 'CHP Vehicle Type At Fault',
#   'desc': 'Indicates the CHP Vehicle Type of the party whi is at fault',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Passenger, car, station Wagon, or Jeep',
#    '2': 'Motorcycle',
#    '3': 'Motor-driven cycle (<15 hp)',
#    '4': 'Bicycle',
#    '5': 'Motorized vehicle',
#    '6': 'All-terrain vehicle (ATV)',
#    '7': 'Sport utility vehicle',
#    '8': 'Minivan',
#    '9': 'Paratransit bus',
#    '10': 'Tour bus',
#    '11': 'Other commercial bus',
#    '12': 'Non-commercial bus',
#    '13': 'Schoolbus public I',
#    '14': 'Schoolbus public II',
#    '15': 'Schoolbus private I',
#    '16': 'Schoolbus private II',
#    '17': 'Schoolbus contractual I',
#    '18': 'Schoolbus contractual II',
#    '19': 'General public paratransit vehicle',
#    '20': 'Public transit authority',
#    '21': 'Two-axle tank truck',
#    '22': 'Pickup or panel truck',
#    '23': 'Pickup truck with camper',
#    '24': 'Three-axle tank truck',
#    '25': 'Truck tractor',
#    '26': 'Two-axle truck',
#    '27': 'Three-axle truck',
#    '28': 'Semi-tank trailer',
#    '29': 'Pull-tank trailer',
#    '30': 'Two-tank trailer',
#    '31': 'Semi-trailer',
#    '32': 'Pull trailer (includes dolly)',
#    '33': 'Two trailers (includes semi and trailer)',
#    '34': 'Boat trailer',
#    '35': 'Utility trailer',
#    '36': 'Trailer coach',
#    '37': 'Oversize vehicle/load',
#    '38': 'Pole, pipe, or logging dolly',
#    '39': 'Three trailers (includes semi and two trailers)',
#    '40': 'Semi 48 or less with king pin to trailer axle of over 38',
#    '41': 'Ambulance',
#    '42': 'Dune buggy',
#    '43': 'Fire truck (not rescue)',
#    '44': 'Forklift',
#    '45': 'Highway construction equipment (only while not in construction area)',
#    '46': 'Implement of husbandry',
#    '47': 'Motor home (40 ft or less)',
#    '48': 'CHP, police, or sheriff car (emergency service or not)',
#    '49': 'CHP, police, or sheriff motorcycle (emergency service or not)',
#    '50': 'Mobile equipment',
#    '51': 'Farm labor vehicle (certified)',
#    '52': 'Federally legal double cargo combo over 75ft',
#    '53': '5th wheel trailer',
#    '54': 'Container chassis',
#    '55': 'Two-axle tow truck',
#    '56': 'Three-axle tow truck',
#    '57': 'Farm labor vehicle (non-certified)',
#    '58': 'Farm labor transporter',
#    '59': 'Motorhome (over 40ft)',
#    '60': 'Pedestrian (includes motorized wheelchair)',
#    '61': 'School pupil activity bus I (prior to 2002)',
#    '62': 'School pupil activity bus II (prior to 2002)',
#    '63': 'Youth bus',
#    '64': 'School pupil activity bus I (eff 2002)',
#    '65': 'School pupil activity bus II (eff 2002)',
#    '66': 'School bus Without pupil passengers (eff 2002)',
#    '71': 'Passenger car - hazardous materials only',
#    '72': 'Pickups and panels - hazardous materials only',
#    '73': 'Pickups and campers - hazardous materials only',
#    '75': 'Truck tractor - hazardous materials only',
#    '76': 'Two-axle truck - hazardous materials only',
#    '77': 'Three or more axle truck - hazardous materials only',
#    '78': 'Two-axle tank truck - hazardous materials only',
#    '79': 'Three axle tank truck - hazardous materials only',
#    '81': 'Passenger car - hazardous waste or waste-material combo',
#    '82': 'Pickups and panels - hazardous waste or waste-material combo',
#    '83': 'Pickups and campers - hazardous waste or waste-material combo',
#    '85': 'Truck tractor - hazardous waste or waste-material combo',
#    '86': 'Two-axle truck - hazardous waste or waste-material combo',
#    '87': 'Three or more axle truck - hazardous waste or waste-material combo',
#    '88': 'Two-axle tank truck - hazardous waste or waste-material combo',
#    '89': 'Three-axle tank truck - hazardous waste or waste-material combo',
#    '91': 'Electric bicycle (class 1,2,3)',
#    '93': 'Electrically motorized board',
#    '94': 'Motorized transportation device',
#    '95': 'Miscellaneous non-motorized vehicle (ridden animal, animal-drawn conveyance, train or building) with victim',
#    '96': 'Miscellaneous motorized vehicle (golf cart)',
#    '97': 'Low speed vehicle',
#    '98': 'Emergency vehicle on an emergency run',
#    '99': 'Not stated or unknown (hit and run)',
#    '-': 'Not Stated'}},
#  'PRIMARY_RAMP': {'no': 85,
#   'level': 'Crash',
#   'alias': 'Primary Ramp',
#   'desc': 'A description of the ramp, if any, on primary roadway. This value is computed by the key operator from information on the crash report',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'TO': 'To',
#    'FR': 'From',
#    'NF': 'North Off Ramp',
#    'SF': 'South Off Ramp',
#    'EF': 'East Off Ramp',
#    'WF': 'West Off Ramp',
#    'NO': 'North On Ramp',
#    'SO': 'South On Ramp',
#    'EO': 'East On Ramp',
#    'WO': 'West On Ramp',
#    'TR': 'Transition',
#    'CO': 'Collector',
#    'CN': 'Connector',
#    '-': 'Not Stated'}},
#  'SECONDARY_RAMP': {'no': 86,
#   'level': 'Crash',
#   'alias': 'Secondary Ramp',
#   'desc': 'A description of the ramp, if any, on secondary roadway. This value is computed by the key operator from information on the crash report',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'TO': 'To',
#    'FR': 'From',
#    'NF': 'North Off Ramp',
#    'SF': 'South Off Ramp',
#    'EF': 'East Off Ramp',
#    'WF': 'West Off Ramp',
#    'NO': 'North On Ramp',
#    'SO': 'South On Ramp',
#    'EO': 'East On Ramp',
#    'WO': 'West On Ramp',
#    'TR': 'Transition',
#    'CO': 'Collector',
#    'CN': 'Connector',
#    '-': 'Not Stated'}},
#  'PARTY_TYPE': {'no': 87,
#   'level': 'Party',
#   'alias': 'Party Type',
#   'desc': 'Involved party type',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Driver (including hit and run)',
#    '2': 'Pedestrian',
#    '3': 'Parked vehicle',
#    '4': 'Bicyclist',
#    '5': 'Other',
#    '6': 'Operator',
#    '-': 'Not Stated'}},
#  'AT_FAULT': {'no': 88,
#   'level': 'Party',
#   'alias': 'At Fault',
#   'desc': 'Indicates whether the party was at fault in the crash',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes', 'N': 'No', '-': 'Not Stated'}},
#  'PARTY_SEX': {'no': 89,
#   'level': 'Party',
#   'alias': 'Party Sex',
#   'desc': 'The gender of the party',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'M': 'Male', 'F': 'Female', 'X': 'Nonbinary', '-': 'Not Stated'}},
#  'PARTY_AGE': {'no': 90,
#   'level': 'Party',
#   'alias': 'Party Age',
#   'desc': 'The age of the party at the time of the crash',
#   'type': 'LONG',
#   'cat': 'Measurement',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'998': 'Unknown'}},
#  'RACE': {'no': 91,
#   'level': 'Party',
#   'alias': 'Party Race',
#   'desc': "The party's race based on the reporting officer's judgment",
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Asian',
#    'B': 'Black',
#    'H': 'Hispanic',
#    'W': 'White',
#    'O': 'Other'}},
#  'PARTY_NUMBER_KILLED': {'no': 92,
#   'level': 'Party',
#   'alias': 'Party Number Killed',
#   'desc': 'Number of killed victims in the party',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'PARTY_NUMBER_INJURED': {'no': 93,
#   'level': 'Party',
#   'alias': 'Party Number Injured',
#   'desc': 'Number of injured victims in the party',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'INATTENTION': {'no': 94,
#   'level': 'Party',
#   'alias': 'Inattention',
#   'desc': 'Type of inattention',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Cell phone handheld',
#    'B': 'Cell phone handsfree',
#    'C': 'Electronic equipment',
#    'D': 'Radio/CD',
#    'E': 'Smoking',
#    'F': 'Eating',
#    'G': 'Children',
#    'H': 'Animal',
#    'I': 'Personal hygiene',
#    'J': 'Reading',
#    'K': 'Other',
#    'P': 'Cell Phone',
#    '-': 'Not Stated'}},
#  'PARTY_SOBRIETY': {'no': 95,
#   'level': 'Party',
#   'alias': 'Party Sobriety',
#   'desc': 'The state of sobriety of the party',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Had not been drinking',
#    'B': 'Had been drinking under influence',
#    'C': 'Had been drinking, not under influence',
#    'D': 'Had been drinking, impairment unknown',
#    'G': 'Impairment unknown',
#    'H': 'Not applicable',
#    '-': 'Not Stated'}},
#  'PARTY_DRUG_PHYSICAL': {'no': 96,
#   'level': 'Party',
#   'alias': 'Party Drug Physical',
#   'desc': 'The state of the party with regard to drugs and physical condition',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'E': 'Under drug influence',
#    'F': 'Impairment - physical',
#    'G': 'Impairment unknown',
#    'H': 'Not applicable',
#    'I': 'Sleepy or fatigued',
#    '-': 'Not Stated'}},
#  'DIR_OF_TRAVEL': {'no': 97,
#   'level': 'Party',
#   'alias': 'Direction of Travel',
#   'desc': 'Direction that the party was traveling at the time of the crash. The direction is the direction of the highway, not the compass direction',
#   'type': 'TEXT',
#   'cat': 'Measurement',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'N': 'North',
#    'S': 'South',
#    'E': 'East',
#    'W': 'West',
#    '-': 'Not Stated'}},
#  'PARTY_SAFETY_EQUIP_1': {'no': 98,
#   'level': 'Party',
#   'alias': 'Party Safety Equipment 1',
#   'desc': 'The safety equipment of the party',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'None in vehicle',
#    'B': 'Unknown',
#    'C': 'Lap belt used',
#    'D': 'Lab belt not used',
#    'E': 'Shoulder harness used',
#    'F': 'Shoulder harness not used',
#    'G': 'Lap/shoulder harness used',
#    'H': 'Lap/shoulder harness not used',
#    'J': 'Passive restraint used',
#    'K': 'Passive restraint not used',
#    'L': 'Air bag deployed',
#    'M': 'Air bag not deployed',
#    'N': 'Other',
#    'P': 'Not required',
#    'Q': 'Child restraint in vehicle used',
#    'R': 'Child restraint in vehicle not used',
#    'S': 'Child restraint in vehicle, use unknown',
#    'T': 'Child restraint in vehicle, improper use',
#    'U': 'No child restraint in vehicle',
#    'V': 'Driver, motorcycle helmet not used',
#    'W': 'Driver, motorcycle helmet used',
#    'X': 'Passenger, motorcycle helmet not used',
#    'Y': 'Passenger, motorcycle helmet used',
#    '-': 'Not Stated'}},
#  'PARTY_SAFETY_EQUIP_2': {'no': 99,
#   'level': 'Party',
#   'alias': 'Party Safety Equipment 2',
#   'desc': 'The safety equipment of the party',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'None in vehicle',
#    'B': 'Unknown',
#    'C': 'Lap belt used',
#    'D': 'Lab belt not used',
#    'E': 'Shoulder harness used',
#    'F': 'Shoulder harness not used',
#    'G': 'Lap/shoulder harness used',
#    'H': 'Lap/shoulder harness not used',
#    'J': 'Passive restraint used',
#    'K': 'Passive restraint not used',
#    'L': 'Air bag deployed',
#    'M': 'Air bag not deployed',
#    'N': 'Other',
#    'P': 'Not required',
#    'Q': 'Child restraint in vehicle used',
#    'R': 'Child restraint in vehicle not used',
#    'S': 'Child restraint in vehicle, use unknown',
#    'T': 'Child restraint in vehicle, improper use',
#    'U': 'No child restraint in vehicle',
#    'V': 'Driver, motorcycle helmet not used',
#    'W': 'Driver, motorcycle helmet used',
#    'X': 'Passenger, motorcycle helmet not used',
#    'Y': 'Passenger, motorcycle helmet used',
#    '-': 'Not Stated'}},
#  'FINAN_RESPONS': {'no': 100,
#   'level': 'Party',
#   'alias': 'Financial Responsibility',
#   'desc': 'Financial responsibility of the party',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'N': 'No proof of insurance obtained',
#    'Y': 'Yes, proof of insurance obtained',
#    'O': 'Not applicable (used for parked cars, bicyclists, pedestrians, and party type others)',
#    'E': 'Used if the officer is called away from the scene of the crash prior to obtaining the insurance information'}},
#  'SP_INFO_1': {'no': 101,
#   'level': 'Party',
#   'alias': 'Special Information 1',
#   'desc': 'Value A indicates that the crash involved in a vehicle known to be, or believed to be, transporting a hazardous material as defined in CVC Section 353, whether or not the crash involved a hazardous material incident',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Hazardous materials', '-': 'Not Stated'}},
#  'SP_INFO_2': {'no': 102,
#   'level': 'Party',
#   'alias': 'Special Information 2',
#   'desc': 'Cell Phone Information',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Cell phone handheld in use',
#    '2': 'Cell phone handsfree in use',
#    '3': 'Cell phone not in use',
#    '4': 'Cell phone use unknown',
#    'B': 'Cell phone in use',
#    'C': 'Cell phone not in use',
#    'D': 'No cell phone/unknown',
#    '-': 'Not Stated'}},
#  'SP_INFO_3': {'no': 103,
#   'level': 'Party',
#   'alias': 'Special Information 3',
#   'desc': 'Value E indicates that the crash involved a motor vehicle in-transport passing a stopped school bus with its red signal lamps in operation pursuant to CVC Section 22112, or reacting to, pursuant to CVC Section 22454',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'E': 'School bus related', '-': 'Not Stated'}},
#  'OAF_VIOLATION_CODE': {'no': 104,
#   'level': 'Party',
#   'alias': 'OAF Violation Code',
#   'desc': 'Other associated factor law code violated',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'B': 'Business and professions',
#    'C': 'Vehicle',
#    'H': 'City Health and Safety',
#    'I': 'City Ordinance',
#    'P': 'Penal',
#    'S': 'Streets and Highways',
#    'W': 'Welfare and institutions',
#    '-': 'Not Stated'}},
#  'OAF_VIOL_CAT': {'no': 105,
#   'level': 'Party',
#   'alias': 'OAF Violation Category',
#   'desc': 'Category of the factor that contributed to the crash but was not the primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not Stated',
#    '1': 'Under influence in public',
#    '2': 'County ordinance',
#    '3': 'City ordinance',
#    '5': 'Business/professions code',
#    '6': 'Felony penal code',
#    '8': 'Controlled substances (felony health and safety)',
#    '9': 'Health/safety code (misdemeanor)',
#    '10': 'Penal code (misdemeanor)',
#    '11': 'Streets/highways code',
#    '13': 'Welfare/institutions code',
#    '15': 'Manslaughter',
#    '16': 'Non-vehicle code not specified above',
#    '17': 'Fish and game code',
#    '18': 'Agriculture code',
#    '19': 'Hit and run',
#    '20': 'Driving or bicycling under the influence of alcohol or drug',
#    '21': 'Improper lane change',
#    '22': 'Impeding traffic',
#    '23': 'Failure to heed stop signal',
#    '24': 'Failure to heed stop sign',
#    '25': 'Unsafe speed',
#    '26': 'Reckless driving',
#    '27': 'Wrong side of road',
#    '28': 'Unsafe lane change',
#    '29': 'Improper passing',
#    '30': 'Following too closely',
#    '31': 'Improper turning',
#    '33': 'Automobile right-of-way',
#    '34': 'Pedestrian right-of-way',
#    '35': 'Pedestrian violation',
#    '38': 'Hazardous parking',
#    '39': 'Lights',
#    '40': 'Brakes',
#    '43': 'Other equipment',
#    '44': 'Other hazardous movement',
#    '46': 'Improper registration',
#    '47': 'Other non-moving violation',
#    '48': 'Excessive smoke',
#    '49': 'Excessive noise',
#    '50': 'Overweight',
#    '51': 'Oversize',
#    '52': 'Over maximum speed',
#    '53': 'Unsafe starting or backing',
#    '60': 'Off-highway vehicle violation',
#    '61': 'Child restraint',
#    '62': 'Seat belt',
#    '63': 'Seat belt (equipment)',
#    '-': 'Not Stated'}},
#  'OAF_VIOL_SECTION': {'no': 106,
#   'level': 'Party',
#   'alias': 'OAF Violation Section',
#   'desc': 'The CVC section of the secondary violation that contributed to the crash',
#   'type': 'DOUBLE',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'OAF_VIOLATION_SUFFIX': {'no': 107,
#   'level': 'Party',
#   'alias': 'OAF Violation Suffix',
#   'desc': 'the subsection of the CVC section of the secondary violation that contributed to the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'OAF_1': {'no': 108,
#   'level': 'Party',
#   'alias': 'Other Associated Factor 1',
#   'desc': 'A factor that contributed to the crash but was not the primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Violation',
#    'E': 'Vision obscurements',
#    'F': 'Inattention',
#    'G': 'Stop and go traffic',
#    'H': 'Entering/leaving ramp',
#    'I': 'Previous collision',
#    'J': 'Unfamiliar with road',
#    'K': 'Defective vehicle equipment',
#    'L': 'Uninvolved vehicle',
#    'M': 'Other',
#    'N': 'None apparent',
#    'O': 'Runaway vehicle',
#    'P': 'Inattention, cell phone',
#    'Q': 'Inattention, electronic equip',
#    'R': 'Inattention, radio/CD',
#    'S': 'Inattention, smoking',
#    'T': 'Inattention, eating',
#    'U': 'Inattention, children',
#    'V': 'Inattention, animal',
#    'W': 'Inattention, personal hygiene',
#    'X': 'Inattention, reading',
#    'Y': 'Inattention, other',
#    '-': 'Not Stated'}},
#  'OAF_2': {'no': 109,
#   'level': 'Party',
#   'alias': 'Other Associated Factor 2',
#   'desc': 'A factor that contributed to the crash but was not the primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Violation',
#    'E': 'Vision obscurements',
#    'F': 'Inattention',
#    'G': 'Stop and go traffic',
#    'H': 'Entering/leaving ramp',
#    'I': 'Previous collision',
#    'J': 'Unfamiliar with road',
#    'K': 'Defective vehicle equipment',
#    'L': 'Uninvolved vehicle',
#    'M': 'Other',
#    'N': 'None apparent',
#    'O': 'Runaway vehicle',
#    'P': 'Inattention, cell phone',
#    'Q': 'Inattention, electronic equip',
#    'R': 'Inattention, radio/CD',
#    'S': 'Inattention, smoking',
#    'T': 'Inattention, eating',
#    'U': 'Inattention, children',
#    'V': 'Inattention, animal',
#    'W': 'Inattention, personal hygiene',
#    'X': 'Inattention, reading',
#    'Y': 'Inattention, other',
#    '-': 'Not Stated'}},
#  'MOVE_PRE_ACC': {'no': 110,
#   'level': 'Party',
#   'alias': 'Movement Preceding Crash',
#   'desc': 'The action of the vehicle prior to the crash and before evasive action. This movement does not have to correspond with the PCF',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Stopped',
#    'B': 'Proceeding straight',
#    'C': 'Ran off road',
#    'D': 'Making right turn',
#    'E': 'Making left turn',
#    'F': 'Making U-turn',
#    'G': 'Backing',
#    'H': 'Slowing/stopping',
#    'I': 'Passing other vehicle',
#    'J': 'Changing lanes',
#    'K': 'Parking maneuver',
#    'L': 'Entering traffic',
#    'M': 'Other unsafe turning',
#    'N': 'Crossed into opposing lane',
#    'O': 'Parked',
#    'P': 'Merging',
#    'Q': 'Traveling wrong way',
#    'R': 'Other',
#    'S': 'Lane splitting',
#    '-': 'Not Stated'}},
#  'VEHICLE_YEAR': {'no': 111,
#   'level': 'Party',
#   'alias': 'Vehicle Year',
#   'desc': "The model year of the party's vehicle",
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'9999': 'Not Stated'}},
#  'VEHICLE_MAKE': {'no': 112,
#   'level': 'Party',
#   'alias': 'Vehicle Make',
#   'desc': "The make of the party's vehicle",
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'-': 'Not Stated'}},
#  'STWD_VEHICLE_TYPE': {'no': 113,
#   'level': 'Party',
#   'alias': 'Statewide Vehicle Type',
#   'desc': "Type of the party's vehicle according to a list called statewide vehicle type",
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Passenger car/station wagon',
#    'B': 'Passenger car with trailer',
#    'C': 'Motorcycle/scooter',
#    'D': 'Pickup or panel truck',
#    'E': 'Pickup or panel truck with trailer',
#    'F': 'Truck or truck tractor',
#    'G': 'Truck or truck tractor with trailer',
#    'H': 'Schoolbus',
#    'I': 'Other bus',
#    'J': 'Emergency vehicle',
#    'K': 'Highway construction equipment',
#    'L': 'Bicycle',
#    'M': 'Other vehicle',
#    'N': 'Pedestrian',
#    'O': 'Moped',
#    '-': 'Not Stated'}},
#  'CHP_VEH_TYPE_TOWING': {'no': 114,
#   'level': 'Party',
#   'alias': 'CHP Vehicle Type Towing',
# ...
#    '61': 'School pupil activity bus I (prior to 2002)',
#    '62': 'School pupil activity bus II (prior to 2002)',
#    '63': 'Youth bus',
#    '64': 'School pupil activity bus I (eff 2002)',
#    '65': 'School pupil activity bus II (eff 2002)',
#    '66': 'School bus Without pupil passengers (eff 2002)',
#    '71': 'Passenger car - hazardous materials only',
#    '72': 'Pickups and panels - hazardous materials only',
#    '73': 'Pickups and campers - hazardous materials only',
#    '75': 'Truck tractor - hazardous materials only',
#    '76': 'Two-axle truck - hazardous materials only',
#    '77': 'Three or more axle truck - hazardous materials only',
#    '78': 'Two-axle tank truck - hazardous materials only',
#    '79': 'Three axle tank truck - hazardous materials only',
#    '81': 'Passenger car - hazardous waste or waste-material combo',
#    '82': 'Pickups and panels - hazardous waste or waste-material combo',
#    '83': 'Pickups and campers - hazardous waste or waste-material combo',
#    '85': 'Truck tractor - hazardous waste or waste-material combo',
#    '86': 'Two-axle truck - hazardous waste or waste-material combo',
#    '87': 'Three or more axle truck - hazardous waste or waste-material combo',
#    '88': 'Two-axle tank truck - hazardous waste or waste-material combo',
#    '89': 'Three-axle tank truck - hazardous waste or waste-material combo',
#    '91': 'Electric bicycle (class 1,2,3)',
#    '93': 'Electrically motorized board',
#    '94': 'Motorized transportation device',
#    '95': 'Miscellaneous non-motorized vehicle (ridden animal, animal-drawn conveyance, train or building) with victim',
#    '96': 'Miscellaneous motorized vehicle (golf cart)',
#    '97': 'Low speed vehicle',
#    '98': 'Emergency vehicle on an emergency run',
#    '99': 'Not stated or unknown (hit and run)',
#    '-': 'Not Stated'}},
#  'CHP_VEH_TYPE_TOWED': {'no': 115,
#   'level': 'Party',
#   'alias': 'CHP Vehicle Type Towed',
#   'desc': 'The type of the first trailer unit according to the CHP manual HPM 110.5 Chapter 3 Annex F vehicle type codes',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Passenger, car, station Wagon, or Jeep',
#    '2': 'Motorcycle',
#    '3': 'Motor-driven cycle (<15 hp)',
#    '4': 'Bicycle',
#    '5': 'Motorized vehicle',
#    '6': 'All-terrain vehicle (ATV)',
#    '7': 'Sport utility vehicle',
#    '8': 'Minivan',
#    '9': 'Paratransit bus',
#    '10': 'Tour bus',
#    '11': 'Other commercial bus',
#    '12': 'Non-commercial bus',
#    '13': 'Schoolbus public I',
#    '14': 'Schoolbus public II',
#    '15': 'Schoolbus private I',
#    '16': 'Schoolbus private II',
#    '17': 'Schoolbus contractual I',
#    '18': 'Schoolbus contractual II',
#    '19': 'General public paratransit vehicle',
#    '20': 'Public transit authority',
#    '21': 'Two-axle tank truck',
#    '22': 'Pickup or panel truck',
#    '23': 'Pickup truck with camper',
#    '24': 'Three-axle tank truck',
#    '25': 'Truck tractor',
#    '26': 'Two-axle truck',
#    '27': 'Three-axle truck',
#    '28': 'Semi-tank trailer',
#    '29': 'Pull-tank trailer',
#    '30': 'Two-tank trailer',
#    '31': 'Semi-trailer',
#    '32': 'Pull trailer (includes dolly)',
#    '33': 'Two trailers (includes semi and trailer)',
#    '34': 'Boat trailer',
#    '35': 'Utility trailer',
#    '36': 'Trailer coach',
#    '37': 'Oversize vehicle/load',
#    '38': 'Pole, pipe, or logging dolly',
#    '39': 'Three trailers (includes semi and two trailers)',
#    '40': 'Semi 48 or less with king pin to trailer axle of over 38',
#    '41': 'Ambulance',
#    '42': 'Dune buggy',
#    '43': 'Fire truck (not rescue)',
#    '44': 'Forklift',
#    '45': 'Highway construction equipment (only while not in construction area)',
#    '46': 'Implement of husbandry',
#    '47': 'Motor home (40 ft or less)',
#    '48': 'CHP, police, or sheriff car (emergency service or not)',
#    '49': 'CHP, police, or sheriff motorcycle (emergency service or not)',
#    '50': 'Mobile equipment',
#    '51': 'Farm labor vehicle (certified)',
#    '52': 'Federally legal double cargo combo over 75ft',
#    '53': '5th wheel trailer',
#    '54': 'Container chassis',
#    '55': 'Two-axle tow truck',
#    '56': 'Three-axle tow truck',
#    '57': 'Farm labor vehicle (non-certified)',
#    '58': 'Farm labor transporter',
#    '59': 'Motorhome (over 40ft)',
#    '60': 'Pedestrian (includes motorized wheelchair)',
#    '61': 'School pupil activity bus I (prior to 2002)',
#    '62': 'School pupil activity bus II (prior to 2002)',
#    '63': 'Youth bus',
#    '64': 'School pupil activity bus I (eff 2002)',
#    '65': 'School pupil activity bus II (eff 2002)',
#    '66': 'School bus Without pupil passengers (eff 2002)',
#    '71': 'Passenger car - hazardous materials only',
#    '72': 'Pickups and panels - hazardous materials only',
#    '73': 'Pickups and campers - hazardous materials only',
#    '75': 'Truck tractor - hazardous materials only',
#    '76': 'Two-axle truck - hazardous materials only',
#    '77': 'Three or more axle truck - hazardous materials only',
#    '78': 'Two-axle tank truck - hazardous materials only',
#    '79': 'Three axle tank truck - hazardous materials only',
#    '81': 'Passenger car - hazardous waste or waste-material combo',
#    '82': 'Pickups and panels - hazardous waste or waste-material combo',
#    '83': 'Pickups and campers - hazardous waste or waste-material combo',
#    '85': 'Truck tractor - hazardous waste or waste-material combo',
#    '86': 'Two-axle truck - hazardous waste or waste-material combo',
#    '87': 'Three or more axle truck - hazardous waste or waste-material combo',
#    '88': 'Two-axle tank truck - hazardous waste or waste-material combo',
#    '89': 'Three-axle tank truck - hazardous waste or waste-material combo',
#    '91': 'Electric bicycle (class 1,2,3)',
#    '93': 'Electrically motorized board',
#    '94': 'Motorized transportation device',
#    '95': 'Miscellaneous non-motorized vehicle (ridden animal, animal-drawn conveyance, train or building) with victim',
#    '96': 'Miscellaneous motorized vehicle (golf cart)',
#    '97': 'Low speed vehicle',
#    '98': 'Emergency vehicle on an emergency run',
#    '99': 'Not stated or unknown (hit and run)',
#    '-': 'Not Stated'}},
#  'SPECIAL_INFO_F': {'no': 116,
#   'level': 'Party',
#   'alias': 'Special Info F',
#   'desc': "The value F indicate that the party's vehicle is a 75ft motor truck combo",
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'F': '75ft motor truck combo', '-': 'Not Stated'}},
#  'SPECIAL_INFO_G': {'no': 117,
#   'level': 'Party',
#   'alias': 'Special Info G',
#   'desc': "The value G indicates that the party's vehicle is a 32ft trailer combo",
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'G': '32ft trailer combo', '-': 'Not Stated'}},
#  'VICTIM_ROLE': {'no': 118,
#   'level': 'Victim',
#   'alias': 'Victim Role',
#   'desc': 'The role of the victim',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Driver',
#    '2': 'Passenger (includes non-operator on bicycle or any victim on/in parked vehicle or multiple victims on/in non-motor vehicle)',
#    '3': 'Pedestrian',
#    '4': 'Bicyclist',
#    '5': 'Other (single victim on/in non-motor vehicle)',
#    '6': 'Non-injured party'}},
#  'VICTIM_SEX': {'no': 119,
#   'level': 'Victim',
#   'alias': 'Victim Sex',
#   'desc': 'The gender of the victim',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'M': 'Male', 'F': 'Female', 'X': 'Nonbinary', '-': 'Not Stated'}},
#  'VICTIM_AGE': {'no': 120,
#   'level': 'Victim',
#   'alias': 'Victim Age',
#   'desc': 'The age of the victim at the time of the crash',
#   'type': 'LONG',
#   'cat': 'Measurement',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'998': 'Not Stated', '999': 'Fatal Fetus'}},
#  'VICTIM_DEGREE_OF_INJURY': {'no': 121,
#   'level': 'Victim',
#   'alias': 'Victim Degree of Injury',
#   'desc': 'The severity of the injury to the victim',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'No injury',
#    '1': 'Killed',
#    '2': 'Severe injury',
#    '3': 'Other visible injury',
#    '4': 'Complaint of pain',
#    '5': 'Suspected serious injury',
#    '6': 'Suspected minor injury',
#    '7': 'Possible injury'}},
#  'VICTIM_DEGREE_OF_INJURY_BINARY': {'no': 122,
#   'level': 'Victim',
#   'alias': 'Victim Injury Severity (Binary)',
#   'desc': 'Binary classification of the severity of the injury to the victim',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Minor (minor injury, pain, or no injury)',
#    '1': 'Severe (killed or serious injury)'}},
#  'VICTIM_SEATING_POSITION': {'no': 123,
#   'level': 'Victim',
#   'alias': 'Victim Seating Position',
#   'desc': 'The seating position of the victim',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Other occupants',
#    '1': 'Driver',
#    '2': 'Passenger 1',
#    '3': 'Passenger 2',
#    '4': 'Passenger 3',
#    '5': 'Passenger 4',
#    '6': 'Passenger 5',
#    '7': 'Station wagon rear',
#    '8': 'Rear occupant of truck or van',
#    '9': 'Position unknown',
#    '-': 'Not Stated'}},
#  'VICTIM_SAFETY_EQUIP_1': {'no': 124,
#   'level': 'Victim',
#   'alias': 'Victim Safety Equipment 1',
#   'desc': 'The safety equipment of the victim',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'None in vehicle',
#    'B': 'Unknown',
#    'C': 'Lap belt used',
#    'D': 'Lap belt not used',
#    'E': 'Shoulder harness used',
#    'F': 'Shoulder harness not used',
#    'G': 'Lap/shoulder harness used',
#    'H': 'Lap/shoulder harness not used',
#    'J': 'Passive restraint used',
#    'K': 'Passive restraint not used',
#    'L': 'Air bag deployed',
#    'M': 'Air bag not deployed',
#    'N': 'Other',
#    'P': 'Not required',
#    'Q': 'Child restraint in vehicle used',
#    'R': 'Child restraint in vehicle not used',
#    'S': 'Child restraint in vehicle, use unknown',
#    'T': 'Child restraint in vehicle, improper use',
#    'U': 'No child restraint in vehicle',
#    'V': 'Driver, motorcycle helmet used',
#    'W': 'Driver, motorcycle helmet not used',
#    'X': 'Passenger, motorcycle helmet not used',
#    'Y': 'Passenger, motorcycle helmet used',
#    '-': 'Not Stated'}},
#  'VICTIM_SAFETY_EQUIP_2': {'no': 125,
#   'level': 'Victim',
#   'alias': 'Victim Safety Equipment 2',
#   'desc': 'The safety equipment of the victim',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'None in vehicle',
#    'B': 'Unknown',
#    'C': 'Lap belt used',
#    'D': 'Lap belt not used',
#    'E': 'Shoulder harness used',
#    'F': 'Shoulder harness not used',
#    'G': 'Lap/shoulder harness used',
#    'H': 'Lap/shoulder harness not used',
#    'J': 'Passive restraint used',
#    'K': 'Passive restraint not used',
#    'L': 'Air bag deployed',
#    'M': 'Air bag not deployed',
#    'N': 'Other',
#    'P': 'Not required',
#    'Q': 'Child restraint in vehicle used',
#    'R': 'Child restraint in vehicle not used',
#    'S': 'Child restraint in vehicle, use unknown',
#    'T': 'Child restraint in vehicle, improper use',
#    'U': 'No child restraint in vehicle',
#    'V': 'Driver, motorcycle helmet used',
#    'W': 'Driver, motorcycle helmet not used',
#    'X': 'Passenger, motorcycle helmet not used',
#    'Y': 'Passenger, motorcycle helmet used',
#    '-': 'Not Stated'}},
#  'VICTIM_EJECTED': {'no': 126,
#   'level': 'Victim',
#   'alias': 'Victim Ejected',
#   'desc': 'Indicates whether the victim was ejected from the vehicle',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not ejected',
#    '1': 'Fully ejected',
#    '2': 'Partially ejected',
#    '3': 'Unknown',
#    '-': 'Not Stated'}},
#  'CITY_AREA_SQMI': {'no': 127,
#   'level': 'City',
#   'alias': 'City Area (sq. miles)',
#   'desc': 'City Area in Square Miles',
#   'type': 'DOUBLE',
#   'cat': 'Measurement',
#   'dbin': 'N'},
#  'CITY_POPDENS': {'no': 128,
#   'level': 'City',
#   'alias': 'City Population Density (per sq. mi)',
#   'desc': 'City population density, population per square mile',
#   'type': 'DOUBLE',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_HUDENS': {'no': 129,
#   'level': 'City',
#   'alias': 'City Housing Density (per sq. mi)',
#   'desc': 'City housing density, houses per square mile',
#   'type': 'DOUBLE',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_POPT': {'no': 130,
#   'level': 'City',
#   'alias': 'City Total Population',
#   'desc': "Total population in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_HUT': {'no': 131,
#   'level': 'City',
#   'alias': 'City Total Housing Units',
#   'desc': "Total housing units in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_POPA': {'no': 132,
#   'level': 'City',
#   'alias': 'City Asian Population',
#   'desc': "Total Asian population in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_POPB': {'no': 133,
#   'level': 'City',
#   'alias': 'City Black Population',
#   'desc': "Total Black or African American population in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_POPH': {'no': 134,
#   'level': 'City',
#   'alias': 'City Hispanic Population',
#   'desc': "Total Hispanic population in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_POPW': {'no': 135,
#   'level': 'City',
#   'alias': 'City White Population',
#   'desc': "Total White population in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_VEHICLES': {'no': 136,
#   'level': 'City',
#   'alias': 'City Aggregate Number of Vehicles Commuting',
#   'desc': "Aggregate number of vehicles used in commuting in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_TRAVEL_TIME': {'no': 137,
#   'level': 'City',
#   'alias': 'City Aggregate Travel Time to Work (min)',
#   'desc': "Aggregate travel time to work (in minutes) in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'RID': {'no': 138,
#   'level': 'Road',
#   'alias': 'Road ID',
#   'desc': "Road ID matching from the road's layer",
#   'type': 'TEXT',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'RNAME': {'no': 139,
#   'level': 'Road',
#   'alias': 'Road Name',
#   'desc': 'Road name from the OC Tiger/Lines layer',
#   'type': 'TEXT',
#   'cat': 'Name',
#   'dbin': 'N'},
#  'RCAT': {'no': 140,
#   'level': 'Road',
#   'alias': 'Road Category',
#   'desc': 'Road category from the OC Tiger/Lines layer',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'RLENGTH': {'no': 141,
#   'level': 'Road',
#   'alias': 'Road Length',
#   'desc': 'Road length from the OC Tiger/Lines layer',
#   'type': 'DOUBLE',
#   'cat': 'Measurement',
#   'dbin': 'N'},
#  'LATITUDE': {'no': 142,
#   'level': 'Crash',
#   'alias': 'GPS Latitude',
#   'desc': 'Latitude of the crash location in decimal degrees. The decimal point is included. LATITUDE and LONGITUDE are from the crash report',
#   'type': 'DOUBLE',
#   'cat': 'Coordinate',
#   'dbin': 'N'},
#  'LONGITUDE': {'no': 143,
#   'level': 'Crash',
#   'alias': 'GPS Longitude',
#   'desc': 'Longitude of the crash location in decimal degrees. The decimal point is included. There is no minus sign. The longitude is understood to be West of Meridian. LATITUDE and LONGITUDE are from the crash report',
#   'type': 'DOUBLE',
#   'cat': 'Coordinate',
#   'dbin': 'N'},
#  'POINT_X': {'no': 144,
#   'level': 'Crash',
#   'alias': 'X Coordinate Location',
#   'desc': 'The longitude of the geocoded location, uses the World Geodetic System from 1984 (WGS84). POINT_X and POINT_Y are generated using the geociding process by UC Berkeley Safe TREC',
#   'type': 'DOUBLE',
#   'cat': 'Coordinate',
#   'dbin': 'N'},
#  'POINT_Y': {'no': 145,
#   'level': 'Crash',
#   'alias': 'Y Coordinate Location',
#   'desc': 'The latitude of the geocoded location, uses the World Geodetic System from 1984 (WGS84). POINT_X and POINT_Y are generated using the geociding process by UC Berkeley Safe TREC',
#   'type': 'DOUBLE',
#   'cat': 'Coordinate',
#   'dbin': 'N'}}

# %%
print("Parties: Modifying codebook field types...")
modify_agp_types(codebook, partiesPointsFields)
# Out:
# Parties: Modifying codebook field types...
# {'OBJECTID': {'no': 1,
#   'level': 'GIS',
#   'alias': 'Object ID',
#   'desc': 'ESRI Object ID',
#   'type': 'OID',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'GlobalID': {'no': 2,
#   'level': 'GIS',
#   'alias': 'Global ID',
#   'desc': 'ESRI Global ID string identifier',
#   'type': 'GlobalID',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'GUID': {'no': 3,
#   'level': 'GIS',
#   'alias': 'GUID Related Table Identifier',
#   'desc': 'ESRI GUID to be used in merging related tables',
#   'type': 'Guid',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'CASE_ID': {'no': 4,
#   'level': 'Crash',
#   'alias': 'Case ID',
#   'desc': 'Unique identifier of the crash case',
#   'type': 'LONG',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'CID': {'no': 5,
#   'level': 'Crash',
#   'alias': 'Crash ID',
#   'desc': 'Unique identifier of the crash case',
#   'type': 'TEXT',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'PID': {'no': 6,
#   'level': 'Party',
#   'alias': 'Party ID',
#   'desc': 'Unique identifier for the party case',
#   'type': 'TEXT',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'VID': {'no': 7,
#   'level': 'Victim',
#   'alias': 'Victim ID',
#   'desc': 'Unique identifier of the victim case',
#   'type': 'TEXT',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'PARTY_NUMBER': {'no': 8,
#   'level': 'Party',
#   'alias': 'Party Number',
#   'desc': 'A number that together with the CASE_ID uniquely identifies a party in a crash',
#   'type': 'LONG',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'VICTIM_NUMBER': {'no': 9,
#   'level': 'Victim',
#   'alias': 'Victim Number',
#   'desc': 'The unique identifier of the victim',
#   'type': 'LONG',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'CRASHES_INDICATOR': {'no': 10,
#   'level': 'Crash',
#   'alias': 'Crashes Binary Indicator',
#   'desc': 'Binary flag, 1 if the record is a crash, 0 if not',
#   'type': 'LONG',
#   'cat': 'Binary',
#   'dbin': 'N'},
#  'PARTIES_INDICATOR': {'no': 11,
#   'level': 'Party',
#   'alias': 'Parties Binary Indicator',
#   'desc': 'Binary flag, 1 if the record is a party, 0 if not',
#   'type': 'LONG',
#   'cat': 'Binary',
#   'dbin': 'N'},
#  'VICTIMS_INDICATOR': {'no': 12,
#   'level': 'Victim',
#   'alias': 'Victims Binary Indicator',
#   'desc': 'Binary flag, 1 if the record is a victim, 0 if not',
#   'type': 'LONG',
#   'cat': 'Binary',
#   'dbin': 'N'},
#  'CITY': {'no': 13,
#   'level': 'City',
#   'alias': 'City',
#   'desc': 'Reported City of the crash',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'CITY_NAME': {'no': 14,
#   'level': 'City',
#   'alias': 'City Name',
#   'desc': 'City name from locational query',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'PLACE_TYPE': {'no': 15,
#   'level': 'City',
#   'alias': 'Place Type',
#   'desc': 'City or Unincorporated Area',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'COLLISION_DATETIME': {'no': 16,
#   'level': 'Crash',
#   'alias': 'Crash Date and Time',
#   'desc': 'Full date and time string of the crash',
#   'type': 'DATE',
#   'cat': 'Date and Time',
#   'dbin': 'N'},
#  'COLLISION_DATE': {'no': 17,
#   'level': 'Crash',
#   'alias': 'Crash Date',
#   'desc': 'The date when the crash occurred',
#   'type': 'DATE',
#   'cat': 'Date and Time',
#   'dbin': 'N'},
#  'COLLISION_TIME': {'no': 18,
#   'level': 'Crash',
#   'alias': 'Crash Time',
#   'desc': 'The time when the crash occurred in 24h format',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'N'},
#  'ACCIDENT_YEAR': {'no': 19,
#   'level': 'Crash',
#   'alias': 'Crash Year',
#   'desc': 'The year when the crash occurred',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'N'},
#  'COLLISION_MONTH': {'no': 20,
#   'level': 'Crash',
#   'alias': 'Crash Month',
#   'desc': 'Month number from crash date',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'January',
#    '2': 'February',
#    '3': 'March',
#    '4': 'April',
#    '5': 'May',
#    '6': 'June',
#    '7': 'July',
#    '8': 'August',
#    '9': 'September',
#    '10': 'October',
#    '11': 'November',
#    '12': 'December'}},
#  'DAY_OF_WEEK': {'no': 21,
#   'level': 'Crash',
#   'alias': 'Day of Week',
#   'desc': 'Code for the day of the week when the crash occurred',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Monday',
#    '2': 'Tuesday',
#    '3': 'Wednesday',
#    '4': 'Thursday',
#    '5': 'Friday',
#    '6': 'Saturday',
#    '7': 'Sunday'}},
#  'PROC_DATE': {'no': 22,
#   'level': 'Crash',
#   'alias': 'Processing Date',
#   'desc': 'The date that the crash case was last changed',
#   'type': 'DATE',
#   'cat': 'Date and Time',
#   'dbin': 'N'},
#  'COLLISION_TIME_INTERVALS': {'no': 23,
#   'level': 'Crash',
#   'alias': 'Crash Time Intervals',
#   'desc': 'Crash time interval ranges classification',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Night (00:00am to 06:00am)',
#    '2': 'Morning (06:00am to 12:00pm)',
#    '3': 'Afternoon (12:00pm to 06:00pm)',
#    '4': 'Evening (06:00pm to 00:00am)',
#    '999': 'Unknown Time'}},
#  'COLLISION_TIME_RUSH_HOURS': {'no': 24,
#   'level': 'Crash',
#   'alias': 'Rush Hours',
#   'desc': 'Rush hours interval ranges (Mon-Fri mornings and evenings)',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Rush Hours (Morning)',
#    '2': 'Rush Hours (Evening)',
#    '3': 'Non-Rush Hours',
#    '999': 'Unknown Time'}},
#  'COLLISION_SEVERITY': {'no': 25,
#   'level': 'Crash',
#   'alias': 'Crash Severity',
#   'desc': 'The worst injury suffered by any victim in the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'No injury, aka property damage only or PDO',
#    '1': 'Fatal injury',
#    '2': 'Suspected serous injury or severe injury',
#    '3': 'Suspected minor injury or visible injury',
#    '4': 'Possible injury or complaint of pain'}},
#  'COLLISION_SEVERITY_BINARY': {'no': 26,
#   'level': 'Crash',
#   'alias': 'Crash Severity (Binary)',
#   'desc': 'Binary classification of the worst injury suffered by any victim in the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Minor (minor injury, pain, or no injury)',
#    '1': 'Severe (killed or serious injury)'}},
#  'COLLISION_SEVERITY_RECLASS': {'no': 27,
#   'level': 'Crash',
#   'alias': 'Crash Severity Reclassified',
#   'desc': 'Reclassified crash severity based on the worst injury suffered by any victim in the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'None',
#    '1': 'Possible Injury or Pain',
#    '2': 'Minor or Visible Injury',
#    '3': 'Serious or Severe Injury',
#    '4': 'Fatal Injury'}},
#  'COLLISION_SEVERITY_RANKED': {'no': 28,
#   'level': 'Crash',
#   'alias': 'Crash Severity Ranked',
#   'desc': 'Ranked crash severity based on the worst injury suffered by any victim in the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'None or Minor Injuries',
#    '1': 'Single Injury (Severe)',
#    '2': 'Multiple Injuries (Severe)',
#    '3': 'Single Fatality, No Injuries (Fatal)',
#    '4': 'Single Fatality, Single Injury (Fatal)',
#    '5': 'Single Fatality, Multiple Injuries (Fatal)',
#    '6': 'Multiple Fatalities, No Injuries (Fatal)',
#    '7': 'Multiple Fatalities, Single Injury (Fatal)',
#    '8': 'Multiple Fatalities, Multiple Injuries (Fatal)'}},
#  'PARTY_COUNT': {'no': 29,
#   'level': 'Party',
#   'alias': 'Party Count',
#   'desc': 'Number of parties involved in the crash',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'VICTIM_COUNT': {'no': 30,
#   'level': 'Victim',
#   'alias': 'Victim Count',
#   'desc': 'Number of victims involved in each party',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'NUMBER_KILLED': {'no': 31,
#   'level': 'Crash',
#   'alias': 'Killed victims',
#   'desc': 'Number of killed victims',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'NUMBER_INJURED': {'no': 32,
#   'level': 'Crash',
#   'alias': 'Injured victims',
#   'desc': 'Number of injured victims',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_SEVERE_INJ': {'no': 33,
#   'level': 'Crash',
#   'alias': 'Severe Injury Count',
#   'desc': 'Number of victims in the crash with suspected serous injury or severe injury',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_VISIBLE_INJ': {'no': 34,
#   'level': 'Crash',
#   'alias': 'Other Visible Injury Count',
#   'desc': 'Number of victims in the crash with suspected minor injury or visible injury',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_COMPLAINT_PAIN': {'no': 35,
#   'level': 'Crash',
#   'alias': 'Complaint of Pain Injury Count',
#   'desc': 'Number of victims in the crash with possible injury or complaint of pain',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_PED_KILLED': {'no': 36,
#   'level': 'Crash',
#   'alias': 'Pedestrian Killed Count',
#   'desc': 'Number of killed pedestrian victims',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_PED_INJURED': {'no': 37,
#   'level': 'Crash',
#   'alias': 'Pedestrian Injured Count',
#   'desc': 'Number of injured pedestrian victims',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_BICYCLIST_KILLED': {'no': 38,
#   'level': 'Crash',
#   'alias': 'Bicyclist Killed Count',
#   'desc': 'Number of killed bicyclists',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_BICYCLIST_INJURED': {'no': 39,
#   'level': 'Crash',
#   'alias': 'Bicyclist Injured Count',
#   'desc': 'Number of injured bicyclists',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_MC_KILLED': {'no': 40,
#   'level': 'Crash',
#   'alias': 'Motorcyclist Killed Count',
#   'desc': 'Number of killed motorcyclists',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_MC_INJURED': {'no': 41,
#   'level': 'Crash',
#   'alias': 'Motorcyclist Injured Count',
#   'desc': 'Number of injured motorcyclists',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'PRIMARY_COLL_FACTOR': {'no': 42,
#   'level': 'Crash',
#   'alias': 'Primary Crash Factor',
#   'desc': 'The primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Vehicle Code Violation',
#    'B': 'Other Improper Driving',
#    'C': 'Other Than Driver',
#    'D': 'Unknown',
#    'E': 'Fell Asleep',
#    '-': 'Not Stated'}},
#  'TYPE_OF_COLLISION': {'no': 43,
#   'level': 'Crash',
#   'alias': 'Type of Crash',
#   'desc': 'The general type of crash as determined by the first injury or damage-causing event',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Head-On',
#    'B': 'Sideswipe',
#    'C': 'Rear End',
#    'D': 'Broadside',
#    'E': 'Hit Object',
#    'F': 'Overturned',
#    'G': 'Vehicle/Pedestrian',
#    'H': 'Other',
#    '-': 'Not Stated'}},
#  'PEDESTRIAN_ACCIDENT': {'no': 44,
#   'level': 'Crash',
#   'alias': 'Pedestrian Crash',
#   'desc': 'Indicates whether the crash involved a pedestrian',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'BICYCLE_ACCIDENT': {'no': 45,
#   'level': 'Crash',
#   'alias': 'Bicycle Crash',
#   'desc': 'Indicates whether the crash involved a bicycle',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'MOTORCYCLE_ACCIDENT': {'no': 46,
#   'level': 'Crash',
#   'alias': 'Motorcycle Crash',
#   'desc': 'Indicates whether the crash involved a motorcycle',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'TRUCK_ACCIDENT': {'no': 47,
#   'level': 'Crash',
#   'alias': 'Truck Crash',
#   'desc': 'Indicates whether the crash involved a big truck',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'HIT_AND_RUN': {'no': 48,
#   'level': 'Crash',
#   'alias': 'Hit and Run',
#   'desc': 'A flag to indicate the severity of hit-and-run crash. Felony hit-and-run resulted in injury or death to other parties. Misdemeanor hit-and-run did not result in injury or death to other parties',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'F': 'Felony', 'M': 'Misdemeanor', 'N': 'Not Hit and Run'}},
#  'ALCOHOL_INVOLVED': {'no': 49,
#   'level': 'Crash',
#   'alias': 'Alcohol Involved',
#   'desc': 'Indicates whether the crash involved a party that had been drinking. Note - a passenger does not count as a party',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'JURIS': {'no': 50,
#   'level': 'Crash',
#   'alias': 'Jurisdiction',
#   'desc': 'Law enforcement agency that has jurisdiction over the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'OFFICER_ID': {'no': 51,
#   'level': 'Crash',
#   'alias': 'Officer ID',
#   'desc': 'The badge number of the officer who wrote the crash report',
#   'type': 'TEXT',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'REPORTING_DISTRICT': {'no': 52,
#   'level': 'Crash',
#   'alias': 'Reporting District',
#   'desc': 'Reporting District on the crash report',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'CHP_SHIFT': {'no': 53,
#   'level': 'Crash',
#   'alias': 'CHP Shift',
#   'desc': 'CHP shift at the time of the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': '0600 thru 1359',
#    '2': '1400 thru 2159',
#    '3': '2200 thru 0559',
#    '4': 'CHP Not Stated',
#    '5': 'Not CHP'}},
#  'CNTY_CITY_LOC': {'no': 54,
#   'level': 'Crash',
#   'alias': 'County City Location',
#   'desc': 'The city or unincorporated county where the crash occurred',
#   'type': 'LONG',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'SPECIAL_COND': {'no': 55,
#   'level': 'Crash',
#   'alias': 'Special Condition',
#   'desc': 'A computed value. O means not private property',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not Above',
#    '1': 'Schoolbus on Public Roadway',
#    '2': 'State University (Also SFIA)',
#    '3': 'Schoolbus Not on Public Roadway',
#    '4': 'Offroad (Unimproved)',
#    '5': 'Vista Point or Rest Area or Sales or Inspection Facility',
#    '6': 'Other Public Access (Improved)',
#    '-': 'Not Stated'}},
#  'BEAT_TYPE': {'no': 56,
#   'level': 'Crash',
#   'alias': 'Beat Type',
#   'desc': 'Location of crash based on beat',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not CHP',
#    '1': 'CHP State Highway',
#    '2': 'CHP County RoadLine',
#    '3': 'CHP County RoadArea',
#    '4': 'Schoolbus on City Roadway',
#    '5': 'Schoolbus not on Public Roadway',
#    '6': 'Offroad (Unimproved)',
#    '7': 'Vista Point or Rest Area or Scales or Inspection Facility',
#    '8': 'Other Public Access (Improved)'}},
#  'CHP_BEAT_TYPE': {'no': 57,
#   'level': 'Crash',
#   'alias': 'CHP Beat Type',
#   'desc': 'Location of crash based on beat',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'NOT CHP',
#    '1': 'Interstate',
#    '2': 'US Highway',
#    '3': 'State Route',
#    '4': 'County RoadLine',
#    '5': 'County RoadArea',
#    '6': 'US Highway',
#    '7': 'State Route',
#    '8': 'County RoadLine',
#    '9': 'County RoadArea'}},
#  'CHP_BEAT_CLASS': {'no': 58,
#   'level': 'Crash',
#   'alias': 'CHP Beat Class',
#   'desc': 'Location of crash based on beat',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not CHP', '1': 'CHP Primary', '2': 'CHP Other'}},
#  'BEAT_NUMBER': {'no': 59,
#   'level': 'Crash',
#   'alias': 'Beat Number',
#   'desc': 'Beat of the officer who reported the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'PRIMARY_RD': {'no': 60,
#   'level': 'Crash',
#   'alias': 'Primary Road',
#   'desc': 'The name of the roadway on which the crash occurred',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'SECONDARY_RD': {'no': 61,
#   'level': 'Crash',
#   'alias': 'Secondary Road',
#   'desc': 'The name of the roadway that intersects the primary roadway',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'DISTANCE': {'no': 62,
#   'level': 'Crash',
#   'alias': 'Distance',
#   'desc': 'Distance of the crash from the intersection with the secondary roadway in ft',
#   'type': 'DOUBLE',
#   'cat': 'Measurement',
#   'dbin': 'N'},
#  'DIRECTION': {'no': 63,
#   'level': 'Crash',
#   'alias': 'Direction',
#   'desc': 'Direction of the crash from the intersection with the secondary roadway',
#   'type': 'TEXT',
#   'cat': 'Measurement',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'N': 'North',
#    'E': 'East',
#    'S': 'South',
#    'W': 'West',
#    '-': 'Not Stated'}},
#  'INTERSECTION': {'no': 64,
#   'level': 'Crash',
#   'alias': 'Intersection',
#   'desc': 'A flag that denotes if the crash occurred at the intersection with the secondary roadway',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Intersection', 'N': 'Not Intersection', '-': 'Not Stated'}},
#  'WEATHER_1': {'no': 65,
#   'level': 'Crash',
#   'alias': 'Weather 1',
#   'desc': 'Weather condition at the time of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Clear',
#    'B': 'Cloudy',
#    'C': 'Raining',
#    'D': 'Snowing',
#    'E': 'Fog',
#    'F': 'Other',
#    'G': 'Wind',
#    '-': 'Not Stated'}},
#  'WEATHER_2': {'no': 66,
#   'level': 'Crash',
#   'alias': 'Weather 2',
#   'desc': 'Additional weather condition at the time of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Clear',
#    'B': 'Cloudy',
#    'C': 'Raining',
#    'D': 'Snowing',
#    'E': 'Fog',
#    'F': 'Other',
#    'G': 'Wind',
#    '-': 'Not Stated'}},
#  'WEATHER_COMBINED': {'no': 67,
#   'level': 'Crash',
#   'alias': 'Combined Weather Conditions',
#   'desc': 'Combined Weather Conditions from WEATHER_1 and WEATHER_2 fields in numeric codes by weather conditions severity',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not Stated',
#    '10': 'Clear',
#    '12': 'Clear Cloudy',
#    '13': 'Clear Other',
#    '14': 'Clear Wind',
#    '15': 'Clear Raining',
#    '16': 'Clear Snowing',
#    '17': 'Clear Fog',
#    '20': 'Cloudy',
#    '21': 'Cloudy Clear',
#    '23': 'Cloudy Other',
#    '24': 'Cloudy Wind',
#    '25': 'Cloudy Raining',
#    '26': 'Cloudy Snowing',
#    '27': 'Cloudy Fog',
#    '30': 'Other',
#    '31': 'Other Clear',
#    '32': 'Other Cloudy',
#    '34': 'Other Wind',
#    '35': 'Other Raining',
#    '36': 'Other Snowing',
#    '37': 'Other Fog',
#    '40': 'Wind',
#    '41': 'Wind Clear',
#    '42': 'Wind Cloudy',
#    '43': 'Wind Other',
#    '45': 'Wind Raining',
#    '46': 'Wind Snowing',
#    '47': 'Wind Fog',
#    '50': 'Raining',
#    '51': 'Raining Clear',
#    '52': 'Raining Cloudy',
#    '53': 'Raining Other',
#    '54': 'Raining Wind',
#    '56': 'Raining Snowing',
#    '57': 'Raining Fog',
#    '60': 'Snowing',
#    '61': 'Snowing Clear',
#    '62': 'Snowing Cloudy',
#    '63': 'Snowing Other',
#    '64': 'Snowing Wind',
#    '65': 'Snowing Raining',
#    '67': 'Snowing Fog',
#    '70': 'Fog',
#    '71': 'Fog Clear',
#    '72': 'Fog Cloudy',
#    '73': 'Fog Other',
#    '74': 'Fog Wind',
#    '75': 'Fog Raining',
#    '76': 'Fog Snowing'}},
#  'ROAD_SURFACE': {'no': 68,
#   'level': 'Crash',
#   'alias': 'Road Surface',
#   'desc': 'Roadway surface condition at the time of the crash in the traffic lane(s) involved',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Dry',
#    'B': 'Wet',
#    'C': 'Snowy or Icy',
#    'D': 'Slippery (Muddy, Oily, etc)',
#    'O': 'Other',
#    '-': 'Not Stated'}},
#  'ROAD_COND_1': {'no': 69,
#   'level': 'Crash',
#   'alias': 'Road Condition 1',
#   'desc': 'Roadway condition at the time of the crash in the traffic lane(s) involved',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Holes, Deep Ruts',
#    'B': 'Loose Material on Roadway',
#    'C': 'Obstruction on Roadway',
#    'D': 'Construction or Repair Zone',
#    'E': 'Reduced Roadway Width',
#    'F': 'Flooded',
#    'G': 'Other',
#    'H': 'No Unusual Condition',
#    '-': 'Not Stated'}},
#  'ROAD_COND_2': {'no': 70,
#   'level': 'Crash',
#   'alias': 'Road Condition 2',
#   'desc': 'Second roadway condition at the time of the crash in the traffic lane(s) involved',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Holes, Deep Ruts',
#    'B': 'Loose Material on Roadway',
#    'C': 'Obstruction on Roadway',
#    'D': 'Construction or Repair Zone',
#    'E': 'Reduced Roadway Width',
#    'F': 'Flooded',
#    'G': 'Other',
#    'H': 'No Unusual Condition',
#    '-': 'Not Stated'}},
#  'LIGHTING': {'no': 71,
#   'level': 'Crash',
#   'alias': 'Lighting',
#   'desc': 'Lighting conditions at the crash location and the time of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Daylight',
#    'B': 'Dusk-Dawn',
#    'C': 'Dark-Street Lights',
#    'D': 'Dark-No Street Lights',
#    'E': 'Dark-Street Lights Not Functioning',
#    '-': 'Not Stated'}},
#  'CONTROL_DEVICE': {'no': 72,
#   'level': 'Crash',
#   'alias': 'Control Device',
#   'desc': 'Presence and condition of crash related traffic control devices at the time of the crash. Control devices include regulatory, warning, and construction sings. This excludes striping and officers or other persons directing traffic',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Functioning',
#    'B': 'Not Functioning',
#    'C': 'Obscured',
#    'D': 'None',
#    '-': 'Not Stated'}},
#  'STATE_HWY_IND': {'no': 73,
#   'level': 'Crash',
#   'alias': 'State Highway Indicator',
#   'desc': 'A flag to indicate whether the crash is on or near a state highway',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'State Highway', 'N': 'Not State Highway'}},
#  'SIDE_OF_HWY': {'no': 74,
#   'level': 'Crash',
#   'alias': 'Side of Highway',
#   'desc': 'Code provided by Caltrans Coders, applies to divided highway, based on nominal direction of route, for single vehicle is same as nominal direction of travel, overruled by impact with second vehicle after crossing median',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'N': 'Northbound',
#    'S': 'Southbound',
#    'E': 'Eastbound',
#    'W': 'Westbound'}},
#  'TOW_AWAY': {'no': 75,
#   'level': 'Crash',
#   'alias': 'Tow Away',
#   'desc': 'A flag to indicate whether the vehicle was towed away from the crash scene',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes', 'N': 'No'}},
#  'PCF_CODE_OF_VIOL': {'no': 76,
#   'level': 'Crash',
#   'alias': 'PCF Violation Code',
#   'desc': 'The law code that was violated and was the primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'B': 'Business and Professions',
#    'C': 'Vehicle',
#    'H': 'City Health and Safety',
#    'I': 'City Ordinance',
#    'O': 'County Ordinance',
#    'P': 'Penal',
#    'S': 'Streets and Highways',
#    'W': 'Welfare and Institutions',
#    '-': 'Not Stated'}},
#  'PCF_VIOL_CATEGORY': {'no': 77,
#   'level': 'Crash',
#   'alias': 'PCF Violation Category',
#   'desc': 'A value computed from the law section that was given as the primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Unknown',
#    '1': 'Driving or Bicycling Under the Influence of Alcohol or Drug',
#    '2': 'Impeding Traffic',
#    '3': 'Unsafe Speed',
#    '4': 'Following Too Closely',
#    '5': 'Wrong Side of Road',
#    '6': 'Improper Passing',
#    '7': 'Unsafe Lane Change',
#    '8': 'Improper Turning',
#    '9': 'Automobile Right of Way',
#    '10': 'Pedestrian Right of Way',
#    '11': 'Pedestrian Violation',
#    '12': 'Traffic Signals and Signs',
#    '13': 'Hazardous Parking',
#    '14': 'Lights',
#    '15': 'Brakes',
#    '16': 'Other Equipment',
#    '17': 'Other Hazardous Violation',
#    '18': 'Other Than Driver or Pedestrian',
#    '21': 'Unsafe Starting or Backing',
#    '22': 'Other Improper Driving',
#    '23': 'Pedestrian or Other Under the Influence of Alcohol or Drug',
#    '24': 'Fell Asleep',
#    '-': 'Not Stated'}},
#  'PCF_VIOLATION': {'no': 78,
#   'level': 'Crash',
#   'alias': 'PCF Violation',
#   'desc': 'The law section given as the primary cause of the crash. The subsection is in the data element pcf_viol_subsection',
#   'type': 'DOUBLE',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'PCF_VIOL_SUBSECTION': {'no': 79,
#   'level': 'Crash',
#   'alias': 'PCF Violation Subsection',
#   'desc': 'The subsection of the law section given as the primary cause of the crash in the data element pcf_violation',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'MVIW': {'no': 80,
#   'level': 'Crash',
#   'alias': 'Motor Vehicle Involved With',
#   'desc': 'Describes what, in conjunction with a motor vehicle in-transport, produced the first injury or damage-causing event, on or off the road',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Non-Collision and Additional Object',
#    '1': 'Pedestrian and Additional Object',
#    '2': 'Other Motor Vehicle and Additional Object',
#    '3': 'Motor Vehicle on Other Roadway and Additional Object',
#    '4': 'Parked Motor Vehicle and Additional Object',
#    '5': 'Train and Additional Object',
#    '6': 'Bicycle and Additional Object',
#    '7': 'Animal and Additional Object',
#    '8': 'Fixed Object and Additional Object',
#    '9': 'Other Object and Additional Object',
#    'A': 'Non-Collision',
#    'B': 'Pedestrian',
#    'C': 'Other Motor Vehicle',
#    'D': 'Motor Vehicle on Other Roadway',
#    'E': 'Parked Motor Vehicle',
#    'F': 'Train',
#    'G': 'Bicycle',
#    'H': 'Animal',
#    'I': 'Fixed Object',
#    'J': 'Other Object',
#    '-': 'Not Stated'}},
#  'PED_ACTION': {'no': 81,
#   'level': 'Crash',
#   'alias': 'Ped Action',
#   'desc': 'The action just prior to the crash of the first pedestrian injured or otherwise involved',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'No Pedestrian Involved',
#    'B': 'Crossing in Crosswalk at Intersection',
#    'C': 'Crossing in Crosswalk Not at Intersection',
#    'D': 'Crossing Not in Crosswalk',
#    'E': 'In Road, Including Shoulder',
#    'F': 'Not in Road',
#    'G': 'Approaching or Leaving School Bus',
#    '-': 'Not Stated'}},
#  'NOT_PRIVATE_PROPERTY': {'no': 82,
#   'level': 'Crash',
#   'alias': 'Not Private Property',
#   'desc': 'Y indicates that the crash did not occur on private property',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'STWD_VEHTYPE_AT_FAULT': {'no': 83,
#   'level': 'Crash',
#   'alias': 'Statewide Vehicle Type At Fault',
#   'desc': 'Indicates the Statewide Vehicle Type of the party who is at fault',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Passenger car/station wagon',
#    'B': 'Passenger car with trailer',
#    'C': 'Motorcycle/scooter',
#    'D': 'Pickup or panel truck',
#    'E': 'Pickup or panel truck with trailer',
#    'F': 'Truck or truck tractor',
#    'G': 'Truck or truck tractor with trailer',
#    'H': 'Schoolbus',
#    'I': 'Other bus',
#    'J': 'Emergency vehicle',
#    'K': 'Highway construction equipment',
#    'L': 'Bicycle',
#    'M': 'Other vehicle',
#    'N': 'Pedestrian',
#    'O': 'Moped',
#    '-': 'Not Stated'}},
#  'CHP_VEHTYPE_AT_FAULT': {'no': 84,
#   'level': 'Crash',
#   'alias': 'CHP Vehicle Type At Fault',
#   'desc': 'Indicates the CHP Vehicle Type of the party whi is at fault',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Passenger, car, station Wagon, or Jeep',
#    '2': 'Motorcycle',
#    '3': 'Motor-driven cycle (<15 hp)',
#    '4': 'Bicycle',
#    '5': 'Motorized vehicle',
#    '6': 'All-terrain vehicle (ATV)',
#    '7': 'Sport utility vehicle',
#    '8': 'Minivan',
#    '9': 'Paratransit bus',
#    '10': 'Tour bus',
#    '11': 'Other commercial bus',
#    '12': 'Non-commercial bus',
#    '13': 'Schoolbus public I',
#    '14': 'Schoolbus public II',
#    '15': 'Schoolbus private I',
#    '16': 'Schoolbus private II',
#    '17': 'Schoolbus contractual I',
#    '18': 'Schoolbus contractual II',
#    '19': 'General public paratransit vehicle',
#    '20': 'Public transit authority',
#    '21': 'Two-axle tank truck',
#    '22': 'Pickup or panel truck',
#    '23': 'Pickup truck with camper',
#    '24': 'Three-axle tank truck',
#    '25': 'Truck tractor',
#    '26': 'Two-axle truck',
#    '27': 'Three-axle truck',
#    '28': 'Semi-tank trailer',
#    '29': 'Pull-tank trailer',
#    '30': 'Two-tank trailer',
#    '31': 'Semi-trailer',
#    '32': 'Pull trailer (includes dolly)',
#    '33': 'Two trailers (includes semi and trailer)',
#    '34': 'Boat trailer',
#    '35': 'Utility trailer',
#    '36': 'Trailer coach',
#    '37': 'Oversize vehicle/load',
#    '38': 'Pole, pipe, or logging dolly',
#    '39': 'Three trailers (includes semi and two trailers)',
#    '40': 'Semi 48 or less with king pin to trailer axle of over 38',
#    '41': 'Ambulance',
#    '42': 'Dune buggy',
#    '43': 'Fire truck (not rescue)',
#    '44': 'Forklift',
#    '45': 'Highway construction equipment (only while not in construction area)',
#    '46': 'Implement of husbandry',
#    '47': 'Motor home (40 ft or less)',
#    '48': 'CHP, police, or sheriff car (emergency service or not)',
#    '49': 'CHP, police, or sheriff motorcycle (emergency service or not)',
#    '50': 'Mobile equipment',
#    '51': 'Farm labor vehicle (certified)',
#    '52': 'Federally legal double cargo combo over 75ft',
#    '53': '5th wheel trailer',
#    '54': 'Container chassis',
#    '55': 'Two-axle tow truck',
#    '56': 'Three-axle tow truck',
#    '57': 'Farm labor vehicle (non-certified)',
#    '58': 'Farm labor transporter',
#    '59': 'Motorhome (over 40ft)',
#    '60': 'Pedestrian (includes motorized wheelchair)',
#    '61': 'School pupil activity bus I (prior to 2002)',
#    '62': 'School pupil activity bus II (prior to 2002)',
#    '63': 'Youth bus',
#    '64': 'School pupil activity bus I (eff 2002)',
#    '65': 'School pupil activity bus II (eff 2002)',
#    '66': 'School bus Without pupil passengers (eff 2002)',
#    '71': 'Passenger car - hazardous materials only',
#    '72': 'Pickups and panels - hazardous materials only',
#    '73': 'Pickups and campers - hazardous materials only',
#    '75': 'Truck tractor - hazardous materials only',
#    '76': 'Two-axle truck - hazardous materials only',
#    '77': 'Three or more axle truck - hazardous materials only',
#    '78': 'Two-axle tank truck - hazardous materials only',
#    '79': 'Three axle tank truck - hazardous materials only',
#    '81': 'Passenger car - hazardous waste or waste-material combo',
#    '82': 'Pickups and panels - hazardous waste or waste-material combo',
#    '83': 'Pickups and campers - hazardous waste or waste-material combo',
#    '85': 'Truck tractor - hazardous waste or waste-material combo',
#    '86': 'Two-axle truck - hazardous waste or waste-material combo',
#    '87': 'Three or more axle truck - hazardous waste or waste-material combo',
#    '88': 'Two-axle tank truck - hazardous waste or waste-material combo',
#    '89': 'Three-axle tank truck - hazardous waste or waste-material combo',
#    '91': 'Electric bicycle (class 1,2,3)',
#    '93': 'Electrically motorized board',
#    '94': 'Motorized transportation device',
#    '95': 'Miscellaneous non-motorized vehicle (ridden animal, animal-drawn conveyance, train or building) with victim',
#    '96': 'Miscellaneous motorized vehicle (golf cart)',
#    '97': 'Low speed vehicle',
#    '98': 'Emergency vehicle on an emergency run',
#    '99': 'Not stated or unknown (hit and run)',
#    '-': 'Not Stated'}},
#  'PRIMARY_RAMP': {'no': 85,
#   'level': 'Crash',
#   'alias': 'Primary Ramp',
#   'desc': 'A description of the ramp, if any, on primary roadway. This value is computed by the key operator from information on the crash report',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'TO': 'To',
#    'FR': 'From',
#    'NF': 'North Off Ramp',
#    'SF': 'South Off Ramp',
#    'EF': 'East Off Ramp',
#    'WF': 'West Off Ramp',
#    'NO': 'North On Ramp',
#    'SO': 'South On Ramp',
#    'EO': 'East On Ramp',
#    'WO': 'West On Ramp',
#    'TR': 'Transition',
#    'CO': 'Collector',
#    'CN': 'Connector',
#    '-': 'Not Stated'}},
#  'SECONDARY_RAMP': {'no': 86,
#   'level': 'Crash',
#   'alias': 'Secondary Ramp',
#   'desc': 'A description of the ramp, if any, on secondary roadway. This value is computed by the key operator from information on the crash report',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'TO': 'To',
#    'FR': 'From',
#    'NF': 'North Off Ramp',
#    'SF': 'South Off Ramp',
#    'EF': 'East Off Ramp',
#    'WF': 'West Off Ramp',
#    'NO': 'North On Ramp',
#    'SO': 'South On Ramp',
#    'EO': 'East On Ramp',
#    'WO': 'West On Ramp',
#    'TR': 'Transition',
#    'CO': 'Collector',
#    'CN': 'Connector',
#    '-': 'Not Stated'}},
#  'PARTY_TYPE': {'no': 87,
#   'level': 'Party',
#   'alias': 'Party Type',
#   'desc': 'Involved party type',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Driver (including hit and run)',
#    '2': 'Pedestrian',
#    '3': 'Parked vehicle',
#    '4': 'Bicyclist',
#    '5': 'Other',
#    '6': 'Operator',
#    '-': 'Not Stated'}},
#  'AT_FAULT': {'no': 88,
#   'level': 'Party',
#   'alias': 'At Fault',
#   'desc': 'Indicates whether the party was at fault in the crash',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes', 'N': 'No', '-': 'Not Stated'}},
#  'PARTY_SEX': {'no': 89,
#   'level': 'Party',
#   'alias': 'Party Sex',
#   'desc': 'The gender of the party',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'M': 'Male', 'F': 'Female', 'X': 'Nonbinary', '-': 'Not Stated'}},
#  'PARTY_AGE': {'no': 90,
#   'level': 'Party',
#   'alias': 'Party Age',
#   'desc': 'The age of the party at the time of the crash',
#   'type': 'LONG',
#   'cat': 'Measurement',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'998': 'Unknown'}},
#  'RACE': {'no': 91,
#   'level': 'Party',
#   'alias': 'Party Race',
#   'desc': "The party's race based on the reporting officer's judgment",
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Asian',
#    'B': 'Black',
#    'H': 'Hispanic',
#    'W': 'White',
#    'O': 'Other'}},
#  'PARTY_NUMBER_KILLED': {'no': 92,
#   'level': 'Party',
#   'alias': 'Party Number Killed',
#   'desc': 'Number of killed victims in the party',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'PARTY_NUMBER_INJURED': {'no': 93,
#   'level': 'Party',
#   'alias': 'Party Number Injured',
#   'desc': 'Number of injured victims in the party',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'INATTENTION': {'no': 94,
#   'level': 'Party',
#   'alias': 'Inattention',
#   'desc': 'Type of inattention',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Cell phone handheld',
#    'B': 'Cell phone handsfree',
#    'C': 'Electronic equipment',
#    'D': 'Radio/CD',
#    'E': 'Smoking',
#    'F': 'Eating',
#    'G': 'Children',
#    'H': 'Animal',
#    'I': 'Personal hygiene',
#    'J': 'Reading',
#    'K': 'Other',
#    'P': 'Cell Phone',
#    '-': 'Not Stated'}},
#  'PARTY_SOBRIETY': {'no': 95,
#   'level': 'Party',
#   'alias': 'Party Sobriety',
#   'desc': 'The state of sobriety of the party',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Had not been drinking',
#    'B': 'Had been drinking under influence',
#    'C': 'Had been drinking, not under influence',
#    'D': 'Had been drinking, impairment unknown',
#    'G': 'Impairment unknown',
#    'H': 'Not applicable',
#    '-': 'Not Stated'}},
#  'PARTY_DRUG_PHYSICAL': {'no': 96,
#   'level': 'Party',
#   'alias': 'Party Drug Physical',
#   'desc': 'The state of the party with regard to drugs and physical condition',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'E': 'Under drug influence',
#    'F': 'Impairment - physical',
#    'G': 'Impairment unknown',
#    'H': 'Not applicable',
#    'I': 'Sleepy or fatigued',
#    '-': 'Not Stated'}},
#  'DIR_OF_TRAVEL': {'no': 97,
#   'level': 'Party',
#   'alias': 'Direction of Travel',
#   'desc': 'Direction that the party was traveling at the time of the crash. The direction is the direction of the highway, not the compass direction',
#   'type': 'TEXT',
#   'cat': 'Measurement',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'N': 'North',
#    'S': 'South',
#    'E': 'East',
#    'W': 'West',
#    '-': 'Not Stated'}},
#  'PARTY_SAFETY_EQUIP_1': {'no': 98,
#   'level': 'Party',
#   'alias': 'Party Safety Equipment 1',
#   'desc': 'The safety equipment of the party',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'None in vehicle',
#    'B': 'Unknown',
#    'C': 'Lap belt used',
#    'D': 'Lab belt not used',
#    'E': 'Shoulder harness used',
#    'F': 'Shoulder harness not used',
#    'G': 'Lap/shoulder harness used',
#    'H': 'Lap/shoulder harness not used',
#    'J': 'Passive restraint used',
#    'K': 'Passive restraint not used',
#    'L': 'Air bag deployed',
#    'M': 'Air bag not deployed',
#    'N': 'Other',
#    'P': 'Not required',
#    'Q': 'Child restraint in vehicle used',
#    'R': 'Child restraint in vehicle not used',
#    'S': 'Child restraint in vehicle, use unknown',
#    'T': 'Child restraint in vehicle, improper use',
#    'U': 'No child restraint in vehicle',
#    'V': 'Driver, motorcycle helmet not used',
#    'W': 'Driver, motorcycle helmet used',
#    'X': 'Passenger, motorcycle helmet not used',
#    'Y': 'Passenger, motorcycle helmet used',
#    '-': 'Not Stated'}},
#  'PARTY_SAFETY_EQUIP_2': {'no': 99,
#   'level': 'Party',
#   'alias': 'Party Safety Equipment 2',
#   'desc': 'The safety equipment of the party',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'None in vehicle',
#    'B': 'Unknown',
#    'C': 'Lap belt used',
#    'D': 'Lab belt not used',
#    'E': 'Shoulder harness used',
#    'F': 'Shoulder harness not used',
#    'G': 'Lap/shoulder harness used',
#    'H': 'Lap/shoulder harness not used',
#    'J': 'Passive restraint used',
#    'K': 'Passive restraint not used',
#    'L': 'Air bag deployed',
#    'M': 'Air bag not deployed',
#    'N': 'Other',
#    'P': 'Not required',
#    'Q': 'Child restraint in vehicle used',
#    'R': 'Child restraint in vehicle not used',
#    'S': 'Child restraint in vehicle, use unknown',
#    'T': 'Child restraint in vehicle, improper use',
#    'U': 'No child restraint in vehicle',
#    'V': 'Driver, motorcycle helmet not used',
#    'W': 'Driver, motorcycle helmet used',
#    'X': 'Passenger, motorcycle helmet not used',
#    'Y': 'Passenger, motorcycle helmet used',
#    '-': 'Not Stated'}},
#  'FINAN_RESPONS': {'no': 100,
#   'level': 'Party',
#   'alias': 'Financial Responsibility',
#   'desc': 'Financial responsibility of the party',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'N': 'No proof of insurance obtained',
#    'Y': 'Yes, proof of insurance obtained',
#    'O': 'Not applicable (used for parked cars, bicyclists, pedestrians, and party type others)',
#    'E': 'Used if the officer is called away from the scene of the crash prior to obtaining the insurance information'}},
#  'SP_INFO_1': {'no': 101,
#   'level': 'Party',
#   'alias': 'Special Information 1',
#   'desc': 'Value A indicates that the crash involved in a vehicle known to be, or believed to be, transporting a hazardous material as defined in CVC Section 353, whether or not the crash involved a hazardous material incident',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Hazardous materials', '-': 'Not Stated'}},
#  'SP_INFO_2': {'no': 102,
#   'level': 'Party',
#   'alias': 'Special Information 2',
#   'desc': 'Cell Phone Information',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Cell phone handheld in use',
#    '2': 'Cell phone handsfree in use',
#    '3': 'Cell phone not in use',
#    '4': 'Cell phone use unknown',
#    'B': 'Cell phone in use',
#    'C': 'Cell phone not in use',
#    'D': 'No cell phone/unknown',
#    '-': 'Not Stated'}},
#  'SP_INFO_3': {'no': 103,
#   'level': 'Party',
#   'alias': 'Special Information 3',
#   'desc': 'Value E indicates that the crash involved a motor vehicle in-transport passing a stopped school bus with its red signal lamps in operation pursuant to CVC Section 22112, or reacting to, pursuant to CVC Section 22454',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'E': 'School bus related', '-': 'Not Stated'}},
#  'OAF_VIOLATION_CODE': {'no': 104,
#   'level': 'Party',
#   'alias': 'OAF Violation Code',
#   'desc': 'Other associated factor law code violated',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'B': 'Business and professions',
#    'C': 'Vehicle',
#    'H': 'City Health and Safety',
#    'I': 'City Ordinance',
#    'P': 'Penal',
#    'S': 'Streets and Highways',
#    'W': 'Welfare and institutions',
#    '-': 'Not Stated'}},
#  'OAF_VIOL_CAT': {'no': 105,
#   'level': 'Party',
#   'alias': 'OAF Violation Category',
#   'desc': 'Category of the factor that contributed to the crash but was not the primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not Stated',
#    '1': 'Under influence in public',
#    '2': 'County ordinance',
#    '3': 'City ordinance',
#    '5': 'Business/professions code',
#    '6': 'Felony penal code',
#    '8': 'Controlled substances (felony health and safety)',
#    '9': 'Health/safety code (misdemeanor)',
#    '10': 'Penal code (misdemeanor)',
#    '11': 'Streets/highways code',
#    '13': 'Welfare/institutions code',
#    '15': 'Manslaughter',
#    '16': 'Non-vehicle code not specified above',
#    '17': 'Fish and game code',
#    '18': 'Agriculture code',
#    '19': 'Hit and run',
#    '20': 'Driving or bicycling under the influence of alcohol or drug',
#    '21': 'Improper lane change',
#    '22': 'Impeding traffic',
#    '23': 'Failure to heed stop signal',
#    '24': 'Failure to heed stop sign',
#    '25': 'Unsafe speed',
#    '26': 'Reckless driving',
#    '27': 'Wrong side of road',
#    '28': 'Unsafe lane change',
#    '29': 'Improper passing',
#    '30': 'Following too closely',
#    '31': 'Improper turning',
#    '33': 'Automobile right-of-way',
#    '34': 'Pedestrian right-of-way',
#    '35': 'Pedestrian violation',
#    '38': 'Hazardous parking',
#    '39': 'Lights',
#    '40': 'Brakes',
#    '43': 'Other equipment',
#    '44': 'Other hazardous movement',
#    '46': 'Improper registration',
#    '47': 'Other non-moving violation',
#    '48': 'Excessive smoke',
#    '49': 'Excessive noise',
#    '50': 'Overweight',
#    '51': 'Oversize',
#    '52': 'Over maximum speed',
#    '53': 'Unsafe starting or backing',
#    '60': 'Off-highway vehicle violation',
#    '61': 'Child restraint',
#    '62': 'Seat belt',
#    '63': 'Seat belt (equipment)',
#    '-': 'Not Stated'}},
#  'OAF_VIOL_SECTION': {'no': 106,
#   'level': 'Party',
#   'alias': 'OAF Violation Section',
#   'desc': 'The CVC section of the secondary violation that contributed to the crash',
#   'type': 'DOUBLE',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'OAF_VIOLATION_SUFFIX': {'no': 107,
#   'level': 'Party',
#   'alias': 'OAF Violation Suffix',
#   'desc': 'the subsection of the CVC section of the secondary violation that contributed to the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'OAF_1': {'no': 108,
#   'level': 'Party',
#   'alias': 'Other Associated Factor 1',
#   'desc': 'A factor that contributed to the crash but was not the primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Violation',
#    'E': 'Vision obscurements',
#    'F': 'Inattention',
#    'G': 'Stop and go traffic',
#    'H': 'Entering/leaving ramp',
#    'I': 'Previous collision',
#    'J': 'Unfamiliar with road',
#    'K': 'Defective vehicle equipment',
#    'L': 'Uninvolved vehicle',
#    'M': 'Other',
#    'N': 'None apparent',
#    'O': 'Runaway vehicle',
#    'P': 'Inattention, cell phone',
#    'Q': 'Inattention, electronic equip',
#    'R': 'Inattention, radio/CD',
#    'S': 'Inattention, smoking',
#    'T': 'Inattention, eating',
#    'U': 'Inattention, children',
#    'V': 'Inattention, animal',
#    'W': 'Inattention, personal hygiene',
#    'X': 'Inattention, reading',
#    'Y': 'Inattention, other',
#    '-': 'Not Stated'}},
#  'OAF_2': {'no': 109,
#   'level': 'Party',
#   'alias': 'Other Associated Factor 2',
#   'desc': 'A factor that contributed to the crash but was not the primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Violation',
#    'E': 'Vision obscurements',
#    'F': 'Inattention',
#    'G': 'Stop and go traffic',
#    'H': 'Entering/leaving ramp',
#    'I': 'Previous collision',
#    'J': 'Unfamiliar with road',
#    'K': 'Defective vehicle equipment',
#    'L': 'Uninvolved vehicle',
#    'M': 'Other',
#    'N': 'None apparent',
#    'O': 'Runaway vehicle',
#    'P': 'Inattention, cell phone',
#    'Q': 'Inattention, electronic equip',
#    'R': 'Inattention, radio/CD',
#    'S': 'Inattention, smoking',
#    'T': 'Inattention, eating',
#    'U': 'Inattention, children',
#    'V': 'Inattention, animal',
#    'W': 'Inattention, personal hygiene',
#    'X': 'Inattention, reading',
#    'Y': 'Inattention, other',
#    '-': 'Not Stated'}},
#  'MOVE_PRE_ACC': {'no': 110,
#   'level': 'Party',
#   'alias': 'Movement Preceding Crash',
#   'desc': 'The action of the vehicle prior to the crash and before evasive action. This movement does not have to correspond with the PCF',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Stopped',
#    'B': 'Proceeding straight',
#    'C': 'Ran off road',
#    'D': 'Making right turn',
#    'E': 'Making left turn',
#    'F': 'Making U-turn',
#    'G': 'Backing',
#    'H': 'Slowing/stopping',
#    'I': 'Passing other vehicle',
#    'J': 'Changing lanes',
#    'K': 'Parking maneuver',
#    'L': 'Entering traffic',
#    'M': 'Other unsafe turning',
#    'N': 'Crossed into opposing lane',
#    'O': 'Parked',
#    'P': 'Merging',
#    'Q': 'Traveling wrong way',
#    'R': 'Other',
#    'S': 'Lane splitting',
#    '-': 'Not Stated'}},
#  'VEHICLE_YEAR': {'no': 111,
#   'level': 'Party',
#   'alias': 'Vehicle Year',
#   'desc': "The model year of the party's vehicle",
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'9999': 'Not Stated'}},
#  'VEHICLE_MAKE': {'no': 112,
#   'level': 'Party',
#   'alias': 'Vehicle Make',
#   'desc': "The make of the party's vehicle",
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'-': 'Not Stated'}},
#  'STWD_VEHICLE_TYPE': {'no': 113,
#   'level': 'Party',
#   'alias': 'Statewide Vehicle Type',
#   'desc': "Type of the party's vehicle according to a list called statewide vehicle type",
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Passenger car/station wagon',
#    'B': 'Passenger car with trailer',
#    'C': 'Motorcycle/scooter',
#    'D': 'Pickup or panel truck',
#    'E': 'Pickup or panel truck with trailer',
#    'F': 'Truck or truck tractor',
#    'G': 'Truck or truck tractor with trailer',
#    'H': 'Schoolbus',
#    'I': 'Other bus',
#    'J': 'Emergency vehicle',
#    'K': 'Highway construction equipment',
#    'L': 'Bicycle',
#    'M': 'Other vehicle',
#    'N': 'Pedestrian',
#    'O': 'Moped',
#    '-': 'Not Stated'}},
#  'CHP_VEH_TYPE_TOWING': {'no': 114,
#   'level': 'Party',
#   'alias': 'CHP Vehicle Type Towing',
# ...
#    '61': 'School pupil activity bus I (prior to 2002)',
#    '62': 'School pupil activity bus II (prior to 2002)',
#    '63': 'Youth bus',
#    '64': 'School pupil activity bus I (eff 2002)',
#    '65': 'School pupil activity bus II (eff 2002)',
#    '66': 'School bus Without pupil passengers (eff 2002)',
#    '71': 'Passenger car - hazardous materials only',
#    '72': 'Pickups and panels - hazardous materials only',
#    '73': 'Pickups and campers - hazardous materials only',
#    '75': 'Truck tractor - hazardous materials only',
#    '76': 'Two-axle truck - hazardous materials only',
#    '77': 'Three or more axle truck - hazardous materials only',
#    '78': 'Two-axle tank truck - hazardous materials only',
#    '79': 'Three axle tank truck - hazardous materials only',
#    '81': 'Passenger car - hazardous waste or waste-material combo',
#    '82': 'Pickups and panels - hazardous waste or waste-material combo',
#    '83': 'Pickups and campers - hazardous waste or waste-material combo',
#    '85': 'Truck tractor - hazardous waste or waste-material combo',
#    '86': 'Two-axle truck - hazardous waste or waste-material combo',
#    '87': 'Three or more axle truck - hazardous waste or waste-material combo',
#    '88': 'Two-axle tank truck - hazardous waste or waste-material combo',
#    '89': 'Three-axle tank truck - hazardous waste or waste-material combo',
#    '91': 'Electric bicycle (class 1,2,3)',
#    '93': 'Electrically motorized board',
#    '94': 'Motorized transportation device',
#    '95': 'Miscellaneous non-motorized vehicle (ridden animal, animal-drawn conveyance, train or building) with victim',
#    '96': 'Miscellaneous motorized vehicle (golf cart)',
#    '97': 'Low speed vehicle',
#    '98': 'Emergency vehicle on an emergency run',
#    '99': 'Not stated or unknown (hit and run)',
#    '-': 'Not Stated'}},
#  'CHP_VEH_TYPE_TOWED': {'no': 115,
#   'level': 'Party',
#   'alias': 'CHP Vehicle Type Towed',
#   'desc': 'The type of the first trailer unit according to the CHP manual HPM 110.5 Chapter 3 Annex F vehicle type codes',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Passenger, car, station Wagon, or Jeep',
#    '2': 'Motorcycle',
#    '3': 'Motor-driven cycle (<15 hp)',
#    '4': 'Bicycle',
#    '5': 'Motorized vehicle',
#    '6': 'All-terrain vehicle (ATV)',
#    '7': 'Sport utility vehicle',
#    '8': 'Minivan',
#    '9': 'Paratransit bus',
#    '10': 'Tour bus',
#    '11': 'Other commercial bus',
#    '12': 'Non-commercial bus',
#    '13': 'Schoolbus public I',
#    '14': 'Schoolbus public II',
#    '15': 'Schoolbus private I',
#    '16': 'Schoolbus private II',
#    '17': 'Schoolbus contractual I',
#    '18': 'Schoolbus contractual II',
#    '19': 'General public paratransit vehicle',
#    '20': 'Public transit authority',
#    '21': 'Two-axle tank truck',
#    '22': 'Pickup or panel truck',
#    '23': 'Pickup truck with camper',
#    '24': 'Three-axle tank truck',
#    '25': 'Truck tractor',
#    '26': 'Two-axle truck',
#    '27': 'Three-axle truck',
#    '28': 'Semi-tank trailer',
#    '29': 'Pull-tank trailer',
#    '30': 'Two-tank trailer',
#    '31': 'Semi-trailer',
#    '32': 'Pull trailer (includes dolly)',
#    '33': 'Two trailers (includes semi and trailer)',
#    '34': 'Boat trailer',
#    '35': 'Utility trailer',
#    '36': 'Trailer coach',
#    '37': 'Oversize vehicle/load',
#    '38': 'Pole, pipe, or logging dolly',
#    '39': 'Three trailers (includes semi and two trailers)',
#    '40': 'Semi 48 or less with king pin to trailer axle of over 38',
#    '41': 'Ambulance',
#    '42': 'Dune buggy',
#    '43': 'Fire truck (not rescue)',
#    '44': 'Forklift',
#    '45': 'Highway construction equipment (only while not in construction area)',
#    '46': 'Implement of husbandry',
#    '47': 'Motor home (40 ft or less)',
#    '48': 'CHP, police, or sheriff car (emergency service or not)',
#    '49': 'CHP, police, or sheriff motorcycle (emergency service or not)',
#    '50': 'Mobile equipment',
#    '51': 'Farm labor vehicle (certified)',
#    '52': 'Federally legal double cargo combo over 75ft',
#    '53': '5th wheel trailer',
#    '54': 'Container chassis',
#    '55': 'Two-axle tow truck',
#    '56': 'Three-axle tow truck',
#    '57': 'Farm labor vehicle (non-certified)',
#    '58': 'Farm labor transporter',
#    '59': 'Motorhome (over 40ft)',
#    '60': 'Pedestrian (includes motorized wheelchair)',
#    '61': 'School pupil activity bus I (prior to 2002)',
#    '62': 'School pupil activity bus II (prior to 2002)',
#    '63': 'Youth bus',
#    '64': 'School pupil activity bus I (eff 2002)',
#    '65': 'School pupil activity bus II (eff 2002)',
#    '66': 'School bus Without pupil passengers (eff 2002)',
#    '71': 'Passenger car - hazardous materials only',
#    '72': 'Pickups and panels - hazardous materials only',
#    '73': 'Pickups and campers - hazardous materials only',
#    '75': 'Truck tractor - hazardous materials only',
#    '76': 'Two-axle truck - hazardous materials only',
#    '77': 'Three or more axle truck - hazardous materials only',
#    '78': 'Two-axle tank truck - hazardous materials only',
#    '79': 'Three axle tank truck - hazardous materials only',
#    '81': 'Passenger car - hazardous waste or waste-material combo',
#    '82': 'Pickups and panels - hazardous waste or waste-material combo',
#    '83': 'Pickups and campers - hazardous waste or waste-material combo',
#    '85': 'Truck tractor - hazardous waste or waste-material combo',
#    '86': 'Two-axle truck - hazardous waste or waste-material combo',
#    '87': 'Three or more axle truck - hazardous waste or waste-material combo',
#    '88': 'Two-axle tank truck - hazardous waste or waste-material combo',
#    '89': 'Three-axle tank truck - hazardous waste or waste-material combo',
#    '91': 'Electric bicycle (class 1,2,3)',
#    '93': 'Electrically motorized board',
#    '94': 'Motorized transportation device',
#    '95': 'Miscellaneous non-motorized vehicle (ridden animal, animal-drawn conveyance, train or building) with victim',
#    '96': 'Miscellaneous motorized vehicle (golf cart)',
#    '97': 'Low speed vehicle',
#    '98': 'Emergency vehicle on an emergency run',
#    '99': 'Not stated or unknown (hit and run)',
#    '-': 'Not Stated'}},
#  'SPECIAL_INFO_F': {'no': 116,
#   'level': 'Party',
#   'alias': 'Special Info F',
#   'desc': "The value F indicate that the party's vehicle is a 75ft motor truck combo",
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'F': '75ft motor truck combo', '-': 'Not Stated'}},
#  'SPECIAL_INFO_G': {'no': 117,
#   'level': 'Party',
#   'alias': 'Special Info G',
#   'desc': "The value G indicates that the party's vehicle is a 32ft trailer combo",
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'G': '32ft trailer combo', '-': 'Not Stated'}},
#  'VICTIM_ROLE': {'no': 118,
#   'level': 'Victim',
#   'alias': 'Victim Role',
#   'desc': 'The role of the victim',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Driver',
#    '2': 'Passenger (includes non-operator on bicycle or any victim on/in parked vehicle or multiple victims on/in non-motor vehicle)',
#    '3': 'Pedestrian',
#    '4': 'Bicyclist',
#    '5': 'Other (single victim on/in non-motor vehicle)',
#    '6': 'Non-injured party'}},
#  'VICTIM_SEX': {'no': 119,
#   'level': 'Victim',
#   'alias': 'Victim Sex',
#   'desc': 'The gender of the victim',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'M': 'Male', 'F': 'Female', 'X': 'Nonbinary', '-': 'Not Stated'}},
#  'VICTIM_AGE': {'no': 120,
#   'level': 'Victim',
#   'alias': 'Victim Age',
#   'desc': 'The age of the victim at the time of the crash',
#   'type': 'LONG',
#   'cat': 'Measurement',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'998': 'Not Stated', '999': 'Fatal Fetus'}},
#  'VICTIM_DEGREE_OF_INJURY': {'no': 121,
#   'level': 'Victim',
#   'alias': 'Victim Degree of Injury',
#   'desc': 'The severity of the injury to the victim',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'No injury',
#    '1': 'Killed',
#    '2': 'Severe injury',
#    '3': 'Other visible injury',
#    '4': 'Complaint of pain',
#    '5': 'Suspected serious injury',
#    '6': 'Suspected minor injury',
#    '7': 'Possible injury'}},
#  'VICTIM_DEGREE_OF_INJURY_BINARY': {'no': 122,
#   'level': 'Victim',
#   'alias': 'Victim Injury Severity (Binary)',
#   'desc': 'Binary classification of the severity of the injury to the victim',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Minor (minor injury, pain, or no injury)',
#    '1': 'Severe (killed or serious injury)'}},
#  'VICTIM_SEATING_POSITION': {'no': 123,
#   'level': 'Victim',
#   'alias': 'Victim Seating Position',
#   'desc': 'The seating position of the victim',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Other occupants',
#    '1': 'Driver',
#    '2': 'Passenger 1',
#    '3': 'Passenger 2',
#    '4': 'Passenger 3',
#    '5': 'Passenger 4',
#    '6': 'Passenger 5',
#    '7': 'Station wagon rear',
#    '8': 'Rear occupant of truck or van',
#    '9': 'Position unknown',
#    '-': 'Not Stated'}},
#  'VICTIM_SAFETY_EQUIP_1': {'no': 124,
#   'level': 'Victim',
#   'alias': 'Victim Safety Equipment 1',
#   'desc': 'The safety equipment of the victim',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'None in vehicle',
#    'B': 'Unknown',
#    'C': 'Lap belt used',
#    'D': 'Lap belt not used',
#    'E': 'Shoulder harness used',
#    'F': 'Shoulder harness not used',
#    'G': 'Lap/shoulder harness used',
#    'H': 'Lap/shoulder harness not used',
#    'J': 'Passive restraint used',
#    'K': 'Passive restraint not used',
#    'L': 'Air bag deployed',
#    'M': 'Air bag not deployed',
#    'N': 'Other',
#    'P': 'Not required',
#    'Q': 'Child restraint in vehicle used',
#    'R': 'Child restraint in vehicle not used',
#    'S': 'Child restraint in vehicle, use unknown',
#    'T': 'Child restraint in vehicle, improper use',
#    'U': 'No child restraint in vehicle',
#    'V': 'Driver, motorcycle helmet used',
#    'W': 'Driver, motorcycle helmet not used',
#    'X': 'Passenger, motorcycle helmet not used',
#    'Y': 'Passenger, motorcycle helmet used',
#    '-': 'Not Stated'}},
#  'VICTIM_SAFETY_EQUIP_2': {'no': 125,
#   'level': 'Victim',
#   'alias': 'Victim Safety Equipment 2',
#   'desc': 'The safety equipment of the victim',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'None in vehicle',
#    'B': 'Unknown',
#    'C': 'Lap belt used',
#    'D': 'Lap belt not used',
#    'E': 'Shoulder harness used',
#    'F': 'Shoulder harness not used',
#    'G': 'Lap/shoulder harness used',
#    'H': 'Lap/shoulder harness not used',
#    'J': 'Passive restraint used',
#    'K': 'Passive restraint not used',
#    'L': 'Air bag deployed',
#    'M': 'Air bag not deployed',
#    'N': 'Other',
#    'P': 'Not required',
#    'Q': 'Child restraint in vehicle used',
#    'R': 'Child restraint in vehicle not used',
#    'S': 'Child restraint in vehicle, use unknown',
#    'T': 'Child restraint in vehicle, improper use',
#    'U': 'No child restraint in vehicle',
#    'V': 'Driver, motorcycle helmet used',
#    'W': 'Driver, motorcycle helmet not used',
#    'X': 'Passenger, motorcycle helmet not used',
#    'Y': 'Passenger, motorcycle helmet used',
#    '-': 'Not Stated'}},
#  'VICTIM_EJECTED': {'no': 126,
#   'level': 'Victim',
#   'alias': 'Victim Ejected',
#   'desc': 'Indicates whether the victim was ejected from the vehicle',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not ejected',
#    '1': 'Fully ejected',
#    '2': 'Partially ejected',
#    '3': 'Unknown',
#    '-': 'Not Stated'}},
#  'CITY_AREA_SQMI': {'no': 127,
#   'level': 'City',
#   'alias': 'City Area (sq. miles)',
#   'desc': 'City Area in Square Miles',
#   'type': 'DOUBLE',
#   'cat': 'Measurement',
#   'dbin': 'N'},
#  'CITY_POPDENS': {'no': 128,
#   'level': 'City',
#   'alias': 'City Population Density (per sq. mi)',
#   'desc': 'City population density, population per square mile',
#   'type': 'DOUBLE',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_HUDENS': {'no': 129,
#   'level': 'City',
#   'alias': 'City Housing Density (per sq. mi)',
#   'desc': 'City housing density, houses per square mile',
#   'type': 'DOUBLE',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_POPT': {'no': 130,
#   'level': 'City',
#   'alias': 'City Total Population',
#   'desc': "Total population in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_HUT': {'no': 131,
#   'level': 'City',
#   'alias': 'City Total Housing Units',
#   'desc': "Total housing units in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_POPA': {'no': 132,
#   'level': 'City',
#   'alias': 'City Asian Population',
#   'desc': "Total Asian population in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_POPB': {'no': 133,
#   'level': 'City',
#   'alias': 'City Black Population',
#   'desc': "Total Black or African American population in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_POPH': {'no': 134,
#   'level': 'City',
#   'alias': 'City Hispanic Population',
#   'desc': "Total Hispanic population in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_POPW': {'no': 135,
#   'level': 'City',
#   'alias': 'City White Population',
#   'desc': "Total White population in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_VEHICLES': {'no': 136,
#   'level': 'City',
#   'alias': 'City Aggregate Number of Vehicles Commuting',
#   'desc': "Aggregate number of vehicles used in commuting in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_TRAVEL_TIME': {'no': 137,
#   'level': 'City',
#   'alias': 'City Aggregate Travel Time to Work (min)',
#   'desc': "Aggregate travel time to work (in minutes) in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'RID': {'no': 138,
#   'level': 'Road',
#   'alias': 'Road ID',
#   'desc': "Road ID matching from the road's layer",
#   'type': 'TEXT',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'RNAME': {'no': 139,
#   'level': 'Road',
#   'alias': 'Road Name',
#   'desc': 'Road name from the OC Tiger/Lines layer',
#   'type': 'TEXT',
#   'cat': 'Name',
#   'dbin': 'N'},
#  'RCAT': {'no': 140,
#   'level': 'Road',
#   'alias': 'Road Category',
#   'desc': 'Road category from the OC Tiger/Lines layer',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'RLENGTH': {'no': 141,
#   'level': 'Road',
#   'alias': 'Road Length',
#   'desc': 'Road length from the OC Tiger/Lines layer',
#   'type': 'DOUBLE',
#   'cat': 'Measurement',
#   'dbin': 'N'},
#  'LATITUDE': {'no': 142,
#   'level': 'Crash',
#   'alias': 'GPS Latitude',
#   'desc': 'Latitude of the crash location in decimal degrees. The decimal point is included. LATITUDE and LONGITUDE are from the crash report',
#   'type': 'DOUBLE',
#   'cat': 'Coordinate',
#   'dbin': 'N'},
#  'LONGITUDE': {'no': 143,
#   'level': 'Crash',
#   'alias': 'GPS Longitude',
#   'desc': 'Longitude of the crash location in decimal degrees. The decimal point is included. There is no minus sign. The longitude is understood to be West of Meridian. LATITUDE and LONGITUDE are from the crash report',
#   'type': 'DOUBLE',
#   'cat': 'Coordinate',
#   'dbin': 'N'},
#  'POINT_X': {'no': 144,
#   'level': 'Crash',
#   'alias': 'X Coordinate Location',
#   'desc': 'The longitude of the geocoded location, uses the World Geodetic System from 1984 (WGS84). POINT_X and POINT_Y are generated using the geociding process by UC Berkeley Safe TREC',
#   'type': 'DOUBLE',
#   'cat': 'Coordinate',
#   'dbin': 'N'},
#  'POINT_Y': {'no': 145,
#   'level': 'Crash',
#   'alias': 'Y Coordinate Location',
#   'desc': 'The latitude of the geocoded location, uses the World Geodetic System from 1984 (WGS84). POINT_X and POINT_Y are generated using the geociding process by UC Berkeley Safe TREC',
#   'type': 'DOUBLE',
#   'cat': 'Coordinate',
#   'dbin': 'N'}}

# %%
print("Victims: Modifying codebook field types...")
modify_agp_types(codebook, victimsPointsFields)
# Out:
# Victims: Modifying codebook field types...
# {'OBJECTID': {'no': 1,
#   'level': 'GIS',
#   'alias': 'Object ID',
#   'desc': 'ESRI Object ID',
#   'type': 'OID',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'GlobalID': {'no': 2,
#   'level': 'GIS',
#   'alias': 'Global ID',
#   'desc': 'ESRI Global ID string identifier',
#   'type': 'GlobalID',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'GUID': {'no': 3,
#   'level': 'GIS',
#   'alias': 'GUID Related Table Identifier',
#   'desc': 'ESRI GUID to be used in merging related tables',
#   'type': 'Guid',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'CASE_ID': {'no': 4,
#   'level': 'Crash',
#   'alias': 'Case ID',
#   'desc': 'Unique identifier of the crash case',
#   'type': 'LONG',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'CID': {'no': 5,
#   'level': 'Crash',
#   'alias': 'Crash ID',
#   'desc': 'Unique identifier of the crash case',
#   'type': 'TEXT',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'PID': {'no': 6,
#   'level': 'Party',
#   'alias': 'Party ID',
#   'desc': 'Unique identifier for the party case',
#   'type': 'TEXT',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'VID': {'no': 7,
#   'level': 'Victim',
#   'alias': 'Victim ID',
#   'desc': 'Unique identifier of the victim case',
#   'type': 'TEXT',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'PARTY_NUMBER': {'no': 8,
#   'level': 'Party',
#   'alias': 'Party Number',
#   'desc': 'A number that together with the CASE_ID uniquely identifies a party in a crash',
#   'type': 'LONG',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'VICTIM_NUMBER': {'no': 9,
#   'level': 'Victim',
#   'alias': 'Victim Number',
#   'desc': 'The unique identifier of the victim',
#   'type': 'LONG',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'CRASHES_INDICATOR': {'no': 10,
#   'level': 'Crash',
#   'alias': 'Crashes Binary Indicator',
#   'desc': 'Binary flag, 1 if the record is a crash, 0 if not',
#   'type': 'LONG',
#   'cat': 'Binary',
#   'dbin': 'N'},
#  'PARTIES_INDICATOR': {'no': 11,
#   'level': 'Party',
#   'alias': 'Parties Binary Indicator',
#   'desc': 'Binary flag, 1 if the record is a party, 0 if not',
#   'type': 'LONG',
#   'cat': 'Binary',
#   'dbin': 'N'},
#  'VICTIMS_INDICATOR': {'no': 12,
#   'level': 'Victim',
#   'alias': 'Victims Binary Indicator',
#   'desc': 'Binary flag, 1 if the record is a victim, 0 if not',
#   'type': 'LONG',
#   'cat': 'Binary',
#   'dbin': 'N'},
#  'CITY': {'no': 13,
#   'level': 'City',
#   'alias': 'City',
#   'desc': 'Reported City of the crash',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'CITY_NAME': {'no': 14,
#   'level': 'City',
#   'alias': 'City Name',
#   'desc': 'City name from locational query',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'PLACE_TYPE': {'no': 15,
#   'level': 'City',
#   'alias': 'Place Type',
#   'desc': 'City or Unincorporated Area',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'COLLISION_DATETIME': {'no': 16,
#   'level': 'Crash',
#   'alias': 'Crash Date and Time',
#   'desc': 'Full date and time string of the crash',
#   'type': 'DATE',
#   'cat': 'Date and Time',
#   'dbin': 'N'},
#  'COLLISION_DATE': {'no': 17,
#   'level': 'Crash',
#   'alias': 'Crash Date',
#   'desc': 'The date when the crash occurred',
#   'type': 'DATE',
#   'cat': 'Date and Time',
#   'dbin': 'N'},
#  'COLLISION_TIME': {'no': 18,
#   'level': 'Crash',
#   'alias': 'Crash Time',
#   'desc': 'The time when the crash occurred in 24h format',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'N'},
#  'ACCIDENT_YEAR': {'no': 19,
#   'level': 'Crash',
#   'alias': 'Crash Year',
#   'desc': 'The year when the crash occurred',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'N'},
#  'COLLISION_MONTH': {'no': 20,
#   'level': 'Crash',
#   'alias': 'Crash Month',
#   'desc': 'Month number from crash date',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'January',
#    '2': 'February',
#    '3': 'March',
#    '4': 'April',
#    '5': 'May',
#    '6': 'June',
#    '7': 'July',
#    '8': 'August',
#    '9': 'September',
#    '10': 'October',
#    '11': 'November',
#    '12': 'December'}},
#  'DAY_OF_WEEK': {'no': 21,
#   'level': 'Crash',
#   'alias': 'Day of Week',
#   'desc': 'Code for the day of the week when the crash occurred',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Monday',
#    '2': 'Tuesday',
#    '3': 'Wednesday',
#    '4': 'Thursday',
#    '5': 'Friday',
#    '6': 'Saturday',
#    '7': 'Sunday'}},
#  'PROC_DATE': {'no': 22,
#   'level': 'Crash',
#   'alias': 'Processing Date',
#   'desc': 'The date that the crash case was last changed',
#   'type': 'DATE',
#   'cat': 'Date and Time',
#   'dbin': 'N'},
#  'COLLISION_TIME_INTERVALS': {'no': 23,
#   'level': 'Crash',
#   'alias': 'Crash Time Intervals',
#   'desc': 'Crash time interval ranges classification',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Night (00:00am to 06:00am)',
#    '2': 'Morning (06:00am to 12:00pm)',
#    '3': 'Afternoon (12:00pm to 06:00pm)',
#    '4': 'Evening (06:00pm to 00:00am)',
#    '999': 'Unknown Time'}},
#  'COLLISION_TIME_RUSH_HOURS': {'no': 24,
#   'level': 'Crash',
#   'alias': 'Rush Hours',
#   'desc': 'Rush hours interval ranges (Mon-Fri mornings and evenings)',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Rush Hours (Morning)',
#    '2': 'Rush Hours (Evening)',
#    '3': 'Non-Rush Hours',
#    '999': 'Unknown Time'}},
#  'COLLISION_SEVERITY': {'no': 25,
#   'level': 'Crash',
#   'alias': 'Crash Severity',
#   'desc': 'The worst injury suffered by any victim in the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'No injury, aka property damage only or PDO',
#    '1': 'Fatal injury',
#    '2': 'Suspected serous injury or severe injury',
#    '3': 'Suspected minor injury or visible injury',
#    '4': 'Possible injury or complaint of pain'}},
#  'COLLISION_SEVERITY_BINARY': {'no': 26,
#   'level': 'Crash',
#   'alias': 'Crash Severity (Binary)',
#   'desc': 'Binary classification of the worst injury suffered by any victim in the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Minor (minor injury, pain, or no injury)',
#    '1': 'Severe (killed or serious injury)'}},
#  'COLLISION_SEVERITY_RECLASS': {'no': 27,
#   'level': 'Crash',
#   'alias': 'Crash Severity Reclassified',
#   'desc': 'Reclassified crash severity based on the worst injury suffered by any victim in the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'None',
#    '1': 'Possible Injury or Pain',
#    '2': 'Minor or Visible Injury',
#    '3': 'Serious or Severe Injury',
#    '4': 'Fatal Injury'}},
#  'COLLISION_SEVERITY_RANKED': {'no': 28,
#   'level': 'Crash',
#   'alias': 'Crash Severity Ranked',
#   'desc': 'Ranked crash severity based on the worst injury suffered by any victim in the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'None or Minor Injuries',
#    '1': 'Single Injury (Severe)',
#    '2': 'Multiple Injuries (Severe)',
#    '3': 'Single Fatality, No Injuries (Fatal)',
#    '4': 'Single Fatality, Single Injury (Fatal)',
#    '5': 'Single Fatality, Multiple Injuries (Fatal)',
#    '6': 'Multiple Fatalities, No Injuries (Fatal)',
#    '7': 'Multiple Fatalities, Single Injury (Fatal)',
#    '8': 'Multiple Fatalities, Multiple Injuries (Fatal)'}},
#  'PARTY_COUNT': {'no': 29,
#   'level': 'Party',
#   'alias': 'Party Count',
#   'desc': 'Number of parties involved in the crash',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'VICTIM_COUNT': {'no': 30,
#   'level': 'Victim',
#   'alias': 'Victim Count',
#   'desc': 'Number of victims involved in each party',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'NUMBER_KILLED': {'no': 31,
#   'level': 'Crash',
#   'alias': 'Killed victims',
#   'desc': 'Number of killed victims',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'NUMBER_INJURED': {'no': 32,
#   'level': 'Crash',
#   'alias': 'Injured victims',
#   'desc': 'Number of injured victims',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_SEVERE_INJ': {'no': 33,
#   'level': 'Crash',
#   'alias': 'Severe Injury Count',
#   'desc': 'Number of victims in the crash with suspected serous injury or severe injury',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_VISIBLE_INJ': {'no': 34,
#   'level': 'Crash',
#   'alias': 'Other Visible Injury Count',
#   'desc': 'Number of victims in the crash with suspected minor injury or visible injury',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_COMPLAINT_PAIN': {'no': 35,
#   'level': 'Crash',
#   'alias': 'Complaint of Pain Injury Count',
#   'desc': 'Number of victims in the crash with possible injury or complaint of pain',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_PED_KILLED': {'no': 36,
#   'level': 'Crash',
#   'alias': 'Pedestrian Killed Count',
#   'desc': 'Number of killed pedestrian victims',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_PED_INJURED': {'no': 37,
#   'level': 'Crash',
#   'alias': 'Pedestrian Injured Count',
#   'desc': 'Number of injured pedestrian victims',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_BICYCLIST_KILLED': {'no': 38,
#   'level': 'Crash',
#   'alias': 'Bicyclist Killed Count',
#   'desc': 'Number of killed bicyclists',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_BICYCLIST_INJURED': {'no': 39,
#   'level': 'Crash',
#   'alias': 'Bicyclist Injured Count',
#   'desc': 'Number of injured bicyclists',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_MC_KILLED': {'no': 40,
#   'level': 'Crash',
#   'alias': 'Motorcyclist Killed Count',
#   'desc': 'Number of killed motorcyclists',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_MC_INJURED': {'no': 41,
#   'level': 'Crash',
#   'alias': 'Motorcyclist Injured Count',
#   'desc': 'Number of injured motorcyclists',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'PRIMARY_COLL_FACTOR': {'no': 42,
#   'level': 'Crash',
#   'alias': 'Primary Crash Factor',
#   'desc': 'The primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Vehicle Code Violation',
#    'B': 'Other Improper Driving',
#    'C': 'Other Than Driver',
#    'D': 'Unknown',
#    'E': 'Fell Asleep',
#    '-': 'Not Stated'}},
#  'TYPE_OF_COLLISION': {'no': 43,
#   'level': 'Crash',
#   'alias': 'Type of Crash',
#   'desc': 'The general type of crash as determined by the first injury or damage-causing event',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Head-On',
#    'B': 'Sideswipe',
#    'C': 'Rear End',
#    'D': 'Broadside',
#    'E': 'Hit Object',
#    'F': 'Overturned',
#    'G': 'Vehicle/Pedestrian',
#    'H': 'Other',
#    '-': 'Not Stated'}},
#  'PEDESTRIAN_ACCIDENT': {'no': 44,
#   'level': 'Crash',
#   'alias': 'Pedestrian Crash',
#   'desc': 'Indicates whether the crash involved a pedestrian',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'BICYCLE_ACCIDENT': {'no': 45,
#   'level': 'Crash',
#   'alias': 'Bicycle Crash',
#   'desc': 'Indicates whether the crash involved a bicycle',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'MOTORCYCLE_ACCIDENT': {'no': 46,
#   'level': 'Crash',
#   'alias': 'Motorcycle Crash',
#   'desc': 'Indicates whether the crash involved a motorcycle',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'TRUCK_ACCIDENT': {'no': 47,
#   'level': 'Crash',
#   'alias': 'Truck Crash',
#   'desc': 'Indicates whether the crash involved a big truck',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'HIT_AND_RUN': {'no': 48,
#   'level': 'Crash',
#   'alias': 'Hit and Run',
#   'desc': 'A flag to indicate the severity of hit-and-run crash. Felony hit-and-run resulted in injury or death to other parties. Misdemeanor hit-and-run did not result in injury or death to other parties',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'F': 'Felony', 'M': 'Misdemeanor', 'N': 'Not Hit and Run'}},
#  'ALCOHOL_INVOLVED': {'no': 49,
#   'level': 'Crash',
#   'alias': 'Alcohol Involved',
#   'desc': 'Indicates whether the crash involved a party that had been drinking. Note - a passenger does not count as a party',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'JURIS': {'no': 50,
#   'level': 'Crash',
#   'alias': 'Jurisdiction',
#   'desc': 'Law enforcement agency that has jurisdiction over the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'OFFICER_ID': {'no': 51,
#   'level': 'Crash',
#   'alias': 'Officer ID',
#   'desc': 'The badge number of the officer who wrote the crash report',
#   'type': 'TEXT',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'REPORTING_DISTRICT': {'no': 52,
#   'level': 'Crash',
#   'alias': 'Reporting District',
#   'desc': 'Reporting District on the crash report',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'CHP_SHIFT': {'no': 53,
#   'level': 'Crash',
#   'alias': 'CHP Shift',
#   'desc': 'CHP shift at the time of the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': '0600 thru 1359',
#    '2': '1400 thru 2159',
#    '3': '2200 thru 0559',
#    '4': 'CHP Not Stated',
#    '5': 'Not CHP'}},
#  'CNTY_CITY_LOC': {'no': 54,
#   'level': 'Crash',
#   'alias': 'County City Location',
#   'desc': 'The city or unincorporated county where the crash occurred',
#   'type': 'LONG',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'SPECIAL_COND': {'no': 55,
#   'level': 'Crash',
#   'alias': 'Special Condition',
#   'desc': 'A computed value. O means not private property',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not Above',
#    '1': 'Schoolbus on Public Roadway',
#    '2': 'State University (Also SFIA)',
#    '3': 'Schoolbus Not on Public Roadway',
#    '4': 'Offroad (Unimproved)',
#    '5': 'Vista Point or Rest Area or Sales or Inspection Facility',
#    '6': 'Other Public Access (Improved)',
#    '-': 'Not Stated'}},
#  'BEAT_TYPE': {'no': 56,
#   'level': 'Crash',
#   'alias': 'Beat Type',
#   'desc': 'Location of crash based on beat',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not CHP',
#    '1': 'CHP State Highway',
#    '2': 'CHP County RoadLine',
#    '3': 'CHP County RoadArea',
#    '4': 'Schoolbus on City Roadway',
#    '5': 'Schoolbus not on Public Roadway',
#    '6': 'Offroad (Unimproved)',
#    '7': 'Vista Point or Rest Area or Scales or Inspection Facility',
#    '8': 'Other Public Access (Improved)'}},
#  'CHP_BEAT_TYPE': {'no': 57,
#   'level': 'Crash',
#   'alias': 'CHP Beat Type',
#   'desc': 'Location of crash based on beat',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'NOT CHP',
#    '1': 'Interstate',
#    '2': 'US Highway',
#    '3': 'State Route',
#    '4': 'County RoadLine',
#    '5': 'County RoadArea',
#    '6': 'US Highway',
#    '7': 'State Route',
#    '8': 'County RoadLine',
#    '9': 'County RoadArea'}},
#  'CHP_BEAT_CLASS': {'no': 58,
#   'level': 'Crash',
#   'alias': 'CHP Beat Class',
#   'desc': 'Location of crash based on beat',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not CHP', '1': 'CHP Primary', '2': 'CHP Other'}},
#  'BEAT_NUMBER': {'no': 59,
#   'level': 'Crash',
#   'alias': 'Beat Number',
#   'desc': 'Beat of the officer who reported the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'PRIMARY_RD': {'no': 60,
#   'level': 'Crash',
#   'alias': 'Primary Road',
#   'desc': 'The name of the roadway on which the crash occurred',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'SECONDARY_RD': {'no': 61,
#   'level': 'Crash',
#   'alias': 'Secondary Road',
#   'desc': 'The name of the roadway that intersects the primary roadway',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'DISTANCE': {'no': 62,
#   'level': 'Crash',
#   'alias': 'Distance',
#   'desc': 'Distance of the crash from the intersection with the secondary roadway in ft',
#   'type': 'DOUBLE',
#   'cat': 'Measurement',
#   'dbin': 'N'},
#  'DIRECTION': {'no': 63,
#   'level': 'Crash',
#   'alias': 'Direction',
#   'desc': 'Direction of the crash from the intersection with the secondary roadway',
#   'type': 'TEXT',
#   'cat': 'Measurement',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'N': 'North',
#    'E': 'East',
#    'S': 'South',
#    'W': 'West',
#    '-': 'Not Stated'}},
#  'INTERSECTION': {'no': 64,
#   'level': 'Crash',
#   'alias': 'Intersection',
#   'desc': 'A flag that denotes if the crash occurred at the intersection with the secondary roadway',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Intersection', 'N': 'Not Intersection', '-': 'Not Stated'}},
#  'WEATHER_1': {'no': 65,
#   'level': 'Crash',
#   'alias': 'Weather 1',
#   'desc': 'Weather condition at the time of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Clear',
#    'B': 'Cloudy',
#    'C': 'Raining',
#    'D': 'Snowing',
#    'E': 'Fog',
#    'F': 'Other',
#    'G': 'Wind',
#    '-': 'Not Stated'}},
#  'WEATHER_2': {'no': 66,
#   'level': 'Crash',
#   'alias': 'Weather 2',
#   'desc': 'Additional weather condition at the time of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Clear',
#    'B': 'Cloudy',
#    'C': 'Raining',
#    'D': 'Snowing',
#    'E': 'Fog',
#    'F': 'Other',
#    'G': 'Wind',
#    '-': 'Not Stated'}},
#  'WEATHER_COMBINED': {'no': 67,
#   'level': 'Crash',
#   'alias': 'Combined Weather Conditions',
#   'desc': 'Combined Weather Conditions from WEATHER_1 and WEATHER_2 fields in numeric codes by weather conditions severity',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not Stated',
#    '10': 'Clear',
#    '12': 'Clear Cloudy',
#    '13': 'Clear Other',
#    '14': 'Clear Wind',
#    '15': 'Clear Raining',
#    '16': 'Clear Snowing',
#    '17': 'Clear Fog',
#    '20': 'Cloudy',
#    '21': 'Cloudy Clear',
#    '23': 'Cloudy Other',
#    '24': 'Cloudy Wind',
#    '25': 'Cloudy Raining',
#    '26': 'Cloudy Snowing',
#    '27': 'Cloudy Fog',
#    '30': 'Other',
#    '31': 'Other Clear',
#    '32': 'Other Cloudy',
#    '34': 'Other Wind',
#    '35': 'Other Raining',
#    '36': 'Other Snowing',
#    '37': 'Other Fog',
#    '40': 'Wind',
#    '41': 'Wind Clear',
#    '42': 'Wind Cloudy',
#    '43': 'Wind Other',
#    '45': 'Wind Raining',
#    '46': 'Wind Snowing',
#    '47': 'Wind Fog',
#    '50': 'Raining',
#    '51': 'Raining Clear',
#    '52': 'Raining Cloudy',
#    '53': 'Raining Other',
#    '54': 'Raining Wind',
#    '56': 'Raining Snowing',
#    '57': 'Raining Fog',
#    '60': 'Snowing',
#    '61': 'Snowing Clear',
#    '62': 'Snowing Cloudy',
#    '63': 'Snowing Other',
#    '64': 'Snowing Wind',
#    '65': 'Snowing Raining',
#    '67': 'Snowing Fog',
#    '70': 'Fog',
#    '71': 'Fog Clear',
#    '72': 'Fog Cloudy',
#    '73': 'Fog Other',
#    '74': 'Fog Wind',
#    '75': 'Fog Raining',
#    '76': 'Fog Snowing'}},
#  'ROAD_SURFACE': {'no': 68,
#   'level': 'Crash',
#   'alias': 'Road Surface',
#   'desc': 'Roadway surface condition at the time of the crash in the traffic lane(s) involved',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Dry',
#    'B': 'Wet',
#    'C': 'Snowy or Icy',
#    'D': 'Slippery (Muddy, Oily, etc)',
#    'O': 'Other',
#    '-': 'Not Stated'}},
#  'ROAD_COND_1': {'no': 69,
#   'level': 'Crash',
#   'alias': 'Road Condition 1',
#   'desc': 'Roadway condition at the time of the crash in the traffic lane(s) involved',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Holes, Deep Ruts',
#    'B': 'Loose Material on Roadway',
#    'C': 'Obstruction on Roadway',
#    'D': 'Construction or Repair Zone',
#    'E': 'Reduced Roadway Width',
#    'F': 'Flooded',
#    'G': 'Other',
#    'H': 'No Unusual Condition',
#    '-': 'Not Stated'}},
#  'ROAD_COND_2': {'no': 70,
#   'level': 'Crash',
#   'alias': 'Road Condition 2',
#   'desc': 'Second roadway condition at the time of the crash in the traffic lane(s) involved',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Holes, Deep Ruts',
#    'B': 'Loose Material on Roadway',
#    'C': 'Obstruction on Roadway',
#    'D': 'Construction or Repair Zone',
#    'E': 'Reduced Roadway Width',
#    'F': 'Flooded',
#    'G': 'Other',
#    'H': 'No Unusual Condition',
#    '-': 'Not Stated'}},
#  'LIGHTING': {'no': 71,
#   'level': 'Crash',
#   'alias': 'Lighting',
#   'desc': 'Lighting conditions at the crash location and the time of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Daylight',
#    'B': 'Dusk-Dawn',
#    'C': 'Dark-Street Lights',
#    'D': 'Dark-No Street Lights',
#    'E': 'Dark-Street Lights Not Functioning',
#    '-': 'Not Stated'}},
#  'CONTROL_DEVICE': {'no': 72,
#   'level': 'Crash',
#   'alias': 'Control Device',
#   'desc': 'Presence and condition of crash related traffic control devices at the time of the crash. Control devices include regulatory, warning, and construction sings. This excludes striping and officers or other persons directing traffic',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Functioning',
#    'B': 'Not Functioning',
#    'C': 'Obscured',
#    'D': 'None',
#    '-': 'Not Stated'}},
#  'STATE_HWY_IND': {'no': 73,
#   'level': 'Crash',
#   'alias': 'State Highway Indicator',
#   'desc': 'A flag to indicate whether the crash is on or near a state highway',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'State Highway', 'N': 'Not State Highway'}},
#  'SIDE_OF_HWY': {'no': 74,
#   'level': 'Crash',
#   'alias': 'Side of Highway',
#   'desc': 'Code provided by Caltrans Coders, applies to divided highway, based on nominal direction of route, for single vehicle is same as nominal direction of travel, overruled by impact with second vehicle after crossing median',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'N': 'Northbound',
#    'S': 'Southbound',
#    'E': 'Eastbound',
#    'W': 'Westbound'}},
#  'TOW_AWAY': {'no': 75,
#   'level': 'Crash',
#   'alias': 'Tow Away',
#   'desc': 'A flag to indicate whether the vehicle was towed away from the crash scene',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes', 'N': 'No'}},
#  'PCF_CODE_OF_VIOL': {'no': 76,
#   'level': 'Crash',
#   'alias': 'PCF Violation Code',
#   'desc': 'The law code that was violated and was the primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'B': 'Business and Professions',
#    'C': 'Vehicle',
#    'H': 'City Health and Safety',
#    'I': 'City Ordinance',
#    'O': 'County Ordinance',
#    'P': 'Penal',
#    'S': 'Streets and Highways',
#    'W': 'Welfare and Institutions',
#    '-': 'Not Stated'}},
#  'PCF_VIOL_CATEGORY': {'no': 77,
#   'level': 'Crash',
#   'alias': 'PCF Violation Category',
#   'desc': 'A value computed from the law section that was given as the primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Unknown',
#    '1': 'Driving or Bicycling Under the Influence of Alcohol or Drug',
#    '2': 'Impeding Traffic',
#    '3': 'Unsafe Speed',
#    '4': 'Following Too Closely',
#    '5': 'Wrong Side of Road',
#    '6': 'Improper Passing',
#    '7': 'Unsafe Lane Change',
#    '8': 'Improper Turning',
#    '9': 'Automobile Right of Way',
#    '10': 'Pedestrian Right of Way',
#    '11': 'Pedestrian Violation',
#    '12': 'Traffic Signals and Signs',
#    '13': 'Hazardous Parking',
#    '14': 'Lights',
#    '15': 'Brakes',
#    '16': 'Other Equipment',
#    '17': 'Other Hazardous Violation',
#    '18': 'Other Than Driver or Pedestrian',
#    '21': 'Unsafe Starting or Backing',
#    '22': 'Other Improper Driving',
#    '23': 'Pedestrian or Other Under the Influence of Alcohol or Drug',
#    '24': 'Fell Asleep',
#    '-': 'Not Stated'}},
#  'PCF_VIOLATION': {'no': 78,
#   'level': 'Crash',
#   'alias': 'PCF Violation',
#   'desc': 'The law section given as the primary cause of the crash. The subsection is in the data element pcf_viol_subsection',
#   'type': 'DOUBLE',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'PCF_VIOL_SUBSECTION': {'no': 79,
#   'level': 'Crash',
#   'alias': 'PCF Violation Subsection',
#   'desc': 'The subsection of the law section given as the primary cause of the crash in the data element pcf_violation',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'MVIW': {'no': 80,
#   'level': 'Crash',
#   'alias': 'Motor Vehicle Involved With',
#   'desc': 'Describes what, in conjunction with a motor vehicle in-transport, produced the first injury or damage-causing event, on or off the road',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Non-Collision and Additional Object',
#    '1': 'Pedestrian and Additional Object',
#    '2': 'Other Motor Vehicle and Additional Object',
#    '3': 'Motor Vehicle on Other Roadway and Additional Object',
#    '4': 'Parked Motor Vehicle and Additional Object',
#    '5': 'Train and Additional Object',
#    '6': 'Bicycle and Additional Object',
#    '7': 'Animal and Additional Object',
#    '8': 'Fixed Object and Additional Object',
#    '9': 'Other Object and Additional Object',
#    'A': 'Non-Collision',
#    'B': 'Pedestrian',
#    'C': 'Other Motor Vehicle',
#    'D': 'Motor Vehicle on Other Roadway',
#    'E': 'Parked Motor Vehicle',
#    'F': 'Train',
#    'G': 'Bicycle',
#    'H': 'Animal',
#    'I': 'Fixed Object',
#    'J': 'Other Object',
#    '-': 'Not Stated'}},
#  'PED_ACTION': {'no': 81,
#   'level': 'Crash',
#   'alias': 'Ped Action',
#   'desc': 'The action just prior to the crash of the first pedestrian injured or otherwise involved',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'No Pedestrian Involved',
#    'B': 'Crossing in Crosswalk at Intersection',
#    'C': 'Crossing in Crosswalk Not at Intersection',
#    'D': 'Crossing Not in Crosswalk',
#    'E': 'In Road, Including Shoulder',
#    'F': 'Not in Road',
#    'G': 'Approaching or Leaving School Bus',
#    '-': 'Not Stated'}},
#  'NOT_PRIVATE_PROPERTY': {'no': 82,
#   'level': 'Crash',
#   'alias': 'Not Private Property',
#   'desc': 'Y indicates that the crash did not occur on private property',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'STWD_VEHTYPE_AT_FAULT': {'no': 83,
#   'level': 'Crash',
#   'alias': 'Statewide Vehicle Type At Fault',
#   'desc': 'Indicates the Statewide Vehicle Type of the party who is at fault',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Passenger car/station wagon',
#    'B': 'Passenger car with trailer',
#    'C': 'Motorcycle/scooter',
#    'D': 'Pickup or panel truck',
#    'E': 'Pickup or panel truck with trailer',
#    'F': 'Truck or truck tractor',
#    'G': 'Truck or truck tractor with trailer',
#    'H': 'Schoolbus',
#    'I': 'Other bus',
#    'J': 'Emergency vehicle',
#    'K': 'Highway construction equipment',
#    'L': 'Bicycle',
#    'M': 'Other vehicle',
#    'N': 'Pedestrian',
#    'O': 'Moped',
#    '-': 'Not Stated'}},
#  'CHP_VEHTYPE_AT_FAULT': {'no': 84,
#   'level': 'Crash',
#   'alias': 'CHP Vehicle Type At Fault',
#   'desc': 'Indicates the CHP Vehicle Type of the party whi is at fault',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Passenger, car, station Wagon, or Jeep',
#    '2': 'Motorcycle',
#    '3': 'Motor-driven cycle (<15 hp)',
#    '4': 'Bicycle',
#    '5': 'Motorized vehicle',
#    '6': 'All-terrain vehicle (ATV)',
#    '7': 'Sport utility vehicle',
#    '8': 'Minivan',
#    '9': 'Paratransit bus',
#    '10': 'Tour bus',
#    '11': 'Other commercial bus',
#    '12': 'Non-commercial bus',
#    '13': 'Schoolbus public I',
#    '14': 'Schoolbus public II',
#    '15': 'Schoolbus private I',
#    '16': 'Schoolbus private II',
#    '17': 'Schoolbus contractual I',
#    '18': 'Schoolbus contractual II',
#    '19': 'General public paratransit vehicle',
#    '20': 'Public transit authority',
#    '21': 'Two-axle tank truck',
#    '22': 'Pickup or panel truck',
#    '23': 'Pickup truck with camper',
#    '24': 'Three-axle tank truck',
#    '25': 'Truck tractor',
#    '26': 'Two-axle truck',
#    '27': 'Three-axle truck',
#    '28': 'Semi-tank trailer',
#    '29': 'Pull-tank trailer',
#    '30': 'Two-tank trailer',
#    '31': 'Semi-trailer',
#    '32': 'Pull trailer (includes dolly)',
#    '33': 'Two trailers (includes semi and trailer)',
#    '34': 'Boat trailer',
#    '35': 'Utility trailer',
#    '36': 'Trailer coach',
#    '37': 'Oversize vehicle/load',
#    '38': 'Pole, pipe, or logging dolly',
#    '39': 'Three trailers (includes semi and two trailers)',
#    '40': 'Semi 48 or less with king pin to trailer axle of over 38',
#    '41': 'Ambulance',
#    '42': 'Dune buggy',
#    '43': 'Fire truck (not rescue)',
#    '44': 'Forklift',
#    '45': 'Highway construction equipment (only while not in construction area)',
#    '46': 'Implement of husbandry',
#    '47': 'Motor home (40 ft or less)',
#    '48': 'CHP, police, or sheriff car (emergency service or not)',
#    '49': 'CHP, police, or sheriff motorcycle (emergency service or not)',
#    '50': 'Mobile equipment',
#    '51': 'Farm labor vehicle (certified)',
#    '52': 'Federally legal double cargo combo over 75ft',
#    '53': '5th wheel trailer',
#    '54': 'Container chassis',
#    '55': 'Two-axle tow truck',
#    '56': 'Three-axle tow truck',
#    '57': 'Farm labor vehicle (non-certified)',
#    '58': 'Farm labor transporter',
#    '59': 'Motorhome (over 40ft)',
#    '60': 'Pedestrian (includes motorized wheelchair)',
#    '61': 'School pupil activity bus I (prior to 2002)',
#    '62': 'School pupil activity bus II (prior to 2002)',
#    '63': 'Youth bus',
#    '64': 'School pupil activity bus I (eff 2002)',
#    '65': 'School pupil activity bus II (eff 2002)',
#    '66': 'School bus Without pupil passengers (eff 2002)',
#    '71': 'Passenger car - hazardous materials only',
#    '72': 'Pickups and panels - hazardous materials only',
#    '73': 'Pickups and campers - hazardous materials only',
#    '75': 'Truck tractor - hazardous materials only',
#    '76': 'Two-axle truck - hazardous materials only',
#    '77': 'Three or more axle truck - hazardous materials only',
#    '78': 'Two-axle tank truck - hazardous materials only',
#    '79': 'Three axle tank truck - hazardous materials only',
#    '81': 'Passenger car - hazardous waste or waste-material combo',
#    '82': 'Pickups and panels - hazardous waste or waste-material combo',
#    '83': 'Pickups and campers - hazardous waste or waste-material combo',
#    '85': 'Truck tractor - hazardous waste or waste-material combo',
#    '86': 'Two-axle truck - hazardous waste or waste-material combo',
#    '87': 'Three or more axle truck - hazardous waste or waste-material combo',
#    '88': 'Two-axle tank truck - hazardous waste or waste-material combo',
#    '89': 'Three-axle tank truck - hazardous waste or waste-material combo',
#    '91': 'Electric bicycle (class 1,2,3)',
#    '93': 'Electrically motorized board',
#    '94': 'Motorized transportation device',
#    '95': 'Miscellaneous non-motorized vehicle (ridden animal, animal-drawn conveyance, train or building) with victim',
#    '96': 'Miscellaneous motorized vehicle (golf cart)',
#    '97': 'Low speed vehicle',
#    '98': 'Emergency vehicle on an emergency run',
#    '99': 'Not stated or unknown (hit and run)',
#    '-': 'Not Stated'}},
#  'PRIMARY_RAMP': {'no': 85,
#   'level': 'Crash',
#   'alias': 'Primary Ramp',
#   'desc': 'A description of the ramp, if any, on primary roadway. This value is computed by the key operator from information on the crash report',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'TO': 'To',
#    'FR': 'From',
#    'NF': 'North Off Ramp',
#    'SF': 'South Off Ramp',
#    'EF': 'East Off Ramp',
#    'WF': 'West Off Ramp',
#    'NO': 'North On Ramp',
#    'SO': 'South On Ramp',
#    'EO': 'East On Ramp',
#    'WO': 'West On Ramp',
#    'TR': 'Transition',
#    'CO': 'Collector',
#    'CN': 'Connector',
#    '-': 'Not Stated'}},
#  'SECONDARY_RAMP': {'no': 86,
#   'level': 'Crash',
#   'alias': 'Secondary Ramp',
#   'desc': 'A description of the ramp, if any, on secondary roadway. This value is computed by the key operator from information on the crash report',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'TO': 'To',
#    'FR': 'From',
#    'NF': 'North Off Ramp',
#    'SF': 'South Off Ramp',
#    'EF': 'East Off Ramp',
#    'WF': 'West Off Ramp',
#    'NO': 'North On Ramp',
#    'SO': 'South On Ramp',
#    'EO': 'East On Ramp',
#    'WO': 'West On Ramp',
#    'TR': 'Transition',
#    'CO': 'Collector',
#    'CN': 'Connector',
#    '-': 'Not Stated'}},
#  'PARTY_TYPE': {'no': 87,
#   'level': 'Party',
#   'alias': 'Party Type',
#   'desc': 'Involved party type',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Driver (including hit and run)',
#    '2': 'Pedestrian',
#    '3': 'Parked vehicle',
#    '4': 'Bicyclist',
#    '5': 'Other',
#    '6': 'Operator',
#    '-': 'Not Stated'}},
#  'AT_FAULT': {'no': 88,
#   'level': 'Party',
#   'alias': 'At Fault',
#   'desc': 'Indicates whether the party was at fault in the crash',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes', 'N': 'No', '-': 'Not Stated'}},
#  'PARTY_SEX': {'no': 89,
#   'level': 'Party',
#   'alias': 'Party Sex',
#   'desc': 'The gender of the party',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'M': 'Male', 'F': 'Female', 'X': 'Nonbinary', '-': 'Not Stated'}},
#  'PARTY_AGE': {'no': 90,
#   'level': 'Party',
#   'alias': 'Party Age',
#   'desc': 'The age of the party at the time of the crash',
#   'type': 'LONG',
#   'cat': 'Measurement',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'998': 'Unknown'}},
#  'RACE': {'no': 91,
#   'level': 'Party',
#   'alias': 'Party Race',
#   'desc': "The party's race based on the reporting officer's judgment",
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Asian',
#    'B': 'Black',
#    'H': 'Hispanic',
#    'W': 'White',
#    'O': 'Other'}},
#  'PARTY_NUMBER_KILLED': {'no': 92,
#   'level': 'Party',
#   'alias': 'Party Number Killed',
#   'desc': 'Number of killed victims in the party',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'PARTY_NUMBER_INJURED': {'no': 93,
#   'level': 'Party',
#   'alias': 'Party Number Injured',
#   'desc': 'Number of injured victims in the party',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'INATTENTION': {'no': 94,
#   'level': 'Party',
#   'alias': 'Inattention',
#   'desc': 'Type of inattention',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Cell phone handheld',
#    'B': 'Cell phone handsfree',
#    'C': 'Electronic equipment',
#    'D': 'Radio/CD',
#    'E': 'Smoking',
#    'F': 'Eating',
#    'G': 'Children',
#    'H': 'Animal',
#    'I': 'Personal hygiene',
#    'J': 'Reading',
#    'K': 'Other',
#    'P': 'Cell Phone',
#    '-': 'Not Stated'}},
#  'PARTY_SOBRIETY': {'no': 95,
#   'level': 'Party',
#   'alias': 'Party Sobriety',
#   'desc': 'The state of sobriety of the party',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Had not been drinking',
#    'B': 'Had been drinking under influence',
#    'C': 'Had been drinking, not under influence',
#    'D': 'Had been drinking, impairment unknown',
#    'G': 'Impairment unknown',
#    'H': 'Not applicable',
#    '-': 'Not Stated'}},
#  'PARTY_DRUG_PHYSICAL': {'no': 96,
#   'level': 'Party',
#   'alias': 'Party Drug Physical',
#   'desc': 'The state of the party with regard to drugs and physical condition',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'E': 'Under drug influence',
#    'F': 'Impairment - physical',
#    'G': 'Impairment unknown',
#    'H': 'Not applicable',
#    'I': 'Sleepy or fatigued',
#    '-': 'Not Stated'}},
#  'DIR_OF_TRAVEL': {'no': 97,
#   'level': 'Party',
#   'alias': 'Direction of Travel',
#   'desc': 'Direction that the party was traveling at the time of the crash. The direction is the direction of the highway, not the compass direction',
#   'type': 'TEXT',
#   'cat': 'Measurement',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'N': 'North',
#    'S': 'South',
#    'E': 'East',
#    'W': 'West',
#    '-': 'Not Stated'}},
#  'PARTY_SAFETY_EQUIP_1': {'no': 98,
#   'level': 'Party',
#   'alias': 'Party Safety Equipment 1',
#   'desc': 'The safety equipment of the party',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'None in vehicle',
#    'B': 'Unknown',
#    'C': 'Lap belt used',
#    'D': 'Lab belt not used',
#    'E': 'Shoulder harness used',
#    'F': 'Shoulder harness not used',
#    'G': 'Lap/shoulder harness used',
#    'H': 'Lap/shoulder harness not used',
#    'J': 'Passive restraint used',
#    'K': 'Passive restraint not used',
#    'L': 'Air bag deployed',
#    'M': 'Air bag not deployed',
#    'N': 'Other',
#    'P': 'Not required',
#    'Q': 'Child restraint in vehicle used',
#    'R': 'Child restraint in vehicle not used',
#    'S': 'Child restraint in vehicle, use unknown',
#    'T': 'Child restraint in vehicle, improper use',
#    'U': 'No child restraint in vehicle',
#    'V': 'Driver, motorcycle helmet not used',
#    'W': 'Driver, motorcycle helmet used',
#    'X': 'Passenger, motorcycle helmet not used',
#    'Y': 'Passenger, motorcycle helmet used',
#    '-': 'Not Stated'}},
#  'PARTY_SAFETY_EQUIP_2': {'no': 99,
#   'level': 'Party',
#   'alias': 'Party Safety Equipment 2',
#   'desc': 'The safety equipment of the party',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'None in vehicle',
#    'B': 'Unknown',
#    'C': 'Lap belt used',
#    'D': 'Lab belt not used',
#    'E': 'Shoulder harness used',
#    'F': 'Shoulder harness not used',
#    'G': 'Lap/shoulder harness used',
#    'H': 'Lap/shoulder harness not used',
#    'J': 'Passive restraint used',
#    'K': 'Passive restraint not used',
#    'L': 'Air bag deployed',
#    'M': 'Air bag not deployed',
#    'N': 'Other',
#    'P': 'Not required',
#    'Q': 'Child restraint in vehicle used',
#    'R': 'Child restraint in vehicle not used',
#    'S': 'Child restraint in vehicle, use unknown',
#    'T': 'Child restraint in vehicle, improper use',
#    'U': 'No child restraint in vehicle',
#    'V': 'Driver, motorcycle helmet not used',
#    'W': 'Driver, motorcycle helmet used',
#    'X': 'Passenger, motorcycle helmet not used',
#    'Y': 'Passenger, motorcycle helmet used',
#    '-': 'Not Stated'}},
#  'FINAN_RESPONS': {'no': 100,
#   'level': 'Party',
#   'alias': 'Financial Responsibility',
#   'desc': 'Financial responsibility of the party',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'N': 'No proof of insurance obtained',
#    'Y': 'Yes, proof of insurance obtained',
#    'O': 'Not applicable (used for parked cars, bicyclists, pedestrians, and party type others)',
#    'E': 'Used if the officer is called away from the scene of the crash prior to obtaining the insurance information'}},
#  'SP_INFO_1': {'no': 101,
#   'level': 'Party',
#   'alias': 'Special Information 1',
#   'desc': 'Value A indicates that the crash involved in a vehicle known to be, or believed to be, transporting a hazardous material as defined in CVC Section 353, whether or not the crash involved a hazardous material incident',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Hazardous materials', '-': 'Not Stated'}},
#  'SP_INFO_2': {'no': 102,
#   'level': 'Party',
#   'alias': 'Special Information 2',
#   'desc': 'Cell Phone Information',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Cell phone handheld in use',
#    '2': 'Cell phone handsfree in use',
#    '3': 'Cell phone not in use',
#    '4': 'Cell phone use unknown',
#    'B': 'Cell phone in use',
#    'C': 'Cell phone not in use',
#    'D': 'No cell phone/unknown',
#    '-': 'Not Stated'}},
#  'SP_INFO_3': {'no': 103,
#   'level': 'Party',
#   'alias': 'Special Information 3',
#   'desc': 'Value E indicates that the crash involved a motor vehicle in-transport passing a stopped school bus with its red signal lamps in operation pursuant to CVC Section 22112, or reacting to, pursuant to CVC Section 22454',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'E': 'School bus related', '-': 'Not Stated'}},
#  'OAF_VIOLATION_CODE': {'no': 104,
#   'level': 'Party',
#   'alias': 'OAF Violation Code',
#   'desc': 'Other associated factor law code violated',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'B': 'Business and professions',
#    'C': 'Vehicle',
#    'H': 'City Health and Safety',
#    'I': 'City Ordinance',
#    'P': 'Penal',
#    'S': 'Streets and Highways',
#    'W': 'Welfare and institutions',
#    '-': 'Not Stated'}},
#  'OAF_VIOL_CAT': {'no': 105,
#   'level': 'Party',
#   'alias': 'OAF Violation Category',
#   'desc': 'Category of the factor that contributed to the crash but was not the primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not Stated',
#    '1': 'Under influence in public',
#    '2': 'County ordinance',
#    '3': 'City ordinance',
#    '5': 'Business/professions code',
#    '6': 'Felony penal code',
#    '8': 'Controlled substances (felony health and safety)',
#    '9': 'Health/safety code (misdemeanor)',
#    '10': 'Penal code (misdemeanor)',
#    '11': 'Streets/highways code',
#    '13': 'Welfare/institutions code',
#    '15': 'Manslaughter',
#    '16': 'Non-vehicle code not specified above',
#    '17': 'Fish and game code',
#    '18': 'Agriculture code',
#    '19': 'Hit and run',
#    '20': 'Driving or bicycling under the influence of alcohol or drug',
#    '21': 'Improper lane change',
#    '22': 'Impeding traffic',
#    '23': 'Failure to heed stop signal',
#    '24': 'Failure to heed stop sign',
#    '25': 'Unsafe speed',
#    '26': 'Reckless driving',
#    '27': 'Wrong side of road',
#    '28': 'Unsafe lane change',
#    '29': 'Improper passing',
#    '30': 'Following too closely',
#    '31': 'Improper turning',
#    '33': 'Automobile right-of-way',
#    '34': 'Pedestrian right-of-way',
#    '35': 'Pedestrian violation',
#    '38': 'Hazardous parking',
#    '39': 'Lights',
#    '40': 'Brakes',
#    '43': 'Other equipment',
#    '44': 'Other hazardous movement',
#    '46': 'Improper registration',
#    '47': 'Other non-moving violation',
#    '48': 'Excessive smoke',
#    '49': 'Excessive noise',
#    '50': 'Overweight',
#    '51': 'Oversize',
#    '52': 'Over maximum speed',
#    '53': 'Unsafe starting or backing',
#    '60': 'Off-highway vehicle violation',
#    '61': 'Child restraint',
#    '62': 'Seat belt',
#    '63': 'Seat belt (equipment)',
#    '-': 'Not Stated'}},
#  'OAF_VIOL_SECTION': {'no': 106,
#   'level': 'Party',
#   'alias': 'OAF Violation Section',
#   'desc': 'The CVC section of the secondary violation that contributed to the crash',
#   'type': 'DOUBLE',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'OAF_VIOLATION_SUFFIX': {'no': 107,
#   'level': 'Party',
#   'alias': 'OAF Violation Suffix',
#   'desc': 'the subsection of the CVC section of the secondary violation that contributed to the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'OAF_1': {'no': 108,
#   'level': 'Party',
#   'alias': 'Other Associated Factor 1',
#   'desc': 'A factor that contributed to the crash but was not the primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Violation',
#    'E': 'Vision obscurements',
#    'F': 'Inattention',
#    'G': 'Stop and go traffic',
#    'H': 'Entering/leaving ramp',
#    'I': 'Previous collision',
#    'J': 'Unfamiliar with road',
#    'K': 'Defective vehicle equipment',
#    'L': 'Uninvolved vehicle',
#    'M': 'Other',
#    'N': 'None apparent',
#    'O': 'Runaway vehicle',
#    'P': 'Inattention, cell phone',
#    'Q': 'Inattention, electronic equip',
#    'R': 'Inattention, radio/CD',
#    'S': 'Inattention, smoking',
#    'T': 'Inattention, eating',
#    'U': 'Inattention, children',
#    'V': 'Inattention, animal',
#    'W': 'Inattention, personal hygiene',
#    'X': 'Inattention, reading',
#    'Y': 'Inattention, other',
#    '-': 'Not Stated'}},
#  'OAF_2': {'no': 109,
#   'level': 'Party',
#   'alias': 'Other Associated Factor 2',
#   'desc': 'A factor that contributed to the crash but was not the primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Violation',
#    'E': 'Vision obscurements',
#    'F': 'Inattention',
#    'G': 'Stop and go traffic',
#    'H': 'Entering/leaving ramp',
#    'I': 'Previous collision',
#    'J': 'Unfamiliar with road',
#    'K': 'Defective vehicle equipment',
#    'L': 'Uninvolved vehicle',
#    'M': 'Other',
#    'N': 'None apparent',
#    'O': 'Runaway vehicle',
#    'P': 'Inattention, cell phone',
#    'Q': 'Inattention, electronic equip',
#    'R': 'Inattention, radio/CD',
#    'S': 'Inattention, smoking',
#    'T': 'Inattention, eating',
#    'U': 'Inattention, children',
#    'V': 'Inattention, animal',
#    'W': 'Inattention, personal hygiene',
#    'X': 'Inattention, reading',
#    'Y': 'Inattention, other',
#    '-': 'Not Stated'}},
#  'MOVE_PRE_ACC': {'no': 110,
#   'level': 'Party',
#   'alias': 'Movement Preceding Crash',
#   'desc': 'The action of the vehicle prior to the crash and before evasive action. This movement does not have to correspond with the PCF',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Stopped',
#    'B': 'Proceeding straight',
#    'C': 'Ran off road',
#    'D': 'Making right turn',
#    'E': 'Making left turn',
#    'F': 'Making U-turn',
#    'G': 'Backing',
#    'H': 'Slowing/stopping',
#    'I': 'Passing other vehicle',
#    'J': 'Changing lanes',
#    'K': 'Parking maneuver',
#    'L': 'Entering traffic',
#    'M': 'Other unsafe turning',
#    'N': 'Crossed into opposing lane',
#    'O': 'Parked',
#    'P': 'Merging',
#    'Q': 'Traveling wrong way',
#    'R': 'Other',
#    'S': 'Lane splitting',
#    '-': 'Not Stated'}},
#  'VEHICLE_YEAR': {'no': 111,
#   'level': 'Party',
#   'alias': 'Vehicle Year',
#   'desc': "The model year of the party's vehicle",
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'9999': 'Not Stated'}},
#  'VEHICLE_MAKE': {'no': 112,
#   'level': 'Party',
#   'alias': 'Vehicle Make',
#   'desc': "The make of the party's vehicle",
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'-': 'Not Stated'}},
#  'STWD_VEHICLE_TYPE': {'no': 113,
#   'level': 'Party',
#   'alias': 'Statewide Vehicle Type',
#   'desc': "Type of the party's vehicle according to a list called statewide vehicle type",
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Passenger car/station wagon',
#    'B': 'Passenger car with trailer',
#    'C': 'Motorcycle/scooter',
#    'D': 'Pickup or panel truck',
#    'E': 'Pickup or panel truck with trailer',
#    'F': 'Truck or truck tractor',
#    'G': 'Truck or truck tractor with trailer',
#    'H': 'Schoolbus',
#    'I': 'Other bus',
#    'J': 'Emergency vehicle',
#    'K': 'Highway construction equipment',
#    'L': 'Bicycle',
#    'M': 'Other vehicle',
#    'N': 'Pedestrian',
#    'O': 'Moped',
#    '-': 'Not Stated'}},
#  'CHP_VEH_TYPE_TOWING': {'no': 114,
#   'level': 'Party',
#   'alias': 'CHP Vehicle Type Towing',
# ...
#    '61': 'School pupil activity bus I (prior to 2002)',
#    '62': 'School pupil activity bus II (prior to 2002)',
#    '63': 'Youth bus',
#    '64': 'School pupil activity bus I (eff 2002)',
#    '65': 'School pupil activity bus II (eff 2002)',
#    '66': 'School bus Without pupil passengers (eff 2002)',
#    '71': 'Passenger car - hazardous materials only',
#    '72': 'Pickups and panels - hazardous materials only',
#    '73': 'Pickups and campers - hazardous materials only',
#    '75': 'Truck tractor - hazardous materials only',
#    '76': 'Two-axle truck - hazardous materials only',
#    '77': 'Three or more axle truck - hazardous materials only',
#    '78': 'Two-axle tank truck - hazardous materials only',
#    '79': 'Three axle tank truck - hazardous materials only',
#    '81': 'Passenger car - hazardous waste or waste-material combo',
#    '82': 'Pickups and panels - hazardous waste or waste-material combo',
#    '83': 'Pickups and campers - hazardous waste or waste-material combo',
#    '85': 'Truck tractor - hazardous waste or waste-material combo',
#    '86': 'Two-axle truck - hazardous waste or waste-material combo',
#    '87': 'Three or more axle truck - hazardous waste or waste-material combo',
#    '88': 'Two-axle tank truck - hazardous waste or waste-material combo',
#    '89': 'Three-axle tank truck - hazardous waste or waste-material combo',
#    '91': 'Electric bicycle (class 1,2,3)',
#    '93': 'Electrically motorized board',
#    '94': 'Motorized transportation device',
#    '95': 'Miscellaneous non-motorized vehicle (ridden animal, animal-drawn conveyance, train or building) with victim',
#    '96': 'Miscellaneous motorized vehicle (golf cart)',
#    '97': 'Low speed vehicle',
#    '98': 'Emergency vehicle on an emergency run',
#    '99': 'Not stated or unknown (hit and run)',
#    '-': 'Not Stated'}},
#  'CHP_VEH_TYPE_TOWED': {'no': 115,
#   'level': 'Party',
#   'alias': 'CHP Vehicle Type Towed',
#   'desc': 'The type of the first trailer unit according to the CHP manual HPM 110.5 Chapter 3 Annex F vehicle type codes',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Passenger, car, station Wagon, or Jeep',
#    '2': 'Motorcycle',
#    '3': 'Motor-driven cycle (<15 hp)',
#    '4': 'Bicycle',
#    '5': 'Motorized vehicle',
#    '6': 'All-terrain vehicle (ATV)',
#    '7': 'Sport utility vehicle',
#    '8': 'Minivan',
#    '9': 'Paratransit bus',
#    '10': 'Tour bus',
#    '11': 'Other commercial bus',
#    '12': 'Non-commercial bus',
#    '13': 'Schoolbus public I',
#    '14': 'Schoolbus public II',
#    '15': 'Schoolbus private I',
#    '16': 'Schoolbus private II',
#    '17': 'Schoolbus contractual I',
#    '18': 'Schoolbus contractual II',
#    '19': 'General public paratransit vehicle',
#    '20': 'Public transit authority',
#    '21': 'Two-axle tank truck',
#    '22': 'Pickup or panel truck',
#    '23': 'Pickup truck with camper',
#    '24': 'Three-axle tank truck',
#    '25': 'Truck tractor',
#    '26': 'Two-axle truck',
#    '27': 'Three-axle truck',
#    '28': 'Semi-tank trailer',
#    '29': 'Pull-tank trailer',
#    '30': 'Two-tank trailer',
#    '31': 'Semi-trailer',
#    '32': 'Pull trailer (includes dolly)',
#    '33': 'Two trailers (includes semi and trailer)',
#    '34': 'Boat trailer',
#    '35': 'Utility trailer',
#    '36': 'Trailer coach',
#    '37': 'Oversize vehicle/load',
#    '38': 'Pole, pipe, or logging dolly',
#    '39': 'Three trailers (includes semi and two trailers)',
#    '40': 'Semi 48 or less with king pin to trailer axle of over 38',
#    '41': 'Ambulance',
#    '42': 'Dune buggy',
#    '43': 'Fire truck (not rescue)',
#    '44': 'Forklift',
#    '45': 'Highway construction equipment (only while not in construction area)',
#    '46': 'Implement of husbandry',
#    '47': 'Motor home (40 ft or less)',
#    '48': 'CHP, police, or sheriff car (emergency service or not)',
#    '49': 'CHP, police, or sheriff motorcycle (emergency service or not)',
#    '50': 'Mobile equipment',
#    '51': 'Farm labor vehicle (certified)',
#    '52': 'Federally legal double cargo combo over 75ft',
#    '53': '5th wheel trailer',
#    '54': 'Container chassis',
#    '55': 'Two-axle tow truck',
#    '56': 'Three-axle tow truck',
#    '57': 'Farm labor vehicle (non-certified)',
#    '58': 'Farm labor transporter',
#    '59': 'Motorhome (over 40ft)',
#    '60': 'Pedestrian (includes motorized wheelchair)',
#    '61': 'School pupil activity bus I (prior to 2002)',
#    '62': 'School pupil activity bus II (prior to 2002)',
#    '63': 'Youth bus',
#    '64': 'School pupil activity bus I (eff 2002)',
#    '65': 'School pupil activity bus II (eff 2002)',
#    '66': 'School bus Without pupil passengers (eff 2002)',
#    '71': 'Passenger car - hazardous materials only',
#    '72': 'Pickups and panels - hazardous materials only',
#    '73': 'Pickups and campers - hazardous materials only',
#    '75': 'Truck tractor - hazardous materials only',
#    '76': 'Two-axle truck - hazardous materials only',
#    '77': 'Three or more axle truck - hazardous materials only',
#    '78': 'Two-axle tank truck - hazardous materials only',
#    '79': 'Three axle tank truck - hazardous materials only',
#    '81': 'Passenger car - hazardous waste or waste-material combo',
#    '82': 'Pickups and panels - hazardous waste or waste-material combo',
#    '83': 'Pickups and campers - hazardous waste or waste-material combo',
#    '85': 'Truck tractor - hazardous waste or waste-material combo',
#    '86': 'Two-axle truck - hazardous waste or waste-material combo',
#    '87': 'Three or more axle truck - hazardous waste or waste-material combo',
#    '88': 'Two-axle tank truck - hazardous waste or waste-material combo',
#    '89': 'Three-axle tank truck - hazardous waste or waste-material combo',
#    '91': 'Electric bicycle (class 1,2,3)',
#    '93': 'Electrically motorized board',
#    '94': 'Motorized transportation device',
#    '95': 'Miscellaneous non-motorized vehicle (ridden animal, animal-drawn conveyance, train or building) with victim',
#    '96': 'Miscellaneous motorized vehicle (golf cart)',
#    '97': 'Low speed vehicle',
#    '98': 'Emergency vehicle on an emergency run',
#    '99': 'Not stated or unknown (hit and run)',
#    '-': 'Not Stated'}},
#  'SPECIAL_INFO_F': {'no': 116,
#   'level': 'Party',
#   'alias': 'Special Info F',
#   'desc': "The value F indicate that the party's vehicle is a 75ft motor truck combo",
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'F': '75ft motor truck combo', '-': 'Not Stated'}},
#  'SPECIAL_INFO_G': {'no': 117,
#   'level': 'Party',
#   'alias': 'Special Info G',
#   'desc': "The value G indicates that the party's vehicle is a 32ft trailer combo",
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'G': '32ft trailer combo', '-': 'Not Stated'}},
#  'VICTIM_ROLE': {'no': 118,
#   'level': 'Victim',
#   'alias': 'Victim Role',
#   'desc': 'The role of the victim',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Driver',
#    '2': 'Passenger (includes non-operator on bicycle or any victim on/in parked vehicle or multiple victims on/in non-motor vehicle)',
#    '3': 'Pedestrian',
#    '4': 'Bicyclist',
#    '5': 'Other (single victim on/in non-motor vehicle)',
#    '6': 'Non-injured party'}},
#  'VICTIM_SEX': {'no': 119,
#   'level': 'Victim',
#   'alias': 'Victim Sex',
#   'desc': 'The gender of the victim',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'M': 'Male', 'F': 'Female', 'X': 'Nonbinary', '-': 'Not Stated'}},
#  'VICTIM_AGE': {'no': 120,
#   'level': 'Victim',
#   'alias': 'Victim Age',
#   'desc': 'The age of the victim at the time of the crash',
#   'type': 'LONG',
#   'cat': 'Measurement',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'998': 'Not Stated', '999': 'Fatal Fetus'}},
#  'VICTIM_DEGREE_OF_INJURY': {'no': 121,
#   'level': 'Victim',
#   'alias': 'Victim Degree of Injury',
#   'desc': 'The severity of the injury to the victim',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'No injury',
#    '1': 'Killed',
#    '2': 'Severe injury',
#    '3': 'Other visible injury',
#    '4': 'Complaint of pain',
#    '5': 'Suspected serious injury',
#    '6': 'Suspected minor injury',
#    '7': 'Possible injury'}},
#  'VICTIM_DEGREE_OF_INJURY_BINARY': {'no': 122,
#   'level': 'Victim',
#   'alias': 'Victim Injury Severity (Binary)',
#   'desc': 'Binary classification of the severity of the injury to the victim',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Minor (minor injury, pain, or no injury)',
#    '1': 'Severe (killed or serious injury)'}},
#  'VICTIM_SEATING_POSITION': {'no': 123,
#   'level': 'Victim',
#   'alias': 'Victim Seating Position',
#   'desc': 'The seating position of the victim',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Other occupants',
#    '1': 'Driver',
#    '2': 'Passenger 1',
#    '3': 'Passenger 2',
#    '4': 'Passenger 3',
#    '5': 'Passenger 4',
#    '6': 'Passenger 5',
#    '7': 'Station wagon rear',
#    '8': 'Rear occupant of truck or van',
#    '9': 'Position unknown',
#    '-': 'Not Stated'}},
#  'VICTIM_SAFETY_EQUIP_1': {'no': 124,
#   'level': 'Victim',
#   'alias': 'Victim Safety Equipment 1',
#   'desc': 'The safety equipment of the victim',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'None in vehicle',
#    'B': 'Unknown',
#    'C': 'Lap belt used',
#    'D': 'Lap belt not used',
#    'E': 'Shoulder harness used',
#    'F': 'Shoulder harness not used',
#    'G': 'Lap/shoulder harness used',
#    'H': 'Lap/shoulder harness not used',
#    'J': 'Passive restraint used',
#    'K': 'Passive restraint not used',
#    'L': 'Air bag deployed',
#    'M': 'Air bag not deployed',
#    'N': 'Other',
#    'P': 'Not required',
#    'Q': 'Child restraint in vehicle used',
#    'R': 'Child restraint in vehicle not used',
#    'S': 'Child restraint in vehicle, use unknown',
#    'T': 'Child restraint in vehicle, improper use',
#    'U': 'No child restraint in vehicle',
#    'V': 'Driver, motorcycle helmet used',
#    'W': 'Driver, motorcycle helmet not used',
#    'X': 'Passenger, motorcycle helmet not used',
#    'Y': 'Passenger, motorcycle helmet used',
#    '-': 'Not Stated'}},
#  'VICTIM_SAFETY_EQUIP_2': {'no': 125,
#   'level': 'Victim',
#   'alias': 'Victim Safety Equipment 2',
#   'desc': 'The safety equipment of the victim',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'None in vehicle',
#    'B': 'Unknown',
#    'C': 'Lap belt used',
#    'D': 'Lap belt not used',
#    'E': 'Shoulder harness used',
#    'F': 'Shoulder harness not used',
#    'G': 'Lap/shoulder harness used',
#    'H': 'Lap/shoulder harness not used',
#    'J': 'Passive restraint used',
#    'K': 'Passive restraint not used',
#    'L': 'Air bag deployed',
#    'M': 'Air bag not deployed',
#    'N': 'Other',
#    'P': 'Not required',
#    'Q': 'Child restraint in vehicle used',
#    'R': 'Child restraint in vehicle not used',
#    'S': 'Child restraint in vehicle, use unknown',
#    'T': 'Child restraint in vehicle, improper use',
#    'U': 'No child restraint in vehicle',
#    'V': 'Driver, motorcycle helmet used',
#    'W': 'Driver, motorcycle helmet not used',
#    'X': 'Passenger, motorcycle helmet not used',
#    'Y': 'Passenger, motorcycle helmet used',
#    '-': 'Not Stated'}},
#  'VICTIM_EJECTED': {'no': 126,
#   'level': 'Victim',
#   'alias': 'Victim Ejected',
#   'desc': 'Indicates whether the victim was ejected from the vehicle',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not ejected',
#    '1': 'Fully ejected',
#    '2': 'Partially ejected',
#    '3': 'Unknown',
#    '-': 'Not Stated'}},
#  'CITY_AREA_SQMI': {'no': 127,
#   'level': 'City',
#   'alias': 'City Area (sq. miles)',
#   'desc': 'City Area in Square Miles',
#   'type': 'DOUBLE',
#   'cat': 'Measurement',
#   'dbin': 'N'},
#  'CITY_POPDENS': {'no': 128,
#   'level': 'City',
#   'alias': 'City Population Density (per sq. mi)',
#   'desc': 'City population density, population per square mile',
#   'type': 'DOUBLE',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_HUDENS': {'no': 129,
#   'level': 'City',
#   'alias': 'City Housing Density (per sq. mi)',
#   'desc': 'City housing density, houses per square mile',
#   'type': 'DOUBLE',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_POPT': {'no': 130,
#   'level': 'City',
#   'alias': 'City Total Population',
#   'desc': "Total population in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_HUT': {'no': 131,
#   'level': 'City',
#   'alias': 'City Total Housing Units',
#   'desc': "Total housing units in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_POPA': {'no': 132,
#   'level': 'City',
#   'alias': 'City Asian Population',
#   'desc': "Total Asian population in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_POPB': {'no': 133,
#   'level': 'City',
#   'alias': 'City Black Population',
#   'desc': "Total Black or African American population in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_POPH': {'no': 134,
#   'level': 'City',
#   'alias': 'City Hispanic Population',
#   'desc': "Total Hispanic population in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_POPW': {'no': 135,
#   'level': 'City',
#   'alias': 'City White Population',
#   'desc': "Total White population in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_VEHICLES': {'no': 136,
#   'level': 'City',
#   'alias': 'City Aggregate Number of Vehicles Commuting',
#   'desc': "Aggregate number of vehicles used in commuting in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_TRAVEL_TIME': {'no': 137,
#   'level': 'City',
#   'alias': 'City Aggregate Travel Time to Work (min)',
#   'desc': "Aggregate travel time to work (in minutes) in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'RID': {'no': 138,
#   'level': 'Road',
#   'alias': 'Road ID',
#   'desc': "Road ID matching from the road's layer",
#   'type': 'TEXT',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'RNAME': {'no': 139,
#   'level': 'Road',
#   'alias': 'Road Name',
#   'desc': 'Road name from the OC Tiger/Lines layer',
#   'type': 'TEXT',
#   'cat': 'Name',
#   'dbin': 'N'},
#  'RCAT': {'no': 140,
#   'level': 'Road',
#   'alias': 'Road Category',
#   'desc': 'Road category from the OC Tiger/Lines layer',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'RLENGTH': {'no': 141,
#   'level': 'Road',
#   'alias': 'Road Length',
#   'desc': 'Road length from the OC Tiger/Lines layer',
#   'type': 'DOUBLE',
#   'cat': 'Measurement',
#   'dbin': 'N'},
#  'LATITUDE': {'no': 142,
#   'level': 'Crash',
#   'alias': 'GPS Latitude',
#   'desc': 'Latitude of the crash location in decimal degrees. The decimal point is included. LATITUDE and LONGITUDE are from the crash report',
#   'type': 'DOUBLE',
#   'cat': 'Coordinate',
#   'dbin': 'N'},
#  'LONGITUDE': {'no': 143,
#   'level': 'Crash',
#   'alias': 'GPS Longitude',
#   'desc': 'Longitude of the crash location in decimal degrees. The decimal point is included. There is no minus sign. The longitude is understood to be West of Meridian. LATITUDE and LONGITUDE are from the crash report',
#   'type': 'DOUBLE',
#   'cat': 'Coordinate',
#   'dbin': 'N'},
#  'POINT_X': {'no': 144,
#   'level': 'Crash',
#   'alias': 'X Coordinate Location',
#   'desc': 'The longitude of the geocoded location, uses the World Geodetic System from 1984 (WGS84). POINT_X and POINT_Y are generated using the geociding process by UC Berkeley Safe TREC',
#   'type': 'DOUBLE',
#   'cat': 'Coordinate',
#   'dbin': 'N'},
#  'POINT_Y': {'no': 145,
#   'level': 'Crash',
#   'alias': 'Y Coordinate Location',
#   'desc': 'The latitude of the geocoded location, uses the World Geodetic System from 1984 (WGS84). POINT_X and POINT_Y are generated using the geociding process by UC Berkeley Safe TREC',
#   'type': 'DOUBLE',
#   'cat': 'Coordinate',
#   'dbin': 'N'}}

# %%
print("Collisions: Modifying codebook field types...")
modify_agp_types(codebook, collisionsPointsFields)
# Out:
# Collisions: Modifying codebook field types...
# {'OBJECTID': {'no': 1,
#   'level': 'GIS',
#   'alias': 'Object ID',
#   'desc': 'ESRI Object ID',
#   'type': 'OID',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'GlobalID': {'no': 2,
#   'level': 'GIS',
#   'alias': 'Global ID',
#   'desc': 'ESRI Global ID string identifier',
#   'type': 'GlobalID',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'GUID': {'no': 3,
#   'level': 'GIS',
#   'alias': 'GUID Related Table Identifier',
#   'desc': 'ESRI GUID to be used in merging related tables',
#   'type': 'Guid',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'CASE_ID': {'no': 4,
#   'level': 'Crash',
#   'alias': 'Case ID',
#   'desc': 'Unique identifier of the crash case',
#   'type': 'LONG',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'CID': {'no': 5,
#   'level': 'Crash',
#   'alias': 'Crash ID',
#   'desc': 'Unique identifier of the crash case',
#   'type': 'TEXT',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'PID': {'no': 6,
#   'level': 'Party',
#   'alias': 'Party ID',
#   'desc': 'Unique identifier for the party case',
#   'type': 'TEXT',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'VID': {'no': 7,
#   'level': 'Victim',
#   'alias': 'Victim ID',
#   'desc': 'Unique identifier of the victim case',
#   'type': 'TEXT',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'PARTY_NUMBER': {'no': 8,
#   'level': 'Party',
#   'alias': 'Party Number',
#   'desc': 'A number that together with the CASE_ID uniquely identifies a party in a crash',
#   'type': 'LONG',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'VICTIM_NUMBER': {'no': 9,
#   'level': 'Victim',
#   'alias': 'Victim Number',
#   'desc': 'The unique identifier of the victim',
#   'type': 'LONG',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'CRASHES_INDICATOR': {'no': 10,
#   'level': 'Crash',
#   'alias': 'Crashes Binary Indicator',
#   'desc': 'Binary flag, 1 if the record is a crash, 0 if not',
#   'type': 'LONG',
#   'cat': 'Binary',
#   'dbin': 'N'},
#  'PARTIES_INDICATOR': {'no': 11,
#   'level': 'Party',
#   'alias': 'Parties Binary Indicator',
#   'desc': 'Binary flag, 1 if the record is a party, 0 if not',
#   'type': 'LONG',
#   'cat': 'Binary',
#   'dbin': 'N'},
#  'VICTIMS_INDICATOR': {'no': 12,
#   'level': 'Victim',
#   'alias': 'Victims Binary Indicator',
#   'desc': 'Binary flag, 1 if the record is a victim, 0 if not',
#   'type': 'LONG',
#   'cat': 'Binary',
#   'dbin': 'N'},
#  'CITY': {'no': 13,
#   'level': 'City',
#   'alias': 'City',
#   'desc': 'Reported City of the crash',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'CITY_NAME': {'no': 14,
#   'level': 'City',
#   'alias': 'City Name',
#   'desc': 'City name from locational query',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'PLACE_TYPE': {'no': 15,
#   'level': 'City',
#   'alias': 'Place Type',
#   'desc': 'City or Unincorporated Area',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'COLLISION_DATETIME': {'no': 16,
#   'level': 'Crash',
#   'alias': 'Crash Date and Time',
#   'desc': 'Full date and time string of the crash',
#   'type': 'DATE',
#   'cat': 'Date and Time',
#   'dbin': 'N'},
#  'COLLISION_DATE': {'no': 17,
#   'level': 'Crash',
#   'alias': 'Crash Date',
#   'desc': 'The date when the crash occurred',
#   'type': 'DATE',
#   'cat': 'Date and Time',
#   'dbin': 'N'},
#  'COLLISION_TIME': {'no': 18,
#   'level': 'Crash',
#   'alias': 'Crash Time',
#   'desc': 'The time when the crash occurred in 24h format',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'N'},
#  'ACCIDENT_YEAR': {'no': 19,
#   'level': 'Crash',
#   'alias': 'Crash Year',
#   'desc': 'The year when the crash occurred',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'N'},
#  'COLLISION_MONTH': {'no': 20,
#   'level': 'Crash',
#   'alias': 'Crash Month',
#   'desc': 'Month number from crash date',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'January',
#    '2': 'February',
#    '3': 'March',
#    '4': 'April',
#    '5': 'May',
#    '6': 'June',
#    '7': 'July',
#    '8': 'August',
#    '9': 'September',
#    '10': 'October',
#    '11': 'November',
#    '12': 'December'}},
#  'DAY_OF_WEEK': {'no': 21,
#   'level': 'Crash',
#   'alias': 'Day of Week',
#   'desc': 'Code for the day of the week when the crash occurred',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Monday',
#    '2': 'Tuesday',
#    '3': 'Wednesday',
#    '4': 'Thursday',
#    '5': 'Friday',
#    '6': 'Saturday',
#    '7': 'Sunday'}},
#  'PROC_DATE': {'no': 22,
#   'level': 'Crash',
#   'alias': 'Processing Date',
#   'desc': 'The date that the crash case was last changed',
#   'type': 'DATE',
#   'cat': 'Date and Time',
#   'dbin': 'N'},
#  'COLLISION_TIME_INTERVALS': {'no': 23,
#   'level': 'Crash',
#   'alias': 'Crash Time Intervals',
#   'desc': 'Crash time interval ranges classification',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Night (00:00am to 06:00am)',
#    '2': 'Morning (06:00am to 12:00pm)',
#    '3': 'Afternoon (12:00pm to 06:00pm)',
#    '4': 'Evening (06:00pm to 00:00am)',
#    '999': 'Unknown Time'}},
#  'COLLISION_TIME_RUSH_HOURS': {'no': 24,
#   'level': 'Crash',
#   'alias': 'Rush Hours',
#   'desc': 'Rush hours interval ranges (Mon-Fri mornings and evenings)',
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Rush Hours (Morning)',
#    '2': 'Rush Hours (Evening)',
#    '3': 'Non-Rush Hours',
#    '999': 'Unknown Time'}},
#  'COLLISION_SEVERITY': {'no': 25,
#   'level': 'Crash',
#   'alias': 'Crash Severity',
#   'desc': 'The worst injury suffered by any victim in the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'No injury, aka property damage only or PDO',
#    '1': 'Fatal injury',
#    '2': 'Suspected serous injury or severe injury',
#    '3': 'Suspected minor injury or visible injury',
#    '4': 'Possible injury or complaint of pain'}},
#  'COLLISION_SEVERITY_BINARY': {'no': 26,
#   'level': 'Crash',
#   'alias': 'Crash Severity (Binary)',
#   'desc': 'Binary classification of the worst injury suffered by any victim in the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Minor (minor injury, pain, or no injury)',
#    '1': 'Severe (killed or serious injury)'}},
#  'COLLISION_SEVERITY_RECLASS': {'no': 27,
#   'level': 'Crash',
#   'alias': 'Crash Severity Reclassified',
#   'desc': 'Reclassified crash severity based on the worst injury suffered by any victim in the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'None',
#    '1': 'Possible Injury or Pain',
#    '2': 'Minor or Visible Injury',
#    '3': 'Serious or Severe Injury',
#    '4': 'Fatal Injury'}},
#  'COLLISION_SEVERITY_RANKED': {'no': 28,
#   'level': 'Crash',
#   'alias': 'Crash Severity Ranked',
#   'desc': 'Ranked crash severity based on the worst injury suffered by any victim in the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'None or Minor Injuries',
#    '1': 'Single Injury (Severe)',
#    '2': 'Multiple Injuries (Severe)',
#    '3': 'Single Fatality, No Injuries (Fatal)',
#    '4': 'Single Fatality, Single Injury (Fatal)',
#    '5': 'Single Fatality, Multiple Injuries (Fatal)',
#    '6': 'Multiple Fatalities, No Injuries (Fatal)',
#    '7': 'Multiple Fatalities, Single Injury (Fatal)',
#    '8': 'Multiple Fatalities, Multiple Injuries (Fatal)'}},
#  'PARTY_COUNT': {'no': 29,
#   'level': 'Party',
#   'alias': 'Party Count',
#   'desc': 'Number of parties involved in the crash',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'VICTIM_COUNT': {'no': 30,
#   'level': 'Victim',
#   'alias': 'Victim Count',
#   'desc': 'Number of victims involved in each party',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'NUMBER_KILLED': {'no': 31,
#   'level': 'Crash',
#   'alias': 'Killed victims',
#   'desc': 'Number of killed victims',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'NUMBER_INJURED': {'no': 32,
#   'level': 'Crash',
#   'alias': 'Injured victims',
#   'desc': 'Number of injured victims',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_SEVERE_INJ': {'no': 33,
#   'level': 'Crash',
#   'alias': 'Severe Injury Count',
#   'desc': 'Number of victims in the crash with suspected serous injury or severe injury',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_VISIBLE_INJ': {'no': 34,
#   'level': 'Crash',
#   'alias': 'Other Visible Injury Count',
#   'desc': 'Number of victims in the crash with suspected minor injury or visible injury',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_COMPLAINT_PAIN': {'no': 35,
#   'level': 'Crash',
#   'alias': 'Complaint of Pain Injury Count',
#   'desc': 'Number of victims in the crash with possible injury or complaint of pain',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_PED_KILLED': {'no': 36,
#   'level': 'Crash',
#   'alias': 'Pedestrian Killed Count',
#   'desc': 'Number of killed pedestrian victims',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_PED_INJURED': {'no': 37,
#   'level': 'Crash',
#   'alias': 'Pedestrian Injured Count',
#   'desc': 'Number of injured pedestrian victims',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_BICYCLIST_KILLED': {'no': 38,
#   'level': 'Crash',
#   'alias': 'Bicyclist Killed Count',
#   'desc': 'Number of killed bicyclists',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_BICYCLIST_INJURED': {'no': 39,
#   'level': 'Crash',
#   'alias': 'Bicyclist Injured Count',
#   'desc': 'Number of injured bicyclists',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_MC_KILLED': {'no': 40,
#   'level': 'Crash',
#   'alias': 'Motorcyclist Killed Count',
#   'desc': 'Number of killed motorcyclists',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'COUNT_MC_INJURED': {'no': 41,
#   'level': 'Crash',
#   'alias': 'Motorcyclist Injured Count',
#   'desc': 'Number of injured motorcyclists',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'PRIMARY_COLL_FACTOR': {'no': 42,
#   'level': 'Crash',
#   'alias': 'Primary Crash Factor',
#   'desc': 'The primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Vehicle Code Violation',
#    'B': 'Other Improper Driving',
#    'C': 'Other Than Driver',
#    'D': 'Unknown',
#    'E': 'Fell Asleep',
#    '-': 'Not Stated'}},
#  'TYPE_OF_COLLISION': {'no': 43,
#   'level': 'Crash',
#   'alias': 'Type of Crash',
#   'desc': 'The general type of crash as determined by the first injury or damage-causing event',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Head-On',
#    'B': 'Sideswipe',
#    'C': 'Rear End',
#    'D': 'Broadside',
#    'E': 'Hit Object',
#    'F': 'Overturned',
#    'G': 'Vehicle/Pedestrian',
#    'H': 'Other',
#    '-': 'Not Stated'}},
#  'PEDESTRIAN_ACCIDENT': {'no': 44,
#   'level': 'Crash',
#   'alias': 'Pedestrian Crash',
#   'desc': 'Indicates whether the crash involved a pedestrian',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'BICYCLE_ACCIDENT': {'no': 45,
#   'level': 'Crash',
#   'alias': 'Bicycle Crash',
#   'desc': 'Indicates whether the crash involved a bicycle',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'MOTORCYCLE_ACCIDENT': {'no': 46,
#   'level': 'Crash',
#   'alias': 'Motorcycle Crash',
#   'desc': 'Indicates whether the crash involved a motorcycle',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'TRUCK_ACCIDENT': {'no': 47,
#   'level': 'Crash',
#   'alias': 'Truck Crash',
#   'desc': 'Indicates whether the crash involved a big truck',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'HIT_AND_RUN': {'no': 48,
#   'level': 'Crash',
#   'alias': 'Hit and Run',
#   'desc': 'A flag to indicate the severity of hit-and-run crash. Felony hit-and-run resulted in injury or death to other parties. Misdemeanor hit-and-run did not result in injury or death to other parties',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'F': 'Felony', 'M': 'Misdemeanor', 'N': 'Not Hit and Run'}},
#  'ALCOHOL_INVOLVED': {'no': 49,
#   'level': 'Crash',
#   'alias': 'Alcohol Involved',
#   'desc': 'Indicates whether the crash involved a party that had been drinking. Note - a passenger does not count as a party',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'JURIS': {'no': 50,
#   'level': 'Crash',
#   'alias': 'Jurisdiction',
#   'desc': 'Law enforcement agency that has jurisdiction over the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'OFFICER_ID': {'no': 51,
#   'level': 'Crash',
#   'alias': 'Officer ID',
#   'desc': 'The badge number of the officer who wrote the crash report',
#   'type': 'TEXT',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'REPORTING_DISTRICT': {'no': 52,
#   'level': 'Crash',
#   'alias': 'Reporting District',
#   'desc': 'Reporting District on the crash report',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'CHP_SHIFT': {'no': 53,
#   'level': 'Crash',
#   'alias': 'CHP Shift',
#   'desc': 'CHP shift at the time of the crash',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': '0600 thru 1359',
#    '2': '1400 thru 2159',
#    '3': '2200 thru 0559',
#    '4': 'CHP Not Stated',
#    '5': 'Not CHP'}},
#  'CNTY_CITY_LOC': {'no': 54,
#   'level': 'Crash',
#   'alias': 'County City Location',
#   'desc': 'The city or unincorporated county where the crash occurred',
#   'type': 'LONG',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'SPECIAL_COND': {'no': 55,
#   'level': 'Crash',
#   'alias': 'Special Condition',
#   'desc': 'A computed value. O means not private property',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not Above',
#    '1': 'Schoolbus on Public Roadway',
#    '2': 'State University (Also SFIA)',
#    '3': 'Schoolbus Not on Public Roadway',
#    '4': 'Offroad (Unimproved)',
#    '5': 'Vista Point or Rest Area or Sales or Inspection Facility',
#    '6': 'Other Public Access (Improved)',
#    '-': 'Not Stated'}},
#  'BEAT_TYPE': {'no': 56,
#   'level': 'Crash',
#   'alias': 'Beat Type',
#   'desc': 'Location of crash based on beat',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not CHP',
#    '1': 'CHP State Highway',
#    '2': 'CHP County RoadLine',
#    '3': 'CHP County RoadArea',
#    '4': 'Schoolbus on City Roadway',
#    '5': 'Schoolbus not on Public Roadway',
#    '6': 'Offroad (Unimproved)',
#    '7': 'Vista Point or Rest Area or Scales or Inspection Facility',
#    '8': 'Other Public Access (Improved)'}},
#  'CHP_BEAT_TYPE': {'no': 57,
#   'level': 'Crash',
#   'alias': 'CHP Beat Type',
#   'desc': 'Location of crash based on beat',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'NOT CHP',
#    '1': 'Interstate',
#    '2': 'US Highway',
#    '3': 'State Route',
#    '4': 'County RoadLine',
#    '5': 'County RoadArea',
#    '6': 'US Highway',
#    '7': 'State Route',
#    '8': 'County RoadLine',
#    '9': 'County RoadArea'}},
#  'CHP_BEAT_CLASS': {'no': 58,
#   'level': 'Crash',
#   'alias': 'CHP Beat Class',
#   'desc': 'Location of crash based on beat',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not CHP', '1': 'CHP Primary', '2': 'CHP Other'}},
#  'BEAT_NUMBER': {'no': 59,
#   'level': 'Crash',
#   'alias': 'Beat Number',
#   'desc': 'Beat of the officer who reported the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'PRIMARY_RD': {'no': 60,
#   'level': 'Crash',
#   'alias': 'Primary Road',
#   'desc': 'The name of the roadway on which the crash occurred',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'SECONDARY_RD': {'no': 61,
#   'level': 'Crash',
#   'alias': 'Secondary Road',
#   'desc': 'The name of the roadway that intersects the primary roadway',
#   'type': 'TEXT',
#   'cat': 'Location or Place Name',
#   'dbin': 'N'},
#  'DISTANCE': {'no': 62,
#   'level': 'Crash',
#   'alias': 'Distance',
#   'desc': 'Distance of the crash from the intersection with the secondary roadway in ft',
#   'type': 'DOUBLE',
#   'cat': 'Measurement',
#   'dbin': 'N'},
#  'DIRECTION': {'no': 63,
#   'level': 'Crash',
#   'alias': 'Direction',
#   'desc': 'Direction of the crash from the intersection with the secondary roadway',
#   'type': 'TEXT',
#   'cat': 'Measurement',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'N': 'North',
#    'E': 'East',
#    'S': 'South',
#    'W': 'West',
#    '-': 'Not Stated'}},
#  'INTERSECTION': {'no': 64,
#   'level': 'Crash',
#   'alias': 'Intersection',
#   'desc': 'A flag that denotes if the crash occurred at the intersection with the secondary roadway',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Intersection', 'N': 'Not Intersection', '-': 'Not Stated'}},
#  'WEATHER_1': {'no': 65,
#   'level': 'Crash',
#   'alias': 'Weather 1',
#   'desc': 'Weather condition at the time of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Clear',
#    'B': 'Cloudy',
#    'C': 'Raining',
#    'D': 'Snowing',
#    'E': 'Fog',
#    'F': 'Other',
#    'G': 'Wind',
#    '-': 'Not Stated'}},
#  'WEATHER_2': {'no': 66,
#   'level': 'Crash',
#   'alias': 'Weather 2',
#   'desc': 'Additional weather condition at the time of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Clear',
#    'B': 'Cloudy',
#    'C': 'Raining',
#    'D': 'Snowing',
#    'E': 'Fog',
#    'F': 'Other',
#    'G': 'Wind',
#    '-': 'Not Stated'}},
#  'WEATHER_COMBINED': {'no': 67,
#   'level': 'Crash',
#   'alias': 'Combined Weather Conditions',
#   'desc': 'Combined Weather Conditions from WEATHER_1 and WEATHER_2 fields in numeric codes by weather conditions severity',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not Stated',
#    '10': 'Clear',
#    '12': 'Clear Cloudy',
#    '13': 'Clear Other',
#    '14': 'Clear Wind',
#    '15': 'Clear Raining',
#    '16': 'Clear Snowing',
#    '17': 'Clear Fog',
#    '20': 'Cloudy',
#    '21': 'Cloudy Clear',
#    '23': 'Cloudy Other',
#    '24': 'Cloudy Wind',
#    '25': 'Cloudy Raining',
#    '26': 'Cloudy Snowing',
#    '27': 'Cloudy Fog',
#    '30': 'Other',
#    '31': 'Other Clear',
#    '32': 'Other Cloudy',
#    '34': 'Other Wind',
#    '35': 'Other Raining',
#    '36': 'Other Snowing',
#    '37': 'Other Fog',
#    '40': 'Wind',
#    '41': 'Wind Clear',
#    '42': 'Wind Cloudy',
#    '43': 'Wind Other',
#    '45': 'Wind Raining',
#    '46': 'Wind Snowing',
#    '47': 'Wind Fog',
#    '50': 'Raining',
#    '51': 'Raining Clear',
#    '52': 'Raining Cloudy',
#    '53': 'Raining Other',
#    '54': 'Raining Wind',
#    '56': 'Raining Snowing',
#    '57': 'Raining Fog',
#    '60': 'Snowing',
#    '61': 'Snowing Clear',
#    '62': 'Snowing Cloudy',
#    '63': 'Snowing Other',
#    '64': 'Snowing Wind',
#    '65': 'Snowing Raining',
#    '67': 'Snowing Fog',
#    '70': 'Fog',
#    '71': 'Fog Clear',
#    '72': 'Fog Cloudy',
#    '73': 'Fog Other',
#    '74': 'Fog Wind',
#    '75': 'Fog Raining',
#    '76': 'Fog Snowing'}},
#  'ROAD_SURFACE': {'no': 68,
#   'level': 'Crash',
#   'alias': 'Road Surface',
#   'desc': 'Roadway surface condition at the time of the crash in the traffic lane(s) involved',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Dry',
#    'B': 'Wet',
#    'C': 'Snowy or Icy',
#    'D': 'Slippery (Muddy, Oily, etc)',
#    'O': 'Other',
#    '-': 'Not Stated'}},
#  'ROAD_COND_1': {'no': 69,
#   'level': 'Crash',
#   'alias': 'Road Condition 1',
#   'desc': 'Roadway condition at the time of the crash in the traffic lane(s) involved',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Holes, Deep Ruts',
#    'B': 'Loose Material on Roadway',
#    'C': 'Obstruction on Roadway',
#    'D': 'Construction or Repair Zone',
#    'E': 'Reduced Roadway Width',
#    'F': 'Flooded',
#    'G': 'Other',
#    'H': 'No Unusual Condition',
#    '-': 'Not Stated'}},
#  'ROAD_COND_2': {'no': 70,
#   'level': 'Crash',
#   'alias': 'Road Condition 2',
#   'desc': 'Second roadway condition at the time of the crash in the traffic lane(s) involved',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Holes, Deep Ruts',
#    'B': 'Loose Material on Roadway',
#    'C': 'Obstruction on Roadway',
#    'D': 'Construction or Repair Zone',
#    'E': 'Reduced Roadway Width',
#    'F': 'Flooded',
#    'G': 'Other',
#    'H': 'No Unusual Condition',
#    '-': 'Not Stated'}},
#  'LIGHTING': {'no': 71,
#   'level': 'Crash',
#   'alias': 'Lighting',
#   'desc': 'Lighting conditions at the crash location and the time of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Daylight',
#    'B': 'Dusk-Dawn',
#    'C': 'Dark-Street Lights',
#    'D': 'Dark-No Street Lights',
#    'E': 'Dark-Street Lights Not Functioning',
#    '-': 'Not Stated'}},
#  'CONTROL_DEVICE': {'no': 72,
#   'level': 'Crash',
#   'alias': 'Control Device',
#   'desc': 'Presence and condition of crash related traffic control devices at the time of the crash. Control devices include regulatory, warning, and construction sings. This excludes striping and officers or other persons directing traffic',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Functioning',
#    'B': 'Not Functioning',
#    'C': 'Obscured',
#    'D': 'None',
#    '-': 'Not Stated'}},
#  'STATE_HWY_IND': {'no': 73,
#   'level': 'Crash',
#   'alias': 'State Highway Indicator',
#   'desc': 'A flag to indicate whether the crash is on or near a state highway',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'State Highway', 'N': 'Not State Highway'}},
#  'SIDE_OF_HWY': {'no': 74,
#   'level': 'Crash',
#   'alias': 'Side of Highway',
#   'desc': 'Code provided by Caltrans Coders, applies to divided highway, based on nominal direction of route, for single vehicle is same as nominal direction of travel, overruled by impact with second vehicle after crossing median',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'N': 'Northbound',
#    'S': 'Southbound',
#    'E': 'Eastbound',
#    'W': 'Westbound'}},
#  'TOW_AWAY': {'no': 75,
#   'level': 'Crash',
#   'alias': 'Tow Away',
#   'desc': 'A flag to indicate whether the vehicle was towed away from the crash scene',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes', 'N': 'No'}},
#  'PCF_CODE_OF_VIOL': {'no': 76,
#   'level': 'Crash',
#   'alias': 'PCF Violation Code',
#   'desc': 'The law code that was violated and was the primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'B': 'Business and Professions',
#    'C': 'Vehicle',
#    'H': 'City Health and Safety',
#    'I': 'City Ordinance',
#    'O': 'County Ordinance',
#    'P': 'Penal',
#    'S': 'Streets and Highways',
#    'W': 'Welfare and Institutions',
#    '-': 'Not Stated'}},
#  'PCF_VIOL_CATEGORY': {'no': 77,
#   'level': 'Crash',
#   'alias': 'PCF Violation Category',
#   'desc': 'A value computed from the law section that was given as the primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Unknown',
#    '1': 'Driving or Bicycling Under the Influence of Alcohol or Drug',
#    '2': 'Impeding Traffic',
#    '3': 'Unsafe Speed',
#    '4': 'Following Too Closely',
#    '5': 'Wrong Side of Road',
#    '6': 'Improper Passing',
#    '7': 'Unsafe Lane Change',
#    '8': 'Improper Turning',
#    '9': 'Automobile Right of Way',
#    '10': 'Pedestrian Right of Way',
#    '11': 'Pedestrian Violation',
#    '12': 'Traffic Signals and Signs',
#    '13': 'Hazardous Parking',
#    '14': 'Lights',
#    '15': 'Brakes',
#    '16': 'Other Equipment',
#    '17': 'Other Hazardous Violation',
#    '18': 'Other Than Driver or Pedestrian',
#    '21': 'Unsafe Starting or Backing',
#    '22': 'Other Improper Driving',
#    '23': 'Pedestrian or Other Under the Influence of Alcohol or Drug',
#    '24': 'Fell Asleep',
#    '-': 'Not Stated'}},
#  'PCF_VIOLATION': {'no': 78,
#   'level': 'Crash',
#   'alias': 'PCF Violation',
#   'desc': 'The law section given as the primary cause of the crash. The subsection is in the data element pcf_viol_subsection',
#   'type': 'DOUBLE',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'PCF_VIOL_SUBSECTION': {'no': 79,
#   'level': 'Crash',
#   'alias': 'PCF Violation Subsection',
#   'desc': 'The subsection of the law section given as the primary cause of the crash in the data element pcf_violation',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'MVIW': {'no': 80,
#   'level': 'Crash',
#   'alias': 'Motor Vehicle Involved With',
#   'desc': 'Describes what, in conjunction with a motor vehicle in-transport, produced the first injury or damage-causing event, on or off the road',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Non-Collision and Additional Object',
#    '1': 'Pedestrian and Additional Object',
#    '2': 'Other Motor Vehicle and Additional Object',
#    '3': 'Motor Vehicle on Other Roadway and Additional Object',
#    '4': 'Parked Motor Vehicle and Additional Object',
#    '5': 'Train and Additional Object',
#    '6': 'Bicycle and Additional Object',
#    '7': 'Animal and Additional Object',
#    '8': 'Fixed Object and Additional Object',
#    '9': 'Other Object and Additional Object',
#    'A': 'Non-Collision',
#    'B': 'Pedestrian',
#    'C': 'Other Motor Vehicle',
#    'D': 'Motor Vehicle on Other Roadway',
#    'E': 'Parked Motor Vehicle',
#    'F': 'Train',
#    'G': 'Bicycle',
#    'H': 'Animal',
#    'I': 'Fixed Object',
#    'J': 'Other Object',
#    '-': 'Not Stated'}},
#  'PED_ACTION': {'no': 81,
#   'level': 'Crash',
#   'alias': 'Ped Action',
#   'desc': 'The action just prior to the crash of the first pedestrian injured or otherwise involved',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'No Pedestrian Involved',
#    'B': 'Crossing in Crosswalk at Intersection',
#    'C': 'Crossing in Crosswalk Not at Intersection',
#    'D': 'Crossing Not in Crosswalk',
#    'E': 'In Road, Including Shoulder',
#    'F': 'Not in Road',
#    'G': 'Approaching or Leaving School Bus',
#    '-': 'Not Stated'}},
#  'NOT_PRIVATE_PROPERTY': {'no': 82,
#   'level': 'Crash',
#   'alias': 'Not Private Property',
#   'desc': 'Y indicates that the crash did not occur on private property',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes'}},
#  'STWD_VEHTYPE_AT_FAULT': {'no': 83,
#   'level': 'Crash',
#   'alias': 'Statewide Vehicle Type At Fault',
#   'desc': 'Indicates the Statewide Vehicle Type of the party who is at fault',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Passenger car/station wagon',
#    'B': 'Passenger car with trailer',
#    'C': 'Motorcycle/scooter',
#    'D': 'Pickup or panel truck',
#    'E': 'Pickup or panel truck with trailer',
#    'F': 'Truck or truck tractor',
#    'G': 'Truck or truck tractor with trailer',
#    'H': 'Schoolbus',
#    'I': 'Other bus',
#    'J': 'Emergency vehicle',
#    'K': 'Highway construction equipment',
#    'L': 'Bicycle',
#    'M': 'Other vehicle',
#    'N': 'Pedestrian',
#    'O': 'Moped',
#    '-': 'Not Stated'}},
#  'CHP_VEHTYPE_AT_FAULT': {'no': 84,
#   'level': 'Crash',
#   'alias': 'CHP Vehicle Type At Fault',
#   'desc': 'Indicates the CHP Vehicle Type of the party whi is at fault',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Passenger, car, station Wagon, or Jeep',
#    '2': 'Motorcycle',
#    '3': 'Motor-driven cycle (<15 hp)',
#    '4': 'Bicycle',
#    '5': 'Motorized vehicle',
#    '6': 'All-terrain vehicle (ATV)',
#    '7': 'Sport utility vehicle',
#    '8': 'Minivan',
#    '9': 'Paratransit bus',
#    '10': 'Tour bus',
#    '11': 'Other commercial bus',
#    '12': 'Non-commercial bus',
#    '13': 'Schoolbus public I',
#    '14': 'Schoolbus public II',
#    '15': 'Schoolbus private I',
#    '16': 'Schoolbus private II',
#    '17': 'Schoolbus contractual I',
#    '18': 'Schoolbus contractual II',
#    '19': 'General public paratransit vehicle',
#    '20': 'Public transit authority',
#    '21': 'Two-axle tank truck',
#    '22': 'Pickup or panel truck',
#    '23': 'Pickup truck with camper',
#    '24': 'Three-axle tank truck',
#    '25': 'Truck tractor',
#    '26': 'Two-axle truck',
#    '27': 'Three-axle truck',
#    '28': 'Semi-tank trailer',
#    '29': 'Pull-tank trailer',
#    '30': 'Two-tank trailer',
#    '31': 'Semi-trailer',
#    '32': 'Pull trailer (includes dolly)',
#    '33': 'Two trailers (includes semi and trailer)',
#    '34': 'Boat trailer',
#    '35': 'Utility trailer',
#    '36': 'Trailer coach',
#    '37': 'Oversize vehicle/load',
#    '38': 'Pole, pipe, or logging dolly',
#    '39': 'Three trailers (includes semi and two trailers)',
#    '40': 'Semi 48 or less with king pin to trailer axle of over 38',
#    '41': 'Ambulance',
#    '42': 'Dune buggy',
#    '43': 'Fire truck (not rescue)',
#    '44': 'Forklift',
#    '45': 'Highway construction equipment (only while not in construction area)',
#    '46': 'Implement of husbandry',
#    '47': 'Motor home (40 ft or less)',
#    '48': 'CHP, police, or sheriff car (emergency service or not)',
#    '49': 'CHP, police, or sheriff motorcycle (emergency service or not)',
#    '50': 'Mobile equipment',
#    '51': 'Farm labor vehicle (certified)',
#    '52': 'Federally legal double cargo combo over 75ft',
#    '53': '5th wheel trailer',
#    '54': 'Container chassis',
#    '55': 'Two-axle tow truck',
#    '56': 'Three-axle tow truck',
#    '57': 'Farm labor vehicle (non-certified)',
#    '58': 'Farm labor transporter',
#    '59': 'Motorhome (over 40ft)',
#    '60': 'Pedestrian (includes motorized wheelchair)',
#    '61': 'School pupil activity bus I (prior to 2002)',
#    '62': 'School pupil activity bus II (prior to 2002)',
#    '63': 'Youth bus',
#    '64': 'School pupil activity bus I (eff 2002)',
#    '65': 'School pupil activity bus II (eff 2002)',
#    '66': 'School bus Without pupil passengers (eff 2002)',
#    '71': 'Passenger car - hazardous materials only',
#    '72': 'Pickups and panels - hazardous materials only',
#    '73': 'Pickups and campers - hazardous materials only',
#    '75': 'Truck tractor - hazardous materials only',
#    '76': 'Two-axle truck - hazardous materials only',
#    '77': 'Three or more axle truck - hazardous materials only',
#    '78': 'Two-axle tank truck - hazardous materials only',
#    '79': 'Three axle tank truck - hazardous materials only',
#    '81': 'Passenger car - hazardous waste or waste-material combo',
#    '82': 'Pickups and panels - hazardous waste or waste-material combo',
#    '83': 'Pickups and campers - hazardous waste or waste-material combo',
#    '85': 'Truck tractor - hazardous waste or waste-material combo',
#    '86': 'Two-axle truck - hazardous waste or waste-material combo',
#    '87': 'Three or more axle truck - hazardous waste or waste-material combo',
#    '88': 'Two-axle tank truck - hazardous waste or waste-material combo',
#    '89': 'Three-axle tank truck - hazardous waste or waste-material combo',
#    '91': 'Electric bicycle (class 1,2,3)',
#    '93': 'Electrically motorized board',
#    '94': 'Motorized transportation device',
#    '95': 'Miscellaneous non-motorized vehicle (ridden animal, animal-drawn conveyance, train or building) with victim',
#    '96': 'Miscellaneous motorized vehicle (golf cart)',
#    '97': 'Low speed vehicle',
#    '98': 'Emergency vehicle on an emergency run',
#    '99': 'Not stated or unknown (hit and run)',
#    '-': 'Not Stated'}},
#  'PRIMARY_RAMP': {'no': 85,
#   'level': 'Crash',
#   'alias': 'Primary Ramp',
#   'desc': 'A description of the ramp, if any, on primary roadway. This value is computed by the key operator from information on the crash report',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'TO': 'To',
#    'FR': 'From',
#    'NF': 'North Off Ramp',
#    'SF': 'South Off Ramp',
#    'EF': 'East Off Ramp',
#    'WF': 'West Off Ramp',
#    'NO': 'North On Ramp',
#    'SO': 'South On Ramp',
#    'EO': 'East On Ramp',
#    'WO': 'West On Ramp',
#    'TR': 'Transition',
#    'CO': 'Collector',
#    'CN': 'Connector',
#    '-': 'Not Stated'}},
#  'SECONDARY_RAMP': {'no': 86,
#   'level': 'Crash',
#   'alias': 'Secondary Ramp',
#   'desc': 'A description of the ramp, if any, on secondary roadway. This value is computed by the key operator from information on the crash report',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'TO': 'To',
#    'FR': 'From',
#    'NF': 'North Off Ramp',
#    'SF': 'South Off Ramp',
#    'EF': 'East Off Ramp',
#    'WF': 'West Off Ramp',
#    'NO': 'North On Ramp',
#    'SO': 'South On Ramp',
#    'EO': 'East On Ramp',
#    'WO': 'West On Ramp',
#    'TR': 'Transition',
#    'CO': 'Collector',
#    'CN': 'Connector',
#    '-': 'Not Stated'}},
#  'PARTY_TYPE': {'no': 87,
#   'level': 'Party',
#   'alias': 'Party Type',
#   'desc': 'Involved party type',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Driver (including hit and run)',
#    '2': 'Pedestrian',
#    '3': 'Parked vehicle',
#    '4': 'Bicyclist',
#    '5': 'Other',
#    '6': 'Operator',
#    '-': 'Not Stated'}},
#  'AT_FAULT': {'no': 88,
#   'level': 'Party',
#   'alias': 'At Fault',
#   'desc': 'Indicates whether the party was at fault in the crash',
#   'type': 'TEXT',
#   'cat': 'Binary',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'Y': 'Yes', 'N': 'No', '-': 'Not Stated'}},
#  'PARTY_SEX': {'no': 89,
#   'level': 'Party',
#   'alias': 'Party Sex',
#   'desc': 'The gender of the party',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'M': 'Male', 'F': 'Female', 'X': 'Nonbinary', '-': 'Not Stated'}},
#  'PARTY_AGE': {'no': 90,
#   'level': 'Party',
#   'alias': 'Party Age',
#   'desc': 'The age of the party at the time of the crash',
#   'type': 'LONG',
#   'cat': 'Measurement',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'998': 'Unknown'}},
#  'RACE': {'no': 91,
#   'level': 'Party',
#   'alias': 'Party Race',
#   'desc': "The party's race based on the reporting officer's judgment",
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Asian',
#    'B': 'Black',
#    'H': 'Hispanic',
#    'W': 'White',
#    'O': 'Other'}},
#  'PARTY_NUMBER_KILLED': {'no': 92,
#   'level': 'Party',
#   'alias': 'Party Number Killed',
#   'desc': 'Number of killed victims in the party',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'PARTY_NUMBER_INJURED': {'no': 93,
#   'level': 'Party',
#   'alias': 'Party Number Injured',
#   'desc': 'Number of injured victims in the party',
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'INATTENTION': {'no': 94,
#   'level': 'Party',
#   'alias': 'Inattention',
#   'desc': 'Type of inattention',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Cell phone handheld',
#    'B': 'Cell phone handsfree',
#    'C': 'Electronic equipment',
#    'D': 'Radio/CD',
#    'E': 'Smoking',
#    'F': 'Eating',
#    'G': 'Children',
#    'H': 'Animal',
#    'I': 'Personal hygiene',
#    'J': 'Reading',
#    'K': 'Other',
#    'P': 'Cell Phone',
#    '-': 'Not Stated'}},
#  'PARTY_SOBRIETY': {'no': 95,
#   'level': 'Party',
#   'alias': 'Party Sobriety',
#   'desc': 'The state of sobriety of the party',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Had not been drinking',
#    'B': 'Had been drinking under influence',
#    'C': 'Had been drinking, not under influence',
#    'D': 'Had been drinking, impairment unknown',
#    'G': 'Impairment unknown',
#    'H': 'Not applicable',
#    '-': 'Not Stated'}},
#  'PARTY_DRUG_PHYSICAL': {'no': 96,
#   'level': 'Party',
#   'alias': 'Party Drug Physical',
#   'desc': 'The state of the party with regard to drugs and physical condition',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'E': 'Under drug influence',
#    'F': 'Impairment - physical',
#    'G': 'Impairment unknown',
#    'H': 'Not applicable',
#    'I': 'Sleepy or fatigued',
#    '-': 'Not Stated'}},
#  'DIR_OF_TRAVEL': {'no': 97,
#   'level': 'Party',
#   'alias': 'Direction of Travel',
#   'desc': 'Direction that the party was traveling at the time of the crash. The direction is the direction of the highway, not the compass direction',
#   'type': 'TEXT',
#   'cat': 'Measurement',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'N': 'North',
#    'S': 'South',
#    'E': 'East',
#    'W': 'West',
#    '-': 'Not Stated'}},
#  'PARTY_SAFETY_EQUIP_1': {'no': 98,
#   'level': 'Party',
#   'alias': 'Party Safety Equipment 1',
#   'desc': 'The safety equipment of the party',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'None in vehicle',
#    'B': 'Unknown',
#    'C': 'Lap belt used',
#    'D': 'Lab belt not used',
#    'E': 'Shoulder harness used',
#    'F': 'Shoulder harness not used',
#    'G': 'Lap/shoulder harness used',
#    'H': 'Lap/shoulder harness not used',
#    'J': 'Passive restraint used',
#    'K': 'Passive restraint not used',
#    'L': 'Air bag deployed',
#    'M': 'Air bag not deployed',
#    'N': 'Other',
#    'P': 'Not required',
#    'Q': 'Child restraint in vehicle used',
#    'R': 'Child restraint in vehicle not used',
#    'S': 'Child restraint in vehicle, use unknown',
#    'T': 'Child restraint in vehicle, improper use',
#    'U': 'No child restraint in vehicle',
#    'V': 'Driver, motorcycle helmet not used',
#    'W': 'Driver, motorcycle helmet used',
#    'X': 'Passenger, motorcycle helmet not used',
#    'Y': 'Passenger, motorcycle helmet used',
#    '-': 'Not Stated'}},
#  'PARTY_SAFETY_EQUIP_2': {'no': 99,
#   'level': 'Party',
#   'alias': 'Party Safety Equipment 2',
#   'desc': 'The safety equipment of the party',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'None in vehicle',
#    'B': 'Unknown',
#    'C': 'Lap belt used',
#    'D': 'Lab belt not used',
#    'E': 'Shoulder harness used',
#    'F': 'Shoulder harness not used',
#    'G': 'Lap/shoulder harness used',
#    'H': 'Lap/shoulder harness not used',
#    'J': 'Passive restraint used',
#    'K': 'Passive restraint not used',
#    'L': 'Air bag deployed',
#    'M': 'Air bag not deployed',
#    'N': 'Other',
#    'P': 'Not required',
#    'Q': 'Child restraint in vehicle used',
#    'R': 'Child restraint in vehicle not used',
#    'S': 'Child restraint in vehicle, use unknown',
#    'T': 'Child restraint in vehicle, improper use',
#    'U': 'No child restraint in vehicle',
#    'V': 'Driver, motorcycle helmet not used',
#    'W': 'Driver, motorcycle helmet used',
#    'X': 'Passenger, motorcycle helmet not used',
#    'Y': 'Passenger, motorcycle helmet used',
#    '-': 'Not Stated'}},
#  'FINAN_RESPONS': {'no': 100,
#   'level': 'Party',
#   'alias': 'Financial Responsibility',
#   'desc': 'Financial responsibility of the party',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'N': 'No proof of insurance obtained',
#    'Y': 'Yes, proof of insurance obtained',
#    'O': 'Not applicable (used for parked cars, bicyclists, pedestrians, and party type others)',
#    'E': 'Used if the officer is called away from the scene of the crash prior to obtaining the insurance information'}},
#  'SP_INFO_1': {'no': 101,
#   'level': 'Party',
#   'alias': 'Special Information 1',
#   'desc': 'Value A indicates that the crash involved in a vehicle known to be, or believed to be, transporting a hazardous material as defined in CVC Section 353, whether or not the crash involved a hazardous material incident',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Hazardous materials', '-': 'Not Stated'}},
#  'SP_INFO_2': {'no': 102,
#   'level': 'Party',
#   'alias': 'Special Information 2',
#   'desc': 'Cell Phone Information',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Cell phone handheld in use',
#    '2': 'Cell phone handsfree in use',
#    '3': 'Cell phone not in use',
#    '4': 'Cell phone use unknown',
#    'B': 'Cell phone in use',
#    'C': 'Cell phone not in use',
#    'D': 'No cell phone/unknown',
#    '-': 'Not Stated'}},
#  'SP_INFO_3': {'no': 103,
#   'level': 'Party',
#   'alias': 'Special Information 3',
#   'desc': 'Value E indicates that the crash involved a motor vehicle in-transport passing a stopped school bus with its red signal lamps in operation pursuant to CVC Section 22112, or reacting to, pursuant to CVC Section 22454',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'E': 'School bus related', '-': 'Not Stated'}},
#  'OAF_VIOLATION_CODE': {'no': 104,
#   'level': 'Party',
#   'alias': 'OAF Violation Code',
#   'desc': 'Other associated factor law code violated',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'B': 'Business and professions',
#    'C': 'Vehicle',
#    'H': 'City Health and Safety',
#    'I': 'City Ordinance',
#    'P': 'Penal',
#    'S': 'Streets and Highways',
#    'W': 'Welfare and institutions',
#    '-': 'Not Stated'}},
#  'OAF_VIOL_CAT': {'no': 105,
#   'level': 'Party',
#   'alias': 'OAF Violation Category',
#   'desc': 'Category of the factor that contributed to the crash but was not the primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not Stated',
#    '1': 'Under influence in public',
#    '2': 'County ordinance',
#    '3': 'City ordinance',
#    '5': 'Business/professions code',
#    '6': 'Felony penal code',
#    '8': 'Controlled substances (felony health and safety)',
#    '9': 'Health/safety code (misdemeanor)',
#    '10': 'Penal code (misdemeanor)',
#    '11': 'Streets/highways code',
#    '13': 'Welfare/institutions code',
#    '15': 'Manslaughter',
#    '16': 'Non-vehicle code not specified above',
#    '17': 'Fish and game code',
#    '18': 'Agriculture code',
#    '19': 'Hit and run',
#    '20': 'Driving or bicycling under the influence of alcohol or drug',
#    '21': 'Improper lane change',
#    '22': 'Impeding traffic',
#    '23': 'Failure to heed stop signal',
#    '24': 'Failure to heed stop sign',
#    '25': 'Unsafe speed',
#    '26': 'Reckless driving',
#    '27': 'Wrong side of road',
#    '28': 'Unsafe lane change',
#    '29': 'Improper passing',
#    '30': 'Following too closely',
#    '31': 'Improper turning',
#    '33': 'Automobile right-of-way',
#    '34': 'Pedestrian right-of-way',
#    '35': 'Pedestrian violation',
#    '38': 'Hazardous parking',
#    '39': 'Lights',
#    '40': 'Brakes',
#    '43': 'Other equipment',
#    '44': 'Other hazardous movement',
#    '46': 'Improper registration',
#    '47': 'Other non-moving violation',
#    '48': 'Excessive smoke',
#    '49': 'Excessive noise',
#    '50': 'Overweight',
#    '51': 'Oversize',
#    '52': 'Over maximum speed',
#    '53': 'Unsafe starting or backing',
#    '60': 'Off-highway vehicle violation',
#    '61': 'Child restraint',
#    '62': 'Seat belt',
#    '63': 'Seat belt (equipment)',
#    '-': 'Not Stated'}},
#  'OAF_VIOL_SECTION': {'no': 106,
#   'level': 'Party',
#   'alias': 'OAF Violation Section',
#   'desc': 'The CVC section of the secondary violation that contributed to the crash',
#   'type': 'DOUBLE',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'OAF_VIOLATION_SUFFIX': {'no': 107,
#   'level': 'Party',
#   'alias': 'OAF Violation Suffix',
#   'desc': 'the subsection of the CVC section of the secondary violation that contributed to the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'OAF_1': {'no': 108,
#   'level': 'Party',
#   'alias': 'Other Associated Factor 1',
#   'desc': 'A factor that contributed to the crash but was not the primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Violation',
#    'E': 'Vision obscurements',
#    'F': 'Inattention',
#    'G': 'Stop and go traffic',
#    'H': 'Entering/leaving ramp',
#    'I': 'Previous collision',
#    'J': 'Unfamiliar with road',
#    'K': 'Defective vehicle equipment',
#    'L': 'Uninvolved vehicle',
#    'M': 'Other',
#    'N': 'None apparent',
#    'O': 'Runaway vehicle',
#    'P': 'Inattention, cell phone',
#    'Q': 'Inattention, electronic equip',
#    'R': 'Inattention, radio/CD',
#    'S': 'Inattention, smoking',
#    'T': 'Inattention, eating',
#    'U': 'Inattention, children',
#    'V': 'Inattention, animal',
#    'W': 'Inattention, personal hygiene',
#    'X': 'Inattention, reading',
#    'Y': 'Inattention, other',
#    '-': 'Not Stated'}},
#  'OAF_2': {'no': 109,
#   'level': 'Party',
#   'alias': 'Other Associated Factor 2',
#   'desc': 'A factor that contributed to the crash but was not the primary cause of the crash',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Violation',
#    'E': 'Vision obscurements',
#    'F': 'Inattention',
#    'G': 'Stop and go traffic',
#    'H': 'Entering/leaving ramp',
#    'I': 'Previous collision',
#    'J': 'Unfamiliar with road',
#    'K': 'Defective vehicle equipment',
#    'L': 'Uninvolved vehicle',
#    'M': 'Other',
#    'N': 'None apparent',
#    'O': 'Runaway vehicle',
#    'P': 'Inattention, cell phone',
#    'Q': 'Inattention, electronic equip',
#    'R': 'Inattention, radio/CD',
#    'S': 'Inattention, smoking',
#    'T': 'Inattention, eating',
#    'U': 'Inattention, children',
#    'V': 'Inattention, animal',
#    'W': 'Inattention, personal hygiene',
#    'X': 'Inattention, reading',
#    'Y': 'Inattention, other',
#    '-': 'Not Stated'}},
#  'MOVE_PRE_ACC': {'no': 110,
#   'level': 'Party',
#   'alias': 'Movement Preceding Crash',
#   'desc': 'The action of the vehicle prior to the crash and before evasive action. This movement does not have to correspond with the PCF',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Stopped',
#    'B': 'Proceeding straight',
#    'C': 'Ran off road',
#    'D': 'Making right turn',
#    'E': 'Making left turn',
#    'F': 'Making U-turn',
#    'G': 'Backing',
#    'H': 'Slowing/stopping',
#    'I': 'Passing other vehicle',
#    'J': 'Changing lanes',
#    'K': 'Parking maneuver',
#    'L': 'Entering traffic',
#    'M': 'Other unsafe turning',
#    'N': 'Crossed into opposing lane',
#    'O': 'Parked',
#    'P': 'Merging',
#    'Q': 'Traveling wrong way',
#    'R': 'Other',
#    'S': 'Lane splitting',
#    '-': 'Not Stated'}},
#  'VEHICLE_YEAR': {'no': 111,
#   'level': 'Party',
#   'alias': 'Vehicle Year',
#   'desc': "The model year of the party's vehicle",
#   'type': 'LONG',
#   'cat': 'Date and Time',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'9999': 'Not Stated'}},
#  'VEHICLE_MAKE': {'no': 112,
#   'level': 'Party',
#   'alias': 'Vehicle Make',
#   'desc': "The make of the party's vehicle",
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'-': 'Not Stated'}},
#  'STWD_VEHICLE_TYPE': {'no': 113,
#   'level': 'Party',
#   'alias': 'Statewide Vehicle Type',
#   'desc': "Type of the party's vehicle according to a list called statewide vehicle type",
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'Passenger car/station wagon',
#    'B': 'Passenger car with trailer',
#    'C': 'Motorcycle/scooter',
#    'D': 'Pickup or panel truck',
#    'E': 'Pickup or panel truck with trailer',
#    'F': 'Truck or truck tractor',
#    'G': 'Truck or truck tractor with trailer',
#    'H': 'Schoolbus',
#    'I': 'Other bus',
#    'J': 'Emergency vehicle',
#    'K': 'Highway construction equipment',
#    'L': 'Bicycle',
#    'M': 'Other vehicle',
#    'N': 'Pedestrian',
#    'O': 'Moped',
#    '-': 'Not Stated'}},
#  'CHP_VEH_TYPE_TOWING': {'no': 114,
#   'level': 'Party',
#   'alias': 'CHP Vehicle Type Towing',
# ...
#    '61': 'School pupil activity bus I (prior to 2002)',
#    '62': 'School pupil activity bus II (prior to 2002)',
#    '63': 'Youth bus',
#    '64': 'School pupil activity bus I (eff 2002)',
#    '65': 'School pupil activity bus II (eff 2002)',
#    '66': 'School bus Without pupil passengers (eff 2002)',
#    '71': 'Passenger car - hazardous materials only',
#    '72': 'Pickups and panels - hazardous materials only',
#    '73': 'Pickups and campers - hazardous materials only',
#    '75': 'Truck tractor - hazardous materials only',
#    '76': 'Two-axle truck - hazardous materials only',
#    '77': 'Three or more axle truck - hazardous materials only',
#    '78': 'Two-axle tank truck - hazardous materials only',
#    '79': 'Three axle tank truck - hazardous materials only',
#    '81': 'Passenger car - hazardous waste or waste-material combo',
#    '82': 'Pickups and panels - hazardous waste or waste-material combo',
#    '83': 'Pickups and campers - hazardous waste or waste-material combo',
#    '85': 'Truck tractor - hazardous waste or waste-material combo',
#    '86': 'Two-axle truck - hazardous waste or waste-material combo',
#    '87': 'Three or more axle truck - hazardous waste or waste-material combo',
#    '88': 'Two-axle tank truck - hazardous waste or waste-material combo',
#    '89': 'Three-axle tank truck - hazardous waste or waste-material combo',
#    '91': 'Electric bicycle (class 1,2,3)',
#    '93': 'Electrically motorized board',
#    '94': 'Motorized transportation device',
#    '95': 'Miscellaneous non-motorized vehicle (ridden animal, animal-drawn conveyance, train or building) with victim',
#    '96': 'Miscellaneous motorized vehicle (golf cart)',
#    '97': 'Low speed vehicle',
#    '98': 'Emergency vehicle on an emergency run',
#    '99': 'Not stated or unknown (hit and run)',
#    '-': 'Not Stated'}},
#  'CHP_VEH_TYPE_TOWED': {'no': 115,
#   'level': 'Party',
#   'alias': 'CHP Vehicle Type Towed',
#   'desc': 'The type of the first trailer unit according to the CHP manual HPM 110.5 Chapter 3 Annex F vehicle type codes',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Passenger, car, station Wagon, or Jeep',
#    '2': 'Motorcycle',
#    '3': 'Motor-driven cycle (<15 hp)',
#    '4': 'Bicycle',
#    '5': 'Motorized vehicle',
#    '6': 'All-terrain vehicle (ATV)',
#    '7': 'Sport utility vehicle',
#    '8': 'Minivan',
#    '9': 'Paratransit bus',
#    '10': 'Tour bus',
#    '11': 'Other commercial bus',
#    '12': 'Non-commercial bus',
#    '13': 'Schoolbus public I',
#    '14': 'Schoolbus public II',
#    '15': 'Schoolbus private I',
#    '16': 'Schoolbus private II',
#    '17': 'Schoolbus contractual I',
#    '18': 'Schoolbus contractual II',
#    '19': 'General public paratransit vehicle',
#    '20': 'Public transit authority',
#    '21': 'Two-axle tank truck',
#    '22': 'Pickup or panel truck',
#    '23': 'Pickup truck with camper',
#    '24': 'Three-axle tank truck',
#    '25': 'Truck tractor',
#    '26': 'Two-axle truck',
#    '27': 'Three-axle truck',
#    '28': 'Semi-tank trailer',
#    '29': 'Pull-tank trailer',
#    '30': 'Two-tank trailer',
#    '31': 'Semi-trailer',
#    '32': 'Pull trailer (includes dolly)',
#    '33': 'Two trailers (includes semi and trailer)',
#    '34': 'Boat trailer',
#    '35': 'Utility trailer',
#    '36': 'Trailer coach',
#    '37': 'Oversize vehicle/load',
#    '38': 'Pole, pipe, or logging dolly',
#    '39': 'Three trailers (includes semi and two trailers)',
#    '40': 'Semi 48 or less with king pin to trailer axle of over 38',
#    '41': 'Ambulance',
#    '42': 'Dune buggy',
#    '43': 'Fire truck (not rescue)',
#    '44': 'Forklift',
#    '45': 'Highway construction equipment (only while not in construction area)',
#    '46': 'Implement of husbandry',
#    '47': 'Motor home (40 ft or less)',
#    '48': 'CHP, police, or sheriff car (emergency service or not)',
#    '49': 'CHP, police, or sheriff motorcycle (emergency service or not)',
#    '50': 'Mobile equipment',
#    '51': 'Farm labor vehicle (certified)',
#    '52': 'Federally legal double cargo combo over 75ft',
#    '53': '5th wheel trailer',
#    '54': 'Container chassis',
#    '55': 'Two-axle tow truck',
#    '56': 'Three-axle tow truck',
#    '57': 'Farm labor vehicle (non-certified)',
#    '58': 'Farm labor transporter',
#    '59': 'Motorhome (over 40ft)',
#    '60': 'Pedestrian (includes motorized wheelchair)',
#    '61': 'School pupil activity bus I (prior to 2002)',
#    '62': 'School pupil activity bus II (prior to 2002)',
#    '63': 'Youth bus',
#    '64': 'School pupil activity bus I (eff 2002)',
#    '65': 'School pupil activity bus II (eff 2002)',
#    '66': 'School bus Without pupil passengers (eff 2002)',
#    '71': 'Passenger car - hazardous materials only',
#    '72': 'Pickups and panels - hazardous materials only',
#    '73': 'Pickups and campers - hazardous materials only',
#    '75': 'Truck tractor - hazardous materials only',
#    '76': 'Two-axle truck - hazardous materials only',
#    '77': 'Three or more axle truck - hazardous materials only',
#    '78': 'Two-axle tank truck - hazardous materials only',
#    '79': 'Three axle tank truck - hazardous materials only',
#    '81': 'Passenger car - hazardous waste or waste-material combo',
#    '82': 'Pickups and panels - hazardous waste or waste-material combo',
#    '83': 'Pickups and campers - hazardous waste or waste-material combo',
#    '85': 'Truck tractor - hazardous waste or waste-material combo',
#    '86': 'Two-axle truck - hazardous waste or waste-material combo',
#    '87': 'Three or more axle truck - hazardous waste or waste-material combo',
#    '88': 'Two-axle tank truck - hazardous waste or waste-material combo',
#    '89': 'Three-axle tank truck - hazardous waste or waste-material combo',
#    '91': 'Electric bicycle (class 1,2,3)',
#    '93': 'Electrically motorized board',
#    '94': 'Motorized transportation device',
#    '95': 'Miscellaneous non-motorized vehicle (ridden animal, animal-drawn conveyance, train or building) with victim',
#    '96': 'Miscellaneous motorized vehicle (golf cart)',
#    '97': 'Low speed vehicle',
#    '98': 'Emergency vehicle on an emergency run',
#    '99': 'Not stated or unknown (hit and run)',
#    '-': 'Not Stated'}},
#  'SPECIAL_INFO_F': {'no': 116,
#   'level': 'Party',
#   'alias': 'Special Info F',
#   'desc': "The value F indicate that the party's vehicle is a 75ft motor truck combo",
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'F': '75ft motor truck combo', '-': 'Not Stated'}},
#  'SPECIAL_INFO_G': {'no': 117,
#   'level': 'Party',
#   'alias': 'Special Info G',
#   'desc': "The value G indicates that the party's vehicle is a 32ft trailer combo",
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'G': '32ft trailer combo', '-': 'Not Stated'}},
#  'VICTIM_ROLE': {'no': 118,
#   'level': 'Victim',
#   'alias': 'Victim Role',
#   'desc': 'The role of the victim',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'1': 'Driver',
#    '2': 'Passenger (includes non-operator on bicycle or any victim on/in parked vehicle or multiple victims on/in non-motor vehicle)',
#    '3': 'Pedestrian',
#    '4': 'Bicyclist',
#    '5': 'Other (single victim on/in non-motor vehicle)',
#    '6': 'Non-injured party'}},
#  'VICTIM_SEX': {'no': 119,
#   'level': 'Victim',
#   'alias': 'Victim Sex',
#   'desc': 'The gender of the victim',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'M': 'Male', 'F': 'Female', 'X': 'Nonbinary', '-': 'Not Stated'}},
#  'VICTIM_AGE': {'no': 120,
#   'level': 'Victim',
#   'alias': 'Victim Age',
#   'desc': 'The age of the victim at the time of the crash',
#   'type': 'LONG',
#   'cat': 'Measurement',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'998': 'Not Stated', '999': 'Fatal Fetus'}},
#  'VICTIM_DEGREE_OF_INJURY': {'no': 121,
#   'level': 'Victim',
#   'alias': 'Victim Degree of Injury',
#   'desc': 'The severity of the injury to the victim',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'No injury',
#    '1': 'Killed',
#    '2': 'Severe injury',
#    '3': 'Other visible injury',
#    '4': 'Complaint of pain',
#    '5': 'Suspected serious injury',
#    '6': 'Suspected minor injury',
#    '7': 'Possible injury'}},
#  'VICTIM_DEGREE_OF_INJURY_BINARY': {'no': 122,
#   'level': 'Victim',
#   'alias': 'Victim Injury Severity (Binary)',
#   'desc': 'Binary classification of the severity of the injury to the victim',
#   'type': 'LONG',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Minor (minor injury, pain, or no injury)',
#    '1': 'Severe (killed or serious injury)'}},
#  'VICTIM_SEATING_POSITION': {'no': 123,
#   'level': 'Victim',
#   'alias': 'Victim Seating Position',
#   'desc': 'The seating position of the victim',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Other occupants',
#    '1': 'Driver',
#    '2': 'Passenger 1',
#    '3': 'Passenger 2',
#    '4': 'Passenger 3',
#    '5': 'Passenger 4',
#    '6': 'Passenger 5',
#    '7': 'Station wagon rear',
#    '8': 'Rear occupant of truck or van',
#    '9': 'Position unknown',
#    '-': 'Not Stated'}},
#  'VICTIM_SAFETY_EQUIP_1': {'no': 124,
#   'level': 'Victim',
#   'alias': 'Victim Safety Equipment 1',
#   'desc': 'The safety equipment of the victim',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'None in vehicle',
#    'B': 'Unknown',
#    'C': 'Lap belt used',
#    'D': 'Lap belt not used',
#    'E': 'Shoulder harness used',
#    'F': 'Shoulder harness not used',
#    'G': 'Lap/shoulder harness used',
#    'H': 'Lap/shoulder harness not used',
#    'J': 'Passive restraint used',
#    'K': 'Passive restraint not used',
#    'L': 'Air bag deployed',
#    'M': 'Air bag not deployed',
#    'N': 'Other',
#    'P': 'Not required',
#    'Q': 'Child restraint in vehicle used',
#    'R': 'Child restraint in vehicle not used',
#    'S': 'Child restraint in vehicle, use unknown',
#    'T': 'Child restraint in vehicle, improper use',
#    'U': 'No child restraint in vehicle',
#    'V': 'Driver, motorcycle helmet used',
#    'W': 'Driver, motorcycle helmet not used',
#    'X': 'Passenger, motorcycle helmet not used',
#    'Y': 'Passenger, motorcycle helmet used',
#    '-': 'Not Stated'}},
#  'VICTIM_SAFETY_EQUIP_2': {'no': 125,
#   'level': 'Victim',
#   'alias': 'Victim Safety Equipment 2',
#   'desc': 'The safety equipment of the victim',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'A': 'None in vehicle',
#    'B': 'Unknown',
#    'C': 'Lap belt used',
#    'D': 'Lap belt not used',
#    'E': 'Shoulder harness used',
#    'F': 'Shoulder harness not used',
#    'G': 'Lap/shoulder harness used',
#    'H': 'Lap/shoulder harness not used',
#    'J': 'Passive restraint used',
#    'K': 'Passive restraint not used',
#    'L': 'Air bag deployed',
#    'M': 'Air bag not deployed',
#    'N': 'Other',
#    'P': 'Not required',
#    'Q': 'Child restraint in vehicle used',
#    'R': 'Child restraint in vehicle not used',
#    'S': 'Child restraint in vehicle, use unknown',
#    'T': 'Child restraint in vehicle, improper use',
#    'U': 'No child restraint in vehicle',
#    'V': 'Driver, motorcycle helmet used',
#    'W': 'Driver, motorcycle helmet not used',
#    'X': 'Passenger, motorcycle helmet not used',
#    'Y': 'Passenger, motorcycle helmet used',
#    '-': 'Not Stated'}},
#  'VICTIM_EJECTED': {'no': 126,
#   'level': 'Victim',
#   'alias': 'Victim Ejected',
#   'desc': 'Indicates whether the victim was ejected from the vehicle',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'Y',
#   'dtype': 'CODED',
#   'domain': {'0': 'Not ejected',
#    '1': 'Fully ejected',
#    '2': 'Partially ejected',
#    '3': 'Unknown',
#    '-': 'Not Stated'}},
#  'CITY_AREA_SQMI': {'no': 127,
#   'level': 'City',
#   'alias': 'City Area (sq. miles)',
#   'desc': 'City Area in Square Miles',
#   'type': 'DOUBLE',
#   'cat': 'Measurement',
#   'dbin': 'N'},
#  'CITY_POPDENS': {'no': 128,
#   'level': 'City',
#   'alias': 'City Population Density (per sq. mi)',
#   'desc': 'City population density, population per square mile',
#   'type': 'DOUBLE',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_HUDENS': {'no': 129,
#   'level': 'City',
#   'alias': 'City Housing Density (per sq. mi)',
#   'desc': 'City housing density, houses per square mile',
#   'type': 'DOUBLE',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_POPT': {'no': 130,
#   'level': 'City',
#   'alias': 'City Total Population',
#   'desc': "Total population in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_HUT': {'no': 131,
#   'level': 'City',
#   'alias': 'City Total Housing Units',
#   'desc': "Total housing units in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_POPA': {'no': 132,
#   'level': 'City',
#   'alias': 'City Asian Population',
#   'desc': "Total Asian population in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_POPB': {'no': 133,
#   'level': 'City',
#   'alias': 'City Black Population',
#   'desc': "Total Black or African American population in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_POPH': {'no': 134,
#   'level': 'City',
#   'alias': 'City Hispanic Population',
#   'desc': "Total Hispanic population in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_POPW': {'no': 135,
#   'level': 'City',
#   'alias': 'City White Population',
#   'desc': "Total White population in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_VEHICLES': {'no': 136,
#   'level': 'City',
#   'alias': 'City Aggregate Number of Vehicles Commuting',
#   'desc': "Aggregate number of vehicles used in commuting in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'CITY_TRAVEL_TIME': {'no': 137,
#   'level': 'City',
#   'alias': 'City Aggregate Travel Time to Work (min)',
#   'desc': "Aggregate travel time to work (in minutes) in the city's area",
#   'type': 'LONG',
#   'cat': 'Count or Amount',
#   'dbin': 'N'},
#  'RID': {'no': 138,
#   'level': 'Road',
#   'alias': 'Road ID',
#   'desc': "Road ID matching from the road's layer",
#   'type': 'TEXT',
#   'cat': 'Unique Identifier',
#   'dbin': 'N'},
#  'RNAME': {'no': 139,
#   'level': 'Road',
#   'alias': 'Road Name',
#   'desc': 'Road name from the OC Tiger/Lines layer',
#   'type': 'TEXT',
#   'cat': 'Name',
#   'dbin': 'N'},
#  'RCAT': {'no': 140,
#   'level': 'Road',
#   'alias': 'Road Category',
#   'desc': 'Road category from the OC Tiger/Lines layer',
#   'type': 'TEXT',
#   'cat': 'Type or Category',
#   'dbin': 'N'},
#  'RLENGTH': {'no': 141,
#   'level': 'Road',
#   'alias': 'Road Length',
#   'desc': 'Road length from the OC Tiger/Lines layer',
#   'type': 'DOUBLE',
#   'cat': 'Measurement',
#   'dbin': 'N'},
#  'LATITUDE': {'no': 142,
#   'level': 'Crash',
#   'alias': 'GPS Latitude',
#   'desc': 'Latitude of the crash location in decimal degrees. The decimal point is included. LATITUDE and LONGITUDE are from the crash report',
#   'type': 'DOUBLE',
#   'cat': 'Coordinate',
#   'dbin': 'N'},
#  'LONGITUDE': {'no': 143,
#   'level': 'Crash',
#   'alias': 'GPS Longitude',
#   'desc': 'Longitude of the crash location in decimal degrees. The decimal point is included. There is no minus sign. The longitude is understood to be West of Meridian. LATITUDE and LONGITUDE are from the crash report',
#   'type': 'DOUBLE',
#   'cat': 'Coordinate',
#   'dbin': 'N'},
#  'POINT_X': {'no': 144,
#   'level': 'Crash',
#   'alias': 'X Coordinate Location',
#   'desc': 'The longitude of the geocoded location, uses the World Geodetic System from 1984 (WGS84). POINT_X and POINT_Y are generated using the geociding process by UC Berkeley Safe TREC',
#   'type': 'DOUBLE',
#   'cat': 'Coordinate',
#   'dbin': 'N'},
#  'POINT_Y': {'no': 145,
#   'level': 'Crash',
#   'alias': 'Y Coordinate Location',
#   'desc': 'The latitude of the geocoded location, uses the World Geodetic System from 1984 (WGS84). POINT_X and POINT_Y are generated using the geociding process by UC Berkeley Safe TREC',
#   'type': 'DOUBLE',
#   'cat': 'Coordinate',
#   'dbin': 'N'}}

# %% [markdown]
# Save the ArcGIS Pro project

# %%
# Save the project
aprx.save()

# %% [markdown]
# ## <font color="orangered">**Assigning Domain Attributes**</font>

# %% [markdown]
# Creating and assigning domain attributes for the feature classes using the JSON codebook dictionary

# %% [markdown]
# ### <font color="lime">**Creating domains in geodatabase**</font>

# %% [markdown]
# > ⚠️ <font color="coral">**Note**</font>: This command can only be run as and if it is necessary. Running this command will delete all domains and domain variables from the geodatabase.

# %% [markdown]
# Delete all domains from the geodatabase

# %%
# Delete domains from the geodatabase
for key in list(d.name for d in list(arcpy.da.ListDomains())):
    arcpy.management.DeleteDomain(workspace, key)
    print(f"{key}: Domain deleted")
    print(arcpy.GetMessages())
# Out:
# COLLISION_MONTH: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:14 AM
# Succeeded at Wednesday, November 13, 2024 8:37:14 AM (Elapsed Time: 0.40 seconds)
# COLLISION_TIME_INTERVALS: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:15 AM
# Succeeded at Wednesday, November 13, 2024 8:37:15 AM (Elapsed Time: 0.38 seconds)
# OAF_2: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:15 AM
# Succeeded at Wednesday, November 13, 2024 8:37:15 AM (Elapsed Time: 0.35 seconds)
# DAY_OF_WEEK: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:16 AM
# Succeeded at Wednesday, November 13, 2024 8:37:16 AM (Elapsed Time: 0.39 seconds)
# COLLISION_TIME_RUSH_HOURS: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:16 AM
# Succeeded at Wednesday, November 13, 2024 8:37:17 AM (Elapsed Time: 0.39 seconds)
# OAF_VIOL_CAT: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:17 AM
# Succeeded at Wednesday, November 13, 2024 8:37:17 AM (Elapsed Time: 0.34 seconds)
# PEDESTRIAN_ACCIDENT: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:17 AM
# Succeeded at Wednesday, November 13, 2024 8:37:18 AM (Elapsed Time: 0.40 seconds)
# COLLISION_SEVERITY: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:18 AM
# Succeeded at Wednesday, November 13, 2024 8:37:18 AM (Elapsed Time: 0.40 seconds)
# COLLISION_SEVERITY_BINARY: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:19 AM
# Succeeded at Wednesday, November 13, 2024 8:37:19 AM (Elapsed Time: 0.38 seconds)
# COLLISION_SEVERITY_RECLASSIFIED: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:19 AM
# Succeeded at Wednesday, November 13, 2024 8:37:19 AM (Elapsed Time: 0.39 seconds)
# COLLISION_SEVERITY_RANKED: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:20 AM
# Succeeded at Wednesday, November 13, 2024 8:37:20 AM (Elapsed Time: 0.37 seconds)
# PRIMARY_COLL_FACTOR: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:20 AM
# Succeeded at Wednesday, November 13, 2024 8:37:21 AM (Elapsed Time: 0.37 seconds)
# TYPE_OF_COLLISION: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:21 AM
# Succeeded at Wednesday, November 13, 2024 8:37:21 AM (Elapsed Time: 0.35 seconds)
# SIDE_OF_HWY: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:21 AM
# Succeeded at Wednesday, November 13, 2024 8:37:22 AM (Elapsed Time: 0.33 seconds)
# BICYCLE_ACCIDENT: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:22 AM
# Succeeded at Wednesday, November 13, 2024 8:37:22 AM (Elapsed Time: 0.37 seconds)
# MOTORCYCLE_ACCIDENT: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:22 AM
# Succeeded at Wednesday, November 13, 2024 8:37:23 AM (Elapsed Time: 0.37 seconds)
# TRUCK_ACCIDENT: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:23 AM
# Succeeded at Wednesday, November 13, 2024 8:37:23 AM (Elapsed Time: 0.38 seconds)
# HIT_AND_RUN: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:23 AM
# Succeeded at Wednesday, November 13, 2024 8:37:24 AM (Elapsed Time: 0.34 seconds)
# ALCOHOL_INVOLVED: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:24 AM
# Succeeded at Wednesday, November 13, 2024 8:37:24 AM (Elapsed Time: 0.34 seconds)
# PCF_VIOL_CATEGORY: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:24 AM
# Succeeded at Wednesday, November 13, 2024 8:37:25 AM (Elapsed Time: 0.60 seconds)
# CHP_SHIFT: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:25 AM
# Succeeded at Wednesday, November 13, 2024 8:37:26 AM (Elapsed Time: 0.37 seconds)
# SPECIAL_COND: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:26 AM
# Succeeded at Wednesday, November 13, 2024 8:37:26 AM (Elapsed Time: 0.33 seconds)
# MVIW: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:26 AM
# Succeeded at Wednesday, November 13, 2024 8:37:27 AM (Elapsed Time: 0.35 seconds)
# BEAT_TYPE: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:27 AM
# Succeeded at Wednesday, November 13, 2024 8:37:27 AM (Elapsed Time: 0.61 seconds)
# CHP_BEAT_TYPE: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:28 AM
# Succeeded at Wednesday, November 13, 2024 8:37:28 AM (Elapsed Time: 0.34 seconds)
# CHP_BEAT_CLASS: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:28 AM
# Succeeded at Wednesday, November 13, 2024 8:37:28 AM (Elapsed Time: 0.36 seconds)
# SP_INFO_3: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:29 AM
# Succeeded at Wednesday, November 13, 2024 8:37:29 AM (Elapsed Time: 0.35 seconds)
# TOW_AWAY: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:29 AM
# Succeeded at Wednesday, November 13, 2024 8:37:29 AM (Elapsed Time: 0.36 seconds)
# DIRECTION: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:30 AM
# Succeeded at Wednesday, November 13, 2024 8:37:30 AM (Elapsed Time: 0.36 seconds)
# INTERSECTION: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:30 AM
# Succeeded at Wednesday, November 13, 2024 8:37:31 AM (Elapsed Time: 0.34 seconds)
# WEATHER_1: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:31 AM
# Succeeded at Wednesday, November 13, 2024 8:37:31 AM (Elapsed Time: 0.37 seconds)
# WEATHER_2: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:31 AM
# Succeeded at Wednesday, November 13, 2024 8:37:32 AM (Elapsed Time: 0.33 seconds)
# ROAD_SURFACE: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:32 AM
# Succeeded at Wednesday, November 13, 2024 8:37:32 AM (Elapsed Time: 0.34 seconds)
# WEATHER_COMBINED: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:32 AM
# Succeeded at Wednesday, November 13, 2024 8:37:33 AM (Elapsed Time: 0.32 seconds)
# ROAD_COND_1: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:33 AM
# Succeeded at Wednesday, November 13, 2024 8:37:33 AM (Elapsed Time: 0.36 seconds)
# ROAD_COND_2: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:33 AM
# Succeeded at Wednesday, November 13, 2024 8:37:34 AM (Elapsed Time: 0.34 seconds)
# SECONDARY_RAMP: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:34 AM
# Succeeded at Wednesday, November 13, 2024 8:37:34 AM (Elapsed Time: 0.32 seconds)
# LIGHTING: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:34 AM
# Succeeded at Wednesday, November 13, 2024 8:37:35 AM (Elapsed Time: 0.33 seconds)
# CONTROL_DEVICE: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:35 AM
# Succeeded at Wednesday, November 13, 2024 8:37:35 AM (Elapsed Time: 0.37 seconds)
# NOT_PRIVATE_PROPERTY: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:35 AM
# Succeeded at Wednesday, November 13, 2024 8:37:36 AM (Elapsed Time: 0.34 seconds)
# PARTY_SOBRIETY: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:36 AM
# Succeeded at Wednesday, November 13, 2024 8:37:36 AM (Elapsed Time: 0.38 seconds)
# STATE_HWY_IND: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:36 AM
# Succeeded at Wednesday, November 13, 2024 8:37:37 AM (Elapsed Time: 0.34 seconds)
# PCF_CODE_OF_VIOL: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:37 AM
# Succeeded at Wednesday, November 13, 2024 8:37:37 AM (Elapsed Time: 0.36 seconds)
# PED_ACTION: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:37 AM
# Succeeded at Wednesday, November 13, 2024 8:37:38 AM (Elapsed Time: 0.34 seconds)
# STWD_VEHTYPE_AT_FAULT: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:38 AM
# Succeeded at Wednesday, November 13, 2024 8:37:38 AM (Elapsed Time: 0.32 seconds)
# PARTY_DRUG_PHYSICAL: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:38 AM
# Succeeded at Wednesday, November 13, 2024 8:37:39 AM (Elapsed Time: 0.31 seconds)
# PARTY_TYPE: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:39 AM
# Succeeded at Wednesday, November 13, 2024 8:37:39 AM (Elapsed Time: 0.31 seconds)
# CHP_VEHTYPE_AT_FAULT: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:39 AM
# Succeeded at Wednesday, November 13, 2024 8:37:40 AM (Elapsed Time: 0.32 seconds)
# PRIMARY_RAMP: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:40 AM
# Succeeded at Wednesday, November 13, 2024 8:37:40 AM (Elapsed Time: 0.32 seconds)
# STWD_VEHICLE_TYPE: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:40 AM
# Succeeded at Wednesday, November 13, 2024 8:37:41 AM (Elapsed Time: 0.35 seconds)
# AT_FAULT: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:41 AM
# Succeeded at Wednesday, November 13, 2024 8:37:41 AM (Elapsed Time: 0.31 seconds)
# PARTY_SEX: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:41 AM
# Succeeded at Wednesday, November 13, 2024 8:37:41 AM (Elapsed Time: 0.33 seconds)
# PARTY_AGE: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:42 AM
# Succeeded at Wednesday, November 13, 2024 8:37:42 AM (Elapsed Time: 0.36 seconds)
# PARTY_SAFETY_EQUIP_2: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:42 AM
# Succeeded at Wednesday, November 13, 2024 8:37:43 AM (Elapsed Time: 0.37 seconds)
# RACE: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:43 AM
# Succeeded at Wednesday, November 13, 2024 8:37:43 AM (Elapsed Time: 0.33 seconds)
# INATTENTION: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:43 AM
# Succeeded at Wednesday, November 13, 2024 8:37:43 AM (Elapsed Time: 0.30 seconds)
# DIR_OF_TRAVEL: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:44 AM
# Succeeded at Wednesday, November 13, 2024 8:37:44 AM (Elapsed Time: 0.33 seconds)
# PARTY_SAFETY_EQUIP_1: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:44 AM
# Succeeded at Wednesday, November 13, 2024 8:37:44 AM (Elapsed Time: 0.36 seconds)
# FINAN_RESPONS: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:45 AM
# Succeeded at Wednesday, November 13, 2024 8:37:45 AM (Elapsed Time: 0.34 seconds)
# VICTIM_DEGREE_OF_INJURY_BINARY: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:45 AM
# Succeeded at Wednesday, November 13, 2024 8:37:45 AM (Elapsed Time: 0.32 seconds)
# SP_INFO_1: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:46 AM
# Succeeded at Wednesday, November 13, 2024 8:37:46 AM (Elapsed Time: 0.31 seconds)
# SP_INFO_2: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:46 AM
# Succeeded at Wednesday, November 13, 2024 8:37:46 AM (Elapsed Time: 0.33 seconds)
# OAF_VIOLATION_CODE: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:47 AM
# Succeeded at Wednesday, November 13, 2024 8:37:47 AM (Elapsed Time: 0.34 seconds)
# OAF_1: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:47 AM
# Succeeded at Wednesday, November 13, 2024 8:37:47 AM (Elapsed Time: 0.30 seconds)
# MOVE_PRE_ACC: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:47 AM
# Succeeded at Wednesday, November 13, 2024 8:37:48 AM (Elapsed Time: 0.31 seconds)
# VEHICLE_YEAR: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:48 AM
# Succeeded at Wednesday, November 13, 2024 8:37:48 AM (Elapsed Time: 0.32 seconds)
# VEHICLE_MAKE: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:48 AM
# Succeeded at Wednesday, November 13, 2024 8:37:49 AM (Elapsed Time: 0.31 seconds)
# CHP_VEH_TYPE_TOWING: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:49 AM
# Succeeded at Wednesday, November 13, 2024 8:37:49 AM (Elapsed Time: 0.30 seconds)
# CHP_VEH_TYPE_TOWED: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:49 AM
# Succeeded at Wednesday, November 13, 2024 8:37:50 AM (Elapsed Time: 0.34 seconds)
# SPECIAL_INFO_F: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:50 AM
# Succeeded at Wednesday, November 13, 2024 8:37:50 AM (Elapsed Time: 0.33 seconds)
# SPECIAL_INFO_G: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:50 AM
# Succeeded at Wednesday, November 13, 2024 8:37:51 AM (Elapsed Time: 0.33 seconds)
# VICTIM_ROLE: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:51 AM
# Succeeded at Wednesday, November 13, 2024 8:37:51 AM (Elapsed Time: 0.34 seconds)
# VICTIM_SEX: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:51 AM
# Succeeded at Wednesday, November 13, 2024 8:37:51 AM (Elapsed Time: 0.31 seconds)
# VICTIM_AGE: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:52 AM
# Succeeded at Wednesday, November 13, 2024 8:37:52 AM (Elapsed Time: 0.30 seconds)
# VICTIM_DEGREE_OF_INJURY: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:52 AM
# Succeeded at Wednesday, November 13, 2024 8:37:52 AM (Elapsed Time: 0.34 seconds)
# VICTIM_SEATING_POSITION: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:53 AM
# Succeeded at Wednesday, November 13, 2024 8:37:53 AM (Elapsed Time: 0.31 seconds)
# VICTIM_SAFETY_EQUIP_1: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:53 AM
# Succeeded at Wednesday, November 13, 2024 8:37:53 AM (Elapsed Time: 0.31 seconds)
# VICTIM_SAFETY_EQUIP_2: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:53 AM
# Succeeded at Wednesday, November 13, 2024 8:37:54 AM (Elapsed Time: 0.28 seconds)
# VICTIM_EJECTED: Domain deleted
# Start Time: Wednesday, November 13, 2024 8:37:54 AM
# Succeeded at Wednesday, November 13, 2024 8:37:54 AM (Elapsed Time: 0.28 seconds)

# %% [markdown]
# Define domain attributes and adding them to the geodatabase for all four levels. The list of domains and domain attributes are defined in the codebook JSON dictionary.

# %%
# Iterate through the keys of the codebook dictionary
for key in list(codebook.keys()):
    # Check if the key has a domain attribute
    if codebook[key]["dbin"] == "Y":
        # Check if the key is in the domain list of the geodatabase
        if key in list(d.name for d in list(arcpy.da.ListDomains())):
            # Let the user know that the domain already exists
            print(f"Match {codebook[key]['no']}: Domain {key} already exists. Aborting...")
        else:
            print(f"Match {codebook[key]['no']}: Domain {key} does not exist. Creating...")
            print(f"Creating domain for {key}...")
            # Create the domain in the geodatabase
            arcpy.management.CreateDomain(
                in_workspace = workspace,
                domain_name = key,
                domain_description = codebook[key]["desc"],
                field_type = codebook[key]["type"],
                domain_type = "CODED",
                split_policy = "DEFAULT",
                merge_policy = "DEFAULT"
            )
            print(arcpy.GetMessages())
            print(f"\tDefining coded values dictionary...")
            # Iterate through the domain values in the codebook dictionary
            for item in list(codebook[key]["domain"]):
                itemCode = codebook[key]["domain"][item]
                # Depending on the field type conditions:
                if codebook[key]["type"] in ["TEXT"]:
                    print(f"\t\t...adding {item}: {itemCode}")
                    # Add the domain value to the domain
                    arcpy.management.AddCodedValueToDomain(
                        in_workspace = workspace,
                        domain_name = key,
                        code = item,
                        code_description = itemCode
                    )
                elif codebook[key]["type"] in ["LONG", "SHORT", "DOUBLE"]:
                    if item.isnumeric():
                        print(f"\t\t...adding {item}: {itemCode}")
                        # Add the domain value to the domain
                        arcpy.management.AddCodedValueToDomain(
                            in_workspace = workspace,
                            domain_name = key,
                            code = int(item),
                            code_description = itemCode
                        )
# Out:
# Match 20: Domain COLLISION_MONTH does not exist. Creating...
# Creating domain for COLLISION_MONTH...
# Start Time: Wednesday, November 13, 2024 8:37:59 AM
# Succeeded at Wednesday, November 13, 2024 8:37:59 AM (Elapsed Time: 0.29 seconds)
# 	Defining coded values dictionary...
# 		...adding 1: January
# 		...adding 2: February
# 		...adding 3: March
# 		...adding 4: April
# 		...adding 5: May
# 		...adding 6: June
# 		...adding 7: July
# 		...adding 8: August
# 		...adding 9: September
# 		...adding 10: October
# 		...adding 11: November
# 		...adding 12: December
# Match 21: Domain DAY_OF_WEEK does not exist. Creating...
# Creating domain for DAY_OF_WEEK...
# Start Time: Wednesday, November 13, 2024 8:38:05 AM
# Succeeded at Wednesday, November 13, 2024 8:38:05 AM (Elapsed Time: 0.29 seconds)
# 	Defining coded values dictionary...
# 		...adding 1: Monday
# 		...adding 2: Tuesday
# 		...adding 3: Wednesday
# 		...adding 4: Thursday
# 		...adding 5: Friday
# 		...adding 6: Saturday
# 		...adding 7: Sunday
# Match 23: Domain COLLISION_TIME_INTERVALS does not exist. Creating...
# Creating domain for COLLISION_TIME_INTERVALS...
# Start Time: Wednesday, November 13, 2024 8:38:09 AM
# Succeeded at Wednesday, November 13, 2024 8:38:09 AM (Elapsed Time: 0.24 seconds)
# 	Defining coded values dictionary...
# 		...adding 1: Night (00:00am to 06:00am)
# 		...adding 2: Morning (06:00am to 12:00pm)
# 		...adding 3: Afternoon (12:00pm to 06:00pm)
# 		...adding 4: Evening (06:00pm to 00:00am)
# 		...adding 999: Unknown Time
# Match 24: Domain COLLISION_TIME_RUSH_HOURS does not exist. Creating...
# Creating domain for COLLISION_TIME_RUSH_HOURS...
# Start Time: Wednesday, November 13, 2024 8:38:11 AM
# Succeeded at Wednesday, November 13, 2024 8:38:11 AM (Elapsed Time: 0.28 seconds)
# 	Defining coded values dictionary...
# 		...adding 1: Rush Hours (Morning)
# 		...adding 2: Rush Hours (Evening)
# 		...adding 3: Non-Rush Hours
# 		...adding 999: Unknown Time
# Match 25: Domain COLLISION_SEVERITY does not exist. Creating...
# Creating domain for COLLISION_SEVERITY...
# Start Time: Wednesday, November 13, 2024 8:38:13 AM
# Succeeded at Wednesday, November 13, 2024 8:38:14 AM (Elapsed Time: 0.24 seconds)
# 	Defining coded values dictionary...
# 		...adding 0: No injury, aka property damage only or PDO
# 		...adding 1: Fatal injury
# 		...adding 2: Suspected serous injury or severe injury
# 		...adding 3: Suspected minor injury or visible injury
# 		...adding 4: Possible injury or complaint of pain
# Match 26: Domain COLLISION_SEVERITY_BINARY does not exist. Creating...
# Creating domain for COLLISION_SEVERITY_BINARY...
# Start Time: Wednesday, November 13, 2024 8:38:16 AM
# Succeeded at Wednesday, November 13, 2024 8:38:16 AM (Elapsed Time: 0.26 seconds)
# 	Defining coded values dictionary...
# 		...adding 0: Minor (minor injury, pain, or no injury)
# 		...adding 1: Severe (killed or serious injury)
# Match 27: Domain COLLISION_SEVERITY_RECLASS does not exist. Creating...
# Creating domain for COLLISION_SEVERITY_RECLASS...
# Start Time: Wednesday, November 13, 2024 8:38:17 AM
# Succeeded at Wednesday, November 13, 2024 8:38:17 AM (Elapsed Time: 0.24 seconds)
# 	Defining coded values dictionary...
# 		...adding 0: None
# 		...adding 1: Possible Injury or Pain
# 		...adding 2: Minor or Visible Injury
# 		...adding 3: Serious or Severe Injury
# 		...adding 4: Fatal Injury
# Match 28: Domain COLLISION_SEVERITY_RANKED does not exist. Creating...
# Creating domain for COLLISION_SEVERITY_RANKED...
# Start Time: Wednesday, November 13, 2024 8:38:20 AM
# Succeeded at Wednesday, November 13, 2024 8:38:20 AM (Elapsed Time: 0.28 seconds)
# 	Defining coded values dictionary...
# 		...adding 0: None or Minor Injuries
# 		...adding 1: Single Injury (Severe)
# 		...adding 2: Multiple Injuries (Severe)
# 		...adding 3: Single Fatality, No Injuries (Fatal)
# 		...adding 4: Single Fatality, Single Injury (Fatal)
# 		...adding 5: Single Fatality, Multiple Injuries (Fatal)
# 		...adding 6: Multiple Fatalities, No Injuries (Fatal)
# 		...adding 7: Multiple Fatalities, Single Injury (Fatal)
# 		...adding 8: Multiple Fatalities, Multiple Injuries (Fatal)
# Match 42: Domain PRIMARY_COLL_FACTOR does not exist. Creating...
# Creating domain for PRIMARY_COLL_FACTOR...
# Start Time: Wednesday, November 13, 2024 8:38:24 AM
# Succeeded at Wednesday, November 13, 2024 8:38:24 AM (Elapsed Time: 0.29 seconds)
# 	Defining coded values dictionary...
# 		...adding A: Vehicle Code Violation
# 		...adding B: Other Improper Driving
# 		...adding C: Other Than Driver
# 		...adding D: Unknown
# 		...adding E: Fell Asleep
# 		...adding -: Not Stated
# Match 43: Domain TYPE_OF_COLLISION does not exist. Creating...
# Creating domain for TYPE_OF_COLLISION...
# Start Time: Wednesday, November 13, 2024 8:38:27 AM
# Succeeded at Wednesday, November 13, 2024 8:38:27 AM (Elapsed Time: 0.25 seconds)
# 	Defining coded values dictionary...
# 		...adding A: Head-On
# 		...adding B: Sideswipe
# 		...adding C: Rear End
# 		...adding D: Broadside
# 		...adding E: Hit Object
# 		...adding F: Overturned
# 		...adding G: Vehicle/Pedestrian
# 		...adding H: Other
# 		...adding -: Not Stated
# Match 44: Domain PEDESTRIAN_ACCIDENT does not exist. Creating...
# Creating domain for PEDESTRIAN_ACCIDENT...
# Start Time: Wednesday, November 13, 2024 8:38:32 AM
# Succeeded at Wednesday, November 13, 2024 8:38:32 AM (Elapsed Time: 0.25 seconds)
# 	Defining coded values dictionary...
# 		...adding Y: Yes
# Match 45: Domain BICYCLE_ACCIDENT does not exist. Creating...
# Creating domain for BICYCLE_ACCIDENT...
# Start Time: Wednesday, November 13, 2024 8:38:33 AM
# Succeeded at Wednesday, November 13, 2024 8:38:33 AM (Elapsed Time: 0.24 seconds)
# 	Defining coded values dictionary...
# 		...adding Y: Yes
# Match 46: Domain MOTORCYCLE_ACCIDENT does not exist. Creating...
# Creating domain for MOTORCYCLE_ACCIDENT...
# Start Time: Wednesday, November 13, 2024 8:38:33 AM
# Succeeded at Wednesday, November 13, 2024 8:38:34 AM (Elapsed Time: 0.26 seconds)
# 	Defining coded values dictionary...
# 		...adding Y: Yes
# Match 47: Domain TRUCK_ACCIDENT does not exist. Creating...
# Creating domain for TRUCK_ACCIDENT...
# Start Time: Wednesday, November 13, 2024 8:38:34 AM
# Succeeded at Wednesday, November 13, 2024 8:38:34 AM (Elapsed Time: 0.26 seconds)
# 	Defining coded values dictionary...
# 		...adding Y: Yes
# Match 48: Domain HIT_AND_RUN does not exist. Creating...
# Creating domain for HIT_AND_RUN...
# Start Time: Wednesday, November 13, 2024 8:38:35 AM
# Succeeded at Wednesday, November 13, 2024 8:38:35 AM (Elapsed Time: 0.27 seconds)
# 	Defining coded values dictionary...
# 		...adding F: Felony
# 		...adding M: Misdemeanor
# 		...adding N: Not Hit and Run
# Match 49: Domain ALCOHOL_INVOLVED does not exist. Creating...
# Creating domain for ALCOHOL_INVOLVED...
# Start Time: Wednesday, November 13, 2024 8:38:37 AM
# Succeeded at Wednesday, November 13, 2024 8:38:37 AM (Elapsed Time: 0.27 seconds)
# 	Defining coded values dictionary...
# 		...adding Y: Yes
# Match 53: Domain CHP_SHIFT does not exist. Creating...
# Creating domain for CHP_SHIFT...
# Start Time: Wednesday, November 13, 2024 8:38:38 AM
# Succeeded at Wednesday, November 13, 2024 8:38:38 AM (Elapsed Time: 0.25 seconds)
# 	Defining coded values dictionary...
# 		...adding 1: 0600 thru 1359
# 		...adding 2: 1400 thru 2159
# 		...adding 3: 2200 thru 0559
# 		...adding 4: CHP Not Stated
# 		...adding 5: Not CHP
# Match 55: Domain SPECIAL_COND does not exist. Creating...
# Creating domain for SPECIAL_COND...
# Start Time: Wednesday, November 13, 2024 8:38:40 AM
# Succeeded at Wednesday, November 13, 2024 8:38:41 AM (Elapsed Time: 0.27 seconds)
# 	Defining coded values dictionary...
# 		...adding 0: Not Above
# 		...adding 1: Schoolbus on Public Roadway
# 		...adding 2: State University (Also SFIA)
# 		...adding 3: Schoolbus Not on Public Roadway
# 		...adding 4: Offroad (Unimproved)
# 		...adding 5: Vista Point or Rest Area or Sales or Inspection Facility
# 		...adding 6: Other Public Access (Improved)
# Match 56: Domain BEAT_TYPE does not exist. Creating...
# Creating domain for BEAT_TYPE...
# Start Time: Wednesday, November 13, 2024 8:38:44 AM
# Succeeded at Wednesday, November 13, 2024 8:38:44 AM (Elapsed Time: 0.24 seconds)
# 	Defining coded values dictionary...
# 		...adding 0: Not CHP
# 		...adding 1: CHP State Highway
# 		...adding 2: CHP County RoadLine
# 		...adding 3: CHP County RoadArea
# 		...adding 4: Schoolbus on City Roadway
# 		...adding 5: Schoolbus not on Public Roadway
# 		...adding 6: Offroad (Unimproved)
# 		...adding 7: Vista Point or Rest Area or Scales or Inspection Facility
# 		...adding 8: Other Public Access (Improved)
# Match 57: Domain CHP_BEAT_TYPE does not exist. Creating...
# Creating domain for CHP_BEAT_TYPE...
# Start Time: Wednesday, November 13, 2024 8:38:48 AM
# Succeeded at Wednesday, November 13, 2024 8:38:49 AM (Elapsed Time: 0.25 seconds)
# 	Defining coded values dictionary...
# 		...adding 0: NOT CHP
# 		...adding 1: Interstate
# 		...adding 2: US Highway
# 		...adding 3: State Route
# 		...adding 4: County RoadLine
# 		...adding 5: County RoadArea
# 		...adding 6: US Highway
# 		...adding 7: State Route
# 		...adding 8: County RoadLine
# 		...adding 9: County RoadArea
# Match 58: Domain CHP_BEAT_CLASS does not exist. Creating...
# Creating domain for CHP_BEAT_CLASS...
# Start Time: Wednesday, November 13, 2024 8:38:53 AM
# Succeeded at Wednesday, November 13, 2024 8:38:53 AM (Elapsed Time: 0.25 seconds)
# 	Defining coded values dictionary...
# 		...adding 0: Not CHP
# 		...adding 1: CHP Primary
# 		...adding 2: CHP Other
# Match 63: Domain DIRECTION does not exist. Creating...
# Creating domain for DIRECTION...
# Start Time: Wednesday, November 13, 2024 8:38:55 AM
# Succeeded at Wednesday, November 13, 2024 8:38:55 AM (Elapsed Time: 0.27 seconds)
# 	Defining coded values dictionary...
# 		...adding N: North
# 		...adding E: East
# 		...adding S: South
# 		...adding W: West
# 		...adding -: Not Stated
# Match 64: Domain INTERSECTION does not exist. Creating...
# Creating domain for INTERSECTION...
# Start Time: Wednesday, November 13, 2024 8:38:58 AM
# Succeeded at Wednesday, November 13, 2024 8:38:58 AM (Elapsed Time: 0.27 seconds)
# 	Defining coded values dictionary...
# 		...adding Y: Intersection
# 		...adding N: Not Intersection
# 		...adding -: Not Stated
# Match 65: Domain WEATHER_1 does not exist. Creating...
# Creating domain for WEATHER_1...
# Start Time: Wednesday, November 13, 2024 8:39:00 AM
# Succeeded at Wednesday, November 13, 2024 8:39:00 AM (Elapsed Time: 0.27 seconds)
# 	Defining coded values dictionary...
# 		...adding A: Clear
# 		...adding B: Cloudy
# 		...adding C: Raining
# 		...adding D: Snowing
# 		...adding E: Fog
# 		...adding F: Other
# 		...adding G: Wind
# 		...adding -: Not Stated
# Match 66: Domain WEATHER_2 does not exist. Creating...
# Creating domain for WEATHER_2...
# Start Time: Wednesday, November 13, 2024 8:39:04 AM
# Succeeded at Wednesday, November 13, 2024 8:39:04 AM (Elapsed Time: 0.27 seconds)
# 	Defining coded values dictionary...
# 		...adding A: Clear
# 		...adding B: Cloudy
# 		...adding C: Raining
# 		...adding D: Snowing
# 		...adding E: Fog
# 		...adding F: Other
# 		...adding G: Wind
# 		...adding -: Not Stated
# Match 67: Domain WEATHER_COMBINED does not exist. Creating...
# Creating domain for WEATHER_COMBINED...
# Start Time: Wednesday, November 13, 2024 8:39:08 AM
# Succeeded at Wednesday, November 13, 2024 8:39:08 AM (Elapsed Time: 0.28 seconds)
# 	Defining coded values dictionary...
# 		...adding 0: Not Stated
# 		...adding 10: Clear
# 		...adding 12: Clear Cloudy
# 		...adding 13: Clear Other
# 		...adding 14: Clear Wind
# 		...adding 15: Clear Raining
# 		...adding 16: Clear Snowing
# 		...adding 17: Clear Fog
# 		...adding 20: Cloudy
# 		...adding 21: Cloudy Clear
# 		...adding 23: Cloudy Other
# 		...adding 24: Cloudy Wind
# 		...adding 25: Cloudy Raining
# 		...adding 26: Cloudy Snowing
# 		...adding 27: Cloudy Fog
# 		...adding 30: Other
# 		...adding 31: Other Clear
# 		...adding 32: Other Cloudy
# 		...adding 34: Other Wind
# 		...adding 35: Other Raining
# 		...adding 36: Other Snowing
# 		...adding 37: Other Fog
# 		...adding 40: Wind
# 		...adding 41: Wind Clear
# 		...adding 42: Wind Cloudy
# 		...adding 43: Wind Other
# 		...adding 45: Wind Raining
# 		...adding 46: Wind Snowing
# 		...adding 47: Wind Fog
# 		...adding 50: Raining
# 		...adding 51: Raining Clear
# 		...adding 52: Raining Cloudy
# 		...adding 53: Raining Other
# 		...adding 54: Raining Wind
# 		...adding 56: Raining Snowing
# 		...adding 57: Raining Fog
# 		...adding 60: Snowing
# 		...adding 61: Snowing Clear
# 		...adding 62: Snowing Cloudy
# 		...adding 63: Snowing Other
# 		...adding 64: Snowing Wind
# 		...adding 65: Snowing Raining
# 		...adding 67: Snowing Fog
# 		...adding 70: Fog
# 		...adding 71: Fog Clear
# 		...adding 72: Fog Cloudy
# 		...adding 73: Fog Other
# 		...adding 74: Fog Wind
# 		...adding 75: Fog Raining
# 		...adding 76: Fog Snowing
# Match 68: Domain ROAD_SURFACE does not exist. Creating...
# Creating domain for ROAD_SURFACE...
# Start Time: Wednesday, November 13, 2024 8:39:31 AM
# Succeeded at Wednesday, November 13, 2024 8:39:32 AM (Elapsed Time: 0.27 seconds)
# 	Defining coded values dictionary...
# 		...adding A: Dry
# 		...adding B: Wet
# 		...adding C: Snowy or Icy
# 		...adding D: Slippery (Muddy, Oily, etc)
# 		...adding O: Other
# 		...adding -: Not Stated
# Match 69: Domain ROAD_COND_1 does not exist. Creating...
# Creating domain for ROAD_COND_1...
# Start Time: Wednesday, November 13, 2024 8:39:35 AM
# Succeeded at Wednesday, November 13, 2024 8:39:35 AM (Elapsed Time: 0.27 seconds)
# 	Defining coded values dictionary...
# 		...adding A: Holes, Deep Ruts
# 		...adding B: Loose Material on Roadway
# 		...adding C: Obstruction on Roadway
# 		...adding D: Construction or Repair Zone
# 		...adding E: Reduced Roadway Width
# 		...adding F: Flooded
# 		...adding G: Other
# 		...adding H: No Unusual Condition
# 		...adding -: Not Stated
# Match 70: Domain ROAD_COND_2 does not exist. Creating...
# Creating domain for ROAD_COND_2...
# Start Time: Wednesday, November 13, 2024 8:39:39 AM
# Succeeded at Wednesday, November 13, 2024 8:39:39 AM (Elapsed Time: 0.29 seconds)
# 	Defining coded values dictionary...
# 		...adding A: Holes, Deep Ruts
# 		...adding B: Loose Material on Roadway
# 		...adding C: Obstruction on Roadway
# 		...adding D: Construction or Repair Zone
# 		...adding E: Reduced Roadway Width
# 		...adding F: Flooded
# 		...adding G: Other
# 		...adding H: No Unusual Condition
# 		...adding -: Not Stated
# Match 71: Domain LIGHTING does not exist. Creating...
# Creating domain for LIGHTING...
# Start Time: Wednesday, November 13, 2024 8:39:44 AM
# Succeeded at Wednesday, November 13, 2024 8:39:44 AM (Elapsed Time: 0.26 seconds)
# 	Defining coded values dictionary...
# 		...adding A: Daylight
# 		...adding B: Dusk-Dawn
# 		...adding C: Dark-Street Lights
# 		...adding D: Dark-No Street Lights
# 		...adding E: Dark-Street Lights Not Functioning
# 		...adding -: Not Stated
# Match 72: Domain CONTROL_DEVICE does not exist. Creating...
# Creating domain for CONTROL_DEVICE...
# Start Time: Wednesday, November 13, 2024 8:39:47 AM
# Succeeded at Wednesday, November 13, 2024 8:39:47 AM (Elapsed Time: 0.26 seconds)
# 	Defining coded values dictionary...
# 		...adding A: Functioning
# 		...adding B: Not Functioning
# 		...adding C: Obscured
# 		...adding D: None
# 		...adding -: Not Stated
# Match 73: Domain STATE_HWY_IND does not exist. Creating...
# Creating domain for STATE_HWY_IND...
# Start Time: Wednesday, November 13, 2024 8:39:50 AM
# Succeeded at Wednesday, November 13, 2024 8:39:50 AM (Elapsed Time: 0.27 seconds)
# 	Defining coded values dictionary...
# 		...adding Y: State Highway
# 		...adding N: Not State Highway
# Match 74: Domain SIDE_OF_HWY does not exist. Creating...
# Creating domain for SIDE_OF_HWY...
# Start Time: Wednesday, November 13, 2024 8:39:51 AM
# Succeeded at Wednesday, November 13, 2024 8:39:51 AM (Elapsed Time: 0.27 seconds)
# 	Defining coded values dictionary...
# 		...adding N: Northbound
# 		...adding S: Southbound
# 		...adding E: Eastbound
# 		...adding W: Westbound
# Match 75: Domain TOW_AWAY does not exist. Creating...
# Creating domain for TOW_AWAY...
# Start Time: Wednesday, November 13, 2024 8:39:53 AM
# Succeeded at Wednesday, November 13, 2024 8:39:54 AM (Elapsed Time: 0.29 seconds)
# 	Defining coded values dictionary...
# 		...adding Y: Yes
# 		...adding N: No
# Match 76: Domain PCF_CODE_OF_VIOL does not exist. Creating...
# Creating domain for PCF_CODE_OF_VIOL...
# Start Time: Wednesday, November 13, 2024 8:39:55 AM
# Succeeded at Wednesday, November 13, 2024 8:39:55 AM (Elapsed Time: 0.31 seconds)
# 	Defining coded values dictionary...
# 		...adding B: Business and Professions
# 		...adding C: Vehicle
# 		...adding H: City Health and Safety
# 		...adding I: City Ordinance
# 		...adding O: County Ordinance
# 		...adding P: Penal
# 		...adding S: Streets and Highways
# 		...adding W: Welfare and Institutions
# 		...adding -: Not Stated
# Match 77: Domain PCF_VIOL_CATEGORY does not exist. Creating...
# Creating domain for PCF_VIOL_CATEGORY...
# Start Time: Wednesday, November 13, 2024 8:39:59 AM
# Succeeded at Wednesday, November 13, 2024 8:40:00 AM (Elapsed Time: 0.27 seconds)
# 	Defining coded values dictionary...
# 		...adding 0: Unknown
# 		...adding 1: Driving or Bicycling Under the Influence of Alcohol or Drug
# 		...adding 2: Impeding Traffic
# 		...adding 3: Unsafe Speed
# 		...adding 4: Following Too Closely
# 		...adding 5: Wrong Side of Road
# 		...adding 6: Improper Passing
# 		...adding 7: Unsafe Lane Change
# 		...adding 8: Improper Turning
# 		...adding 9: Automobile Right of Way
# 		...adding 10: Pedestrian Right of Way
# 		...adding 11: Pedestrian Violation
# 		...adding 12: Traffic Signals and Signs
# 		...adding 13: Hazardous Parking
# 		...adding 14: Lights
# 		...adding 15: Brakes
# 		...adding 16: Other Equipment
# 		...adding 17: Other Hazardous Violation
# 		...adding 18: Other Than Driver or Pedestrian
# 		...adding 21: Unsafe Starting or Backing
# 		...adding 22: Other Improper Driving
# 		...adding 23: Pedestrian or Other Under the Influence of Alcohol or Drug
# 		...adding 24: Fell Asleep
# 		...adding -: Not Stated
# Match 80: Domain MVIW does not exist. Creating...
# Creating domain for MVIW...
# Start Time: Wednesday, November 13, 2024 8:40:11 AM
# Succeeded at Wednesday, November 13, 2024 8:40:12 AM (Elapsed Time: 0.31 seconds)
# 	Defining coded values dictionary...
# 		...adding 0: Non-Collision and Additional Object
# 		...adding 1: Pedestrian and Additional Object
# 		...adding 2: Other Motor Vehicle and Additional Object
# 		...adding 3: Motor Vehicle on Other Roadway and Additional Object
# 		...adding 4: Parked Motor Vehicle and Additional Object
# 		...adding 5: Train and Additional Object
# 		...adding 6: Bicycle and Additional Object
# 		...adding 7: Animal and Additional Object
# 		...adding 8: Fixed Object and Additional Object
# 		...adding 9: Other Object and Additional Object
# 		...adding A: Non-Collision
# 		...adding B: Pedestrian
# 		...adding C: Other Motor Vehicle
# 		...adding D: Motor Vehicle on Other Roadway
# 		...adding E: Parked Motor Vehicle
# 		...adding F: Train
# 		...adding G: Bicycle
# 		...adding H: Animal
# 		...adding I: Fixed Object
# 		...adding J: Other Object
# 		...adding -: Not Stated
# Match 81: Domain PED_ACTION does not exist. Creating...
# Creating domain for PED_ACTION...
# Start Time: Wednesday, November 13, 2024 8:40:22 AM
# Succeeded at Wednesday, November 13, 2024 8:40:23 AM (Elapsed Time: 0.33 seconds)
# 	Defining coded values dictionary...
# 		...adding A: No Pedestrian Involved
# 		...adding B: Crossing in Crosswalk at Intersection
# 		...adding C: Crossing in Crosswalk Not at Intersection
# 		...adding D: Crossing Not in Crosswalk
# 		...adding E: In Road, Including Shoulder
# 		...adding F: Not in Road
# 		...adding G: Approaching or Leaving School Bus
# 		...adding -: Not Stated
# Match 82: Domain NOT_PRIVATE_PROPERTY does not exist. Creating...
# Creating domain for NOT_PRIVATE_PROPERTY...
# Start Time: Wednesday, November 13, 2024 8:40:27 AM
# Succeeded at Wednesday, November 13, 2024 8:40:27 AM (Elapsed Time: 0.28 seconds)
# 	Defining coded values dictionary...
# 		...adding Y: Yes
# Match 83: Domain STWD_VEHTYPE_AT_FAULT does not exist. Creating...
# Creating domain for STWD_VEHTYPE_AT_FAULT...
# Start Time: Wednesday, November 13, 2024 8:40:28 AM
# Succeeded at Wednesday, November 13, 2024 8:40:28 AM (Elapsed Time: 0.36 seconds)
# 	Defining coded values dictionary...
# 		...adding A: Passenger car/station wagon
# 		...adding B: Passenger car with trailer
# 		...adding C: Motorcycle/scooter
# 		...adding D: Pickup or panel truck
# 		...adding E: Pickup or panel truck with trailer
# 		...adding F: Truck or truck tractor
# 		...adding G: Truck or truck tractor with trailer
# 		...adding H: Schoolbus
# 		...adding I: Other bus
# 		...adding J: Emergency vehicle
# 		...adding K: Highway construction equipment
# 		...adding L: Bicycle
# 		...adding M: Other vehicle
# 		...adding N: Pedestrian
# 		...adding O: Moped
# 		...adding -: Not Stated
# Match 84: Domain CHP_VEHTYPE_AT_FAULT does not exist. Creating...
# Creating domain for CHP_VEHTYPE_AT_FAULT...
# Start Time: Wednesday, November 13, 2024 8:40:37 AM
# Succeeded at Wednesday, November 13, 2024 8:40:37 AM (Elapsed Time: 0.28 seconds)
# 	Defining coded values dictionary...
# 		...adding 1: Passenger, car, station Wagon, or Jeep
# 		...adding 2: Motorcycle
# 		...adding 3: Motor-driven cycle (<15 hp)
# 		...adding 4: Bicycle
# 		...adding 5: Motorized vehicle
# 		...adding 6: All-terrain vehicle (ATV)
# 		...adding 7: Sport utility vehicle
# 		...adding 8: Minivan
# 		...adding 9: Paratransit bus
# 		...adding 10: Tour bus
# 		...adding 11: Other commercial bus
# 		...adding 12: Non-commercial bus
# 		...adding 13: Schoolbus public I
# 		...adding 14: Schoolbus public II
# 		...adding 15: Schoolbus private I
# 		...adding 16: Schoolbus private II
# 		...adding 17: Schoolbus contractual I
# 		...adding 18: Schoolbus contractual II
# 		...adding 19: General public paratransit vehicle
# 		...adding 20: Public transit authority
# 		...adding 21: Two-axle tank truck
# 		...adding 22: Pickup or panel truck
# 		...adding 23: Pickup truck with camper
# 		...adding 24: Three-axle tank truck
# 		...adding 25: Truck tractor
# 		...adding 26: Two-axle truck
# 		...adding 27: Three-axle truck
# 		...adding 28: Semi-tank trailer
# 		...adding 29: Pull-tank trailer
# 		...adding 30: Two-tank trailer
# 		...adding 31: Semi-trailer
# 		...adding 32: Pull trailer (includes dolly)
# 		...adding 33: Two trailers (includes semi and trailer)
# 		...adding 34: Boat trailer
# 		...adding 35: Utility trailer
# 		...adding 36: Trailer coach
# 		...adding 37: Oversize vehicle/load
# 		...adding 38: Pole, pipe, or logging dolly
# 		...adding 39: Three trailers (includes semi and two trailers)
# 		...adding 40: Semi 48 or less with king pin to trailer axle of over 38
# 		...adding 41: Ambulance
# 		...adding 42: Dune buggy
# 		...adding 43: Fire truck (not rescue)
# 		...adding 44: Forklift
# 		...adding 45: Highway construction equipment (only while not in construction area)
# 		...adding 46: Implement of husbandry
# 		...adding 47: Motor home (40 ft or less)
# 		...adding 48: CHP, police, or sheriff car (emergency service or not)
# 		...adding 49: CHP, police, or sheriff motorcycle (emergency service or not)
# 		...adding 50: Mobile equipment
# 		...adding 51: Farm labor vehicle (certified)
# 		...adding 52: Federally legal double cargo combo over 75ft
# 		...adding 53: 5th wheel trailer
# 		...adding 54: Container chassis
# 		...adding 55: Two-axle tow truck
# 		...adding 56: Three-axle tow truck
# 		...adding 57: Farm labor vehicle (non-certified)
# 		...adding 58: Farm labor transporter
# 		...adding 59: Motorhome (over 40ft)
# 		...adding 60: Pedestrian (includes motorized wheelchair)
# 		...adding 61: School pupil activity bus I (prior to 2002)
# 		...adding 62: School pupil activity bus II (prior to 2002)
# 		...adding 63: Youth bus
# 		...adding 64: School pupil activity bus I (eff 2002)
# 		...adding 65: School pupil activity bus II (eff 2002)
# 		...adding 66: School bus Without pupil passengers (eff 2002)
# 		...adding 71: Passenger car - hazardous materials only
# 		...adding 72: Pickups and panels - hazardous materials only
# 		...adding 73: Pickups and campers - hazardous materials only
# 		...adding 75: Truck tractor - hazardous materials only
# 		...adding 76: Two-axle truck - hazardous materials only
# 		...adding 77: Three or more axle truck - hazardous materials only
# 		...adding 78: Two-axle tank truck - hazardous materials only
# 		...adding 79: Three axle tank truck - hazardous materials only
# 		...adding 81: Passenger car - hazardous waste or waste-material combo
# 		...adding 82: Pickups and panels - hazardous waste or waste-material combo
# 		...adding 83: Pickups and campers - hazardous waste or waste-material combo
# 		...adding 85: Truck tractor - hazardous waste or waste-material combo
# 		...adding 86: Two-axle truck - hazardous waste or waste-material combo
# 		...adding 87: Three or more axle truck - hazardous waste or waste-material combo
# 		...adding 88: Two-axle tank truck - hazardous waste or waste-material combo
# 		...adding 89: Three-axle tank truck - hazardous waste or waste-material combo
# 		...adding 91: Electric bicycle (class 1,2,3)
# 		...adding 93: Electrically motorized board
# 		...adding 94: Motorized transportation device
# 		...adding 95: Miscellaneous non-motorized vehicle (ridden animal, animal-drawn conveyance, train or building) with victim
# 		...adding 96: Miscellaneous motorized vehicle (golf cart)
# 		...adding 97: Low speed vehicle
# 		...adding 98: Emergency vehicle on an emergency run
# 		...adding 99: Not stated or unknown (hit and run)
# 		...adding -: Not Stated
# Match 85: Domain PRIMARY_RAMP does not exist. Creating...
# Creating domain for PRIMARY_RAMP...
# Start Time: Wednesday, November 13, 2024 8:41:22 AM
# Succeeded at Wednesday, November 13, 2024 8:41:23 AM (Elapsed Time: 0.33 seconds)
# 	Defining coded values dictionary...
# 		...adding TO: To
# 		...adding FR: From
# 		...adding NF: North Off Ramp
# 		...adding SF: South Off Ramp
# 		...adding EF: East Off Ramp
# 		...adding WF: West Off Ramp
# 		...adding NO: North On Ramp
# 		...adding SO: South On Ramp
# 		...adding EO: East On Ramp
# 		...adding WO: West On Ramp
# 		...adding TR: Transition
# 		...adding CO: Collector
# 		...adding CN: Connector
# 		...adding -: Not Stated
# Match 86: Domain SECONDARY_RAMP does not exist. Creating...
# Creating domain for SECONDARY_RAMP...
# Start Time: Wednesday, November 13, 2024 8:41:30 AM
# Succeeded at Wednesday, November 13, 2024 8:41:31 AM (Elapsed Time: 0.30 seconds)
# 	Defining coded values dictionary...
# 		...adding TO: To
# 		...adding FR: From
# 		...adding NF: North Off Ramp
# 		...adding SF: South Off Ramp
# 		...adding EF: East Off Ramp
# 		...adding WF: West Off Ramp
# 		...adding NO: North On Ramp
# 		...adding SO: South On Ramp
# 		...adding EO: East On Ramp
# 		...adding WO: West On Ramp
# 		...adding TR: Transition
# 		...adding CO: Collector
# 		...adding CN: Connector
# 		...adding -: Not Stated
# Match 87: Domain PARTY_TYPE does not exist. Creating...
# Creating domain for PARTY_TYPE...
# Start Time: Wednesday, November 13, 2024 8:41:38 AM
# Succeeded at Wednesday, November 13, 2024 8:41:38 AM (Elapsed Time: 0.32 seconds)
# 	Defining coded values dictionary...
# 		...adding 1: Driver (including hit and run)
# 		...adding 2: Pedestrian
# 		...adding 3: Parked vehicle
# 		...adding 4: Bicyclist
# 		...adding 5: Other
# 		...adding 6: Operator
# 		...adding -: Not Stated
# Match 88: Domain AT_FAULT does not exist. Creating...
# Creating domain for AT_FAULT...
# Start Time: Wednesday, November 13, 2024 8:41:42 AM
# Succeeded at Wednesday, November 13, 2024 8:41:42 AM (Elapsed Time: 0.29 seconds)
# 	Defining coded values dictionary...
# 		...adding Y: Yes
# 		...adding N: No
# 		...adding -: Not Stated
# Match 89: Domain PARTY_SEX does not exist. Creating...
# Creating domain for PARTY_SEX...
# Start Time: Wednesday, November 13, 2024 8:41:44 AM
# Succeeded at Wednesday, November 13, 2024 8:41:44 AM (Elapsed Time: 0.29 seconds)
# 	Defining coded values dictionary...
# 		...adding M: Male
# 		...adding F: Female
# 		...adding X: Nonbinary
# 		...adding -: Not Stated
# Match 90: Domain PARTY_AGE does not exist. Creating...
# Creating domain for PARTY_AGE...
# Start Time: Wednesday, November 13, 2024 8:41:46 AM
# Succeeded at Wednesday, November 13, 2024 8:41:46 AM (Elapsed Time: 0.31 seconds)
# 	Defining coded values dictionary...
# 		...adding 998: Unknown
# Match 91: Domain RACE does not exist. Creating...
# Creating domain for RACE...
# Start Time: Wednesday, November 13, 2024 8:41:47 AM
# Succeeded at Wednesday, November 13, 2024 8:41:47 AM (Elapsed Time: 0.28 seconds)
# 	Defining coded values dictionary...
# 		...adding A: Asian
# 		...adding B: Black
# 		...adding H: Hispanic
# 		...adding W: White
# 		...adding O: Other
# Match 94: Domain INATTENTION does not exist. Creating...
# Creating domain for INATTENTION...
# Start Time: Wednesday, November 13, 2024 8:41:50 AM
# Succeeded at Wednesday, November 13, 2024 8:41:50 AM (Elapsed Time: 0.28 seconds)
# 	Defining coded values dictionary...
# 		...adding A: Cell phone handheld
# 		...adding B: Cell phone handsfree
# 		...adding C: Electronic equipment
# 		...adding D: Radio/CD
# 		...adding E: Smoking
# 		...adding F: Eating
# 		...adding G: Children
# 		...adding H: Animal
# 		...adding I: Personal hygiene
# 		...adding J: Reading
# 		...adding K: Other
# 		...adding P: Cell Phone
# 		...adding -: Not Stated
# Match 95: Domain PARTY_SOBRIETY does not exist. Creating...
# Creating domain for PARTY_SOBRIETY...
# Start Time: Wednesday, November 13, 2024 8:41:57 AM
# Succeeded at Wednesday, November 13, 2024 8:41:57 AM (Elapsed Time: 0.31 seconds)
# 	Defining coded values dictionary...
# 		...adding A: Had not been drinking
# 		...adding B: Had been drinking under influence
# 		...adding C: Had been drinking, not under influence
# 		...adding D: Had been drinking, impairment unknown
# 		...adding G: Impairment unknown
# 		...adding H: Not applicable
# 		...adding -: Not Stated
# Match 96: Domain PARTY_DRUG_PHYSICAL does not exist. Creating...
# Creating domain for PARTY_DRUG_PHYSICAL...
# Start Time: Wednesday, November 13, 2024 8:42:01 AM
# Succeeded at Wednesday, November 13, 2024 8:42:02 AM (Elapsed Time: 0.34 seconds)
# 	Defining coded values dictionary...
# 		...adding E: Under drug influence
# 		...adding F: Impairment - physical
# 		...adding G: Impairment unknown
# 		...adding H: Not applicable
# 		...adding I: Sleepy or fatigued
# 		...adding -: Not Stated
# Match 97: Domain DIR_OF_TRAVEL does not exist. Creating...
# Creating domain for DIR_OF_TRAVEL...
# Start Time: Wednesday, November 13, 2024 8:42:05 AM
# Succeeded at Wednesday, November 13, 2024 8:42:05 AM (Elapsed Time: 0.34 seconds)
# 	Defining coded values dictionary...
# 		...adding N: North
# 		...adding S: South
# 		...adding E: East
# 		...adding W: West
# 		...adding -: Not Stated
# Match 98: Domain PARTY_SAFETY_EQUIP_1 does not exist. Creating...
# Creating domain for PARTY_SAFETY_EQUIP_1...
# Start Time: Wednesday, November 13, 2024 8:42:08 AM
# Succeeded at Wednesday, November 13, 2024 8:42:08 AM (Elapsed Time: 0.31 seconds)
# 	Defining coded values dictionary...
# 		...adding A: None in vehicle
# 		...adding B: Unknown
# 		...adding C: Lap belt used
# 		...adding D: Lab belt not used
# 		...adding E: Shoulder harness used
# 		...adding F: Shoulder harness not used
# 		...adding G: Lap/shoulder harness used
# 		...adding H: Lap/shoulder harness not used
# 		...adding J: Passive restraint used
# 		...adding K: Passive restraint not used
# 		...adding L: Air bag deployed
# 		...adding M: Air bag not deployed
# 		...adding N: Other
# 		...adding P: Not required
# 		...adding Q: Child restraint in vehicle used
# 		...adding R: Child restraint in vehicle not used
# 		...adding S: Child restraint in vehicle, use unknown
# 		...adding T: Child restraint in vehicle, improper use
# 		...adding U: No child restraint in vehicle
# 		...adding V: Driver, motorcycle helmet not used
# 		...adding W: Driver, motorcycle helmet used
# 		...adding X: Passenger, motorcycle helmet not used
# 		...adding Y: Passenger, motorcycle helmet used
# 		...adding -: Not Stated
# Match 99: Domain PARTY_SAFETY_EQUIP_2 does not exist. Creating...
# Creating domain for PARTY_SAFETY_EQUIP_2...
# Start Time: Wednesday, November 13, 2024 8:42:20 AM
# Succeeded at Wednesday, November 13, 2024 8:42:21 AM (Elapsed Time: 0.31 seconds)
# 	Defining coded values dictionary...
# 		...adding A: None in vehicle
# 		...adding B: Unknown
# 		...adding C: Lap belt used
# 		...adding D: Lab belt not used
# 		...adding E: Shoulder harness used
# 		...adding F: Shoulder harness not used
# 		...adding G: Lap/shoulder harness used
# 		...adding H: Lap/shoulder harness not used
# 		...adding J: Passive restraint used
# 		...adding K: Passive restraint not used
# 		...adding L: Air bag deployed
# 		...adding M: Air bag not deployed
# 		...adding N: Other
# 		...adding P: Not required
# 		...adding Q: Child restraint in vehicle used
# 		...adding R: Child restraint in vehicle not used
# 		...adding S: Child restraint in vehicle, use unknown
# 		...adding T: Child restraint in vehicle, improper use
# 		...adding U: No child restraint in vehicle
# 		...adding V: Driver, motorcycle helmet not used
# 		...adding W: Driver, motorcycle helmet used
# 		...adding X: Passenger, motorcycle helmet not used
# 		...adding Y: Passenger, motorcycle helmet used
# 		...adding -: Not Stated
# Match 100: Domain FINAN_RESPONS does not exist. Creating...
# Creating domain for FINAN_RESPONS...
# Start Time: Wednesday, November 13, 2024 8:42:33 AM
# Succeeded at Wednesday, November 13, 2024 8:42:33 AM (Elapsed Time: 0.27 seconds)
# 	Defining coded values dictionary...
# 		...adding N: No proof of insurance obtained
# 		...adding Y: Yes, proof of insurance obtained
# 		...adding O: Not applicable (used for parked cars, bicyclists, pedestrians, and party type others)
# 		...adding E: Used if the officer is called away from the scene of the crash prior to obtaining the insurance information
# Match 101: Domain SP_INFO_1 does not exist. Creating...
# Creating domain for SP_INFO_1...
# Start Time: Wednesday, November 13, 2024 8:42:35 AM
# Succeeded at Wednesday, November 13, 2024 8:42:35 AM (Elapsed Time: 0.30 seconds)
# 	Defining coded values dictionary...
# 		...adding A: Hazardous materials
# 		...adding -: Not Stated
# Match 102: Domain SP_INFO_2 does not exist. Creating...
# Creating domain for SP_INFO_2...
# Start Time: Wednesday, November 13, 2024 8:42:36 AM
# Succeeded at Wednesday, November 13, 2024 8:42:37 AM (Elapsed Time: 0.27 seconds)
# 	Defining coded values dictionary...
# 		...adding 1: Cell phone handheld in use
# 		...adding 2: Cell phone handsfree in use
# 		...adding 3: Cell phone not in use
# 		...adding 4: Cell phone use unknown
# 		...adding B: Cell phone in use
# 		...adding C: Cell phone not in use
# 		...adding D: No cell phone/unknown
# 		...adding -: Not Stated
# Match 103: Domain SP_INFO_3 does not exist. Creating...
# Creating domain for SP_INFO_3...
# Start Time: Wednesday, November 13, 2024 8:42:41 AM
# Succeeded at Wednesday, November 13, 2024 8:42:41 AM (Elapsed Time: 0.31 seconds)
# 	Defining coded values dictionary...
# 		...adding E: School bus related
# 		...adding -: Not Stated
# Match 104: Domain OAF_VIOLATION_CODE does not exist. Creating...
# Creating domain for OAF_VIOLATION_CODE...
# Start Time: Wednesday, November 13, 2024 8:42:42 AM
# Succeeded at Wednesday, November 13, 2024 8:42:43 AM (Elapsed Time: 0.33 seconds)
# 	Defining coded values dictionary...
# 		...adding B: Business and professions
# 		...adding C: Vehicle
# 		...adding H: City Health and Safety
# 		...adding I: City Ordinance
# 		...adding P: Penal
# 		...adding S: Streets and Highways
# 		...adding W: Welfare and institutions
# 		...adding -: Not Stated
# Match 105: Domain OAF_VIOL_CAT does not exist. Creating...
# Creating domain for OAF_VIOL_CAT...
# Start Time: Wednesday, November 13, 2024 8:42:47 AM
# Succeeded at Wednesday, November 13, 2024 8:42:47 AM (Elapsed Time: 0.33 seconds)
# 	Defining coded values dictionary...
# 		...adding 0: Not Stated
# 		...adding 1: Under influence in public
# 		...adding 2: County ordinance
# 		...adding 3: City ordinance
# 		...adding 5: Business/professions code
# 		...adding 6: Felony penal code
# 		...adding 8: Controlled substances (felony health and safety)
# 		...adding 9: Health/safety code (misdemeanor)
# 		...adding 10: Penal code (misdemeanor)
# 		...adding 11: Streets/highways code
# 		...adding 13: Welfare/institutions code
# 		...adding 15: Manslaughter
# 		...adding 16: Non-vehicle code not specified above
# 		...adding 17: Fish and game code
# 		...adding 18: Agriculture code
# 		...adding 19: Hit and run
# 		...adding 20: Driving or bicycling under the influence of alcohol or drug
# 		...adding 21: Improper lane change
# 		...adding 22: Impeding traffic
# 		...adding 23: Failure to heed stop signal
# 		...adding 24: Failure to heed stop sign
# 		...adding 25: Unsafe speed
# 		...adding 26: Reckless driving
# 		...adding 27: Wrong side of road
# 		...adding 28: Unsafe lane change
# 		...adding 29: Improper passing
# 		...adding 30: Following too closely
# 		...adding 31: Improper turning
# 		...adding 33: Automobile right-of-way
# 		...adding 34: Pedestrian right-of-way
# 		...adding 35: Pedestrian violation
# 		...adding 38: Hazardous parking
# 		...adding 39: Lights
# 		...adding 40: Brakes
# 		...adding 43: Other equipment
# 		...adding 44: Other hazardous movement
# 		...adding 46: Improper registration
# 		...adding 47: Other non-moving violation
# 		...adding 48: Excessive smoke
# 		...adding 49: Excessive noise
# 		...adding 50: Overweight
# 		...adding 51: Oversize
# 		...adding 52: Over maximum speed
# 		...adding 53: Unsafe starting or backing
# 		...adding 60: Off-highway vehicle violation
# 		...adding 61: Child restraint
# 		...adding 62: Seat belt
# 		...adding 63: Seat belt (equipment)
# 		...adding -: Not Stated
# Match 108: Domain OAF_1 does not exist. Creating...
# Creating domain for OAF_1...
# Start Time: Wednesday, November 13, 2024 8:43:12 AM
# Succeeded at Wednesday, November 13, 2024 8:43:12 AM (Elapsed Time: 0.35 seconds)
# 	Defining coded values dictionary...
# 		...adding A: Violation
# 		...adding E: Vision obscurements
# 		...adding F: Inattention
# 		...adding G: Stop and go traffic
# 		...adding H: Entering/leaving ramp
# 		...adding I: Previous collision
# 		...adding J: Unfamiliar with road
# 		...adding K: Defective vehicle equipment
# 		...adding L: Uninvolved vehicle
# 		...adding M: Other
# 		...adding N: None apparent
# 		...adding O: Runaway vehicle
# 		...adding P: Inattention, cell phone
# 		...adding Q: Inattention, electronic equip
# 		...adding R: Inattention, radio/CD
# 		...adding S: Inattention, smoking
# 		...adding T: Inattention, eating
# 		...adding U: Inattention, children
# 		...adding V: Inattention, animal
# 		...adding W: Inattention, personal hygiene
# 		...adding X: Inattention, reading
# 		...adding Y: Inattention, other
# 		...adding -: Not Stated
# Match 109: Domain OAF_2 does not exist. Creating...
# Creating domain for OAF_2...
# Start Time: Wednesday, November 13, 2024 8:43:25 AM
# Succeeded at Wednesday, November 13, 2024 8:43:25 AM (Elapsed Time: 0.33 seconds)
# 	Defining coded values dictionary...
# 		...adding A: Violation
# 		...adding E: Vision obscurements
# 		...adding F: Inattention
# 		...adding G: Stop and go traffic
# 		...adding H: Entering/leaving ramp
# 		...adding I: Previous collision
# 		...adding J: Unfamiliar with road
# 		...adding K: Defective vehicle equipment
# 		...adding L: Uninvolved vehicle
# 		...adding M: Other
# 		...adding N: None apparent
# 		...adding O: Runaway vehicle
# 		...adding P: Inattention, cell phone
# 		...adding Q: Inattention, electronic equip
# 		...adding R: Inattention, radio/CD
# 		...adding S: Inattention, smoking
# 		...adding T: Inattention, eating
# 		...adding U: Inattention, children
# 		...adding V: Inattention, animal
# 		...adding W: Inattention, personal hygiene
# 		...adding X: Inattention, reading
# 		...adding Y: Inattention, other
# 		...adding -: Not Stated
# Match 110: Domain MOVE_PRE_ACC does not exist. Creating...
# Creating domain for MOVE_PRE_ACC...
# Start Time: Wednesday, November 13, 2024 8:43:37 AM
# Succeeded at Wednesday, November 13, 2024 8:43:38 AM (Elapsed Time: 0.32 seconds)
# 	Defining coded values dictionary...
# 		...adding A: Stopped
# 		...adding B: Proceeding straight
# 		...adding C: Ran off road
# 		...adding D: Making right turn
# 		...adding E: Making left turn
# 		...adding F: Making U-turn
# 		...adding G: Backing
# 		...adding H: Slowing/stopping
# 		...adding I: Passing other vehicle
# 		...adding J: Changing lanes
# 		...adding K: Parking maneuver
# 		...adding L: Entering traffic
# 		...adding M: Other unsafe turning
# 		...adding N: Crossed into opposing lane
# 		...adding O: Parked
# 		...adding P: Merging
# 		...adding Q: Traveling wrong way
# 		...adding R: Other
# 		...adding S: Lane splitting
# 		...adding -: Not Stated
# Match 111: Domain VEHICLE_YEAR does not exist. Creating...
# Creating domain for VEHICLE_YEAR...
# Start Time: Wednesday, November 13, 2024 8:43:48 AM
# Succeeded at Wednesday, November 13, 2024 8:43:48 AM (Elapsed Time: 0.34 seconds)
# 	Defining coded values dictionary...
# 		...adding 9999: Not Stated
# Match 112: Domain VEHICLE_MAKE does not exist. Creating...
# Creating domain for VEHICLE_MAKE...
# Start Time: Wednesday, November 13, 2024 8:43:49 AM
# Succeeded at Wednesday, November 13, 2024 8:43:49 AM (Elapsed Time: 0.28 seconds)
# 	Defining coded values dictionary...
# 		...adding -: Not Stated
# Match 113: Domain STWD_VEHICLE_TYPE does not exist. Creating...
# Creating domain for STWD_VEHICLE_TYPE...
# Start Time: Wednesday, November 13, 2024 8:43:50 AM
# Succeeded at Wednesday, November 13, 2024 8:43:50 AM (Elapsed Time: 0.29 seconds)
# 	Defining coded values dictionary...
# 		...adding A: Passenger car/station wagon
# 		...adding B: Passenger car with trailer
# 		...adding C: Motorcycle/scooter
# 		...adding D: Pickup or panel truck
# 		...adding E: Pickup or panel truck with trailer
# 		...adding F: Truck or truck tractor
# 		...adding G: Truck or truck tractor with trailer
# 		...adding H: Schoolbus
# 		...adding I: Other bus
# 		...adding J: Emergency vehicle
# 		...adding K: Highway construction equipment
# 		...adding L: Bicycle
# 		...adding M: Other vehicle
# 		...adding N: Pedestrian
# 		...adding O: Moped
# 		...adding -: Not Stated
# Match 114: Domain CHP_VEH_TYPE_TOWING does not exist. Creating...
# Creating domain for CHP_VEH_TYPE_TOWING...
# Start Time: Wednesday, November 13, 2024 8:43:59 AM
# Succeeded at Wednesday, November 13, 2024 8:43:59 AM (Elapsed Time: 0.31 seconds)
# 	Defining coded values dictionary...
# 		...adding 1: Passenger, car, station Wagon, or Jeep
# 		...adding 2: Motorcycle
# 		...adding 3: Motor-driven cycle (<15 hp)
# 		...adding 4: Bicycle
# 		...adding 5: Motorized vehicle
# 		...adding 6: All-terrain vehicle (ATV)
# 		...adding 7: Sport utility vehicle
# 		...adding 8: Minivan
# 		...adding 9: Paratransit bus
# 		...adding 10: Tour bus
# 		...adding 11: Other commercial bus
# 		...adding 12: Non-commercial bus
# 		...adding 13: Schoolbus public I
# 		...adding 14: Schoolbus public II
# 		...adding 15: Schoolbus private I
# 		...adding 16: Schoolbus private II
# 		...adding 17: Schoolbus contractual I
# 		...adding 18: Schoolbus contractual II
# 		...adding 19: General public paratransit vehicle
# 		...adding 20: Public transit authority
# 		...adding 21: Two-axle tank truck
# 		...adding 22: Pickup or panel truck
# 		...adding 23: Pickup truck with camper
# 		...adding 24: Three-axle tank truck
# 		...adding 25: Truck tractor
# 		...adding 26: Two-axle truck
# 		...adding 27: Three-axle truck
# 		...adding 28: Semi-tank trailer
# 		...adding 29: Pull-tank trailer
# 		...adding 30: Two-tank trailer
# 		...adding 31: Semi-trailer
# 		...adding 32: Pull trailer (includes dolly)
# 		...adding 33: Two trailers (includes semi and trailer)
# 		...adding 34: Boat trailer
# 		...adding 35: Utility trailer
# 		...adding 36: Trailer coach
# 		...adding 37: Oversize vehicle/load
# 		...adding 38: Pole, pipe, or logging dolly
# 		...adding 39: Three trailers (includes semi and two trailers)
# 		...adding 40: Semi 48 or less with king pin to trailer axle of over 38
# 		...adding 41: Ambulance
# 		...adding 42: Dune buggy
# 		...adding 43: Fire truck (not rescue)
# 		...adding 44: Forklift
# 		...adding 45: Highway construction equipment (only while not in construction area)
# 		...adding 46: Implement of husbandry
# 		...adding 47: Motor home (40 ft or less)
# 		...adding 48: CHP, police, or sheriff car (emergency service or not)
# 		...adding 49: CHP, police, or sheriff motorcycle (emergency service or not)
# 		...adding 50: Mobile equipment
# 		...adding 51: Farm labor vehicle (certified)
# 		...adding 52: Federally legal double cargo combo over 75ft
# 		...adding 53: 5th wheel trailer
# 		...adding 54: Container chassis
# 		...adding 55: Two-axle tow truck
# 		...adding 56: Three-axle tow truck
# 		...adding 57: Farm labor vehicle (non-certified)
# 		...adding 58: Farm labor transporter
# 		...adding 59: Motorhome (over 40ft)
# 		...adding 60: Pedestrian (includes motorized wheelchair)
# 		...adding 61: School pupil activity bus I (prior to 2002)
# 		...adding 62: School pupil activity bus II (prior to 2002)
# 		...adding 63: Youth bus
# 		...adding 64: School pupil activity bus I (eff 2002)
# 		...adding 65: School pupil activity bus II (eff 2002)
# 		...adding 66: School bus Without pupil passengers (eff 2002)
# 		...adding 71: Passenger car - hazardous materials only
# 		...adding 72: Pickups and panels - hazardous materials only
# 		...adding 73: Pickups and campers - hazardous materials only
# 		...adding 75: Truck tractor - hazardous materials only
# 		...adding 76: Two-axle truck - hazardous materials only
# 		...adding 77: Three or more axle truck - hazardous materials only
# 		...adding 78: Two-axle tank truck - hazardous materials only
# 		...adding 79: Three axle tank truck - hazardous materials only
# 		...adding 81: Passenger car - hazardous waste or waste-material combo
# 		...adding 82: Pickups and panels - hazardous waste or waste-material combo
# 		...adding 83: Pickups and campers - hazardous waste or waste-material combo
# 		...adding 85: Truck tractor - hazardous waste or waste-material combo
# 		...adding 86: Two-axle truck - hazardous waste or waste-material combo
# 		...adding 87: Three or more axle truck - hazardous waste or waste-material combo
# 		...adding 88: Two-axle tank truck - hazardous waste or waste-material combo
# 		...adding 89: Three-axle tank truck - hazardous waste or waste-material combo
# 		...adding 91: Electric bicycle (class 1,2,3)
# 		...adding 93: Electrically motorized board
# 		...adding 94: Motorized transportation device
# 		...adding 95: Miscellaneous non-motorized vehicle (ridden animal, animal-drawn conveyance, train or building) with victim
# 		...adding 96: Miscellaneous motorized vehicle (golf cart)
# 		...adding 97: Low speed vehicle
# 		...adding 98: Emergency vehicle on an emergency run
# 		...adding 99: Not stated or unknown (hit and run)
# 		...adding -: Not Stated
# Match 115: Domain CHP_VEH_TYPE_TOWED does not exist. Creating...
# Creating domain for CHP_VEH_TYPE_TOWED...
# Start Time: Wednesday, November 13, 2024 8:44:46 AM
# Succeeded at Wednesday, November 13, 2024 8:44:47 AM (Elapsed Time: 0.32 seconds)
# 	Defining coded values dictionary...
# 		...adding 1: Passenger, car, station Wagon, or Jeep
# 		...adding 2: Motorcycle
# 		...adding 3: Motor-driven cycle (<15 hp)
# 		...adding 4: Bicycle
# 		...adding 5: Motorized vehicle
# 		...adding 6: All-terrain vehicle (ATV)
# 		...adding 7: Sport utility vehicle
# 		...adding 8: Minivan
# 		...adding 9: Paratransit bus
# 		...adding 10: Tour bus
# 		...adding 11: Other commercial bus
# 		...adding 12: Non-commercial bus
# 		...adding 13: Schoolbus public I
# 		...adding 14: Schoolbus public II
# 		...adding 15: Schoolbus private I
# 		...adding 16: Schoolbus private II
# 		...adding 17: Schoolbus contractual I
# 		...adding 18: Schoolbus contractual II
# 		...adding 19: General public paratransit vehicle
# 		...adding 20: Public transit authority
# 		...adding 21: Two-axle tank truck
# 		...adding 22: Pickup or panel truck
# 		...adding 23: Pickup truck with camper
# 		...adding 24: Three-axle tank truck
# 		...adding 25: Truck tractor
# 		...adding 26: Two-axle truck
# 		...adding 27: Three-axle truck
# 		...adding 28: Semi-tank trailer
# 		...adding 29: Pull-tank trailer
# 		...adding 30: Two-tank trailer
# 		...adding 31: Semi-trailer
# 		...adding 32: Pull trailer (includes dolly)
# 		...adding 33: Two trailers (includes semi and trailer)
# 		...adding 34: Boat trailer
# 		...adding 35: Utility trailer
# 		...adding 36: Trailer coach
# 		...adding 37: Oversize vehicle/load
# 		...adding 38: Pole, pipe, or logging dolly
# 		...adding 39: Three trailers (includes semi and two trailers)
# 		...adding 40: Semi 48 or less with king pin to trailer axle of over 38
# 		...adding 41: Ambulance
# 		...adding 42: Dune buggy
# 		...adding 43: Fire truck (not rescue)
# 		...adding 44: Forklift
# 		...adding 45: Highway construction equipment (only while not in construction area)
# 		...adding 46: Implement of husbandry
# 		...adding 47: Motor home (40 ft or less)
# 		...adding 48: CHP, police, or sheriff car (emergency service or not)
# 		...adding 49: CHP, police, or sheriff motorcycle (emergency service or not)
# 		...adding 50: Mobile equipment
# 		...adding 51: Farm labor vehicle (certified)
# 		...adding 52: Federally legal double cargo combo over 75ft
# 		...adding 53: 5th wheel trailer
# 		...adding 54: Container chassis
# 		...adding 55: Two-axle tow truck
# 		...adding 56: Three-axle tow truck
# 		...adding 57: Farm labor vehicle (non-certified)
# 		...adding 58: Farm labor transporter
# 		...adding 59: Motorhome (over 40ft)
# 		...adding 60: Pedestrian (includes motorized wheelchair)
# 		...adding 61: School pupil activity bus I (prior to 2002)
# 		...adding 62: School pupil activity bus II (prior to 2002)
# 		...adding 63: Youth bus
# 		...adding 64: School pupil activity bus I (eff 2002)
# 		...adding 65: School pupil activity bus II (eff 2002)
# 		...adding 66: School bus Without pupil passengers (eff 2002)
# 		...adding 71: Passenger car - hazardous materials only
# 		...adding 72: Pickups and panels - hazardous materials only
# 		...adding 73: Pickups and campers - hazardous materials only
# 		...adding 75: Truck tractor - hazardous materials only
# 		...adding 76: Two-axle truck - hazardous materials only
# 		...adding 77: Three or more axle truck - hazardous materials only
# 		...adding 78: Two-axle tank truck - hazardous materials only
# 		...adding 79: Three axle tank truck - hazardous materials only
# 		...adding 81: Passenger car - hazardous waste or waste-material combo
# 		...adding 82: Pickups and panels - hazardous waste or waste-material combo
# 		...adding 83: Pickups and campers - hazardous waste or waste-material combo
# 		...adding 85: Truck tractor - hazardous waste or waste-material combo
# 		...adding 86: Two-axle truck - hazardous waste or waste-material combo
# 		...adding 87: Three or more axle truck - hazardous waste or waste-material combo
# 		...adding 88: Two-axle tank truck - hazardous waste or waste-material combo
# 		...adding 89: Three-axle tank truck - hazardous waste or waste-material combo
# 		...adding 91: Electric bicycle (class 1,2,3)
# 		...adding 93: Electrically motorized board
# 		...adding 94: Motorized transportation device
# 		...adding 95: Miscellaneous non-motorized vehicle (ridden animal, animal-drawn conveyance, train or building) with victim
# 		...adding 96: Miscellaneous motorized vehicle (golf cart)
# 		...adding 97: Low speed vehicle
# 		...adding 98: Emergency vehicle on an emergency run
# 		...adding 99: Not stated or unknown (hit and run)
# 		...adding -: Not Stated
# Match 116: Domain SPECIAL_INFO_F does not exist. Creating...
# Creating domain for SPECIAL_INFO_F...
# Start Time: Wednesday, November 13, 2024 8:45:35 AM
# Succeeded at Wednesday, November 13, 2024 8:45:35 AM (Elapsed Time: 0.34 seconds)
# 	Defining coded values dictionary...
# 		...adding F: 75ft motor truck combo
# 		...adding -: Not Stated
# Match 117: Domain SPECIAL_INFO_G does not exist. Creating...
# Creating domain for SPECIAL_INFO_G...
# Start Time: Wednesday, November 13, 2024 8:45:37 AM
# Succeeded at Wednesday, November 13, 2024 8:45:37 AM (Elapsed Time: 0.33 seconds)
# 	Defining coded values dictionary...
# 		...adding G: 32ft trailer combo
# 		...adding -: Not Stated
# Match 118: Domain VICTIM_ROLE does not exist. Creating...
# Creating domain for VICTIM_ROLE...
# Start Time: Wednesday, November 13, 2024 8:45:38 AM
# Succeeded at Wednesday, November 13, 2024 8:45:39 AM (Elapsed Time: 0.30 seconds)
# 	Defining coded values dictionary...
# 		...adding 1: Driver
# 		...adding 2: Passenger (includes non-operator on bicycle or any victim on/in parked vehicle or multiple victims on/in non-motor vehicle)
# 		...adding 3: Pedestrian
# 		...adding 4: Bicyclist
# 		...adding 5: Other (single victim on/in non-motor vehicle)
# 		...adding 6: Non-injured party
# Match 119: Domain VICTIM_SEX does not exist. Creating...
# Creating domain for VICTIM_SEX...
# Start Time: Wednesday, November 13, 2024 8:45:42 AM
# Succeeded at Wednesday, November 13, 2024 8:45:42 AM (Elapsed Time: 0.34 seconds)
# 	Defining coded values dictionary...
# 		...adding M: Male
# 		...adding F: Female
# 		...adding X: Nonbinary
# 		...adding -: Not Stated
# Match 120: Domain VICTIM_AGE does not exist. Creating...
# Creating domain for VICTIM_AGE...
# Start Time: Wednesday, November 13, 2024 8:45:45 AM
# Succeeded at Wednesday, November 13, 2024 8:45:45 AM (Elapsed Time: 0.31 seconds)
# 	Defining coded values dictionary...
# 		...adding 998: Not Stated
# 		...adding 999: Fatal Fetus
# Match 121: Domain VICTIM_DEGREE_OF_INJURY does not exist. Creating...
# Creating domain for VICTIM_DEGREE_OF_INJURY...
# Start Time: Wednesday, November 13, 2024 8:45:46 AM
# Succeeded at Wednesday, November 13, 2024 8:45:47 AM (Elapsed Time: 0.36 seconds)
# 	Defining coded values dictionary...
# 		...adding 0: No injury
# 		...adding 1: Killed
# 		...adding 2: Severe injury
# 		...adding 3: Other visible injury
# 		...adding 4: Complaint of pain
# 		...adding 5: Suspected serious injury
# 		...adding 6: Suspected minor injury
# 		...adding 7: Possible injury
# Match 122: Domain VICTIM_DEGREE_OF_INJURY_BINARY does not exist. Creating...
# Creating domain for VICTIM_DEGREE_OF_INJURY_BINARY...
# Start Time: Wednesday, November 13, 2024 8:45:51 AM
# Succeeded at Wednesday, November 13, 2024 8:45:51 AM (Elapsed Time: 0.32 seconds)
# 	Defining coded values dictionary...
# 		...adding 0: Minor (minor injury, pain, or no injury)
# 		...adding 1: Severe (killed or serious injury)
# Match 123: Domain VICTIM_SEATING_POSITION does not exist. Creating...
# Creating domain for VICTIM_SEATING_POSITION...
# Start Time: Wednesday, November 13, 2024 8:45:53 AM
# Succeeded at Wednesday, November 13, 2024 8:45:53 AM (Elapsed Time: 0.33 seconds)
# 	Defining coded values dictionary...
# 		...adding 0: Other occupants
# 		...adding 1: Driver
# 		...adding 2: Passenger 1
# 		...adding 3: Passenger 2
# 		...adding 4: Passenger 3
# 		...adding 5: Passenger 4
# 		...adding 6: Passenger 5
# 		...adding 7: Station wagon rear
# 		...adding 8: Rear occupant of truck or van
# 		...adding 9: Position unknown
# 		...adding -: Not Stated
# Match 124: Domain VICTIM_SAFETY_EQUIP_1 does not exist. Creating...
# Creating domain for VICTIM_SAFETY_EQUIP_1...
# Start Time: Wednesday, November 13, 2024 8:45:59 AM
# Succeeded at Wednesday, November 13, 2024 8:45:59 AM (Elapsed Time: 0.31 seconds)
# 	Defining coded values dictionary...
# 		...adding A: None in vehicle
# 		...adding B: Unknown
# 		...adding C: Lap belt used
# 		...adding D: Lap belt not used
# 		...adding E: Shoulder harness used
# 		...adding F: Shoulder harness not used
# 		...adding G: Lap/shoulder harness used
# 		...adding H: Lap/shoulder harness not used
# 		...adding J: Passive restraint used
# 		...adding K: Passive restraint not used
# 		...adding L: Air bag deployed
# 		...adding M: Air bag not deployed
# 		...adding N: Other
# 		...adding P: Not required
# 		...adding Q: Child restraint in vehicle used
# 		...adding R: Child restraint in vehicle not used
# 		...adding S: Child restraint in vehicle, use unknown
# 		...adding T: Child restraint in vehicle, improper use
# 		...adding U: No child restraint in vehicle
# 		...adding V: Driver, motorcycle helmet used
# 		...adding W: Driver, motorcycle helmet not used
# 		...adding X: Passenger, motorcycle helmet not used
# 		...adding Y: Passenger, motorcycle helmet used
# 		...adding -: Not Stated
# Match 125: Domain VICTIM_SAFETY_EQUIP_2 does not exist. Creating...
# Creating domain for VICTIM_SAFETY_EQUIP_2...
# Start Time: Wednesday, November 13, 2024 8:46:12 AM
# Succeeded at Wednesday, November 13, 2024 8:46:13 AM (Elapsed Time: 0.33 seconds)
# 	Defining coded values dictionary...
# 		...adding A: None in vehicle
# 		...adding B: Unknown
# 		...adding C: Lap belt used
# 		...adding D: Lap belt not used
# 		...adding E: Shoulder harness used
# 		...adding F: Shoulder harness not used
# 		...adding G: Lap/shoulder harness used
# 		...adding H: Lap/shoulder harness not used
# 		...adding J: Passive restraint used
# 		...adding K: Passive restraint not used
# 		...adding L: Air bag deployed
# 		...adding M: Air bag not deployed
# 		...adding N: Other
# 		...adding P: Not required
# 		...adding Q: Child restraint in vehicle used
# 		...adding R: Child restraint in vehicle not used
# 		...adding S: Child restraint in vehicle, use unknown
# 		...adding T: Child restraint in vehicle, improper use
# 		...adding U: No child restraint in vehicle
# 		...adding V: Driver, motorcycle helmet used
# 		...adding W: Driver, motorcycle helmet not used
# 		...adding X: Passenger, motorcycle helmet not used
# 		...adding Y: Passenger, motorcycle helmet used
# 		...adding -: Not Stated
# Match 126: Domain VICTIM_EJECTED does not exist. Creating...
# Creating domain for VICTIM_EJECTED...
# Start Time: Wednesday, November 13, 2024 8:46:25 AM
# Succeeded at Wednesday, November 13, 2024 8:46:26 AM (Elapsed Time: 0.33 seconds)
# 	Defining coded values dictionary...
# 		...adding 0: Not ejected
# 		...adding 1: Fully ejected
# 		...adding 2: Partially ejected
# 		...adding 3: Unknown
# 		...adding -: Not Stated

# %% [markdown]
# ### <font color="lime">**Assigning domains to feature classes**</font>

# %% [markdown]
# #### <font color="deepskyblue">Crashes Feature Class</font>

# %% [markdown]
# Assigning domain attributes to fields for the Crashes feature class

# %%
update_datetime("start")

# Iterate through the fields of the Crashes feature class
for field in crashesPointsFields:
    # if both conditions are met
    if (field.name in list(codebook.keys())) and (codebook[field.name]["dbin"] == "Y"):
        # if, also, the field name is in the geodatabase domain list
        if field.name in list(d.name for d in list(arcpy.da.ListDomains())):
            print(f"Match {codebook[field.name]['no']}: Domain {field.name}")
            print(f"\tAssigning domain {field.name} to field.\n")
            # Assign the domain to the field
            arcpy.management.AssignDomainToField(
                in_table = crashesPointsPath,
                field_name = field.name,
                domain_name = field.name,
                subtype_code = None
            )
            
update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 08:46 AM (PST)
# Match 20: Domain COLLISION_MONTH
# 	Assigning domain COLLISION_MONTH to field.
#
# Match 21: Domain DAY_OF_WEEK
# 	Assigning domain DAY_OF_WEEK to field.
#
# Match 23: Domain COLLISION_TIME_INTERVALS
# 	Assigning domain COLLISION_TIME_INTERVALS to field.
#
# Match 24: Domain COLLISION_TIME_RUSH_HOURS
# 	Assigning domain COLLISION_TIME_RUSH_HOURS to field.
#
# Match 25: Domain COLLISION_SEVERITY
# 	Assigning domain COLLISION_SEVERITY to field.
#
# Match 26: Domain COLLISION_SEVERITY_BINARY
# 	Assigning domain COLLISION_SEVERITY_BINARY to field.
#
# Match 27: Domain COLLISION_SEVERITY_RECLASS
# 	Assigning domain COLLISION_SEVERITY_RECLASS to field.
#
# Match 28: Domain COLLISION_SEVERITY_RANKED
# 	Assigning domain COLLISION_SEVERITY_RANKED to field.
#
# Match 42: Domain PRIMARY_COLL_FACTOR
# 	Assigning domain PRIMARY_COLL_FACTOR to field.
#
# Match 43: Domain TYPE_OF_COLLISION
# 	Assigning domain TYPE_OF_COLLISION to field.
#
# Match 44: Domain PEDESTRIAN_ACCIDENT
# 	Assigning domain PEDESTRIAN_ACCIDENT to field.
#
# Match 45: Domain BICYCLE_ACCIDENT
# 	Assigning domain BICYCLE_ACCIDENT to field.
#
# Match 46: Domain MOTORCYCLE_ACCIDENT
# 	Assigning domain MOTORCYCLE_ACCIDENT to field.
#
# Match 47: Domain TRUCK_ACCIDENT
# 	Assigning domain TRUCK_ACCIDENT to field.
#
# Match 48: Domain HIT_AND_RUN
# 	Assigning domain HIT_AND_RUN to field.
#
# Match 49: Domain ALCOHOL_INVOLVED
# 	Assigning domain ALCOHOL_INVOLVED to field.
#
# Match 53: Domain CHP_SHIFT
# 	Assigning domain CHP_SHIFT to field.
#
# Match 55: Domain SPECIAL_COND
# 	Assigning domain SPECIAL_COND to field.
#
# Match 56: Domain BEAT_TYPE
# 	Assigning domain BEAT_TYPE to field.
#
# Match 57: Domain CHP_BEAT_TYPE
# 	Assigning domain CHP_BEAT_TYPE to field.
#
# Match 58: Domain CHP_BEAT_CLASS
# 	Assigning domain CHP_BEAT_CLASS to field.
#
# Match 63: Domain DIRECTION
# 	Assigning domain DIRECTION to field.
#
# Match 64: Domain INTERSECTION
# 	Assigning domain INTERSECTION to field.
#
# Match 65: Domain WEATHER_1
# 	Assigning domain WEATHER_1 to field.
#
# Match 66: Domain WEATHER_2
# 	Assigning domain WEATHER_2 to field.
#
# Match 67: Domain WEATHER_COMBINED
# 	Assigning domain WEATHER_COMBINED to field.
#
# Match 68: Domain ROAD_SURFACE
# 	Assigning domain ROAD_SURFACE to field.
#
# Match 69: Domain ROAD_COND_1
# 	Assigning domain ROAD_COND_1 to field.
#
# Match 70: Domain ROAD_COND_2
# 	Assigning domain ROAD_COND_2 to field.
#
# Match 71: Domain LIGHTING
# 	Assigning domain LIGHTING to field.
#
# Match 72: Domain CONTROL_DEVICE
# 	Assigning domain CONTROL_DEVICE to field.
#
# Match 73: Domain STATE_HWY_IND
# 	Assigning domain STATE_HWY_IND to field.
#
# Match 74: Domain SIDE_OF_HWY
# 	Assigning domain SIDE_OF_HWY to field.
#
# Match 75: Domain TOW_AWAY
# 	Assigning domain TOW_AWAY to field.
#
# Match 76: Domain PCF_CODE_OF_VIOL
# 	Assigning domain PCF_CODE_OF_VIOL to field.
#
# Match 77: Domain PCF_VIOL_CATEGORY
# 	Assigning domain PCF_VIOL_CATEGORY to field.
#
# Match 80: Domain MVIW
# 	Assigning domain MVIW to field.
#
# Match 81: Domain PED_ACTION
# 	Assigning domain PED_ACTION to field.
#
# Match 82: Domain NOT_PRIVATE_PROPERTY
# 	Assigning domain NOT_PRIVATE_PROPERTY to field.
#
# Match 83: Domain STWD_VEHTYPE_AT_FAULT
# 	Assigning domain STWD_VEHTYPE_AT_FAULT to field.
#
# Match 84: Domain CHP_VEHTYPE_AT_FAULT
# 	Assigning domain CHP_VEHTYPE_AT_FAULT to field.
#
# Match 85: Domain PRIMARY_RAMP
# 	Assigning domain PRIMARY_RAMP to field.
#
# Match 86: Domain SECONDARY_RAMP
# 	Assigning domain SECONDARY_RAMP to field.
#
# End: Wednesday November 13, 2024, 08:47 AM (PST). Elapsed time: 0:00:32

# %% [markdown]
# #### <font color="deepskyblue">Parties Feature Class</font>

# %% [markdown]
# Assigning domain attributes to fields for the Parties feature class

# %%
update_datetime("start")

# Iterate through the fields of the Parties feature class
for field in partiesPointsFields:
    # if both conditions are met
    if (field.name in list(codebook.keys())) and (codebook[field.name]["dbin"] == "Y"):
        # if, also, the field name is in the geodatabase domain list
        if field.name in list(d.name for d in list(arcpy.da.ListDomains())):
            print(f"Match {codebook[field.name]['no']}: Domain {field.name}")
            print(f"\tAssigning domain {field.name} to field.\n")
            # Assign the domain to the field
            arcpy.management.AssignDomainToField(
                in_table = partiesPointsPath,
                field_name = field.name,
                domain_name = field.name,
                subtype_code = None
            )
            
update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 08:52 AM (PST)
# Match 20: Domain COLLISION_MONTH
# 	Assigning domain COLLISION_MONTH to field.
#
# Match 21: Domain DAY_OF_WEEK
# 	Assigning domain DAY_OF_WEEK to field.
#
# Match 23: Domain COLLISION_TIME_INTERVALS
# 	Assigning domain COLLISION_TIME_INTERVALS to field.
#
# Match 24: Domain COLLISION_TIME_RUSH_HOURS
# 	Assigning domain COLLISION_TIME_RUSH_HOURS to field.
#
# Match 25: Domain COLLISION_SEVERITY
# 	Assigning domain COLLISION_SEVERITY to field.
#
# Match 26: Domain COLLISION_SEVERITY_BINARY
# 	Assigning domain COLLISION_SEVERITY_BINARY to field.
#
# Match 27: Domain COLLISION_SEVERITY_RECLASS
# 	Assigning domain COLLISION_SEVERITY_RECLASS to field.
#
# Match 28: Domain COLLISION_SEVERITY_RANKED
# 	Assigning domain COLLISION_SEVERITY_RANKED to field.
#
# Match 42: Domain PRIMARY_COLL_FACTOR
# 	Assigning domain PRIMARY_COLL_FACTOR to field.
#
# Match 43: Domain TYPE_OF_COLLISION
# 	Assigning domain TYPE_OF_COLLISION to field.
#
# Match 44: Domain PEDESTRIAN_ACCIDENT
# 	Assigning domain PEDESTRIAN_ACCIDENT to field.
#
# Match 45: Domain BICYCLE_ACCIDENT
# 	Assigning domain BICYCLE_ACCIDENT to field.
#
# Match 46: Domain MOTORCYCLE_ACCIDENT
# 	Assigning domain MOTORCYCLE_ACCIDENT to field.
#
# Match 47: Domain TRUCK_ACCIDENT
# 	Assigning domain TRUCK_ACCIDENT to field.
#
# Match 48: Domain HIT_AND_RUN
# 	Assigning domain HIT_AND_RUN to field.
#
# Match 49: Domain ALCOHOL_INVOLVED
# 	Assigning domain ALCOHOL_INVOLVED to field.
#
# Match 53: Domain CHP_SHIFT
# 	Assigning domain CHP_SHIFT to field.
#
# Match 55: Domain SPECIAL_COND
# 	Assigning domain SPECIAL_COND to field.
#
# Match 56: Domain BEAT_TYPE
# 	Assigning domain BEAT_TYPE to field.
#
# Match 57: Domain CHP_BEAT_TYPE
# 	Assigning domain CHP_BEAT_TYPE to field.
#
# Match 58: Domain CHP_BEAT_CLASS
# 	Assigning domain CHP_BEAT_CLASS to field.
#
# Match 63: Domain DIRECTION
# 	Assigning domain DIRECTION to field.
#
# Match 64: Domain INTERSECTION
# 	Assigning domain INTERSECTION to field.
#
# Match 65: Domain WEATHER_1
# 	Assigning domain WEATHER_1 to field.
#
# Match 66: Domain WEATHER_2
# 	Assigning domain WEATHER_2 to field.
#
# Match 67: Domain WEATHER_COMBINED
# 	Assigning domain WEATHER_COMBINED to field.
#
# Match 68: Domain ROAD_SURFACE
# 	Assigning domain ROAD_SURFACE to field.
#
# Match 69: Domain ROAD_COND_1
# 	Assigning domain ROAD_COND_1 to field.
#
# Match 70: Domain ROAD_COND_2
# 	Assigning domain ROAD_COND_2 to field.
#
# Match 71: Domain LIGHTING
# 	Assigning domain LIGHTING to field.
#
# Match 72: Domain CONTROL_DEVICE
# 	Assigning domain CONTROL_DEVICE to field.
#
# Match 73: Domain STATE_HWY_IND
# 	Assigning domain STATE_HWY_IND to field.
#
# Match 74: Domain SIDE_OF_HWY
# 	Assigning domain SIDE_OF_HWY to field.
#
# Match 75: Domain TOW_AWAY
# 	Assigning domain TOW_AWAY to field.
#
# Match 76: Domain PCF_CODE_OF_VIOL
# 	Assigning domain PCF_CODE_OF_VIOL to field.
#
# Match 77: Domain PCF_VIOL_CATEGORY
# 	Assigning domain PCF_VIOL_CATEGORY to field.
#
# Match 80: Domain MVIW
# 	Assigning domain MVIW to field.
#
# Match 81: Domain PED_ACTION
# 	Assigning domain PED_ACTION to field.
#
# Match 82: Domain NOT_PRIVATE_PROPERTY
# 	Assigning domain NOT_PRIVATE_PROPERTY to field.
#
# Match 83: Domain STWD_VEHTYPE_AT_FAULT
# 	Assigning domain STWD_VEHTYPE_AT_FAULT to field.
#
# Match 84: Domain CHP_VEHTYPE_AT_FAULT
# 	Assigning domain CHP_VEHTYPE_AT_FAULT to field.
#
# Match 85: Domain PRIMARY_RAMP
# 	Assigning domain PRIMARY_RAMP to field.
#
# Match 86: Domain SECONDARY_RAMP
# 	Assigning domain SECONDARY_RAMP to field.
#
# Match 87: Domain PARTY_TYPE
# 	Assigning domain PARTY_TYPE to field.
#
# Match 88: Domain AT_FAULT
# 	Assigning domain AT_FAULT to field.
#
# Match 89: Domain PARTY_SEX
# 	Assigning domain PARTY_SEX to field.
#
# Match 90: Domain PARTY_AGE
# 	Assigning domain PARTY_AGE to field.
#
# Match 91: Domain RACE
# 	Assigning domain RACE to field.
#
# Match 94: Domain INATTENTION
# 	Assigning domain INATTENTION to field.
#
# Match 95: Domain PARTY_SOBRIETY
# 	Assigning domain PARTY_SOBRIETY to field.
#
# Match 96: Domain PARTY_DRUG_PHYSICAL
# 	Assigning domain PARTY_DRUG_PHYSICAL to field.
#
# Match 97: Domain DIR_OF_TRAVEL
# 	Assigning domain DIR_OF_TRAVEL to field.
#
# Match 98: Domain PARTY_SAFETY_EQUIP_1
# 	Assigning domain PARTY_SAFETY_EQUIP_1 to field.
#
# Match 99: Domain PARTY_SAFETY_EQUIP_2
# 	Assigning domain PARTY_SAFETY_EQUIP_2 to field.
#
# Match 100: Domain FINAN_RESPONS
# 	Assigning domain FINAN_RESPONS to field.
#
# Match 101: Domain SP_INFO_1
# 	Assigning domain SP_INFO_1 to field.
#
# Match 102: Domain SP_INFO_2
# 	Assigning domain SP_INFO_2 to field.
#
# Match 103: Domain SP_INFO_3
# 	Assigning domain SP_INFO_3 to field.
#
# Match 104: Domain OAF_VIOLATION_CODE
# 	Assigning domain OAF_VIOLATION_CODE to field.
#
# Match 105: Domain OAF_VIOL_CAT
# 	Assigning domain OAF_VIOL_CAT to field.
#
# Match 108: Domain OAF_1
# 	Assigning domain OAF_1 to field.
#
# Match 109: Domain OAF_2
# 	Assigning domain OAF_2 to field.
#
# Match 110: Domain MOVE_PRE_ACC
# 	Assigning domain MOVE_PRE_ACC to field.
#
# Match 111: Domain VEHICLE_YEAR
# 	Assigning domain VEHICLE_YEAR to field.
#
# Match 112: Domain VEHICLE_MAKE
# 	Assigning domain VEHICLE_MAKE to field.
#
# Match 113: Domain STWD_VEHICLE_TYPE
# 	Assigning domain STWD_VEHICLE_TYPE to field.
#
# Match 114: Domain CHP_VEH_TYPE_TOWING
# 	Assigning domain CHP_VEH_TYPE_TOWING to field.
#
# Match 115: Domain CHP_VEH_TYPE_TOWED
# 	Assigning domain CHP_VEH_TYPE_TOWED to field.
#
# Match 116: Domain SPECIAL_INFO_F
# 	Assigning domain SPECIAL_INFO_F to field.
#
# Match 117: Domain SPECIAL_INFO_G
# 	Assigning domain SPECIAL_INFO_G to field.
#
# End: Wednesday November 13, 2024, 08:53 AM (PST). Elapsed time: 0:00:55

# %% [markdown]
# #### <font color="deepskyblue">Victims Feature Class</font>

# %% [markdown]
# Assigning domain attributes to fields for the Victims feature class

# %%
update_datetime("start")

# Iterate through the fields of the Victims feature class
for field in victimsPointsFields:
    # if both conditions are met
    if (field.name in list(codebook.keys())) and (codebook[field.name]["dbin"] == "Y"):
        # if, also, the field name is in the geodatabase domain list
        if field.name in list(d.name for d in list(arcpy.da.ListDomains())):
            print(f"Match {codebook[field.name]['no']}: Domain {field.name}")
            print(f"\tAssigning domain {field.name} to field.\n")
            # Assign the domain to the field
            arcpy.management.AssignDomainToField(
                in_table = victimsPointsPath,
                field_name = field.name,
                domain_name = field.name,
                subtype_code = None
            )
            
update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 08:53 AM (PST)
# Match 20: Domain COLLISION_MONTH
# 	Assigning domain COLLISION_MONTH to field.
#
# Match 21: Domain DAY_OF_WEEK
# 	Assigning domain DAY_OF_WEEK to field.
#
# Match 23: Domain COLLISION_TIME_INTERVALS
# 	Assigning domain COLLISION_TIME_INTERVALS to field.
#
# Match 24: Domain COLLISION_TIME_RUSH_HOURS
# 	Assigning domain COLLISION_TIME_RUSH_HOURS to field.
#
# Match 25: Domain COLLISION_SEVERITY
# 	Assigning domain COLLISION_SEVERITY to field.
#
# Match 26: Domain COLLISION_SEVERITY_BINARY
# 	Assigning domain COLLISION_SEVERITY_BINARY to field.
#
# Match 27: Domain COLLISION_SEVERITY_RECLASS
# 	Assigning domain COLLISION_SEVERITY_RECLASS to field.
#
# Match 28: Domain COLLISION_SEVERITY_RANKED
# 	Assigning domain COLLISION_SEVERITY_RANKED to field.
#
# Match 42: Domain PRIMARY_COLL_FACTOR
# 	Assigning domain PRIMARY_COLL_FACTOR to field.
#
# Match 43: Domain TYPE_OF_COLLISION
# 	Assigning domain TYPE_OF_COLLISION to field.
#
# Match 44: Domain PEDESTRIAN_ACCIDENT
# 	Assigning domain PEDESTRIAN_ACCIDENT to field.
#
# Match 45: Domain BICYCLE_ACCIDENT
# 	Assigning domain BICYCLE_ACCIDENT to field.
#
# Match 46: Domain MOTORCYCLE_ACCIDENT
# 	Assigning domain MOTORCYCLE_ACCIDENT to field.
#
# Match 47: Domain TRUCK_ACCIDENT
# 	Assigning domain TRUCK_ACCIDENT to field.
#
# Match 48: Domain HIT_AND_RUN
# 	Assigning domain HIT_AND_RUN to field.
#
# Match 49: Domain ALCOHOL_INVOLVED
# 	Assigning domain ALCOHOL_INVOLVED to field.
#
# Match 53: Domain CHP_SHIFT
# 	Assigning domain CHP_SHIFT to field.
#
# Match 55: Domain SPECIAL_COND
# 	Assigning domain SPECIAL_COND to field.
#
# Match 56: Domain BEAT_TYPE
# 	Assigning domain BEAT_TYPE to field.
#
# Match 57: Domain CHP_BEAT_TYPE
# 	Assigning domain CHP_BEAT_TYPE to field.
#
# Match 58: Domain CHP_BEAT_CLASS
# 	Assigning domain CHP_BEAT_CLASS to field.
#
# Match 63: Domain DIRECTION
# 	Assigning domain DIRECTION to field.
#
# Match 64: Domain INTERSECTION
# 	Assigning domain INTERSECTION to field.
#
# Match 65: Domain WEATHER_1
# 	Assigning domain WEATHER_1 to field.
#
# Match 66: Domain WEATHER_2
# 	Assigning domain WEATHER_2 to field.
#
# Match 67: Domain WEATHER_COMBINED
# 	Assigning domain WEATHER_COMBINED to field.
#
# Match 68: Domain ROAD_SURFACE
# 	Assigning domain ROAD_SURFACE to field.
#
# Match 69: Domain ROAD_COND_1
# 	Assigning domain ROAD_COND_1 to field.
#
# Match 70: Domain ROAD_COND_2
# 	Assigning domain ROAD_COND_2 to field.
#
# Match 71: Domain LIGHTING
# 	Assigning domain LIGHTING to field.
#
# Match 72: Domain CONTROL_DEVICE
# 	Assigning domain CONTROL_DEVICE to field.
#
# Match 73: Domain STATE_HWY_IND
# 	Assigning domain STATE_HWY_IND to field.
#
# Match 74: Domain SIDE_OF_HWY
# 	Assigning domain SIDE_OF_HWY to field.
#
# Match 75: Domain TOW_AWAY
# 	Assigning domain TOW_AWAY to field.
#
# Match 76: Domain PCF_CODE_OF_VIOL
# 	Assigning domain PCF_CODE_OF_VIOL to field.
#
# Match 77: Domain PCF_VIOL_CATEGORY
# 	Assigning domain PCF_VIOL_CATEGORY to field.
#
# Match 80: Domain MVIW
# 	Assigning domain MVIW to field.
#
# Match 81: Domain PED_ACTION
# 	Assigning domain PED_ACTION to field.
#
# Match 82: Domain NOT_PRIVATE_PROPERTY
# 	Assigning domain NOT_PRIVATE_PROPERTY to field.
#
# Match 83: Domain STWD_VEHTYPE_AT_FAULT
# 	Assigning domain STWD_VEHTYPE_AT_FAULT to field.
#
# Match 84: Domain CHP_VEHTYPE_AT_FAULT
# 	Assigning domain CHP_VEHTYPE_AT_FAULT to field.
#
# Match 85: Domain PRIMARY_RAMP
# 	Assigning domain PRIMARY_RAMP to field.
#
# Match 86: Domain SECONDARY_RAMP
# 	Assigning domain SECONDARY_RAMP to field.
#
# Match 87: Domain PARTY_TYPE
# 	Assigning domain PARTY_TYPE to field.
#
# Match 88: Domain AT_FAULT
# 	Assigning domain AT_FAULT to field.
#
# Match 89: Domain PARTY_SEX
# 	Assigning domain PARTY_SEX to field.
#
# Match 90: Domain PARTY_AGE
# 	Assigning domain PARTY_AGE to field.
#
# Match 91: Domain RACE
# 	Assigning domain RACE to field.
#
# Match 94: Domain INATTENTION
# 	Assigning domain INATTENTION to field.
#
# Match 95: Domain PARTY_SOBRIETY
# 	Assigning domain PARTY_SOBRIETY to field.
#
# Match 96: Domain PARTY_DRUG_PHYSICAL
# 	Assigning domain PARTY_DRUG_PHYSICAL to field.
#
# Match 97: Domain DIR_OF_TRAVEL
# 	Assigning domain DIR_OF_TRAVEL to field.
#
# Match 98: Domain PARTY_SAFETY_EQUIP_1
# 	Assigning domain PARTY_SAFETY_EQUIP_1 to field.
#
# Match 99: Domain PARTY_SAFETY_EQUIP_2
# 	Assigning domain PARTY_SAFETY_EQUIP_2 to field.
#
# Match 100: Domain FINAN_RESPONS
# 	Assigning domain FINAN_RESPONS to field.
#
# Match 101: Domain SP_INFO_1
# 	Assigning domain SP_INFO_1 to field.
#
# Match 102: Domain SP_INFO_2
# 	Assigning domain SP_INFO_2 to field.
#
# Match 103: Domain SP_INFO_3
# 	Assigning domain SP_INFO_3 to field.
#
# Match 104: Domain OAF_VIOLATION_CODE
# 	Assigning domain OAF_VIOLATION_CODE to field.
#
# Match 105: Domain OAF_VIOL_CAT
# 	Assigning domain OAF_VIOL_CAT to field.
#
# Match 108: Domain OAF_1
# 	Assigning domain OAF_1 to field.
#
# Match 109: Domain OAF_2
# 	Assigning domain OAF_2 to field.
#
# Match 110: Domain MOVE_PRE_ACC
# 	Assigning domain MOVE_PRE_ACC to field.
#
# Match 111: Domain VEHICLE_YEAR
# 	Assigning domain VEHICLE_YEAR to field.
#
# Match 112: Domain VEHICLE_MAKE
# 	Assigning domain VEHICLE_MAKE to field.
#
# Match 113: Domain STWD_VEHICLE_TYPE
# 	Assigning domain STWD_VEHICLE_TYPE to field.
#
# Match 114: Domain CHP_VEH_TYPE_TOWING
# 	Assigning domain CHP_VEH_TYPE_TOWING to field.
#
# Match 115: Domain CHP_VEH_TYPE_TOWED
# 	Assigning domain CHP_VEH_TYPE_TOWED to field.
#
# Match 116: Domain SPECIAL_INFO_F
# 	Assigning domain SPECIAL_INFO_F to field.
#
# Match 117: Domain SPECIAL_INFO_G
# 	Assigning domain SPECIAL_INFO_G to field.
#
# Match 118: Domain VICTIM_ROLE
# 	Assigning domain VICTIM_ROLE to field.
#
# Match 119: Domain VICTIM_SEX
# 	Assigning domain VICTIM_SEX to field.
#
# Match 120: Domain VICTIM_AGE
# 	Assigning domain VICTIM_AGE to field.
#
# Match 121: Domain VICTIM_DEGREE_OF_INJURY
# 	Assigning domain VICTIM_DEGREE_OF_INJURY to field.
#
# Match 122: Domain VICTIM_DEGREE_OF_INJURY_BINARY
# 	Assigning domain VICTIM_DEGREE_OF_INJURY_BINARY to field.
#
# Match 123: Domain VICTIM_SEATING_POSITION
# 	Assigning domain VICTIM_SEATING_POSITION to field.
#
# Match 124: Domain VICTIM_SAFETY_EQUIP_1
# 	Assigning domain VICTIM_SAFETY_EQUIP_1 to field.
#
# Match 125: Domain VICTIM_SAFETY_EQUIP_2
# 	Assigning domain VICTIM_SAFETY_EQUIP_2 to field.
#
# Match 126: Domain VICTIM_EJECTED
# 	Assigning domain VICTIM_EJECTED to field.
#
# End: Wednesday November 13, 2024, 08:54 AM (PST). Elapsed time: 0:01:00

# %% [markdown]
# #### <font color="deepskyblue">Collisions Feature Class</font>

# %% [markdown]
# Assigning domain attributes to fields for the Collisions feature class

# %%
update_datetime("start")

# Iterate through the fields of the Collisions feature class
for field in collisionsPointsFields:
    # if both conditions are met
    if (field.name in list(codebook.keys())) and (codebook[field.name]["dbin"] == "Y"):
        # if, also, the field name is in the geodatabase domain list
        if field.name in list(d.name for d in list(arcpy.da.ListDomains())):
            print(f"Match {codebook[field.name]['no']}: Domain {field.name}")
            print(f"\tAssigning domain {field.name} to field.\n")
            # Assign the domain to the field
            arcpy.management.AssignDomainToField(
                in_table = collisionsPointsPath,
                field_name = field.name,
                domain_name = field.name,
                subtype_code = None
            )
            
update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 08:54 AM (PST)
# Match 20: Domain COLLISION_MONTH
# 	Assigning domain COLLISION_MONTH to field.
#
# Match 21: Domain DAY_OF_WEEK
# 	Assigning domain DAY_OF_WEEK to field.
#
# Match 23: Domain COLLISION_TIME_INTERVALS
# 	Assigning domain COLLISION_TIME_INTERVALS to field.
#
# Match 24: Domain COLLISION_TIME_RUSH_HOURS
# 	Assigning domain COLLISION_TIME_RUSH_HOURS to field.
#
# Match 25: Domain COLLISION_SEVERITY
# 	Assigning domain COLLISION_SEVERITY to field.
#
# Match 26: Domain COLLISION_SEVERITY_BINARY
# 	Assigning domain COLLISION_SEVERITY_BINARY to field.
#
# Match 27: Domain COLLISION_SEVERITY_RECLASS
# 	Assigning domain COLLISION_SEVERITY_RECLASS to field.
#
# Match 28: Domain COLLISION_SEVERITY_RANKED
# 	Assigning domain COLLISION_SEVERITY_RANKED to field.
#
# Match 42: Domain PRIMARY_COLL_FACTOR
# 	Assigning domain PRIMARY_COLL_FACTOR to field.
#
# Match 43: Domain TYPE_OF_COLLISION
# 	Assigning domain TYPE_OF_COLLISION to field.
#
# Match 44: Domain PEDESTRIAN_ACCIDENT
# 	Assigning domain PEDESTRIAN_ACCIDENT to field.
#
# Match 45: Domain BICYCLE_ACCIDENT
# 	Assigning domain BICYCLE_ACCIDENT to field.
#
# Match 46: Domain MOTORCYCLE_ACCIDENT
# 	Assigning domain MOTORCYCLE_ACCIDENT to field.
#
# Match 47: Domain TRUCK_ACCIDENT
# 	Assigning domain TRUCK_ACCIDENT to field.
#
# Match 48: Domain HIT_AND_RUN
# 	Assigning domain HIT_AND_RUN to field.
#
# Match 49: Domain ALCOHOL_INVOLVED
# 	Assigning domain ALCOHOL_INVOLVED to field.
#
# Match 53: Domain CHP_SHIFT
# 	Assigning domain CHP_SHIFT to field.
#
# Match 55: Domain SPECIAL_COND
# 	Assigning domain SPECIAL_COND to field.
#
# Match 56: Domain BEAT_TYPE
# 	Assigning domain BEAT_TYPE to field.
#
# Match 57: Domain CHP_BEAT_TYPE
# 	Assigning domain CHP_BEAT_TYPE to field.
#
# Match 58: Domain CHP_BEAT_CLASS
# 	Assigning domain CHP_BEAT_CLASS to field.
#
# Match 63: Domain DIRECTION
# 	Assigning domain DIRECTION to field.
#
# Match 64: Domain INTERSECTION
# 	Assigning domain INTERSECTION to field.
#
# Match 65: Domain WEATHER_1
# 	Assigning domain WEATHER_1 to field.
#
# Match 66: Domain WEATHER_2
# 	Assigning domain WEATHER_2 to field.
#
# Match 67: Domain WEATHER_COMBINED
# 	Assigning domain WEATHER_COMBINED to field.
#
# Match 68: Domain ROAD_SURFACE
# 	Assigning domain ROAD_SURFACE to field.
#
# Match 69: Domain ROAD_COND_1
# 	Assigning domain ROAD_COND_1 to field.
#
# Match 70: Domain ROAD_COND_2
# 	Assigning domain ROAD_COND_2 to field.
#
# Match 71: Domain LIGHTING
# 	Assigning domain LIGHTING to field.
#
# Match 72: Domain CONTROL_DEVICE
# 	Assigning domain CONTROL_DEVICE to field.
#
# Match 73: Domain STATE_HWY_IND
# 	Assigning domain STATE_HWY_IND to field.
#
# Match 74: Domain SIDE_OF_HWY
# 	Assigning domain SIDE_OF_HWY to field.
#
# Match 75: Domain TOW_AWAY
# 	Assigning domain TOW_AWAY to field.
#
# Match 76: Domain PCF_CODE_OF_VIOL
# 	Assigning domain PCF_CODE_OF_VIOL to field.
#
# Match 77: Domain PCF_VIOL_CATEGORY
# 	Assigning domain PCF_VIOL_CATEGORY to field.
#
# Match 80: Domain MVIW
# 	Assigning domain MVIW to field.
#
# Match 81: Domain PED_ACTION
# 	Assigning domain PED_ACTION to field.
#
# Match 82: Domain NOT_PRIVATE_PROPERTY
# 	Assigning domain NOT_PRIVATE_PROPERTY to field.
#
# Match 83: Domain STWD_VEHTYPE_AT_FAULT
# 	Assigning domain STWD_VEHTYPE_AT_FAULT to field.
#
# Match 84: Domain CHP_VEHTYPE_AT_FAULT
# 	Assigning domain CHP_VEHTYPE_AT_FAULT to field.
#
# Match 85: Domain PRIMARY_RAMP
# 	Assigning domain PRIMARY_RAMP to field.
#
# Match 86: Domain SECONDARY_RAMP
# 	Assigning domain SECONDARY_RAMP to field.
#
# Match 87: Domain PARTY_TYPE
# 	Assigning domain PARTY_TYPE to field.
#
# Match 88: Domain AT_FAULT
# 	Assigning domain AT_FAULT to field.
#
# Match 89: Domain PARTY_SEX
# 	Assigning domain PARTY_SEX to field.
#
# Match 90: Domain PARTY_AGE
# 	Assigning domain PARTY_AGE to field.
#
# Match 91: Domain RACE
# 	Assigning domain RACE to field.
#
# Match 94: Domain INATTENTION
# 	Assigning domain INATTENTION to field.
#
# Match 95: Domain PARTY_SOBRIETY
# 	Assigning domain PARTY_SOBRIETY to field.
#
# Match 96: Domain PARTY_DRUG_PHYSICAL
# 	Assigning domain PARTY_DRUG_PHYSICAL to field.
#
# Match 97: Domain DIR_OF_TRAVEL
# 	Assigning domain DIR_OF_TRAVEL to field.
#
# Match 98: Domain PARTY_SAFETY_EQUIP_1
# 	Assigning domain PARTY_SAFETY_EQUIP_1 to field.
#
# Match 99: Domain PARTY_SAFETY_EQUIP_2
# 	Assigning domain PARTY_SAFETY_EQUIP_2 to field.
#
# Match 100: Domain FINAN_RESPONS
# 	Assigning domain FINAN_RESPONS to field.
#
# Match 101: Domain SP_INFO_1
# 	Assigning domain SP_INFO_1 to field.
#
# Match 102: Domain SP_INFO_2
# 	Assigning domain SP_INFO_2 to field.
#
# Match 103: Domain SP_INFO_3
# 	Assigning domain SP_INFO_3 to field.
#
# Match 104: Domain OAF_VIOLATION_CODE
# 	Assigning domain OAF_VIOLATION_CODE to field.
#
# Match 105: Domain OAF_VIOL_CAT
# 	Assigning domain OAF_VIOL_CAT to field.
#
# Match 108: Domain OAF_1
# 	Assigning domain OAF_1 to field.
#
# Match 109: Domain OAF_2
# 	Assigning domain OAF_2 to field.
#
# Match 110: Domain MOVE_PRE_ACC
# 	Assigning domain MOVE_PRE_ACC to field.
#
# Match 111: Domain VEHICLE_YEAR
# 	Assigning domain VEHICLE_YEAR to field.
#
# Match 112: Domain VEHICLE_MAKE
# 	Assigning domain VEHICLE_MAKE to field.
#
# Match 113: Domain STWD_VEHICLE_TYPE
# 	Assigning domain STWD_VEHICLE_TYPE to field.
#
# Match 114: Domain CHP_VEH_TYPE_TOWING
# 	Assigning domain CHP_VEH_TYPE_TOWING to field.
#
# Match 115: Domain CHP_VEH_TYPE_TOWED
# 	Assigning domain CHP_VEH_TYPE_TOWED to field.
#
# Match 116: Domain SPECIAL_INFO_F
# 	Assigning domain SPECIAL_INFO_F to field.
#
# Match 117: Domain SPECIAL_INFO_G
# 	Assigning domain SPECIAL_INFO_G to field.
#
# Match 118: Domain VICTIM_ROLE
# 	Assigning domain VICTIM_ROLE to field.
#
# Match 119: Domain VICTIM_SEX
# 	Assigning domain VICTIM_SEX to field.
#
# Match 120: Domain VICTIM_AGE
# 	Assigning domain VICTIM_AGE to field.
#
# Match 121: Domain VICTIM_DEGREE_OF_INJURY
# 	Assigning domain VICTIM_DEGREE_OF_INJURY to field.
#
# Match 122: Domain VICTIM_DEGREE_OF_INJURY_BINARY
# 	Assigning domain VICTIM_DEGREE_OF_INJURY_BINARY to field.
#
# Match 123: Domain VICTIM_SEATING_POSITION
# 	Assigning domain VICTIM_SEATING_POSITION to field.
#
# Match 124: Domain VICTIM_SAFETY_EQUIP_1
# 	Assigning domain VICTIM_SAFETY_EQUIP_1 to field.
#
# Match 125: Domain VICTIM_SAFETY_EQUIP_2
# 	Assigning domain VICTIM_SAFETY_EQUIP_2 to field.
#
# Match 126: Domain VICTIM_EJECTED
# 	Assigning domain VICTIM_EJECTED to field.
#
# End: Wednesday November 13, 2024, 08:55 AM (PST). Elapsed time: 0:01:01

# %% [markdown]
# Save the ArcGIS Pro project

# %%
# Save the project
aprx.save()

# %% [markdown]
# ## <font color="orangered">**Geodatabase Metadata Operations**</font>

# %% [markdown]
# ### <font color="lime">**Feature Class Aliases**</font>

# %% [markdown]
# Define name aliases for the feature classes (to be used both for defining feature class aliases, and for calling layer names in map contents)

# %%
# Define aliases for each of the feature classes
aliasCrashes = "OCSWITRS Crashes"
aliasParties = "OCSWITRS Parties"
aliasVictims = "OCSWITRS Victims"
aliasCollisions = "OCSWITRS Collisions"
aliasCities = "OCSWITRS Cities"
aliasRoads = "OCSWITRS Roads"

# %% [markdown]
# Assign aliases to feature classes

# %%
# Assign alias operations to each of the feature classes
arcpy.AlterAliasName(crashesPointsPath, aliasCrashes)
arcpy.AlterAliasName(partiesPointsPath, aliasParties)
arcpy.AlterAliasName(victimsPointsPath, aliasVictims)
arcpy.AlterAliasName(collisionsPointsPath, aliasCollisions)
arcpy.AlterAliasName(citiesPath, aliasCities)
arcpy.AlterAliasName(roadsPath, aliasRoads)

# %% [markdown]
# Save the ArcGIS Pro project

# %%
# Save the project
aprx.save()

# %% [markdown]
# ### <font color="lime">**Crashes Metadata**</font>

# %% [markdown]
# Create a new *Crashes* metadata object

# %%
# Define key metadata attributes for the Crashes feature class
mdoCrashes = md.Metadata()
mdoCrashes.title = "OCSWITRS Crashes Points"
mdoCrashes.tags = "Orange County, California, Traffic, Traffic Conditions, Crashes, Collisions, Road Safety, Accidents, SWITRS, OCSWITRS, Transportation"
mdoCrashes.summary = "Statewide Integrated Traffic Records System (SWITRS) Crash Data for Orange County, California (2013-2024)"
mdoCrashes.description = f"""<div style="text-align:Left;"><div><div><p><span style="font-weight:bold;">Statewide Integrated Traffic Records System (SWITRS)</span><span> location point data, containing </span><span style="font-weight:bold;">reports on crashes</span><span> in Orange County, California for 2013-2024 (December 31, 2012 to June 30, 2024). The data are collected and maintained by the </span><a href="https://www.chp.ca.gov:443/" style="text-decoration:underline;"><span>California Highway Patrol (CHP)</span></a><span>, from incidents reported by local and government agencies. Original tabular datasets are provided by the </span><a href="https://tims.berkeley.edu:443/" style="text-decoration:underline;"><span>Transportation Injury Mapping System (TIMS)</span></a><span>. Only records with reported locational GPS attributes in Orange County are included in the spatial database (either from X and Y geocoded coordinates, or the longitude and latitude coordinates generated by the CHP officer on site). Incidents without valid coordinates are omitted from this spatial dataset representation. Last Updated on <b>{lastUpdateDate}</b></span></p></div></div></div>"""
mdoCrashes.credits = "Dr. Kostas Alexandridis, GISP, Data Scientist, OC Public Works, OC Survey Geospatial Services"
mdoCrashes.accessConstraints = """<div style="text-align:Left;"><p><span>The SWITRS data displayed are provided by the California Highway Patrol (CHP) reports through the Transportation Injury Mapping System (TIMS) of the University of California, Berkeley. Issues of report accuracy should be addressed to CHP.</span></p><p>The displayed mapped data can be used under a <a href="https://creativecommons.org/licenses/by-sa/3.0/" target="_blank">Creative Commons CC-SA-BY</a> License, providing attribution to TIMS, CHP, and OC Public Works, OC Survey Geospatial Services. </p><div>We make every effort to provide the most accurate and up-to-date data and information. Nevertheless, the data feed is provided, 'as is' and OC Public Work's standard <a href="https://www.ocgov.com/contact-county/disclaimer" target="_blank">Disclaimer</a> applies.<br /></div><div><br /></div><div>For any inquiries, suggestions or questions, please contact:</div><div><br /></div><div style="text-align:center;"><a href="https://www.linkedin.com/in/ktalexan/" target="_blank"><b>Dr. Kostas Alexandridis, GISP</b></a><br /></div><div style="text-align:center;">GIS Analyst | Spatial Complex Systems Scientist</div><div style="text-align:center;">OC Public Works/OC Survey Geospatial Applications</div><div style="text-align:center;"><div>601 N. Ross Street, P.O. Box 4048, Santa Ana, CA 92701</div><div>Email: <a href="mailto:kostas.alexandridis@ocpw.ocgov.com" target="_blank">kostas.alexandridis@ocpw.ocgov.com</a> | Phone: (714) 967-0826</div><div><br /></div></div></div>"""
mdoCrashes.thumbnailUri = "https://ocpw.maps.arcgis.com/sharing/rest/content/items/6b96b7d6d5394cbb95aa2fae390503a9/data"

# %% [markdown]
# Assign the *Crashes* metadata object's content to the feature layer

# %%
# Apply the metadata object to the Crashes feature class
mdCrashes = md.Metadata(crashesPointsPath)
if not mdCrashes.isReadOnly:
    mdCrashes.copy(mdoCrashes)
    mdCrashes.save()

# %% [markdown]
# ### <font color="lime">**Parties Metadata**</font>

# %% [markdown]
# Create a new *Parties* metadata object

# %%
# Define key metadata attributes for the Parties feature class
mdoParties = md.Metadata()
mdoParties.title = "OCSWITRS Parties Points"
mdoParties.tags = "Orange County, California, Traffic, Traffic Conditions, Crashes, Parties, Collisions, Road Safety, Accidents, SWITRS, OCSWITRS, Transportation"
mdoParties.summary = "Statewide Integrated Traffic Records System (SWITRS) Incident-Involved Parties Data for Orange County, California (2013-2024)"
mdoParties.description = f"""<div style="text-align:Left;"><div><div><p><span style="font-weight:bold;">Statewide Integrated Traffic Records System (SWITRS)</span><span> location point data, containing </span><span style="font-weight:bold;">reports on parties involved in crash incidents</span><span> in Orange County, California for 2013-2024 (December 31, 2012 to June 30, 2024). The data are collected and maintained by the </span><a href="https://www.chp.ca.gov:443/" style="text-decoration:underline;"><span>California Highway Patrol (CHP)</span></a><span>, from incidents reported by local and government agencies. Original tabular datasets are provided by the </span><a href="https://tims.berkeley.edu:443/" style="text-decoration:underline;"><span>Transportation Injury Mapping System (TIMS)</span></a><span>. Only records with reported locational GPS attributes in Orange County are included in the spatial database (either from X and Y geocoded coordinates, or the longitude and latitude coordinates generated by the CHP officer on site). Incidents without valid coordinates are omitted from this spatial dataset representation. Last Updated on <b>{lastUpdateDate}</b></span></p></div></div></div>"""
mdoParties.credits = "Dr. Kostas Alexandridis, GISP, Data Scientist, OC Public Works, OC Survey Geospatial Services"
mdoParties.accessConstraints = """<div style="text-align:Left;"><p><span>The SWITRS data displayed are provided by the California Highway Patrol (CHP) reports through the Transportation Injury Mapping System (TIMS) of the University of California, Berkeley. Issues of report accuracy should be addressed to CHP.</span></p><p>The displayed mapped data can be used under a <a href="https://creativecommons.org/licenses/by-sa/3.0/" target="_blank">Creative Commons CC-SA-BY</a> License, providing attribution to TIMS, CHP, and OC Public Works, OC Survey Geospatial Services. </p><div>We make every effort to provide the most accurate and up-to-date data and information. Nevertheless, the data feed is provided, 'as is' and OC Public Work's standard <a href="https://www.ocgov.com/contact-county/disclaimer" target="_blank">Disclaimer</a> applies.<br /></div><div><br /></div><div>For any inquiries, suggestions or questions, please contact:</div><div><br /></div><div style="text-align:center;"><a href="https://www.linkedin.com/in/ktalexan/" target="_blank"><b>Dr. Kostas Alexandridis, GISP</b></a><br /></div><div style="text-align:center;">GIS Analyst | Spatial Complex Systems Scientist</div><div style="text-align:center;">OC Public Works/OC Survey Geospatial Applications</div><div style="text-align:center;"><div>601 N. Ross Street, P.O. Box 4048, Santa Ana, CA 92701</div><div>Email: <a href="mailto:kostas.alexandridis@ocpw.ocgov.com" target="_blank">kostas.alexandridis@ocpw.ocgov.com</a> | Phone: (714) 967-0826</div><div><br /></div></div></div>"""
mdoParties.thumbnailUri = "https://ocpw.maps.arcgis.com/sharing/rest/content/items/1e07bb1002f9457fa6fd3540fdb08e29/data"

# %% [markdown]
# Assign the *Parties* metadata object's content to the feature layer

# %%
# Apply the metadata object to the Parties feature class
mdParties = md.Metadata(partiesPointsPath)
if not mdParties.isReadOnly:
    mdParties.copy(mdoParties)
    mdParties.save()

# %% [markdown]
# ### <font color="lime">**Victims Metadata**</font>

# %% [markdown]
# Create a new *Victims* metadata object

# %%
# Define key metadata attributes for the Victims feature class
mdoVictims = md.Metadata()
mdoVictims.title = "OCSWITRS Victims Points"
mdoVictims.tags = "Orange County, California, Traffic, Traffic Conditions, Crashes, Victims, Collisions, Road Safety, Accidents, SWITRS, OCSWITRS, Transportation"
mdoVictims.summary = "Statewide Integrated Traffic Records System (SWITRS) Incident-Involved Victims Data for Orange County, California (2013-2024)"
mdoVictims.description = f"""<div style="text-align:Left;"><div><div><p><span style="font-weight:bold;">Statewide Integrated Traffic Records System (SWITRS)</span><span> location point data, containing </span><span style="font-weight:bold;">reports on victims/persons involved in crash incidents</span><span> in Orange County, California for 2013-2024 (December 31, 2012 to June 30, 2024). The data are collected and maintained by the </span><a href="https://www.chp.ca.gov:443/" style="text-decoration:underline;"><span>California Highway Patrol (CHP)</span></a><span>, from incidents reported by local and government agencies. Original tabular datasets are provided by the </span><a href="https://tims.berkeley.edu:443/" style="text-decoration:underline;"><span>Transportation Injury Mapping System (TIMS)</span></a><span>. Only records with reported locational GPS attributes in Orange County are included in the spatial database (either from X and Y geocoded coordinates, or the longitude and latitude coordinates generated by the CHP officer on site). Incidents without valid coordinates are omitted from this spatial dataset representation. Last Updated on <b>{lastUpdateDate}</b></span></p></div></div></div>"""
mdoVictims.credits = "Dr. Kostas Alexandridis, GISP, Data Scientist, OC Public Works, OC Survey Geospatial Services"
mdoVictims.accessConstraints = """<div style="text-align:Left;"><p><span>The SWITRS data displayed are provided by the California Highway Patrol (CHP) reports through the Transportation Injury Mapping System (TIMS) of the University of California, Berkeley. Issues of report accuracy should be addressed to CHP.</span></p><p>The displayed mapped data can be used under a <a href="https://creativecommons.org/licenses/by-sa/3.0/" target="_blank">Creative Commons CC-SA-BY</a> License, providing attribution to TIMS, CHP, and OC Public Works, OC Survey Geospatial Services. </p><div>We make every effort to provide the most accurate and up-to-date data and information. Nevertheless, the data feed is provided, 'as is' and OC Public Work's standard <a href="https://www.ocgov.com/contact-county/disclaimer" target="_blank">Disclaimer</a> applies.<br /></div><div><br /></div><div>For any inquiries, suggestions or questions, please contact:</div><div><br /></div><div style="text-align:center;"><a href="https://www.linkedin.com/in/ktalexan/" target="_blank"><b>Dr. Kostas Alexandridis, GISP</b></a><br /></div><div style="text-align:center;">GIS Analyst | Spatial Complex Systems Scientist</div><div style="text-align:center;">OC Public Works/OC Survey Geospatial Applications</div><div style="text-align:center;"><div>601 N. Ross Street, P.O. Box 4048, Santa Ana, CA 92701</div><div>Email: <a href="mailto:kostas.alexandridis@ocpw.ocgov.com" target="_blank">kostas.alexandridis@ocpw.ocgov.com</a> | Phone: (714) 967-0826</div><div><br /></div></div></div>"""
mdoVictims.thumbnailUri = "https://ocpw.maps.arcgis.com/sharing/rest/content/items/78682395df4744009c58625f1db0c25b/data"

# %% [markdown]
# Assign the *Victims* metadata object's content to the feature layer

# %%
# Apply the metadata object to the Victims feature class
mdVictims = md.Metadata(victimsPointsPath)
if not mdVictims.isReadOnly:
    mdVictims.copy(mdoVictims)
    mdVictims.save()

# %% [markdown]
# ### <font color="lime">**Collisions Metadata**</font>

# %% [markdown]
# Create a new *Collisions* metadata object

# %%
mdyears = f"{rawDateStart.strftime('%Y')}-{rawDateEnd.strftime('%Y')}"

# write string rawDateStart in format mont, date, year
mddates = f"{rawDateStart.strftime('%B %d, %Y')} to {rawDateEnd.strftime('%B %d, %Y')}"

# %%
# Define key metadata attributes for the Collisions feature class
mdoCollisions = md.Metadata()
mdoCollisions.title = "OCSWITRS Combined Collisions Points"
mdoCollisions.tags = "Orange County, California, Traffic, Traffic Conditions, Crashes, Collisions, Road Safety, Accidents, SWITRS, OCSWITRS, Transportation"
mdoCollisions.summary = f"Statewide Integrated Traffic Records System (SWITRS) Combined Collisions Data for Orange County, California ({mdyears})"
mdoCollisions.description = f"""<div style="text-align:Left;"><div><div><p><span style="font-weight:bold;">Statewide Integrated Traffic Records System (SWITRS)</span><span> location point data, containing </span><span style="font-weight:bold;">combined reports on collision crashes, parties, and victims</span><span> in Orange County, California for {mdyears} ({mddates}). The data are collected and maintained by the </span><a href="https://www.chp.ca.gov:443/" style="text-decoration:underline;"><span>California Highway Patrol (CHP)</span></a><span>, from incidents reported by local and government agencies. Original tabular datasets are provided by the </span><a href="https://tims.berkeley.edu:443/" style="text-decoration:underline;"><span>Transportation Injury Mapping System (TIMS)</span></a><span>. Only records with reported locational GPS attributes in Orange County are included in the spatial database (either from X and Y geocoded coordinates, or the longitude and latitude coordinates generated by the CHP officer on site). Incidents without valid coordinates are omitted from this spatial dataset representation. Last Updated on <b>{lastUpdateDate}</b></span></p></div></div></div>"""
mdoCollisions.credits = "Dr. Kostas Alexandridis, GISP, Data Scientist, OC Public Works, OC Survey Geospatial Services"
mdoCollisions.accessConstraints = """<div style="text-align:Left;"><p><span>The SWITRS data displayed are provided by the California Highway Patrol (CHP) reports through the Transportation Injury Mapping System (TIMS) of the University of California, Berkeley. Issues of report accuracy should be addressed to CHP.</span></p><p>The displayed mapped data can be used under a <a href="https://creativecommons.org/licenses/by-sa/3.0/" target="_blank">Creative Commons CC-SA-BY</a> License, providing attribution to TIMS, CHP, and OC Public Works, OC Survey Geospatial Services. </p><div>We make every effort to provide the most accurate and up-to-date data and information. Nevertheless, the data feed is provided, 'as is' and OC Public Work's standard <a href="https://www.ocgov.com/contact-county/disclaimer" target="_blank">Disclaimer</a> applies.<br /></div><div><br /></div><div>For any inquiries, suggestions or questions, please contact:</div><div><br /></div><div style="text-align:center;"><a href="https://www.linkedin.com/in/ktalexan/" target="_blank"><b>Dr. Kostas Alexandridis, GISP</b></a><br /></div><div style="text-align:center;">GIS Analyst | Spatial Complex Systems Scientist</div><div style="text-align:center;">OC Public Works/OC Survey Geospatial Applications</div><div style="text-align:center;"><div>601 N. Ross Street, P.O. Box 4048, Santa Ana, CA 92701</div><div>Email: <a href="mailto:kostas.alexandridis@ocpw.ocgov.com" target="_blank">kostas.alexandridis@ocpw.ocgov.com</a> | Phone: (714) 967-0826</div><div><br /></div></div></div>"""
mdoCollisions.thumbnailUri = "https://ocpw.maps.arcgis.com/sharing/rest/content/items/6b96b7d6d5394cbb95aa2fae390503a9/data"

# %% [markdown]
# Assign the *Collisions* metadata object's content to the feature layer

# %%
# Apply the metadata object to the Collisions feature class
mdCollisions = md.Metadata(collisionsPointsPath)
if not mdCollisions.isReadOnly:
    mdCollisions.copy(mdoCollisions)
    mdCollisions.save()

# %% [markdown]
# Save the ArcGIS Pro project

# %%
# Save the project
aprx.save()

# %% [markdown]
# ## <font color="orangered">**Map Layer Operations**</font>

# %% [markdown]
# In this section we will be creating map layers for the feature classes.

# %% [markdown]
# ### <font color="lime">**Visual Layer Operations**</font>

# %% [markdown]
# Add and rename layers in contents view, using their aliases

# %%
for lyr in map.listLayers():
    if "OCSWITRS" in lyr.name:
        map.removeLayer(lyr)

# %%
# Add the four feature classes (Crashes Points, Parties Points, Victims Points, Collisions Points) from the geodatabase to the map
crashesLyrName = map.addDataFromPath(crashesPointsPath)
partiesLyrName =map.addDataFromPath(partiesPointsPath)
victimsLyrName = map.addDataFromPath(victimsPointsPath)
collisionsLyrName = map.addDataFromPath(collisionsPointsPath)

# Add the supporting data Cities and Roads layers to the map
citiesLyrName = map.addDataFromPath(citiesPath)
roadsLyrName = map.addDataFromPath(roadsPath)

print(f"Added layers to the map:\n\t- {crashesLyrName}\n\t- {partiesLyrName}\n\t- {victimsLyrName}\n\t- {collisionsLyrName}\n\t- {citiesLyrName}\n\t- {roadsLyrName}")
# Out:
# Added layers to the map:
# 	- OCSWITRS Crashes
# 	- OCSWITRS Parties
# 	- OCSWITRS Victims
# 	- OCSWITRS Collisions
# 	- OCSWITRS Cities
# 	- OCSWITRS Roads

# %% [markdown]
# Define layers in current map

# %%
# Store the current list of layers to a new variable
mapLyrs = map.listLayers()
# Store the names of the layers in a list
mapLyrsList = [mlyr.name for mlyr in mapLyrs]

print("Active Map Layers:")
# Loop through the list of layers in the map, and print their names
for mlyr in mapLyrs:
    print(f" - {mlyr.name}")
# Out:
# Active Map Layers:
#  - OCSWITRS Collisions
#  - OCSWITRS Victims
#  - OCSWITRS Parties
#  - OCSWITRS Crashes
#  - OCSWITRS Roads
#  - OCSWITRS Cities
#  - World Topographic Map

# %% [markdown]
# Define individual layers for each of the SWITRS feature classes

# %%
# Identify each of the Crashes, Parties, Victim and Collisions layers
crashesLyr = next((mlyr for mlyr in mapLyrs if mlyr.name == aliasCrashes), False)
partiesLyr = next((mlyr for mlyr in mapLyrs if mlyr.name == aliasParties), False)
victimsLyr = next((mlyr for mlyr in mapLyrs if mlyr.name == aliasVictims), False)
collisionsLyr = next((mlyr for mlyr in mapLyrs if mlyr.name == aliasCollisions), False)
citiesLyr = next((mlyr for mlyr in mapLyrs if mlyr.name == aliasCities), False)
roadsLyr = next((mlyr for mlyr in mapLyrs if mlyr.name == aliasRoads), False)

# Define a list of the four layers, and a list of supporting data layers
dataLyrsList = [crashesLyr, partiesLyr, victimsLyr, collisionsLyr]
suppLyrsList = [citiesLyr, roadsLyr]

# %% [markdown]
# Turn off the initial visibility of all layers in the map

# %%
# Iterate through the data layers list
for lyr in dataLyrsList:
    # If the layer is not False
    if lyr:
        # Set the visibility of the layer to True
        lyr.visible = False
        
# Iterate through the supporting data layers list
for lyr in suppLyrsList:
    # If the layer is not False
    if lyr:
        # Set the visibility of the layer to True
        lyr.visible = False

# %% [markdown]
# Save the ArcGIS Pro project

# %%
# Save the project
aprx.save()

# %% [markdown]
# ### <font color="lime">**Map Layer Time Settings Configuration**</font>

# %% [markdown]
# In this subsection we will configure the time settings for the map layers, so that the map view will be time-enabled

# %% [markdown]
# > <font color="orange">⚠️ **Reminder**:</font> When doing an update on the raw data, make sure you update the the end-time date for the project (this changes with each update).
# - Current End Date: 6/30/2024, thus the time settings for the map layers will be set to the end of this date (6/30/2024, 23:59:59, or better, 7/1/2024, 00:00:00).

# %% [markdown]
# Set time settings configuration for the map layers

# %%
# Define the key time parameters for the layers using a dictionary
timeSettings = {
    "st": datetime(2013, 1, 1, 0, 0),
    "et": datetime(2024, 7, 1, 0, 0),
    "td": datetime(2024, 7, 1, 0, 0) - datetime(2013, 1, 1, 0, 0),
    "stf": "COLLISION_DATETIME",
    "tsi": 1.0,
    "tsiu": "months",
    "tz": arcpy.mp.ListTimeZones("*Pacific*")[0]
} # where, st: start time, et: end time, td: time extent, stf: time field, tsi: time interval, tsiu: time units, tz: time zone

# %% [markdown]
# Enable layer time, if needed

# %%
# Iterate through the data layer list and enable time
for mylyr in dataLyrsList:
    # if the layer is not time-enabled
    if not mylyr.isTimeEnabled:
        # Enable time for the layer
        mylyr.enableTime("COLLISION_DATETIME", "", "TRUE", None)
    # Set the start time for the layer
    mylyr.time.startTime = timeSettings["st"]
    # Set the end time for the layer
    mylyr.time.endTime = timeSettings["et"]
    # Set the time field for the layer
    mylyr.time.startTimeField = timeSettings["stf"]
    # Set the time step interval for the layer
    mylyr.time.timeStepInterval = timeSettings["tsi"]
    # Set the time step interval units for the layer
    mylyr.time.timeStepIntervalUnits = timeSettings["tsiu"]
    # Set the time zone for the layer
    mylyr.time.timeZone = timeSettings["tz"]

# %% [markdown]
# Reset time step interval parameters (seems to be a problem showing 10 months instead of 1 month)

# %%
# Iterate through the data layer list and manually change the time's time step interval
for mylyr in dataLyrsList:
    if mylyr.isTimeEnabled:
        mylyr.time.timeStepInterval = 1.0

# %% [markdown]
# Read and display the current time settings of the layers

# %%
# Iterate through the data layer list and display the time settings
for mylyr in dataLyrsList:
    print(mylyr.name)    
    print(f" - Time Field: {codebook[timeSettings['stf']]['alias']} ({timeSettings['stf']})")
    print(f" - Time Step Intervals: {int(mylyr.time.timeStepInterval)} {mylyr.time.timeStepIntervalUnits}")
    print(f" - Start Time: {str(timeSettings['st'].strftime('%m/%d/%Y %H:%M %p'))}")
    print(f" - End Time: {str(timeSettings['et'].strftime('%m/%d/%Y %H:%M %p'))}")
    print(f" - Time Extent: {int(timeSettings['td'].days):,} days ({int((timeSettings['td'].days/365)*12)} months)")
    print(f" - Time Zone: {timeSettings['tz']}")
# Out:
# OCSWITRS Crashes
#  - Time Field: Crash Date and Time (COLLISION_DATETIME)
#  - Time Step Intervals: 1 months
#  - Start Time: 01/01/2013 00:00 AM
#  - End Time: 07/01/2024 00:00 AM
#  - Time Extent: 4,199 days (138 months)
#  - Time Zone: (UTC-08:00) Pacific Time (US & Canada)
# OCSWITRS Parties
#  - Time Field: Crash Date and Time (COLLISION_DATETIME)
#  - Time Step Intervals: 1 months
#  - Start Time: 01/01/2013 00:00 AM
#  - End Time: 07/01/2024 00:00 AM
#  - Time Extent: 4,199 days (138 months)
#  - Time Zone: (UTC-08:00) Pacific Time (US & Canada)
# OCSWITRS Victims
#  - Time Field: Crash Date and Time (COLLISION_DATETIME)
#  - Time Step Intervals: 1 months
#  - Start Time: 01/01/2013 00:00 AM
#  - End Time: 07/01/2024 00:00 AM
#  - Time Extent: 4,199 days (138 months)
#  - Time Zone: (UTC-08:00) Pacific Time (US & Canada)
# OCSWITRS Collisions
#  - Time Field: Crash Date and Time (COLLISION_DATETIME)
#  - Time Step Intervals: 1 months
#  - Start Time: 01/01/2013 00:00 AM
#  - End Time: 07/01/2024 00:00 AM
#  - Time Extent: 4,199 days (138 months)
#  - Time Zone: (UTC-08:00) Pacific Time (US & Canada)

# %% [markdown]
# Save the ArcGIS Pro project

# %%
# Save the project
aprx.save()

# %% [markdown]
# ### <font color="lime">**Update Layer Views and File Lists**</font>

# %% [markdown]
# List project and directories, layers in contents view, and layer files in directories

# %%
# Display the project details
print(f"Project:\n\tName: {aprx}\n\tPath: {aprxPath}\n\tLayers Directory: {layersPath}")
# Display the layers in content view
print(f"Layers in Content View:\n\tCrashes: {crashesLyr}\n\tParties: {partiesLyr}\n\tVictims: {victimsLyr}\n\tCollisions: {collisionsLyr}\n\tCities: {citiesLyr}\n\tRoads: {roadsLyr}")
# Layers in Directory
print(f"Layers in Directory:\n\tCrashes: {crashesPointsPath}\n\tParties: {partiesPointsPath}\n\tVictims: {victimsPointsPath}\n\tCollisions: {collisionsPointsPath}\n\tCities: {citiesPath}\n\tRoads: {roadsPath}")
# Out:
# Project:
# 	Name: <arcpy._mp.ArcGISProject object at 0x000002AFBF334850>
# 	Path: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.aprx
# 	Layers Directory: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\Layers
# Layers in Content View:
# 	Crashes: OCSWITRS Crashes
# 	Parties: OCSWITRS Parties
# 	Victims: OCSWITRS Victims
# 	Collisions: OCSWITRS Collisions
# 	Cities: OCSWITRS Cities
# 	Roads: OCSWITRS Roads
# Layers in Directory:
# 	Crashes: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\CrashesPoints
# 	Parties: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\PartiesPoints
# 	Victims: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\VictimsPoints
# 	Collisions: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\CollisionsPoints
# 	Cities: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\SupportingData\OCSWITRS_Cities
# 	Roads: I:\Professional\Projects-OCPW\OCTraffic\OCSWITRS\AGPSWITRS\AGPSWITRS.gdb\SupportingData\OCSWITRS_Roads

# %% [markdown]
# ## <font color="orangered">**Symbology Operations**</font>

# %% [markdown]
# ### <font color="lime">**Data Layer Symbologies**</font>

# %% [markdown]
# Define symbology for each of the data layers (Crashes, Parties, Victims, and Collisions). The symbology is pre-saved in the SWITRS layer file, stored in the project's layer folder.

# %%
# Apply the symbology from the OCSWITRS layer file to the data layers
for layer in [crashesLyr, partiesLyr, victimsLyr, collisionsLyr]:
    # Set the layer's symbology to the OCSWITRS layer file
    arcpy.management.ApplySymbologyFromLayer(
        in_layer = layer,
        in_symbology_layer = os.path.join(layersPath, "OCSWITRS.lyrx"),
        symbology_fields = "VALUE_FIELD COLLISION_SEVERITY COLLISION_SEVERITY",
        update_symbology = "MAINTAIN"
    )

# %% [markdown]
# Define symbology for the supporting data layers (Cities, Roads). The symbology for each of the supporting data layers is pre-saved in the CITIES and ROADS layer files respectively, stored in the project's layer folder.

# %%
# Apply the symbology from the CITIES layer to the Cities data layer
arcpy.management.ApplySymbologyFromLayer(
    in_layer = citiesLyr,
    in_symbology_layer = os.path.join(layersPath, "CITIES.lyrx"),
    symbology_fields = "VALUE_FIELD POPDENS POPDENS",
    update_symbology = "MAINTAIN"
)

# Apply the symbology from the ROADS layer to the Roads data layer
arcpy.management.ApplySymbologyFromLayer(
    in_layer = roadsLyr,
    in_symbology_layer = os.path.join(layersPath, "ROADS.lyrx"),
    symbology_fields = "VALUE_FIELD ROADCAT ROADCAT",
    update_symbology = "MAINTAIN"
)
# Out:
# <Result 'GPLYR_{2BD1CFC9-3A6D-4D47-915B-05C3CBB046BE}'>

# %% [markdown]
# Save the ArcGIS Pro project

# %%
# Save the project
aprx.save()

# %% [markdown]
# ### <font color="lime">**Export Layer Views to Files**</font>

# %% [markdown]
# In this final section of the notebook, we will export the layer views to files. for the feature classes and supporting data layers.

# %% [markdown]
# Define layer paths and names for the layers to be created and exported to filesystem

# %%
# Get locations of the layers in the map
crashesLyrFile = os.path.join(layersPath, crashesLyr.name + ".lyrx")
partiesLyrFile = os.path.join(layersPath, partiesLyr.name + ".lyrx")
victimsLyrFile = os.path.join(layersPath, victimsLyr.name + ".lyrx")
collisionsLyrFile = os.path.join(layersPath, collisionsLyr.name + ".lyrx")
citiesLyrFile = os.path.join(layersPath, citiesLyr.name + ".lyrx")
roadsLyrFile = os.path.join(layersPath, roadsLyr.name + ".lyrx")

# %% [markdown]
# Save each of the layers to the filesystem

# %%
update_datetime("start")

# Save the Crashes layer to a layer file
arcpy.management.SaveToLayerFile(crashesLyr, crashesLyrFile, "ABSOLUTE")
print(arcpy.GetMessages())

# Save the Parties layer to a layer file
arcpy.management.SaveToLayerFile(partiesLyr, partiesLyrFile, "ABSOLUTE")
print(arcpy.GetMessages())

# Save the Victims layer to a layer file
arcpy.management.SaveToLayerFile(victimsLyr, victimsLyrFile, "ABSOLUTE")
print(arcpy.GetMessages())

# Save the Collisions layer to a layer file
arcpy.management.SaveToLayerFile(collisionsLyr, collisionsLyrFile, "ABSOLUTE")
print(arcpy.GetMessages())

# Save the Cities layer to a layer file
arcpy.management.SaveToLayerFile(citiesLyr, citiesLyrFile, "ABSOLUTE")
print(arcpy.GetMessages())

# Save the Roads layer to a layer file
arcpy.management.SaveToLayerFile(roadsLyr, roadsLyrFile, "ABSOLUTE")
print(arcpy.GetMessages())

update_datetime("end")
# Out:
# Start: Wednesday November 13, 2024, 09:10 AM (PST)
# Start Time: Wednesday, November 13, 2024 9:10:01 AM
# Succeeded at Wednesday, November 13, 2024 9:10:01 AM (Elapsed Time: 0.10 seconds)
# Start Time: Wednesday, November 13, 2024 9:10:01 AM
# Succeeded at Wednesday, November 13, 2024 9:10:01 AM (Elapsed Time: 0.08 seconds)
# Start Time: Wednesday, November 13, 2024 9:10:01 AM
# Succeeded at Wednesday, November 13, 2024 9:10:01 AM (Elapsed Time: 0.07 seconds)
# Start Time: Wednesday, November 13, 2024 9:10:01 AM
# Succeeded at Wednesday, November 13, 2024 9:10:02 AM (Elapsed Time: 0.09 seconds)
# Start Time: Wednesday, November 13, 2024 9:10:02 AM
# Succeeded at Wednesday, November 13, 2024 9:10:02 AM (Elapsed Time: 0.05 seconds)
# Start Time: Wednesday, November 13, 2024 9:10:02 AM
# Succeeded at Wednesday, November 13, 2024 9:10:02 AM (Elapsed Time: 0.04 seconds)
# End: Wednesday November 13, 2024, 09:10 AM (PST). Elapsed time: 0:00:01

# %% [markdown]
# Save the ArcGIS Pro project

# %%
# Save the project
aprx.save()

# %% [markdown]
# ### <font color="lime">**Pop-Ups Configuration (Arcade)**</font>

# %% [markdown]
# Run these code segments below after opening the ArcGIS Pro project to configure the pop-ups for the feature classes.

# %% [markdown]
# **<font color="orange">Arcade Expression:</font> Configure Pop-Ups for the Crashes layer**
#
# - Language: `Arcade`
# - Name: `expression0`
# - Title: `popupCrashes`
# - Expression:
#     ```javascript
#     var c = $feature.CID
#     var ct = $feature.CITY
#     var dt = Text($feature.COLLISION_DATETIME, 'M/D/YYYY H:m A')
#     "Crash ID: " + c + " | Date: " + dt + ", " + ct
#     ```

# %% [markdown]
# **<font color="orange">Arcade Expression:</font> Configure Pop-Ups for the Parties layer**
#
# - Language: `Arcade`
# - Name: `expression0`
# - Title: `popupParties`
# - Expression:
#     ```javascript
#     var c = $feature.CID
#     var p = $feature.PARTY_NUMBER
#     var ct = $feature.CITY
#     var dt = Text($feature.COLLISION_DATETIME, 'M/D/YYYY H:m A')
#     "Crash ID: " + c + ", Party: " + p + " | Date: " + dt + ", " + ct
#     ```

# %% [markdown]
# **<font color="orange">Arcade Expression</font> Configure Pop-Ups for the Victims layer**
#
# - Language: `Arcade`
# - Name: `expression0`
# - Title: `popupVictims`
# - Expression:
#     ```javascript
#     var c = $feature.CID
#     var p = $feature.PARTY_NUMBER
#     var v = $feature.VICTIM_NUMBER
#     var ct = $feature.CITY
#     var dt = Text($feature.COLLISION_DATETIME, 'M/D/YYYY H:m A')
#     "Crash ID: " + c + ", Party: " + p + ", Victim: " + v + " | Date: " + dt + ", " + ct
#     ```

# %% [markdown]
# **<font color="orange">Arcade Expression</font> Configure Pop-Ups for the Collisions layer**
#
# - Language: `Arcade`
# - Name: `expression0`
# - Title: `popupCollisions`
# - Expression:
#     ```javascript
#     var c = $feature.CID
#     var p = $feature.PARTY_NUMBER
#     var v = $feature.VICTIM_NUMBER
#     var ct = $feature.CITY
#     var dt = Text($feature.COLLISION_DATETIME, 'M/D/YYYY H:m A')
#     var exp1 = "Crash ID: " + c + ", Party: " + p + ", Victim: " + v + " | Date: " + dt + ", " + ct
#     var exp2 = "Crash ID: " + c + ", Party: " + p + ", No Victim | Date: " + dt + ", " + ct
#     if(!isEmpty(p) && !isEmpty(v)){
#         return exp1
#     } else if(!isEmpty(p) && isEmpty(v)){
#         return exp2
#     }
#     ```

# %% [markdown]
# ----

# %% [markdown]
# > <font color="coral">💬 **Note**:</font> <font color="lime"> This is the end of data pre-processing (Notebook Part 2). The ArcGIS Online (AGO) processing of the data is continuing on a new ArcGIS notebook (Part 3)</font>
